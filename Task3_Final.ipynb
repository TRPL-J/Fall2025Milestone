# %% [markdown]
# ## Package Installation

# %%
import os
import sys
import types

# Install core dependencies
# !pip install easy-tpp lightning pytorch-lightning hydra-core omegaconf torchmetrics stribor -q

print("✓ Core dependencies installed")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 53.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.0 MB/s eta 0:00:00
# ✓ Core dependencies installed

# %%
# Import required libraries
import os

# Set PyTorch memory allocation config BEFORE importing torch
# This helps prevent OOM errors with large models like AttNHP
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

import yaml
import pandas as pd
import numpy as np
from datetime import datetime
from easy_tpp.config_factory import Config
from easy_tpp.runner import Runner
from google.colab import drive
import json
from IPython.display import display, clear_output
import time

# %%
# ==============================================================================
# FULLYNN GRADIENT FIX - Monkey Patch
# ==============================================================================
# FullyNN uses torch.autograd.grad() to compute intensity derivatives, but during
# validation/evaluation, EasyTPP runs under torch.no_grad() context which disables
# gradient tracking. This patch wraps the computation in torch.enable_grad().
# ==============================================================================

import torch
from easy_tpp.model.torch_model import torch_fullynn

def patched_compute_intensities_at_sample_times(self, time_seqs, time_delta_seqs, type_seqs, sample_dtimes, **kwargs):
    """Patched version that enables gradients during intensity computation.

    FullyNN requires gradient computation for intensity derivatives via autograd.grad().
    During validation, EasyTPP disables gradients with torch.no_grad(), causing failures.
    This patch wraps the computation in torch.enable_grad() to fix the issue.
    """
    compute_last_step_only = kwargs.get('compute_last_step_only', False)

    # Enable gradients for this computation even during evaluation
    with torch.enable_grad():
        # Forward pass to get hidden states
        hidden_states = self.forward(
            time_seqs=time_seqs,
            time_delta_seqs=time_delta_seqs,
            type_seqs=type_seqs,
        )

        num_samples = sample_dtimes.size()[-1]
        batch_size, seq_len, hidden_size = hidden_states.shape

        # Expand hidden states for all sample times
        hidden_states_ = hidden_states[..., None, :].expand(batch_size, seq_len, num_samples, hidden_size)

        # Clone sample_dtimes to avoid in-place modification issues
        sample_dtimes_grad = sample_dtimes.clone().detach().requires_grad_(True)

        # Compute intensities (this uses autograd.grad internally)
        _, derivative_integral_lambda = self.layer_intensity.forward(
            hidden_states=hidden_states_,
            time_delta_seqs=sample_dtimes_grad,
        )

    # Detach the result since we don't need gradients flowing back
    derivative_integral_lambda = derivative_integral_lambda.detach()

    if compute_last_step_only:
        return derivative_integral_lambda[:, -1:, :, :]
    return derivative_integral_lambda

# Apply the monkey patch
torch_fullynn.FullyNN.compute_intensities_at_sample_times = patched_compute_intensities_at_sample_times
print("✓ FullyNN patched for gradient computation during evaluation")
print("  This fixes the 'element 0 of tensors does not require grad' error")
# Out:
# ✓ FullyNN patched for gradient computation during evaluation
#   This fixes the 'element 0 of tensors does not require grad' error

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Base directory (your Drive location)
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
CHECKPOINT_DIR = os.path.join(BASE_DIR, 'checkpoints')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task3')

# Create results directory if it doesn't exist
os.makedirs(RESULTS_DIR, exist_ok=True)

print(f"✓ Base Directory: {BASE_DIR}")
print(f"✓ Dataset Directory: {DATASET_DIR}")
print(f"✓ Checkpoint Directory: {CHECKPOINT_DIR}")
print(f"✓ Results Directory: {RESULTS_DIR}")
# Out:
# Mounted at /content/drive
# ✓ Base Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025
# ✓ Dataset Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets
# ✓ Checkpoint Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints
# ✓ Results Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3

# %% [markdown]
# ## Configuration Dictionary

# %% [markdown]
# ### Data Configuration

# %%
# Data specifications for each dataset
data_spec_dict = {
    "stationary_hawkes": {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, "stationary_hawkes", "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, "stationary_hawkes", "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, "stationary_hawkes", "test.pkl"),
        "data_specs": {
            "num_event_types": 2,
            "pad_token_id": 2,
            "padding_side": "right",
            "max_seq_len": 20,
            "strict_pad_leng": True
        }
    }
}

print("✓ Data specifications loaded for Hawkes Stationary")
# Out:
# ✓ Data specifications loaded for Hawkes Stationary

# %% [markdown]
# ### Model Configuration

# %%
# Model specifications
model_spec_dict = {
    "RMTPP": {
        "model_id": "RMTPP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_heads": 2,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "NHP": {
        "model_id": "NHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_heads": 2,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "FullyNN": {
        "model_id": "FullyNN",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "num_heads": 2,
        "seed": 2019,
        "model_specs": {
            "num_mlp_layers": 3,
            "proper_marked_intensities": True
        },
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "SAHP": {
        "model_id": "SAHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "THP": {
        "model_id": "THP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "IntensityFree": {
        "model_id": "IntensityFree",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "num_heads": 2,
        "seed": 2019,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_mix_components": 3,
        "model_specs": {
            "num_mix_components": 3
        },
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5,
            "num_step_gen": 10
        }
    },
    "AttNHP": {
        "model_id": "AttNHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 4,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    }
}

print("✓ Model specifications loaded for 7 models")
# Out:
# ✓ Model specifications loaded for 7 models

# %% [markdown]
# ### Training Configuration

# %%
# Trainer configuration (shared across all experiments)
trainer_config = {
    "batch_size": 256,
    "max_epoch": 200,
    "shuffle": False,
    "optimizer": "adam",
    "learning_rate": 1e-3,
    "valid_freq": 1,
    "use_tfb": False,
    "metrics": ["acc", "rmse"],
    "seed": 2019,
    "gpu": 0
}

print("✓ Trainer configuration loaded")
print(f"  - Batch size: {trainer_config['batch_size']}")
print(f"  - Max epochs: {trainer_config['max_epoch']}")
print(f"  - Learning rate: {trainer_config['learning_rate']}")
# Out:
# ✓ Trainer configuration loaded
#   - Batch size: 256
#   - Max epochs: 200
#   - Learning rate: 0.001

# %% [markdown]
# ## Helper Functions

# %%
def create_experiment_config(model_id, data_id, data_spec, model_spec, trainer_cfg):
    """Create a complete experiment configuration."""
    experiment_id = f"{model_id}_{data_id}_train"

    config = {
        "pipeline_config_id": "runner_config",
        "data": {
            data_id: data_spec
        },
        experiment_id: {
            "base_config": {
                "stage": "train",
                "backend": "torch",
                "dataset_id": data_id,
                "runner_id": "std_tpp",
                "model_id": model_id,
                "base_dir": CHECKPOINT_DIR
            },
            "trainer_config": trainer_cfg,
            "model_config": model_spec
        }
    }

    return config, experiment_id

def extract_results_from_logs(log_path):
    """Extract best results from training logs.

    Args:
        log_path: Can be either a log file or a directory containing log files
    """
    try:
        # Determine if log_path is a file or directory
        if os.path.isfile(log_path):
            # It's a file - read it directly
            log_file = log_path
        elif os.path.isdir(log_path):
            # It's a directory - find .log files inside
            log_files = [f for f in os.listdir(log_path) if f.endswith('.log')]
            if not log_files:
                return None
            log_file = os.path.join(log_path, log_files[0])
        else:
            print(f"  Warning: Log path does not exist: {log_path}")
            return None

        # Read the log file
        with open(log_file, 'r') as f:
            lines = f.readlines()

        # Find the LAST test metrics (final epoch results)
        best_ll = None
        best_acc = None
        best_rmse = None

        for line in lines:
            if 'test loglike is' in line:
                try:
                    parts = line.split(',')
                    # Extract log-likelihood
                    ll_part = [p for p in parts if 'test loglike is' in p][0]
                    best_ll = float(ll_part.split('test loglike is')[1].strip())

                    # Extract accuracy
                    acc_parts = [p for p in parts if 'acc is' in p]
                    if acc_parts:
                        best_acc = float(acc_parts[0].split('acc is')[1].strip())

                    # Extract RMSE
                    rmse_parts = [p for p in parts if 'rmse is' in p]
                    if rmse_parts:
                        best_rmse = float(rmse_parts[0].split('rmse is')[1].strip())
                except (IndexError, ValueError) as e:
                    print(f"  Warning: Could not parse line: {e}")
                    continue

        if best_ll is None:
            return None

        return {
            'log_likelihood': best_ll,
            'accuracy': best_acc,
            'rmse': best_rmse
        }
    except Exception as e:
        print(f"  Warning: Could not extract results from logs: {e}")
        return None
def find_latest_checkpoint_dir(base_dir, model_id, data_id):
    """Find the most recent checkpoint directory for an experiment."""
    try:
        # EasyTPP creates directories with random names but puts
        # {model_id}_{data_id}_train_output.yaml inside them
        target_yaml = f"{model_id}_{data_id}_train_output.yaml"

        matching_dirs = []
        for d in os.listdir(base_dir):
            dir_path = os.path.join(base_dir, d)
            if os.path.isdir(dir_path):
                # Check if the target yaml file exists in this directory
                yaml_path = os.path.join(dir_path, target_yaml)
                if os.path.exists(yaml_path):
                    matching_dirs.append(dir_path)

        if not matching_dirs:
            return None

        # Return the most recently modified directory
        latest = max(matching_dirs, key=os.path.getmtime)
        return latest
    except Exception as e:
        print(f"  Warning: Error finding checkpoint dir: {e}")
        return None
print("✓ Helper functions loaded")
# Out:
# ✓ Helper functions loaded

# %%
def run_model_on_all_datasets(
    model_id,
    model_number,
    total_models,
    aggressive_gpu_clearing=False
):
    """
    Run a single TPP model on all configured datasets.

    This function encapsulates the complete workflow for running a model:
    - Creates and saves experiment configs for each dataset
    - Runs training and evaluation
    - Extracts metrics from logs
    - Saves results (both intermediate and model-specific)
    - Handles errors gracefully
    - Manages GPU memory

    Parameters
    ----------
    model_id : str
        The model identifier (e.g., 'RMTPP', 'NHP', 'AttNHP')
        Must exist as a key in model_spec_dict
    model_number : int
        Current model number (1-7) for progress tracking
    total_models : int
        Total number of models (typically 7) for progress tracking
    aggressive_gpu_clearing : bool, default=False
        If True, performs GPU memory clearing after EACH dataset.
        Use this for memory-intensive models like AttNHP.
        If False, only clears GPU memory after all datasets complete.

    Returns
    -------
    model_results : list of dict
        List containing result dictionaries for each dataset.
        Each dict contains: model, dataset, log_likelihood, accuracy,
        rmse, status, and time_seconds

    Side Effects
    ------------
    - Appends results to the global results_list
    - Saves intermediate results to 'intermediate_results.csv' after each dataset
    - Saves model-specific results to '{model_id}_results.csv'
    - Creates experiment config files in the configs directory
    - Clears GPU memory (timing depends on aggressive_gpu_clearing flag)

    Notes
    -----
    This function relies on several global variables and functions:
    - data_spec_dict: Dictionary of dataset configurations
    - model_spec_dict: Dictionary of model configurations
    - trainer_config: Training configuration
    - results_list: Global list to store all results
    - total_experiments: Total number of experiments
    - BASE_DIR, CHECKPOINT_DIR, RESULTS_DIR: Directory paths
    - create_experiment_config(): Function to create config dicts
    - find_latest_checkpoint_dir(): Function to locate checkpoints
    - extract_results_from_logs(): Function to parse training logs

    Example
    -------
    >>> # Run RMTPP on all datasets (standard memory management)
    >>> rmtpp_results = run_model_on_all_datasets('RMTPP', 1, 7)

    >>> # Run AttNHP with aggressive memory clearing
    >>> attnhp_results = run_model_on_all_datasets('AttNHP', 7, 7,
    ...                                             aggressive_gpu_clearing=True)
    """
    import time
    import os
    import yaml
    import pandas as pd
    import torch
    import gc
    from easy_tpp.config_factory import Config
    from easy_tpp.runner import Runner

    print("\n" + "=" * 70)
    print(f"[MODEL {model_number}/{total_models}] Running {model_id} on all datasets")
    print("=" * 70)

    model_start_time = time.time()
    model_results = []

    for data_id, data_spec in data_spec_dict.items():
        experiment_name = f"{model_id}_{data_id}"
        experiment_num = len(results_list) + 1

        print(f"\n[{experiment_num}/{total_experiments}] Running {model_id} on {data_id} dataset")
        print("=" * 70)

        try:
            # Create config
            config_dict, experiment_id = create_experiment_config(
                model_id=model_id,
                data_id=data_id,
                data_spec=data_spec,
                model_spec=model_spec_dict[model_id],
                trainer_cfg=trainer_config
            )

            # Save config
            CONFIG_DIR = os.path.join(BASE_DIR, 'configs')
            os.makedirs(CONFIG_DIR, exist_ok=True)
            config_path = os.path.join(CONFIG_DIR, f"{experiment_name}.yaml")
            with open(config_path, 'w') as f:
                yaml.dump(config_dict, f)

            # Build and run
            config = Config.build_from_yaml_file(config_path, experiment_id=experiment_id)
            runner = Runner.build_from_config(config)
            runner.run()

            # Find checkpoint directory
            checkpoint_dir = find_latest_checkpoint_dir(CHECKPOINT_DIR, model_id, data_id)

            # Extract results from logs
            if checkpoint_dir:
                log_dir = os.path.join(checkpoint_dir, 'log')
                metrics = extract_results_from_logs(log_dir)

                if metrics:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': metrics['log_likelihood'],
                        'accuracy': metrics['accuracy'],
                        'rmse': metrics['rmse'],
                        'status': 'success',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"✓ {model_id} on {data_id} completed successfully!")
                    print(f"  - Log-Likelihood: {metrics['log_likelihood']:.4f}")
                    if metrics['accuracy'] and metrics['accuracy'] > 0:
                        print(f"  - Accuracy: {metrics['accuracy']:.4f}")
                    if metrics['rmse'] and metrics['rmse'] > 0:
                        print(f"  - RMSE: {metrics['rmse']:.4f}")
                else:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': None,
                        'accuracy': None,
                        'rmse': None,
                        'status': 'completed_no_metrics',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"⚠ {model_id} on {data_id} completed but no metrics found")
            else:
                result = {
                    'model': model_id,
                    'dataset': data_id,
                    'log_likelihood': None,
                    'accuracy': None,
                    'rmse': None,
                    'status': 'no_checkpoint',
                    'time_seconds': time.time() - model_start_time
                }
                print(f"⚠ {model_id} on {data_id} - no checkpoint directory found")

        except Exception as e:
            result = {
                'model': model_id,
                'dataset': data_id,
                'log_likelihood': None,
                'accuracy': None,
                'rmse': None,
                'status': 'failed',
                'error': str(e),
                'time_seconds': time.time() - model_start_time
            }
            print(f"✗ Error running {model_id} on {data_id}: {str(e)}")

        results_list.append(result)
        model_results.append(result)

        # Save intermediate results after each experiment
        intermediate_df = pd.DataFrame(results_list)
        intermediate_df.to_csv(os.path.join(RESULTS_DIR, 'intermediate_results.csv'), index=False)

        # Aggressive GPU memory clearing (for memory-intensive models like AttNHP)
        if aggressive_gpu_clearing:
            try:
                del runner
                del config
            except:
                pass
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
                torch.cuda.synchronize()

    # Save model-specific results
    model_df = pd.DataFrame(model_results)
    model_csv_path = os.path.join(RESULTS_DIR, f'{model_id}_results.csv')
    model_df.to_csv(model_csv_path, index=False)

    # Model summary
    model_elapsed = time.time() - model_start_time
    successful = sum(1 for r in model_results if r['status'] == 'success')
    failed = sum(1 for r in model_results if r['status'] == 'failed')

    print(f"\n" + "=" * 70)
    print(f"✓ {model_id} completed on all datasets")
    print(f"  - Time: {model_elapsed/60:.1f} minutes")
    print(f"  - Successful: {successful}/{len(data_spec_dict)}")
    print(f"  - Failed: {failed}/{len(data_spec_dict)}")
    print(f"  - Results saved to: {model_csv_path}")
    print("=" * 70)

    # Clear GPU memory for next model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        print(f"✓ GPU memory cleared for next model")

    return model_results

# %% [markdown]
# ## Run Models On Data

# %%
# Initialize results storage
results_list = []
total_experiments = len(model_spec_dict) * len(data_spec_dict)

print(f"Starting {total_experiments} experiments...")
print(f"Running {len(model_spec_dict)} models on {len(data_spec_dict)} datasets")
print(f"Results will be saved incrementally to: {RESULTS_DIR}")
print("=" * 70)
# Out:
# Starting 7 experiments...
# Running 7 models on 1 datasets
# Results will be saved incrementally to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3
# ======================================================================

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
all_model_results = {}

for i, model_id in enumerate(model_ids, start=1):
    aggressive = (model_id == 'AttNHP')
    all_model_results[model_id] = run_model_on_all_datasets(
        model_id, i, len(model_ids), aggressive
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-12-27 18:21:48,051 - base_runner.py[pid:4457;line:110:train] - INFO: End RMTPP train! Cost time: 0.161m
# ✓ RMTPP on stationary_hawkes completed successfully!
#   - Log-Likelihood: -1.1404
#   - Accuracy: 0.5456
#   - RMSE: 1.2044
#
# ======================================================================
# ✓ RMTPP completed on all datasets
#   - Time: 0.8 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/RMTPP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model
#
# ======================================================================
# [MODEL 2/7] Running NHP on all datasets
# ======================================================================
#
# [2/7] Running NHP on stationary_hawkes dataset
# ======================================================================
# 2025-12-27 18:22:12,559 - config.py[pid:4457;line:34:build_from_yaml_file] - CRITICAL: Load pipeline config class RunnerConfig
# 2025-12-27 18:22:12,565 - runner_config.py[pid:4457;line:140:update_config] - CRITICAL: train model NHP using GPU with torch backend
# 2025-12-27 18:22:12,576 - runner_config.py[pid:4457;line:35:__init__] - INFO: Save the config to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/4457_139428872557184_251227-182212/NHP_stationary_hawkes_train_output.yaml
# 2025-12-27 18:22:12,592 - base_runner.py[pid:4457;line:176:save_log] - INFO: Save the log to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/4457_139428872557184_251227-182212/log
# 0.6100027294188909 0.745759392243132
# min_dt: 0.00012170050202264804
# max_dt: 7.493633863438951
# 2025-12-27 18:22:12,615 - tpp_runner.py[pid:4457;line:60:_init_model] - INFO: Num of model parameters 14724
# 2025-12-27 18:22:12,629 - base_runner.py[pid:4457;line:98:train] - INFO: Data 'stationary_hawkes' loaded...
# 2025-12-27 18:22:12,630 - base_runner.py[pid:4457;line:103:train] - INFO: Start NHP training...
# 2025-12-27 18:22:12,877 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 0 (train) ]: train loglike is -1.1970162064655232, num_events is 8997
# 2025-12-27 18:22:12,977 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 0 (valid) ]:  valid loglike is -1.1576579782042942, num_events is 3074, acc is 0.529277813923227, rmse is 0.9575701916106558
# 2025-12-27 18:22:13,093 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 0 (test) ]: test loglike is -1.160777254110779, num_events is 3094, acc is 0.5471881060116355, rmse is 0.979660388897879
# 2025-12-27 18:22:13,094 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1577 (updated at epoch-0), best updated at this epoch
# 2025-12-27 18:22:13,239 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 1 (train) ]: train loglike is -1.1922532527118415, num_events is 8997
# 2025-12-27 18:22:13,333 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 1 (valid) ]:  valid loglike is -1.1546496637626058, num_events is 3074, acc is 0.5361093038386467, rmse is 0.959902674276683
# 2025-12-27 18:22:13,449 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 1 (test) ]: test loglike is -1.1566241806217679, num_events is 3094, acc is 0.5578539107950873, rmse is 0.9652897702654617
# 2025-12-27 18:22:13,450 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1546 (updated at epoch-1), best updated at this epoch
# 2025-12-27 18:22:13,595 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 2 (train) ]: train loglike is -1.1884970228791543, num_events is 8997
# 2025-12-27 18:22:13,689 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 2 (valid) ]:  valid loglike is -1.152289425931197, num_events is 3074, acc is 0.5406636304489265, rmse is 0.970362141513965
# 2025-12-27 18:22:13,804 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 2 (test) ]: test loglike is -1.1531918506585326, num_events is 3094, acc is 0.5714285714285714, rmse is 0.956972474047247
# 2025-12-27 18:22:13,805 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1523 (updated at epoch-2), best updated at this epoch
# 2025-12-27 18:22:13,951 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 3 (train) ]: train loglike is -1.1853399646670417, num_events is 8997
# 2025-12-27 18:22:14,047 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 3 (valid) ]:  valid loglike is -1.1504181841401675, num_events is 3074, acc is 0.5513988288874431, rmse is 0.9649556515605728
# 2025-12-27 18:22:14,165 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 3 (test) ]: test loglike is -1.1503192923804137, num_events is 3094, acc is 0.5740142210730446, rmse is 0.9608424481293167
# 2025-12-27 18:22:14,166 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1504 (updated at epoch-3), best updated at this epoch
# 2025-12-27 18:22:14,311 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 4 (train) ]: train loglike is -1.1826666153257683, num_events is 8997
# 2025-12-27 18:22:14,405 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 4 (valid) ]:  valid loglike is -1.1489316584153384, num_events is 3074, acc is 0.5575797007156799, rmse is 0.9682173394721795
# 2025-12-27 18:22:14,530 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 4 (test) ]: test loglike is -1.1479086601587751, num_events is 3094, acc is 0.5798319327731093, rmse is 0.9773997587853781
# 2025-12-27 18:22:14,532 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1489 (updated at epoch-4), best updated at this epoch
# 2025-12-27 18:22:14,676 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 5 (train) ]: train loglike is -1.1804031926657845, num_events is 8997
# 2025-12-27 18:22:14,771 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 5 (valid) ]:  valid loglike is -1.1477337491613127, num_events is 3074, acc is 0.5510735198438517, rmse is 0.983222419260565
# 2025-12-27 18:22:14,891 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 5 (test) ]: test loglike is -1.1458755226850355, num_events is 3094, acc is 0.579185520361991, rmse is 0.9975671203390569
# 2025-12-27 18:22:14,892 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1477 (updated at epoch-5), best updated at this epoch
# 2025-12-27 18:22:15,043 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 6 (train) ]: train loglike is -1.1784808667776412, num_events is 8997
# 2025-12-27 18:22:15,140 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 6 (valid) ]:  valid loglike is -1.1467218442481295, num_events is 3074, acc is 0.5455432661027977, rmse is 0.9766385022063087
# 2025-12-27 18:22:15,256 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 6 (test) ]: test loglike is -1.1441318978011878, num_events is 3094, acc is 0.5769230769230769, rmse is 0.9740591827159338
# 2025-12-27 18:22:15,257 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1467 (updated at epoch-6), best updated at this epoch
# 2025-12-27 18:22:15,404 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 7 (train) ]: train loglike is -1.1768231554615427, num_events is 8997
# 2025-12-27 18:22:15,500 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 7 (valid) ]:  valid loglike is -1.14578721611703, num_events is 3074, acc is 0.544242029928432, rmse is 0.9618574839581087
# 2025-12-27 18:22:15,619 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 7 (test) ]: test loglike is -1.1425827016503718, num_events is 3094, acc is 0.5765998707175177, rmse is 1.0020272397269703
# 2025-12-27 18:22:15,620 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1458 (updated at epoch-7), best updated at this epoch
# 2025-12-27 18:22:15,767 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 8 (train) ]: train loglike is -1.1753429528592865, num_events is 8997
# 2025-12-27 18:22:15,862 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 8 (valid) ]:  valid loglike is -1.1448235992650049, num_events is 3074, acc is 0.5465191932335719, rmse is 0.9781231328137173
# 2025-12-27 18:22:15,981 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 8 (test) ]: test loglike is -1.1411307198660714, num_events is 3094, acc is 0.5788623141564319, rmse is 0.9888191509381239
# 2025-12-27 18:22:15,982 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1448 (updated at epoch-8), best updated at this epoch
# 2025-12-27 18:22:16,132 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 9 (train) ]: train loglike is -1.1739490420417917, num_events is 8997
# 2025-12-27 18:22:16,227 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 9 (valid) ]:  valid loglike is -1.1437391034177782, num_events is 3074, acc is 0.5468445022771633, rmse is 0.972543503166459
# 2025-12-27 18:22:16,346 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 9 (test) ]: test loglike is -1.139686628858274, num_events is 3094, acc is 0.5795087265675501, rmse is 0.9927742123434241
# 2025-12-27 18:22:16,348 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1437 (updated at epoch-9), best updated at this epoch
# 2025-12-27 18:22:16,497 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 10 (train) ]: train loglike is -1.172553882978354, num_events is 8997
# 2025-12-27 18:22:16,591 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 10 (valid) ]:  valid loglike is -1.1424673324912573, num_events is 3074, acc is 0.5478204294079375, rmse is 1.0005243860650312
# 2025-12-27 18:22:16,709 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 10 (test) ]: test loglike is -1.1381775967598577, num_events is 3094, acc is 0.5801551389786684, rmse is 0.9891742335081959
# 2025-12-27 18:22:16,710 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1425 (updated at epoch-10), best updated at this epoch
# 2025-12-27 18:22:16,856 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 11 (train) ]: train loglike is -1.171084249762942, num_events is 8997
# 2025-12-27 18:22:16,951 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 11 (valid) ]:  valid loglike is -1.140972546966493, num_events is 3074, acc is 0.5481457384515289, rmse is 0.9572521452601928
# 2025-12-27 18:22:17,072 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 11 (test) ]: test loglike is -1.1365547007565044, num_events is 3094, acc is 0.5827407886231416, rmse is 0.9926803039615107
# 2025-12-27 18:22:17,073 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1410 (updated at epoch-11), best updated at this epoch
# 2025-12-27 18:22:17,218 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 12 (train) ]: train loglike is -1.1694897512495486, num_events is 8997
# 2025-12-27 18:22:17,311 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 12 (valid) ]:  valid loglike is -1.1392493462050668, num_events is 3074, acc is 0.5458685751463891, rmse is 0.9777505280482807
# 2025-12-27 18:22:17,428 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 12 (test) ]: test loglike is -1.134795767766241, num_events is 3094, acc is 0.5840336134453782, rmse is 0.972716599686758
# 2025-12-27 18:22:17,429 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1392 (updated at epoch-12), best updated at this epoch
# 2025-12-27 18:22:17,572 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 13 (train) ]: train loglike is -1.1677480275543237, num_events is 8997
# 2025-12-27 18:22:17,665 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 13 (valid) ]:  valid loglike is -1.137317982601049, num_events is 3074, acc is 0.5491216655823032, rmse is 1.0027426624975038
# 2025-12-27 18:22:17,822 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 13 (test) ]: test loglike is -1.1329032439297835, num_events is 3094, acc is 0.5833872010342599, rmse is 0.9944267443190437
# 2025-12-27 18:22:17,823 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1373 (updated at epoch-13), best updated at this epoch
# 2025-12-27 18:22:17,968 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 14 (train) ]: train loglike is -1.1658643294509627, num_events is 8997
# 2025-12-27 18:22:18,065 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 14 (valid) ]:  valid loglike is -1.1352167371502928, num_events is 3074, acc is 0.5504229017566689, rmse is 0.9884567127428091
# 2025-12-27 18:22:18,182 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 14 (test) ]: test loglike is -1.1308986710669844, num_events is 3094, acc is 0.5850032320620556, rmse is 1.020949393945004
# 2025-12-27 18:22:18,183 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1352 (updated at epoch-14), best updated at this epoch
# 2025-12-27 18:22:18,331 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 15 (train) ]: train loglike is -1.163866335436465, num_events is 8997
# 2025-12-27 18:22:18,425 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 15 (valid) ]:  valid loglike is -1.1329931037024235, num_events is 3074, acc is 0.549772283669486, rmse is 0.9794102992792955
# 2025-12-27 18:22:18,543 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 15 (test) ]: test loglike is -1.1288159795168067, num_events is 3094, acc is 0.5817711700064642, rmse is 0.9705668300112237
# 2025-12-27 18:22:18,544 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1330 (updated at epoch-15), best updated at this epoch
# 2025-12-27 18:22:18,688 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 16 (train) ]: train loglike is -1.161795929589377, num_events is 8997
# 2025-12-27 18:22:18,781 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 16 (valid) ]:  valid loglike is -1.1306974352685832, num_events is 3074, acc is 0.5500975927130775, rmse is 0.9865390953985863
# 2025-12-27 18:22:18,899 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 16 (test) ]: test loglike is -1.1266944653462347, num_events is 3094, acc is 0.5846800258564965, rmse is 1.0120792069076594
# 2025-12-27 18:22:18,900 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1307 (updated at epoch-16), best updated at this epoch
# 2025-12-27 18:22:19,045 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 17 (train) ]: train loglike is -1.1597012914895244, num_events is 8997
# 2025-12-27 18:22:19,140 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 17 (valid) ]:  valid loglike is -1.1283782581733897, num_events is 3074, acc is 0.5465191932335719, rmse is 0.9738537703306799
# 2025-12-27 18:22:19,257 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 17 (test) ]: test loglike is -1.124573898068843, num_events is 3094, acc is 0.5801551389786684, rmse is 1.0348223184194334
# 2025-12-27 18:22:19,258 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1284 (updated at epoch-17), best updated at this epoch
# 2025-12-27 18:22:19,405 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 18 (train) ]: train loglike is -1.157629610260712, num_events is 8997
# 2025-12-27 18:22:19,498 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 18 (valid) ]:  valid loglike is -1.1260793334722674, num_events is 3074, acc is 0.5478204294079375, rmse is 0.9784066442409227
# 2025-12-27 18:22:19,615 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 18 (test) ]: test loglike is -1.1224915221497254, num_events is 3094, acc is 0.5830639948287007, rmse is 0.9929855185785406
# 2025-12-27 18:22:19,616 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1261 (updated at epoch-18), best updated at this epoch
# 2025-12-27 18:22:19,760 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 19 (train) ]: train loglike is -1.1556232991292237, num_events is 8997
# 2025-12-27 18:22:19,855 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 19 (valid) ]:  valid loglike is -1.1238399746360606, num_events is 3074, acc is 0.5455432661027977, rmse is 1.0286249862134569
# 2025-12-27 18:22:19,973 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 19 (test) ]: test loglike is -1.1204813468356092, num_events is 3094, acc is 0.581447963800905, rmse is 1.012546310189653
# 2025-12-27 18:22:19,974 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1238 (updated at epoch-19), best updated at this epoch
# 2025-12-27 18:22:20,121 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 20 (train) ]: train loglike is -1.1537165898832598, num_events is 8997
# 2025-12-27 18:22:20,216 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 20 (valid) ]:  valid loglike is -1.1216970330798635, num_events is 3074, acc is 0.5494469746258946, rmse is 1.0256065257203082
# 2025-12-27 18:22:20,337 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 20 (test) ]: test loglike is -1.1185740672470912, num_events is 3094, acc is 0.581447963800905, rmse is 1.0181673667278481
# 2025-12-27 18:22:20,338 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1217 (updated at epoch-20), best updated at this epoch
# 2025-12-27 18:22:20,483 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 21 (train) ]: train loglike is -1.1519354921692648, num_events is 8997
# 2025-12-27 18:22:20,577 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 21 (valid) ]:  valid loglike is -1.1196872013764638, num_events is 3074, acc is 0.5461938841899805, rmse is 1.0012511581014711
# 2025-12-27 18:22:20,692 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 21 (test) ]: test loglike is -1.1167983269028765, num_events is 3094, acc is 0.5801551389786684, rmse is 1.0256541411911488
# 2025-12-27 18:22:20,693 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1197 (updated at epoch-21), best updated at this epoch
# 2025-12-27 18:22:20,838 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 22 (train) ]: train loglike is -1.1502984718864622, num_events is 8997
# 2025-12-27 18:22:20,930 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 22 (valid) ]:  valid loglike is -1.1178478074678757, num_events is 3074, acc is 0.5504229017566689, rmse is 1.0368068419297034
# 2025-12-27 18:22:21,050 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 22 (test) ]: test loglike is -1.1151792973800096, num_events is 3094, acc is 0.5811247575953459, rmse is 0.9836319007472651
# 2025-12-27 18:22:21,051 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1178 (updated at epoch-22), best updated at this epoch
# 2025-12-27 18:22:21,195 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 23 (train) ]: train loglike is -1.1488178079759226, num_events is 8997
# 2025-12-27 18:22:21,287 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 23 (valid) ]:  valid loglike is -1.116211969974992, num_events is 3074, acc is 0.5491216655823032, rmse is 1.0084874915109403
# 2025-12-27 18:22:21,405 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 23 (test) ]: test loglike is -1.1137358376343325, num_events is 3094, acc is 0.5824175824175825, rmse is 1.0574009771582171
# 2025-12-27 18:22:21,406 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1162 (updated at epoch-23), best updated at this epoch
# 2025-12-27 18:22:21,551 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 24 (train) ]: train loglike is -1.1474990090012642, num_events is 8997
# 2025-12-27 18:22:21,645 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 24 (valid) ]:  valid loglike is -1.1148007355034157, num_events is 3074, acc is 0.5458685751463891, rmse is 1.0260948867665896
# 2025-12-27 18:22:21,764 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 24 (test) ]: test loglike is -1.1124769431510586, num_events is 3094, acc is 0.5801551389786684, rmse is 1.0069963928995838
# 2025-12-27 18:22:21,765 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1148 (updated at epoch-24), best updated at this epoch
# 2025-12-27 18:22:21,911 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 25 (train) ]: train loglike is -1.1463415593826414, num_events is 8997
# 2025-12-27 18:22:22,023 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 25 (valid) ]:  valid loglike is -1.1136167249512037, num_events is 3074, acc is 0.5556278464541314, rmse is 1.0395113712982105
# 2025-12-27 18:22:22,142 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 25 (test) ]: test loglike is -1.1113992998040563, num_events is 3094, acc is 0.5824175824175825, rmse is 1.0351623974414705
# 2025-12-27 18:22:22,143 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1136 (updated at epoch-25), best updated at this epoch
# 2025-12-27 18:22:22,289 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 26 (train) ]: train loglike is -1.1453385123600228, num_events is 8997
# 2025-12-27 18:22:22,388 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 26 (valid) ]:  valid loglike is -1.1126426245069534, num_events is 3074, acc is 0.5491216655823032, rmse is 1.0235225864720714
# 2025-12-27 18:22:22,506 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 26 (test) ]: test loglike is -1.1104885463800904, num_events is 3094, acc is 0.5866192630898514, rmse is 1.0260029294415334
# 2025-12-27 18:22:22,507 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1126 (updated at epoch-26), best updated at this epoch
# 2025-12-27 18:22:22,652 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 27 (train) ]: train loglike is -1.144476462857411, num_events is 8997
# 2025-12-27 18:22:22,748 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 27 (valid) ]:  valid loglike is -1.1118457920766915, num_events is 3074, acc is 0.5494469746258946, rmse is 1.0528940089096415
# 2025-12-27 18:22:22,883 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 27 (test) ]: test loglike is -1.109722036350598, num_events is 3094, acc is 0.5840336134453782, rmse is 1.041665624589769
# 2025-12-27 18:22:22,884 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1118 (updated at epoch-27), best updated at this epoch
# 2025-12-27 18:22:23,035 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 28 (train) ]: train loglike is -1.1437373927159749, num_events is 8997
# 2025-12-27 18:22:23,130 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 28 (valid) ]:  valid loglike is -1.1111885026126382, num_events is 3074, acc is 0.5513988288874431, rmse is 1.0515329671081974
# 2025-12-27 18:22:23,249 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 28 (test) ]: test loglike is -1.1090753083084195, num_events is 3094, acc is 0.579185520361991, rmse is 1.0643988027895754
# 2025-12-27 18:22:23,250 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1112 (updated at epoch-28), best updated at this epoch
# 2025-12-27 18:22:23,395 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 29 (train) ]: train loglike is -1.1431008279886699, num_events is 8997
# 2025-12-27 18:22:23,490 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 29 (valid) ]:  valid loglike is -1.1106384317054327, num_events is 3074, acc is 0.5507482108002603, rmse is 1.0398481019262373
# 2025-12-27 18:22:23,609 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 29 (test) ]: test loglike is -1.1085274516958226, num_events is 3094, acc is 0.5808015513897867, rmse is 1.0180797343333583
# 2025-12-27 18:22:23,610 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1106 (updated at epoch-29), best updated at this epoch
# 2025-12-27 18:22:23,765 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 30 (train) ]: train loglike is -1.1425476515175197, num_events is 8997
# 2025-12-27 18:22:23,861 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 30 (valid) ]:  valid loglike is -1.1101728649052538, num_events is 3074, acc is 0.5517241379310345, rmse is 1.024783545189575
# 2025-12-27 18:22:23,981 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 30 (test) ]: test loglike is -1.1080635529452165, num_events is 3094, acc is 0.5785391079508727, rmse is 1.0323281827884954
# 2025-12-27 18:22:23,982 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1102 (updated at epoch-30), best updated at this epoch
# 2025-12-27 18:22:24,144 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 31 (train) ]: train loglike is -1.1420628707833167, num_events is 8997
# 2025-12-27 18:22:24,244 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 31 (valid) ]:  valid loglike is -1.1097756002968444, num_events is 3074, acc is 0.5527000650618087, rmse is 1.0188957565057701
# 2025-12-27 18:22:24,362 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 31 (test) ]: test loglike is -1.1076724860617324, num_events is 3094, acc is 0.5843568196509373, rmse is 1.0418536517628174
# 2025-12-27 18:22:24,363 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1098 (updated at epoch-31), best updated at this epoch
# 2025-12-27 18:22:24,511 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 32 (train) ]: train loglike is -1.141634030462411, num_events is 8997
# 2025-12-27 18:22:24,606 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 32 (valid) ]:  valid loglike is -1.1094326597572381, num_events is 3074, acc is 0.5504229017566689, rmse is 1.0695166512939744
# 2025-12-27 18:22:24,722 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 32 (test) ]: test loglike is -1.1073444664825065, num_events is 3094, acc is 0.5808015513897867, rmse is 1.054436540899892
# 2025-12-27 18:22:24,723 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1094 (updated at epoch-32), best updated at this epoch
# 2025-12-27 18:22:24,887 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 33 (train) ]: train loglike is -1.1412516058955415, num_events is 8997
# 2025-12-27 18:22:24,984 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 33 (valid) ]:  valid loglike is -1.1091301445846211, num_events is 3074, acc is 0.5494469746258946, rmse is 1.0624866604658043
# 2025-12-27 18:22:25,104 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 33 (test) ]: test loglike is -1.107069078382555, num_events is 3094, acc is 0.5869424692954105, rmse is 1.0123419432078529
# 2025-12-27 18:22:25,105 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1091 (updated at epoch-33), best updated at this epoch
# 2025-12-27 18:22:25,252 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 34 (train) ]: train loglike is -1.1409075648914222, num_events is 8997
# 2025-12-27 18:22:25,351 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 34 (valid) ]:  valid loglike is -1.108855029709865, num_events is 3074, acc is 0.5540013012361744, rmse is 1.040769714282896
# 2025-12-27 18:22:25,470 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 34 (test) ]: test loglike is -1.1068367739223093, num_events is 3094, acc is 0.5769230769230769, rmse is 1.0444072092903822
# 2025-12-27 18:22:25,471 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1089 (updated at epoch-34), best updated at this epoch
# 2025-12-27 18:22:25,617 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 35 (train) ]: train loglike is -1.1405960054176045, num_events is 8997
# 2025-12-27 18:22:25,712 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 35 (valid) ]:  valid loglike is -1.1085988170695755, num_events is 3074, acc is 0.5566037735849056, rmse is 1.030740636958049
# 2025-12-27 18:22:25,829 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 35 (test) ]: test loglike is -1.1066390310631464, num_events is 3094, acc is 0.5850032320620556, rmse is 1.091443734096349
# 2025-12-27 18:22:25,830 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1086 (updated at epoch-35), best updated at this epoch
# 2025-12-27 18:22:25,976 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 36 (train) ]: train loglike is -1.1403124500701622, num_events is 8997
# 2025-12-27 18:22:26,072 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 36 (valid) ]:  valid loglike is -1.108359124029156, num_events is 3074, acc is 0.5478204294079375, rmse is 1.058512629580336
# 2025-12-27 18:22:26,190 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 36 (test) ]: test loglike is -1.1064699317226891, num_events is 3094, acc is 0.5788623141564319, rmse is 1.074019205626603
# 2025-12-27 18:22:26,191 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1084 (updated at epoch-36), best updated at this epoch
# 2025-12-27 18:22:26,339 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 37 (train) ]: train loglike is -1.140053981752598, num_events is 8997
# 2025-12-27 18:22:26,433 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 37 (valid) ]:  valid loglike is -1.1081394451193478, num_events is 3074, acc is 0.5507482108002603, rmse is 1.0525432571725122
# 2025-12-27 18:22:26,552 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 37 (test) ]: test loglike is -1.106326003959276, num_events is 3094, acc is 0.5778926955397543, rmse is 1.0581952723447114
# 2025-12-27 18:22:26,553 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1081 (updated at epoch-37), best updated at this epoch
# 2025-12-27 18:22:26,699 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 38 (train) ]: train loglike is -1.1398190130217016, num_events is 8997
# 2025-12-27 18:22:26,795 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 38 (valid) ]:  valid loglike is -1.1079460546112556, num_events is 3074, acc is 0.5500975927130775, rmse is 1.0418859543295675
# 2025-12-27 18:22:26,914 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 38 (test) ]: test loglike is -1.1062046438166613, num_events is 3094, acc is 0.5753070458952811, rmse is 1.0671386226479236
# 2025-12-27 18:22:26,915 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1079 (updated at epoch-38), best updated at this epoch
# 2025-12-27 18:22:27,067 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 39 (train) ]: train loglike is -1.1396060107058255, num_events is 8997
# 2025-12-27 18:22:27,162 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 39 (valid) ]:  valid loglike is -1.1077838766163792, num_events is 3074, acc is 0.5579050097592713, rmse is 1.0955468433823028
# 2025-12-27 18:22:27,280 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 39 (test) ]: test loglike is -1.1061030106153038, num_events is 3094, acc is 0.5769230769230769, rmse is 1.0868835539146264
# 2025-12-27 18:22:27,281 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1078 (updated at epoch-39), best updated at this epoch
# 2025-12-27 18:22:27,427 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 40 (train) ]: train loglike is -1.139412451177302, num_events is 8997
# 2025-12-27 18:22:27,522 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 40 (valid) ]:  valid loglike is -1.107653467082791, num_events is 3074, acc is 0.5504229017566689, rmse is 1.0018145438611994
# 2025-12-27 18:22:27,640 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 40 (test) ]: test loglike is -1.106017001151422, num_events is 3094, acc is 0.5769230769230769, rmse is 1.0801288101152982
# 2025-12-27 18:22:27,641 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1077 (updated at epoch-40), best updated at this epoch
# 2025-12-27 18:22:27,786 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 41 (train) ]: train loglike is -1.1392353087965086, num_events is 8997
# 2025-12-27 18:22:27,881 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 41 (valid) ]:  valid loglike is -1.1075510137951365, num_events is 3074, acc is 0.5566037735849056, rmse is 1.057118299243728
# 2025-12-27 18:22:28,000 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 41 (test) ]: test loglike is -1.1059414075125242, num_events is 3094, acc is 0.581447963800905, rmse is 1.0850406897989773
# 2025-12-27 18:22:28,001 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1076 (updated at epoch-41), best updated at this epoch
# 2025-12-27 18:22:28,145 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 42 (train) ]: train loglike is -1.1390702961099881, num_events is 8997
# 2025-12-27 18:22:28,239 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 42 (valid) ]:  valid loglike is -1.1074695276919324, num_events is 3074, acc is 0.5513988288874431, rmse is 1.0768169354059431
# 2025-12-27 18:22:28,359 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 42 (test) ]: test loglike is -1.1058707061550581, num_events is 3094, acc is 0.5846800258564965, rmse is 1.084210480615706
# 2025-12-27 18:22:28,360 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1075 (updated at epoch-42), best updated at this epoch
# 2025-12-27 18:22:28,509 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 43 (train) ]: train loglike is -1.1389135869725673, num_events is 8997
# 2025-12-27 18:22:28,604 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 43 (valid) ]:  valid loglike is -1.1074015431847755, num_events is 3074, acc is 0.5527000650618087, rmse is 1.0139772580518227
# 2025-12-27 18:22:28,721 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 43 (test) ]: test loglike is -1.1058007938752423, num_events is 3094, acc is 0.574983839689722, rmse is 1.0857186536124899
# 2025-12-27 18:22:28,722 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1074 (updated at epoch-43), best updated at this epoch
# 2025-12-27 18:22:28,868 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 44 (train) ]: train loglike is -1.1387620472014977, num_events is 8997
# 2025-12-27 18:22:28,963 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 44 (valid) ]:  valid loglike is -1.107340547739102, num_events is 3074, acc is 0.5504229017566689, rmse is 1.0759819279514662
# 2025-12-27 18:22:29,093 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 44 (test) ]: test loglike is -1.1057286721780057, num_events is 3094, acc is 0.5795087265675501, rmse is 1.1089622831914359
# 2025-12-27 18:22:29,094 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1073 (updated at epoch-44), best updated at this epoch
# 2025-12-27 18:22:29,239 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 45 (train) ]: train loglike is -1.1386137230205207, num_events is 8997
# 2025-12-27 18:22:29,334 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 45 (valid) ]:  valid loglike is -1.1072829674030173, num_events is 3074, acc is 0.5484710474951203, rmse is 1.0404986718444675
# 2025-12-27 18:22:29,460 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 45 (test) ]: test loglike is -1.1056538676167582, num_events is 3094, acc is 0.5827407886231416, rmse is 1.0965705792438991
# 2025-12-27 18:22:29,461 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1073 (updated at epoch-45), best updated at this epoch
# 2025-12-27 18:22:29,606 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 46 (train) ]: train loglike is -1.1384680445782274, num_events is 8997
# 2025-12-27 18:22:29,700 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 46 (valid) ]:  valid loglike is -1.1072266578053838, num_events is 3074, acc is 0.5585556278464542, rmse is 1.0652783114564188
# 2025-12-27 18:22:29,817 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 46 (test) ]: test loglike is -1.1055770903613849, num_events is 3094, acc is 0.5743374272786037, rmse is 1.0770513390799876
# 2025-12-27 18:22:29,818 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1072 (updated at epoch-46), best updated at this epoch
# 2025-12-27 18:22:29,962 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 47 (train) ]: train loglike is -1.1383251611214156, num_events is 8997
# 2025-12-27 18:22:30,057 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 47 (valid) ]:  valid loglike is -1.107171221840436, num_events is 3074, acc is 0.5523747560182173, rmse is 1.0370986819916097
# 2025-12-27 18:22:30,175 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 47 (test) ]: test loglike is -1.1054998396594216, num_events is 3094, acc is 0.572721396250808, rmse is 1.061579281908262
# 2025-12-27 18:22:30,176 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1072 (updated at epoch-47), best updated at this epoch
# 2025-12-27 18:22:30,320 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 48 (train) ]: train loglike is -1.1381862530565745, num_events is 8997
# 2025-12-27 18:22:30,416 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 48 (valid) ]:  valid loglike is -1.1071164212447138, num_events is 3074, acc is 0.5543266102797658, rmse is 1.03465231042217
# 2025-12-27 18:22:30,534 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 48 (test) ]: test loglike is -1.1054237725739333, num_events is 3094, acc is 0.5675500969618616, rmse is 1.0327419964070228
# 2025-12-27 18:22:30,535 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1071 (updated at epoch-48), best updated at this epoch
# 2025-12-27 18:22:30,681 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 49 (train) ]: train loglike is -1.138052148025036, num_events is 8997
# 2025-12-27 18:22:30,778 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 49 (valid) ]:  valid loglike is -1.1070628119662898, num_events is 3074, acc is 0.5422901756668835, rmse is 1.0624849594340946
# 2025-12-27 18:22:30,897 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 49 (test) ]: test loglike is -1.1053506250757514, num_events is 3094, acc is 0.5782159017453136, rmse is 1.0833324478604913
# 2025-12-27 18:22:30,898 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1071 (updated at epoch-49), best updated at this epoch
# 2025-12-27 18:22:31,046 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 50 (train) ]: train loglike is -1.1379236872360232, num_events is 8997
# 2025-12-27 18:22:31,140 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 50 (valid) ]:  valid loglike is -1.107011426480156, num_events is 3074, acc is 0.5468445022771633, rmse is 1.0709899212975618
# 2025-12-27 18:22:31,256 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 50 (test) ]: test loglike is -1.1052826854900615, num_events is 3094, acc is 0.5743374272786037, rmse is 1.0166144744261059
# 2025-12-27 18:22:31,257 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1070 (updated at epoch-50), best updated at this epoch
# 2025-12-27 18:22:31,401 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 51 (train) ]: train loglike is -1.137801793306102, num_events is 8997
# 2025-12-27 18:22:31,496 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 51 (valid) ]:  valid loglike is -1.106964567999756, num_events is 3074, acc is 0.5614834092387768, rmse is 1.1095583787944057
# 2025-12-27 18:22:31,613 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 51 (test) ]: test loglike is -1.105222163234284, num_events is 3094, acc is 0.5801551389786684, rmse is 1.0604055051487282
# 2025-12-27 18:22:31,614 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1070 (updated at epoch-51), best updated at this epoch
# 2025-12-27 18:22:31,758 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 52 (train) ]: train loglike is -1.1376871174940257, num_events is 8997
# 2025-12-27 18:22:31,851 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 52 (valid) ]:  valid loglike is -1.1069251751077587, num_events is 3074, acc is 0.549772283669486, rmse is 1.0204168061090093
# 2025-12-27 18:22:31,977 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 52 (test) ]: test loglike is -1.1051715044491355, num_events is 3094, acc is 0.5723981900452488, rmse is 1.0605717495998908
# 2025-12-27 18:22:31,978 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-52), best updated at this epoch
# 2025-12-27 18:22:32,124 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 53 (train) ]: train loglike is -1.1375807859347213, num_events is 8997
# 2025-12-27 18:22:32,218 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 53 (valid) ]:  valid loglike is -1.1068962658079864, num_events is 3074, acc is 0.5523747560182173, rmse is 1.054243936851487
# 2025-12-27 18:22:32,334 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 53 (test) ]: test loglike is -1.1051321294743859, num_events is 3094, acc is 0.5765998707175177, rmse is 1.0771405760245831
# 2025-12-27 18:22:32,335 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-53), best updated at this epoch
# 2025-12-27 18:22:32,481 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 54 (train) ]: train loglike is -1.1374834363190507, num_events is 8997
# 2025-12-27 18:22:32,575 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 54 (valid) ]:  valid loglike is -1.106879269681197, num_events is 3074, acc is 0.5562784645413142, rmse is 1.060532752076589
# 2025-12-27 18:22:32,692 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 54 (test) ]: test loglike is -1.1051038804945055, num_events is 3094, acc is 0.5804783451842276, rmse is 1.0785199876362852
# 2025-12-27 18:22:32,693 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-54), best updated at this epoch
# 2025-12-27 18:22:32,839 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 55 (train) ]: train loglike is -1.1373955299552976, num_events is 8997
# 2025-12-27 18:22:32,932 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 55 (valid) ]:  valid loglike is -1.1068738690427782, num_events is 3074, acc is 0.5487963565387117, rmse is 1.0382042639182232
# 2025-12-27 18:22:33,051 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 55 (test) ]: test loglike is -1.1050856528007837, num_events is 3094, acc is 0.5711053652230123, rmse is 1.0368465712795816
# 2025-12-27 18:22:33,052 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-55), best updated at this epoch
# 2025-12-27 18:22:33,198 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 56 (train) ]: train loglike is -1.1373163884489275, num_events is 8997
# 2025-12-27 18:22:33,295 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 56 (valid) ]:  valid loglike is -1.1068776812581327, num_events is 3074, acc is 0.5520494469746259, rmse is 1.045211602533145
# 2025-12-27 18:22:33,408 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 56 (test) ]: test loglike is -1.1050749213447397, num_events is 3094, acc is 0.577246283128636, rmse is 1.070008998610597
# 2025-12-27 18:22:33,410 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-55)
# 2025-12-27 18:22:33,558 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 57 (train) ]: train loglike is -1.137245116319155, num_events is 8997
# 2025-12-27 18:22:33,653 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 57 (valid) ]:  valid loglike is -1.1068876883234384, num_events is 3074, acc is 0.5458685751463891, rmse is 1.0392257571590124
# 2025-12-27 18:22:33,764 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 57 (test) ]: test loglike is -1.1050704236021331, num_events is 3094, acc is 0.5798319327731093, rmse is 1.069046033728076
# 2025-12-27 18:22:33,765 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-55)
# 2025-12-27 18:22:33,917 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 58 (train) ]: train loglike is -1.1371800175796447, num_events is 8997
# 2025-12-27 18:22:34,013 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 58 (valid) ]:  valid loglike is -1.1069017458675585, num_events is 3074, acc is 0.55530253741054, rmse is 1.0638074410443081
# 2025-12-27 18:22:34,125 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 58 (test) ]: test loglike is -1.1050713704953135, num_events is 3094, acc is 0.581447963800905, rmse is 1.027409564071118
# 2025-12-27 18:22:34,126 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-55)
# 2025-12-27 18:22:34,270 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 59 (train) ]: train loglike is -1.1371199660954694, num_events is 8997
# 2025-12-27 18:22:34,368 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 59 (valid) ]:  valid loglike is -1.1069191391001139, num_events is 3074, acc is 0.5468445022771633, rmse is 1.0885560969865729
# 2025-12-27 18:22:34,480 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 59 (test) ]: test loglike is -1.1050787878252262, num_events is 3094, acc is 0.5785391079508727, rmse is 1.087843901135904
# 2025-12-27 18:22:34,481 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-55)
# 2025-12-27 18:22:34,631 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 60 (train) ]: train loglike is -1.1370641206574066, num_events is 8997
# ...
# 2025-12-27 18:30:27,914 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 179 (valid) ]:  valid loglike is -1.152409669557173, num_events is 3074, acc is 0.5279765777488614, rmse is 0.8628221569279846
# 2025-12-27 18:30:28,983 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 179 (test) ]: test loglike is -1.1547297629989495, num_events is 3094, acc is 0.5649644473173885, rmse is 0.8745704413324377
# 2025-12-27 18:30:28,984 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:29,199 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 180 (train) ]: train loglike is -1.1316368558399674, num_events is 8997
# 2025-12-27 18:30:29,912 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 180 (valid) ]:  valid loglike is -1.1472298219441281, num_events is 3074, acc is 0.5279765777488614, rmse is 0.8693035052370105
# 2025-12-27 18:30:30,984 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 180 (test) ]: test loglike is -1.1586033451842275, num_events is 3094, acc is 0.5597931480284422, rmse is 0.8612144168593039
# 2025-12-27 18:30:30,986 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:31,198 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 181 (train) ]: train loglike is -1.1310699486634435, num_events is 8997
# 2025-12-27 18:30:31,905 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 181 (valid) ]:  valid loglike is -1.1509316418957385, num_events is 3074, acc is 0.529277813923227, rmse is 0.8680486921425078
# 2025-12-27 18:30:32,976 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 181 (test) ]: test loglike is -1.1594209874454589, num_events is 3094, acc is 0.5488041370394312, rmse is 0.8673816331740349
# 2025-12-27 18:30:32,978 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:33,194 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 182 (train) ]: train loglike is -1.1318087745828471, num_events is 8997
# 2025-12-27 18:30:33,912 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 182 (valid) ]:  valid loglike is -1.1550493110056115, num_events is 3074, acc is 0.5312296681847756, rmse is 0.8780049570689151
# 2025-12-27 18:30:34,989 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 182 (test) ]: test loglike is -1.1588315464406918, num_events is 3094, acc is 0.5559146735617324, rmse is 0.8872547071324973
# 2025-12-27 18:30:34,991 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:35,204 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 183 (train) ]: train loglike is -1.132095274162568, num_events is 8997
# 2025-12-27 18:30:35,918 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 183 (valid) ]:  valid loglike is -1.1499989198723162, num_events is 3074, acc is 0.5322055953155498, rmse is 0.8643807161799566
# 2025-12-27 18:30:37,000 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 183 (test) ]: test loglike is -1.1575669705983356, num_events is 3094, acc is 0.5562378797672916, rmse is 0.8575417070667024
# 2025-12-27 18:30:37,002 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:37,216 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 184 (train) ]: train loglike is -1.129264903622388, num_events is 8997
# 2025-12-27 18:30:37,934 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 184 (valid) ]:  valid loglike is -1.1489278461999837, num_events is 3074, acc is 0.5296031229668184, rmse is 0.8693114858333276
# 2025-12-27 18:30:39,018 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 184 (test) ]: test loglike is -1.1551454491051227, num_events is 3094, acc is 0.5610859728506787, rmse is 0.8724851178145128
# 2025-12-27 18:30:39,019 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:39,233 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 185 (train) ]: train loglike is -1.1296564458117984, num_events is 8997
# 2025-12-27 18:30:39,943 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 185 (valid) ]:  valid loglike is -1.1514974381912817, num_events is 3074, acc is 0.5357839947950553, rmse is 0.8505525408856368
# 2025-12-27 18:30:41,019 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 185 (test) ]: test loglike is -1.1588252338194893, num_events is 3094, acc is 0.5610859728506787, rmse is 0.8653266337701947
# 2025-12-27 18:30:41,021 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:41,233 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 186 (train) ]: train loglike is -1.1301558663000515, num_events is 8997
# 2025-12-27 18:30:41,947 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 186 (valid) ]:  valid loglike is -1.151623876667209, num_events is 3074, acc is 0.533181522446324, rmse is 0.8732843366064413
# 2025-12-27 18:30:43,025 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 186 (test) ]: test loglike is -1.16422552344255, num_events is 3094, acc is 0.5523594053005818, rmse is 0.8713016290622607
# 2025-12-27 18:30:43,026 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:43,238 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 187 (train) ]: train loglike is -1.1291666178222601, num_events is 8997
# 2025-12-27 18:30:43,952 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 187 (valid) ]:  valid loglike is -1.1492885770779115, num_events is 3074, acc is 0.5351333767078725, rmse is 0.8609460564790257
# 2025-12-27 18:30:45,028 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 187 (test) ]: test loglike is -1.1593799554076438, num_events is 3094, acc is 0.5565610859728507, rmse is 0.8887638479422199
# 2025-12-27 18:30:45,030 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:45,244 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 188 (train) ]: train loglike is -1.1270033668992094, num_events is 8997
# 2025-12-27 18:30:45,959 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 188 (valid) ]:  valid loglike is -1.152138922845844, num_events is 3074, acc is 0.5335068314899154, rmse is 0.8647922711988149
# 2025-12-27 18:30:47,039 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 188 (test) ]: test loglike is -1.1597558720002423, num_events is 3094, acc is 0.5665804783451842, rmse is 0.883055774036972
# 2025-12-27 18:30:47,041 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:47,254 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 189 (train) ]: train loglike is -1.1278167483779316, num_events is 8997
# 2025-12-27 18:30:47,960 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 189 (valid) ]:  valid loglike is -1.1502807061239428, num_events is 3074, acc is 0.5322055953155498, rmse is 0.8610983311119076
# 2025-12-27 18:30:49,031 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 189 (test) ]: test loglike is -1.162735823746566, num_events is 3094, acc is 0.5636716224951519, rmse is 0.881061534140928
# 2025-12-27 18:30:49,033 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:49,245 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 190 (train) ]: train loglike is -1.1260059776870068, num_events is 8997
# 2025-12-27 18:30:49,960 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 190 (valid) ]:  valid loglike is -1.152155045339948, num_events is 3074, acc is 0.5263500325309044, rmse is 0.8582559098830135
# 2025-12-27 18:30:51,041 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 190 (test) ]: test loglike is -1.1673400129282483, num_events is 3094, acc is 0.5481577246283129, rmse is 0.891198854442909
# 2025-12-27 18:30:51,043 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:51,261 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 191 (train) ]: train loglike is -1.1283913756842558, num_events is 8997
# 2025-12-27 18:30:51,978 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 191 (valid) ]:  valid loglike is -1.1534014809185915, num_events is 3074, acc is 0.5341574495770982, rmse is 0.8728566360438447
# 2025-12-27 18:30:53,059 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 191 (test) ]: test loglike is -1.1617633644503476, num_events is 3094, acc is 0.5633484162895928, rmse is 0.8848603953776225
# 2025-12-27 18:30:53,061 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:53,276 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 192 (train) ]: train loglike is -1.1270275584483023, num_events is 8997
# 2025-12-27 18:30:53,991 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 192 (valid) ]:  valid loglike is -1.150862704334743, num_events is 3074, acc is 0.5380611581001952, rmse is 0.8518425707292134
# 2025-12-27 18:30:55,061 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 192 (test) ]: test loglike is -1.160481744530745, num_events is 3094, acc is 0.5672268907563025, rmse is 0.8808577546237696
# 2025-12-27 18:30:55,063 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:55,275 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 193 (train) ]: train loglike is -1.125303337332062, num_events is 8997
# 2025-12-27 18:30:55,980 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 193 (valid) ]:  valid loglike is -1.1545308497173878, num_events is 3074, acc is 0.5283018867924528, rmse is 0.8755892149588386
# 2025-12-27 18:30:57,058 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 193 (test) ]: test loglike is -1.168912802500808, num_events is 3094, acc is 0.5504201680672269, rmse is 0.888769895319209
# 2025-12-27 18:30:57,060 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:57,273 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 194 (train) ]: train loglike is -1.1271423292356133, num_events is 8997
# 2025-12-27 18:30:57,990 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 194 (valid) ]:  valid loglike is -1.1550745669323357, num_events is 3074, acc is 0.5286271958360442, rmse is 0.8501314539193169
# 2025-12-27 18:30:59,062 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 194 (test) ]: test loglike is -1.165725402240223, num_events is 3094, acc is 0.5575307045895281, rmse is 0.8865233644639883
# 2025-12-27 18:30:59,063 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:30:59,277 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 195 (train) ]: train loglike is -1.1277948090986927, num_events is 8997
# 2025-12-27 18:30:59,982 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 195 (valid) ]:  valid loglike is -1.1520359930312702, num_events is 3074, acc is 0.5341574495770982, rmse is 0.8567822274165084
# 2025-12-27 18:31:01,051 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 195 (test) ]: test loglike is -1.1639222809015433, num_events is 3094, acc is 0.5591467356173239, rmse is 0.8841041386065213
# 2025-12-27 18:31:01,053 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:31:01,265 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 196 (train) ]: train loglike is -1.1247825338480884, num_events is 8997
# 2025-12-27 18:31:01,980 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 196 (valid) ]:  valid loglike is -1.153896115860849, num_events is 3074, acc is 0.5289525048796356, rmse is 0.8459271410350884
# 2025-12-27 18:31:03,059 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 196 (test) ]: test loglike is -1.1650366952670492, num_events is 3094, acc is 0.5559146735617324, rmse is 0.8635374862775159
# 2025-12-27 18:31:03,061 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:31:03,274 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 197 (train) ]: train loglike is -1.1273835527641158, num_events is 8997
# 2025-12-27 18:31:03,989 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 197 (valid) ]:  valid loglike is -1.1551619302008784, num_events is 3074, acc is 0.5335068314899154, rmse is 0.8658581124862506
# 2025-12-27 18:31:05,071 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 197 (test) ]: test loglike is -1.1636114632150938, num_events is 3094, acc is 0.561732385261797, rmse is 0.8753091649017525
# 2025-12-27 18:31:05,073 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:31:05,288 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 198 (train) ]: train loglike is -1.1255018762764673, num_events is 8997
# 2025-12-27 18:31:05,992 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 198 (valid) ]:  valid loglike is -1.1538687155629879, num_events is 3074, acc is 0.5283018867924528, rmse is 0.8589989892378361
# 2025-12-27 18:31:07,066 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 198 (test) ]: test loglike is -1.1652439070580156, num_events is 3094, acc is 0.554945054945055, rmse is 0.8744477464687486
# 2025-12-27 18:31:07,068 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:31:07,281 - tpp_runner.py[pid:4457;line:96:_train_model] - INFO: [ Epoch 199 (train) ]: train loglike is -1.1266989441358926, num_events is 8997
# 2025-12-27 18:31:07,987 - tpp_runner.py[pid:4457;line:107:_train_model] - INFO: [ Epoch 199 (valid) ]:  valid loglike is -1.155572696405335, num_events is 3074, acc is 0.5302537410540012, rmse is 0.8726379666765933
# 2025-12-27 18:31:09,058 - tpp_runner.py[pid:4457;line:122:_train_model] - INFO: [ Epoch 199 (test) ]: test loglike is -1.1655025667117809, num_events is 3094, acc is 0.5614091790562379, rmse is 0.8768669349664344
# 2025-12-27 18:31:09,060 - tpp_runner.py[pid:4457;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1382 (updated at epoch-122)
# 2025-12-27 18:31:09,061 - base_runner.py[pid:4457;line:110:train] - INFO: End AttNHP train! Cost time: 6.704m
# ✓ AttNHP on stationary_hawkes completed successfully!
#   - Log-Likelihood: -1.1655
#   - Accuracy: 0.5614
#   - RMSE: 0.8769
#
# ======================================================================
# ✓ AttNHP completed on all datasets
#   - Time: 6.7 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/AttNHP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model

# %% [markdown]
# ## Save Model Results

# %% [markdown]
# ### Function Definition

# %%
import pandas as pd
from typing import Optional, List

def format_results_table(
    results_df: pd.DataFrame,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    log_likelihood_col: str = 'log_likelihood',
    rmse_col: str = 'rmse',
    accuracy_col: str = 'accuracy',
    type_error_from_accuracy: bool = True,
    format_type: str = 'combined'
) -> pd.DataFrame:
    """
    Format results into EasyTPP paper style with mean/std for metrics.
    NOW HANDLES PARTIAL NaN VALUES - shows available metrics even when others are NaN.

    Parameters
    ----------
    results_df : pd.DataFrame
        DataFrame containing columns: 'model', 'dataset', 'log_likelihood', 'rmse', 'accuracy'
    models : List[str], optional
        List of model names to include. If None, uses all models in results_df
    datasets : List[str], optional
        List of dataset names to include. If None, uses all datasets in results_df
    log_likelihood_col : str, default='log_likelihood'
        Column name for log-likelihood values
    rmse_col : str, default='rmse'
        Column name for RMSE values
    accuracy_col : str, default='accuracy'
        Column name for accuracy values
    type_error_from_accuracy : bool, default=True
        If True, compute Type Error Rate as (1 - accuracy) * 100
    format_type : str, default='combined'
        Output format type:
        - 'combined': "log_like/rmse/type_error% ± std_log/std_rmse/std_type"
        - 'log_likelihood': "log_like ± std_log"
        - 'rmse': "rmse ± std_rmse"
        - 'type_error': "type_error% ± std_type"

    Returns
    -------
    pd.DataFrame
        Formatted table with rows as models and columns as datasets
    """
    # Filter models and datasets if specified
    if models is not None:
        results_df = results_df[results_df['model'].isin(models)].copy()
    if datasets is not None:
        results_df = results_df[results_df['dataset'].isin(datasets)].copy()

    # Compute type error rate if needed
    if type_error_from_accuracy:
        results_df['type_error_rate'] = (1 - results_df[accuracy_col]) * 100

    # Get unique models and datasets (sorted)
    all_models = sorted(results_df['model'].unique())
    all_datasets = sorted(results_df['dataset'].unique())

    # Compute mean and std for each model-dataset combination
    agg_dict = {
        log_likelihood_col: ['mean', 'std'],
        rmse_col: ['mean', 'std'],
        'type_error_rate': ['mean', 'std']
    }

    grouped = results_df.groupby(['model', 'dataset']).agg(agg_dict).reset_index()

    # Flatten column names
    grouped.columns = ['model', 'dataset',
                       'log_like_mean', 'log_like_std',
                       'rmse_mean', 'rmse_std',
                       'type_error_mean', 'type_error_std']

    # Fill NaN std with 0 (for single runs)
    grouped['log_like_std'] = grouped['log_like_std'].fillna(0)
    grouped['rmse_std'] = grouped['rmse_std'].fillna(0)
    grouped['type_error_std'] = grouped['type_error_std'].fillna(0)

    # Create formatted strings based on format_type
    def format_cell(row):
        """Format a single cell based on format_type - HANDLES PARTIAL NaN VALUES"""
        log_like_mean = row['log_like_mean']
        log_like_std = row['log_like_std']
        rmse_mean = row['rmse_mean']
        rmse_std = row['rmse_std']
        type_mean = row['type_error_mean']
        type_std = row['type_error_std']

        if format_type == 'log_likelihood':
            # Log-likelihood only format
            if pd.isna(log_like_mean):
                return 'NaN'
            if log_like_std == 0:
                return f"{log_like_mean:.3f}"
            return f"{log_like_mean:.3f} ± {log_like_std:.3f}"

        elif format_type == 'rmse':
            # RMSE only format
            if pd.isna(rmse_mean):
                return 'NaN'
            if rmse_std == 0:
                return f"{rmse_mean:.3f}"
            return f"{rmse_mean:.3f} ± {rmse_std:.3f}"

        elif format_type == 'type_error':
            # Type Error only format
            if pd.isna(type_mean):
                return 'NaN'
            if type_std == 0:
                return f"{type_mean:.1f}%"
            return f"{type_mean:.1f}% ± {type_std:.3f}"

        else:  # format_type == 'combined' (default)
            # FIXED: Show available metrics even when some are NaN
            # Build mean string
            log_str = f"{log_like_mean:.3f}" if not pd.isna(log_like_mean) else "NaN"
            rmse_str = f"{rmse_mean:.3f}" if not pd.isna(rmse_mean) else "NaN"
            type_str = f"{type_mean:.1f}%" if not pd.isna(type_mean) else "NaN%"
            mean_str = f"{log_str}/{rmse_str}/{type_str}"

            # Build std string (only if at least one mean is not NaN)
            if not pd.isna(log_like_mean) or not pd.isna(rmse_mean) or not pd.isna(type_mean):
                log_std_str = f"{log_like_std:.3f}" if not pd.isna(log_like_mean) else "nan"
                rmse_std_str = f"{rmse_std:.3f}" if not pd.isna(rmse_mean) else "nan"
                type_std_str = f"{type_std:.3f}" if not pd.isna(type_mean) else "nan"
                std_str = f"{log_std_str}/{rmse_std_str}/{type_std_str}"
                return f"{mean_str} ± {std_str}"
            else:
                # All NaN case (shouldn't happen often)
                return 'NaN/NaN/NaN%'

    grouped['formatted'] = grouped.apply(format_cell, axis=1)

    # Pivot to create the final table
    formatted_table = grouped.pivot(index='model', columns='dataset', values='formatted')

    # Ensure all models and datasets are present (fill missing with N/A)
    formatted_table = formatted_table.reindex(index=all_models, columns=all_datasets, fill_value='N/A')

    return formatted_table


def save_results_easytpp_format(
    results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    save_csv: bool = True,
    save_latex: bool = True,
    save_markdown: bool = True,
    save_individual_metrics: bool = True,
    **format_kwargs
) -> dict:
    """
    Save formatted results in multiple formats (CSV, LaTeX, Markdown).

    Parameters
    ----------
    results_df : pd.DataFrame
        Results DataFrame with columns: model, dataset, log_likelihood, rmse, accuracy
    output_path : str
        Base path for output files (without extension)
    models : List[str], optional
        List of models to include
    datasets : List[str], optional
        List of datasets to include
    save_csv : bool, default=True
        Save as CSV
    save_latex : bool, default=True
        Save as LaTeX table
    save_markdown : bool, default=True
        Save as Markdown table
    save_individual_metrics : bool, default=True
        Save separate tables for each metric (log-likelihood, RMSE, Type Error)
    **format_kwargs
        Additional keyword arguments passed to format_results_table

    Returns
    -------
    dict
        Dictionary containing all generated tables
    """
    output_tables = {}

    # Generate combined table (with log-likelihood/RMSE/Type Error)
    combined_table = format_results_table(
        results_df,
        models=models,
        datasets=datasets,
        format_type='combined',
        **format_kwargs
    )
    output_tables['combined'] = combined_table

    # Save combined table
    if save_csv:
        combined_table.to_csv(f"{output_path}.csv")
        print(f"✓ Results saved to: {output_path}.csv")

    if save_latex:
        with open(f"{output_path}.tex", 'w') as f:
            f.write(combined_table.to_latex())
        print(f"✓ LaTeX table saved to: {output_path}.tex")

    if save_markdown:
        with open(f"{output_path}.md", 'w') as f:
            f.write(combined_table.to_markdown())
        print(f"✓ Markdown table saved to: {output_path}.md")

    return output_tables


def create_comparison_table(
    stationary_results_df: pd.DataFrame,
    nonstationary_results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None
) -> pd.DataFrame:
    """
    Create a side-by-side comparison table for stationary vs non-stationary results.

    Parameters
    ----------
    stationary_results_df : pd.DataFrame
        Results from stationary Hawkes data
    nonstationary_results_df : pd.DataFrame
        Results from non-stationary Hawkes data
    output_path : str
        Base path for output files
    models : List[str], optional
        List of models to include

    Returns
    -------
    pd.DataFrame
        Comparison table with degradation analysis
    """
    # Format both tables
    stat_table = format_results_table(stationary_results_df, models=models)
    nonstat_table = format_results_table(nonstationary_results_df, models=models)

    # Compute degradation statistics
    stat_grouped = stationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'stat_log_like',
        'rmse': 'stat_rmse',
        'accuracy': 'stat_type_error'
    })

    nonstat_grouped = nonstationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'nonstat_log_like',
        'rmse': 'nonstat_rmse',
        'accuracy': 'nonstat_type_error'
    })

    degradation = stat_grouped.join(nonstat_grouped)

    # Calculate degradation percentages
    degradation['log_like_degradation_%'] = (
        (degradation['nonstat_log_like'] - degradation['stat_log_like']) /
        abs(degradation['stat_log_like']) * 100
    )
    degradation['rmse_degradation_%'] = (
        (degradation['nonstat_rmse'] - degradation['stat_rmse']) /
        degradation['stat_rmse'] * 100
    )
    degradation['type_error_degradation_%'] = (
        degradation['nonstat_type_error'] - degradation['stat_type_error']
    )

    # Save comparison
    degradation.to_csv(f"{output_path}_degradation.csv")
    print(f"✓ Degradation analysis saved to: {output_path}_degradation.csv")

    return degradation

# %% [markdown]
# ### Function Execution

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
data_ids = ['stationary_hawkes']

# %%
import pandas as pd

def flatten_model_results(all_model_results):
    """
    Properly convert all_model_results dictionary to DataFrame.

    The issue: pd.DataFrame(dict) treats keys as COLUMN names, not data rows.
    This function flattens it correctly.
    """
    all_results = []
    for model_name, results_list in all_model_results.items():
        all_results.extend(results_list)
    return pd.DataFrame(all_results)

results_df = flatten_model_results(all_model_results)
results_df = results_df[
    results_df['status'] == 'success'
]

# Check the structure
print("✓ DataFrame created successfully!")
print(f"  Shape: {results_df.shape}")
print(f"  Columns: {list(results_df.columns)}")
print(f"\nFirst few rows:")
print(results_df.head())

formatted_table = format_results_table(
    results_df,
    models=model_ids,
    datasets=data_ids
)

print("\n✓ Formatted table:")
print(formatted_table)

# Save to files
saved_table = save_results_easytpp_format(
    results_df,
    output_path=f'{RESULTS_DIR}/Task3_results',
    models=model_ids,
    datasets=data_ids
)
# Out:
# ✓ DataFrame created successfully!
#   Shape: (7, 7)
#   Columns: ['model', 'dataset', 'log_likelihood', 'accuracy', 'rmse', 'status', 'time_seconds']
#
# First few rows:
#      model            dataset  log_likelihood  accuracy      rmse   status  \
# 0    RMTPP  stationary_hawkes       -1.140369  0.545572  1.204448  success
# 1      NHP  stationary_hawkes       -1.137822  0.540724  1.034238  success
# 2  FullyNN  stationary_hawkes       -1.262615  0.540724  1.072807  success
# 3     SAHP  stationary_hawkes       -1.138142  0.567550  1.064994  success
# 4      THP  stationary_hawkes       -1.148825  0.566257  1.094921  success
#
#    time_seconds
# 0     46.436246
# 1     72.288431
# 2     26.896221
# 3     11.746105
# 4     11.718945
#
# ✓ Formatted table:
# dataset                             stationary_hawkes
# model
# AttNHP         -1.166/0.877/43.9% ± 0.000/0.000/0.000
# FullyNN        -1.263/1.073/45.9% ± 0.000/0.000/0.000
# IntensityFree  -1.122/1.125/42.1% ± 0.000/0.000/0.000
# NHP            -1.138/1.034/45.9% ± 0.000/0.000/0.000
# RMTPP          -1.140/1.204/45.4% ± 0.000/0.000/0.000
# SAHP           -1.138/1.065/43.2% ± 0.000/0.000/0.000
# THP            -1.149/1.095/43.4% ± 0.000/0.000/0.000
# ✓ Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.csv
# ✓ LaTeX table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.tex
# ✓ Markdown table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.md

# %% [markdown]
# ## Data Conversion: EasyTPP → Meta-TPP Format
#
# Convert stationary Hawkes pickle files to npz format for Meta-TPP:
# - **EasyTPP format**: `{time_seqs: List[List[float]], type_seqs: List[List[int]]}`
# - **Meta-TPP format**: `.npz` with `TIMES`, `MARKS`, `MASKS` arrays

# %%
import pickle
import numpy as np
import json
import os


def convert_sparklen_hawkes_to_metatpp(dataset_dir, output_dir, dataset_name='stationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes dataset to Meta-TPP format.

    Your data format (from Sparklen):
    {
        'dim_process': 2,
        'train': [
            [
                {'idx_event': 1, 'type_event': 0, 'time_since_start': 0.876, ...},
                {'idx_event': 2, 'type_event': 1, 'time_since_start': 1.883, ...},
                ...
            ],
            ...
        ]
    }
    """
    os.makedirs(output_dir, exist_ok=True)

    print("="*70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("="*70)

    # Define file paths and their corresponding keys
    splits = {
        'train': ('train.pkl', 'train'),
        'dev': ('dev.pkl', 'dev'),
        'test': ('test.pkl', 'test')
    }

    all_times = []
    all_marks = []
    all_masks = []
    split_indices = {}

    current_idx = 0

    for split_name, (filename, data_key) in splits.items():
        pickle_path = os.path.join(dataset_dir, filename)

        print(f"\n{split_name.upper()} split:")

        # Load pickle file
        with open(pickle_path, 'rb') as f:
            data = pickle.load(f)

        # Extract sequences
        sequences = data[data_key]
        num_seqs = len(sequences)

        # Extract times and marks from event dictionaries
        time_seqs = []
        type_seqs = []

        for seq in sequences:
            # Each seq is a list of event dicts
            times = [event['time_since_start'] for event in seq]
            marks = [event['type_event'] for event in seq]

            time_seqs.append(times)
            type_seqs.append(marks)

        # Find max sequence length
        max_len = max(len(seq) for seq in time_seqs)

        # Create padded arrays
        times = np.zeros((num_seqs, max_len), dtype=np.float32)
        marks = np.zeros((num_seqs, max_len), dtype=np.int64)
        masks = np.zeros((num_seqs, max_len), dtype=np.float32)

        for i, (time_seq, type_seq) in enumerate(zip(time_seqs, type_seqs)):
            seq_len = len(time_seq)
            times[i, :seq_len] = time_seq
            marks[i, :seq_len] = type_seq
            masks[i, :seq_len] = 1.0

        all_times.append(times)
        all_marks.append(marks)
        all_masks.append(masks)

        split_indices[split_name] = (current_idx, current_idx + num_seqs)
        current_idx += num_seqs

        print(f"  - Sequences: {num_seqs}")
        print(f"  - Max length: {max_len}")
        print(f"  - Avg length: {np.mean([len(seq) for seq in time_seqs]):.1f}")

    # Pad to global max length
    global_max_len = max(arr.shape[1] for arr in all_times)

    def pad_to_length(arrays, target_len):
        padded = []
        for arr in arrays:
            if arr.shape[1] < target_len:
                pad_width = ((0, 0), (0, target_len - arr.shape[1]))
                padded.append(np.pad(arr, pad_width, mode='constant', constant_values=0))
            else:
                padded.append(arr)
        return padded

    all_times = pad_to_length(all_times, global_max_len)
    all_marks = pad_to_length(all_marks, global_max_len)
    all_masks = pad_to_length(all_masks, global_max_len)

    # Concatenate
    times_combined = np.concatenate(all_times, axis=0)
    marks_combined = np.concatenate(all_marks, axis=0)
    masks_combined = np.concatenate(all_masks, axis=0)

    # Save npz
    output_path = os.path.join(output_dir, f'{dataset_name}.npz')
    np.savez(
        output_path,
        times=times_combined,
        marks=marks_combined,
        masks=masks_combined
    )

    # Save split info
    split_info_path = os.path.join(output_dir, f'{dataset_name}_split_info.json')
    with open(split_info_path, 'w') as f:
        json.dump({
            'train': split_indices['train'],
            'val': split_indices['dev'],
            'test': split_indices['test'],
            'num_event_types': int(data['dim_process']),
            'global_max_len': int(global_max_len)
        }, f, indent=2)

    print(f"\n{'='*70}")
    print(f"✓ Conversion complete!")
    print(f"  - Output NPZ: {output_path}")
    print(f"  - Split info: {split_info_path}")
    print(f"  - Total sequences: {times_combined.shape[0]}")
    print(f"  - Sequence length: {times_combined.shape[1]}")
    print(f"  - Train: {split_indices['train']}")
    print(f"  - Val: {split_indices['dev']}")
    print(f"  - Test: {split_indices['test']}")
    print("="*70)

    return output_path


# ============================================================================
# RUN CONVERSION
# ============================================================================

# Convert the stationary Hawkes dataset
hawkes_input_dir = os.path.join(DATASET_DIR, 'stationary_hawkes')
metatpp_dataset_dir = os.path.join(DATASET_DIR, 'metatpp_format')

# Convert the stationary Hawkes dataset
converted_npz_path = convert_sparklen_hawkes_to_metatpp(
    dataset_dir=hawkes_input_dir,
    output_dir=metatpp_dataset_dir,
    dataset_name='stationary_hawkes'
)
# Out:
# ======================================================================
# Converting stationary_hawkes to Meta-TPP format
# ======================================================================
#
# TRAIN split:
#   - Sequences: 300
#   - Max length: 63
#   - Avg length: 31.0
#
# DEV split:
#   - Sequences: 100
#   - Max length: 55
#   - Avg length: 31.7
#
# TEST split:
#   - Sequences: 100
#   - Max length: 66
#   - Avg length: 31.9
#
# ======================================================================
# ✓ Conversion complete!
#   - Output NPZ: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/stationary_hawkes.npz
#   - Split info: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/stationary_hawkes_split_info.json
#   - Total sequences: 500
#   - Sequence length: 66
#   - Train: (0, 300)
#   - Val: (300, 400)
#   - Test: (400, 500)
# ======================================================================

# %% [markdown]
# ## Meta TPP

# %% [markdown]
# ### Cell 1: Install Dependencies (CRITICAL - Run First, Then Restart Runtime)

# %%
# ==============================================================================
# CELL 1: Install Dependencies with Correct Versions
# ==============================================================================
# IMPORTANT: After running this cell, you MUST restart the runtime!
# Runtime → Restart runtime (or Ctrl+M .)

# Uninstall any existing stribor (Colab installs 0.2.0 which breaks)
# !pip uninstall stribor -y -q 2>/dev/null

# Install stribor 0.1.0 (does NOT require torchtyping)
# !pip install stribor==0.1.0 -q

# Install nfe (neural-flows-experiments) from GitHub
# !SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True pip install git+https://github.com/mbilos/neural-flows-experiments -q

# Install other Meta-TPP dependencies
# !pip install lightning pytorch-lightning hydra-core omegaconf hydra-colorlog pyrootutils torchmetrics rich -q

# Verify stribor version
import subprocess
result = subprocess.run(['pip', 'show', 'stribor'], capture_output=True, text=True)
version_line = [l for l in result.stdout.split('\n') if 'Version' in l][0]
print(f"✓ Installed: stribor {version_line.split(': ')[1]}")

print("\n" + "=" * 70)
print("⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime")
print("   Then continue to Cell 2 (do NOT re-run this cell)")
print("=" * 70)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for nfe (setup.py) ... done
#   Building wheel for reverse_geocoder (setup.py) ... done
#   Building wheel for sklearn (setup.py) ... done
# ✓ Installed: stribor 0.1.0
#
# ======================================================================
# ⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime
#    Then continue to Cell 2 (do NOT re-run this cell)
# ======================================================================

# %% [markdown]
# ### Cell 2: Verify Imports (Run After Restart)

# %%
# ==============================================================================
# CELL 2: Verify Imports After Runtime Restart
# ==============================================================================
# Run this AFTER restarting the runtime

import stribor

# This import should now work without torchtyping errors
import torch
print(f"✓ PyTorch version: {torch.__version__}")

# Test that stribor's distributions work
try:
    from stribor.dist import Normal
    print("✓ stribor.dist imports work")
except Exception as e:
    print(f"✗ Error: {e}")

print("\n✓ All imports successful - ready to proceed!")
# Out:
# ✓ PyTorch version: 2.9.0+cu126
# ✓ stribor.dist imports work
#
# ✓ All imports successful - ready to proceed!

# %% [markdown]
# ### Cell 3: Setup Paths and Clone Meta-TPP

# %%
# ==============================================================================
# CELL 3: Setup Paths and Clone Meta-TPP
# ==============================================================================
import os
import sys

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Base directories
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task3')
METATPP_DIR = '/content/meta-tpp'

os.makedirs(RESULTS_DIR, exist_ok=True)

# Clone Meta-TPP
if not os.path.exists(METATPP_DIR):
    # !git clone https://github.com/BorealisAI/meta-tpp.git {METATPP_DIR}
    print("✓ Meta-TPP cloned")
else:
    print("✓ Meta-TPP already exists")

# Add to Python path
if METATPP_DIR not in sys.path:
    sys.path.insert(0, METATPP_DIR)

# Change to Meta-TPP directory (required for Hydra)
os.chdir(METATPP_DIR)
print(f"✓ Working directory: {os.getcwd()}")

# Create data directories
os.makedirs(os.path.join(METATPP_DIR, 'data', 'synthetic'), exist_ok=True)
print("✓ Data directories ready")

# ==============================================================================
# Create .project-root indicator file (required by pyrootutils)
# ==============================================================================
project_root_file = os.path.join(METATPP_DIR, '.project-root')
if not os.path.exists(project_root_file):
    with open(project_root_file, 'w') as f:
        f.write('')  # Empty file is fine, just needs to exist
    print(f"✓ Created .project-root indicator file")
else:
    print(f"✓ .project-root already exists")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into '/content/meta-tpp'...
# remote: Enumerating objects: 3610, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 3610 (delta 159), reused 211 (delta 155), pack-reused 3384 (from 1)
# Receiving objects: 100% (3610/3610), 3.45 MiB | 32.71 MiB/s, done.
# Resolving deltas: 100% (2132/2132), done.
# ✓ Meta-TPP cloned
# ✓ Working directory: /content/meta-tpp
# ✓ Data directories ready
# ✓ Created .project-root indicator file

# %% [markdown]
# ### Cell 4: Convert Stationary Hawkes Data to Meta-TPP Format

# %%
# ==============================================================================
# CELL 4: Convert Stationary Hawkes Data to Meta-TPP Format
# ==============================================================================
import numpy as np
import pickle

def convert_hawkes_to_metatpp_format(dataset_dir, output_path, dataset_name='stationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes pickle files to Meta-TPP npz format.

    Meta-TPP expects:
    - Single npz file with all sequences
    - Keys: 'times', 'marks', 'masks'
    - Shape: (num_sequences, max_seq_len)
    - Split by indices: 60% train, 20% val, 20% test (or custom)
    """
    print("=" * 70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("=" * 70)

    all_times = []
    all_marks = []
    splits = ['train', 'dev', 'test']
    split_files = {'train': 'train.pkl', 'dev': 'dev.pkl', 'test': 'test.pkl'}

    for split in splits:
        pkl_path = os.path.join(dataset_dir, split_files[split])
        print(f"\nLoading {split}...")

        with open(pkl_path, 'rb') as f:
            data = pickle.load(f)

        # Handle different pickle structures
        if split in data:
            sequences = data[split]
        elif 'train' in data or 'dev' in data or 'test' in data:
            sequences = data.get(split, data.get('train', []))
        else:
            sequences = data if isinstance(data, list) else list(data.values())[0]

        print(f"  - {len(sequences)} sequences")

        for seq in sequences:
            if isinstance(seq, list) and len(seq) > 0 and isinstance(seq[0], dict):
                # Format: [{'time_since_start': t, 'type_event': m}, ...]
                times = [event['time_since_start'] for event in seq]
                marks = [event['type_event'] for event in seq]
            else:
                # Assume it's already (times, marks) format
                times = [e[0] if isinstance(e, (list, tuple)) else e for e in seq]
                marks = [e[1] if isinstance(e, (list, tuple)) else 0 for e in seq]

            all_times.append(times)
            all_marks.append(marks)

    # Find max sequence length
    max_len = max(len(t) for t in all_times)
    num_seqs = len(all_times)

    print(f"\n  Total sequences: {num_seqs}")
    print(f"  Max sequence length: {max_len}")

    # Create padded arrays
    times_arr = np.zeros((num_seqs, max_len), dtype=np.float32)
    marks_arr = np.zeros((num_seqs, max_len), dtype=np.int64)
    masks_arr = np.zeros((num_seqs, max_len), dtype=np.float32)

    for i, (t, m) in enumerate(zip(all_times, all_marks)):
        seq_len = len(t)
        times_arr[i, :seq_len] = t
        marks_arr[i, :seq_len] = m
        masks_arr[i, :seq_len] = 1.0

    # Save as npz
    np.savez(output_path, times=times_arr, marks=marks_arr, masks=masks_arr)

    print(f"\n✓ Saved to: {output_path}")
    print(f"  - times: {times_arr.shape}, dtype={times_arr.dtype}")
    print(f"  - marks: {marks_arr.shape}, dtype={marks_arr.dtype}")
    print(f"  - masks: {masks_arr.shape}, dtype={masks_arr.dtype}")
    print(f"  - Split: [0:{int(num_seqs*0.6)}] train, [{int(num_seqs*0.6)}:{int(num_seqs*0.8)}] val, [{int(num_seqs*0.8)}:] test")
    print("=" * 70)

    return output_path

# Convert the data
hawkes_input_dir = os.path.join(DATASET_DIR, 'stationary_hawkes')
metatpp_data_path = os.path.join(METATPP_DIR, 'data', 'synthetic', 'stationary_hawkes.npz')

convert_hawkes_to_metatpp_format(hawkes_input_dir, metatpp_data_path)

# Verify
data = np.load(metatpp_data_path)
print("\n✓ Verification:")
for key in data.keys():
    print(f"  {key}: shape={data[key].shape}, dtype={data[key].dtype}")
# Out:
# ======================================================================
# Converting stationary_hawkes to Meta-TPP format
# ======================================================================
#
# Loading train...
#   - 300 sequences
#
# Loading dev...
#   - 100 sequences
#
# Loading test...
#   - 100 sequences
#
#   Total sequences: 500
#   Max sequence length: 66
#
# ✓ Saved to: /content/meta-tpp/data/synthetic/stationary_hawkes.npz
#   - times: (500, 66), dtype=float32
#   - marks: (500, 66), dtype=int64
#   - masks: (500, 66), dtype=float32
#   - Split: [0:300] train, [300:400] val, [400:] test
# ======================================================================
#
# ✓ Verification:
#   times: shape=(500, 66), dtype=float32
#   marks: shape=(500, 66), dtype=int64
#   masks: shape=(500, 66), dtype=float32

# %% [markdown]
# ### Cell 5: Create Dataset Config and Patch TPPDataset

# %%
# ==============================================================================
# CELL 5: Create Dataset Config and Register Dataset
# ==============================================================================
import yaml

# Create dataset config YAML
dataset_config = {
    'dataset': 'stationary_hawkes',
    'num_classes': 2  # Your Hawkes data has 2 event types
}

config_dir = os.path.join(METATPP_DIR, 'configs', 'data', 'datasets')
config_path = os.path.join(config_dir, 'stationary_hawkes.yaml')

with open(config_path, 'w') as f:
    yaml.dump(dataset_config, f)

print(f"✓ Created dataset config: {config_path}")

# Patch TPPDataset to include our new dataset
tpp_dataset_path = os.path.join(METATPP_DIR, 'src', 'data', 'tpp_dataset.py')

with open(tpp_dataset_path, 'r') as f:
    content = f.read()

# Add stationary_hawkes to synthetic_data list if not already there
if 'stationary_hawkes' not in content:
    old_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\"]"
    new_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\", 'stationary_hawkes']"

    if old_line in content:
        content = content.replace(old_line, new_line)
        with open(tpp_dataset_path, 'w') as f:
            f.write(content)
        print("✓ Added 'stationary_hawkes' to synthetic_data list")
    else:
        # Try alternative format
        import re
        pattern = r"(synthetic_data\s*=\s*\[.*?\])"
        match = re.search(pattern, content, re.DOTALL)
        if match:
            old = match.group(1)
            if 'stationary_hawkes' not in old:
                new = old.rstrip(']') + ", 'stationary_hawkes']"
                content = content.replace(old, new)
                with open(tpp_dataset_path, 'w') as f:
                    f.write(content)
                print("✓ Added 'stationary_hawkes' to synthetic_data list")
else:
    print("✓ 'stationary_hawkes' already registered")

# Reload the module
import importlib
if 'src.data.tpp_dataset' in sys.modules:
    del sys.modules['src.data.tpp_dataset']

print("✓ Dataset configuration complete")
# Out:
# ✓ Created dataset config: /content/meta-tpp/configs/data/datasets/stationary_hawkes.yaml
# ✓ Added 'stationary_hawkes' to synthetic_data list
# ✓ Dataset configuration complete

# %% [markdown]
# ### Cell 6: Test Data Loading

# %%
# ==============================================================================
# CELL 6: Test Data Loading
# ==============================================================================
# Verify the data can be loaded by Meta-TPP's dataset class

from src.data.tpp_dataset import TPPDataset

# Test loading
data_dir = os.path.join(METATPP_DIR, 'data')

print("Testing data loading...")
try:
    train_ds = TPPDataset(data_dir, 'stationary_hawkes', num_classes=2, mode='train')
    val_ds = TPPDataset(data_dir, 'stationary_hawkes', num_classes=2, mode='val')
    test_ds = TPPDataset(data_dir, 'stationary_hawkes', num_classes=2, mode='test')

    print(f"\n✓ Train: {len(train_ds)} sequences")
    print(f"✓ Val: {len(val_ds)} sequences")
    print(f"✓ Test: {len(test_ds)} sequences")

    # Test a sample
    sample = train_ds[0]
    print(f"\nSample batch keys: {list(sample.keys())}")
    print(f"  times shape: {sample['times'].shape}")
    print(f"  marks shape: {sample['marks'].shape}")
    print(f"  masks shape: {sample['masks'].shape}")

    print("\n✓ Data loading test passed!")
except Exception as e:
    print(f"✗ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Testing data loading...
# time shape: torch.Size([300, 66, 1]), marks shape: torch.Size([300, 66, 1]), masks shape: torch.Size([300, 66, 1])
# time shape: torch.Size([100, 66, 1]), marks shape: torch.Size([100, 66, 1]), masks shape: torch.Size([100, 66, 1])
# time shape: torch.Size([100, 66, 1]), marks shape: torch.Size([100, 66, 1]), masks shape: torch.Size([100, 66, 1])
#
# ✓ Train: 300 sequences
# ✓ Val: 100 sequences
# ✓ Test: 100 sequences
#
# Sample batch keys: ['times', 'marks', 'masks', 'missing_masks']
#   times shape: torch.Size([66, 1])
#   marks shape: torch.Size([66, 1])
#   masks shape: torch.Size([66, 1])
#
# ✓ Data loading test passed!

# %% [markdown]
# ### Cell 7: Train Meta-TPP Using Hydra

# %%
# ==============================================================================
# CELL 7: Train Meta-TPP Using Hydra
# ==============================================================================
import subprocess
import os

# Ensure we're in the Meta-TPP directory
os.chdir(METATPP_DIR)

# Training command using Hydra
# This replicates: python src/train.py data/datasets=stationary_hawkes
cmd = [
    'python', 'src/train.py',
    'data/datasets=stationary_hawkes',
    'model=thp_mix',
    'trainer.max_epochs=200',
    'trainer.accelerator=gpu',
    'trainer.devices=1',
    'data.batch_size=256',
    'tag=colab_run',
    'test=False',
    'seed=42'
]

print("=" * 70)
print("Starting Meta-TPP Training")
print("=" * 70)
print(f"Command: {' '.join(cmd)}")
print("=" * 70 + "\n")

# Run training
process = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

# Stream output
for line in iter(process.stdout.readline, ''):
    print(line, end='')

process.wait()

if process.returncode == 0:
    print("\n" + "=" * 70)
    print("✓ Training completed successfully!")
    print("=" * 70)
else:
    print(f"\n✗ Training failed with return code: {process.returncode}")
# Out:
# ======================================================================
# Starting Meta-TPP Training
# ======================================================================
# Command: python src/train.py data/datasets=stationary_hawkes model=thp_mix trainer.max_epochs=200 trainer.accelerator=gpu trainer.devices=1 data.batch_size=256 tag=colab_run test=False seed=42
# ======================================================================
#
# [2025-12-27 18:33:45,563][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2025-12-27 18:33:45,567][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# [2025-12-27 18:33:45,568][src.utils.rich_utils][WARNING] - Field 'logger' not found in config. Skipping 'logger' config printing...
# CONFIG
# ├── data
# │   └── _target_: src.data.tpp_dataset.TPPDataModule
# │       data_dir: /content/meta-tpp/data/
# │       batch_size: 256
# │       num_workers: 4
# │       pin_memory: false
# │       train_rate: 1.0
# │       eval_rate: 1.0
# │       noise_rate: 0.0
# │       seq_rate: 1.0
# │       missing_rate: 0.0
# │       use_mark: true
# │       run_bootstrap: false
# │       datasets:
# │         dataset: stationary_hawkes
# │         num_classes: 2
# │
# ├── model
# │   └── _target_: src.models.tpp_module.TPPLitModule
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.0001
# │         weight_decay: 0.0001
# │         eps: 1.0e-05
# │         betas:
# │         - 0.9
# │         - 0.999
# │       net:
# │         _target_: src.models.tpp.tpp_network.TransformerMix
# │         name: thp_mix
# │         num_classes: 2
# │         d_model: 64
# │         d_inner: 64
# │         n_layers: 2
# │         cattn_n_layers: 1
# │         n_head: 1
# │         d_k: 64
# │         d_v: 64
# │         dropout: 0.1
# │         attn_l: 0
# │         base_l: 0
# │         perm_invar: false
# │         use_avg: true
# │         share_weights: true
# │         attn_only: false
# │         concat: false
# │         num_latent: 64
# │         vi_method: None
# │         num_z_samples: 32
# │         compute_acc: true
# │         activation:
# │           name: tanh
# │           in_features: 64
# │           trainable: true
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: lightning.pytorch.callbacks.ModelCheckpoint
# │         dirpath: /content/meta-tpp/logs/stationary_hawkes_thp_mix_colab_run/se
# │         filename: epoch_{epoch:03d}
# │         monitor: val/rmse
# │         verbose: false
# │         save_last: true
# │         save_top_k: 1
# │         mode: min
# │         auto_insert_metric_name: false
# │         save_weights_only: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: null
# │       early_stopping:
# │         _target_: lightning.pytorch.callbacks.EarlyStopping
# │         monitor: val/nll
# │         min_delta: 0.0
# │         patience: 500
# │         verbose: false
# │         mode: min
# │         strict: true
# │         check_finite: true
# │         stopping_threshold: null
# │         divergence_threshold: null
# │         check_on_train_epoch_end: null
# │       model_summary:
# │         _target_: lightning.pytorch.callbacks.RichModelSummary
# │         max_depth: -1
# │       rich_progress_bar:
# │         _target_: lightning.pytorch.callbacks.RichProgressBar
# │
# ├── trainer
# │   └── _target_: lightning.pytorch.trainer.Trainer
# │       default_root_dir: /content/meta-tpp/logs/stationary_hawkes_thp_mix_colab
# │       min_epochs: 1
# │       max_epochs: 200
# │       accelerator: gpu
# │       devices: 1
# │       check_val_every_n_epoch: 1
# │       deterministic: false
# │
# ├── paths
# │   └── root_dir: /content/meta-tpp
# │       data_dir: /content/meta-tpp/data/
# │       log_dir: /content/meta-tpp/logs/
# │       output_dir: /content/meta-tpp/logs/stationary_hawkes_thp_mix_colab_run/s
# │       work_dir: /content/meta-tpp
# │       ckpt_dir: /content/meta-tpp/checkpoints/
# │
# ├── extras
# │   └── ignore_warnings: false
# │       enforce_tags: true
# │       print_config: true
# │
# ├── task_name
# │   └── stationary_hawkes_thp_mix_colab_run
# ├── tags
# │   └── ['dev']
# ├── tag
# │   └── colab_run
# ├── train
# │   └── True
# ├── test
# │   └── False
# ├── compile
# │   └── False
# ├── ckpt_path
# │   └── None
# └── seed
#     └── 42
# Seed set to 42
# [2025-12-27 18:33:45,625][__main__][INFO] - Instantiating datamodule <src.data.tpp_dataset.TPPDataModule>
# [2025-12-27 18:33:45,628][__main__][INFO] - Instantiating model <src.models.tpp_module.TPPLitModule>
# The number of trainable model parameters: 56284
# [2025-12-27 18:33:45,806][__main__][INFO] - Instantiating callbacks...
# [2025-12-27 18:33:45,806][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.ModelCheckpoint>
# [2025-12-27 18:33:45,820][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.EarlyStopping>
# [2025-12-27 18:33:45,821][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichModelSummary>
# [2025-12-27 18:33:45,821][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichProgressBar>
# [2025-12-27 18:33:45,821][__main__][INFO] - Instantiating loggers...
# [2025-12-27 18:33:45,822][src.utils.instantiators][WARNING] - No logger configs found! Skipping...
# [2025-12-27 18:33:45,822][__main__][INFO] - Instantiating trainer <lightning.pytorch.trainer.Trainer>
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# [2025-12-27 18:33:45,865][__main__][INFO] - Starting training!
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1551: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return _C._get_float32_matmul_precision()
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# time shape: torch.Size([300, 66, 1]), marks shape: torch.Size([300, 66, 1]), masks shape: torch.Size([300, 66, 1])
# time shape: torch.Size([100, 66, 1]), marks shape: torch.Size([100, 66, 1]), masks shape: torch.Size([100, 66, 1])
# time shape: torch.Size([100, 66, 1]), marks shape: torch.Size([100, 66, 1]), masks shape: torch.Size([100, 66, 1])
# ┏━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━┳━━━━┳━━━┓
# ┃    ┃ Name                                                 ┃ T… ┃ P… ┃ M… ┃ … ┃
# ┡━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━╇━━━━╇━━━┩
# │ 0  │ net                                                  │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 1  │ net.encoder                                          │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 2  │ net.encoder.event_emb                                │ E… │ 1… │ t… │ 0 │
# │ 3  │ net.encoder.layer_stack                              │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 4  │ net.encoder.layer_stack.0                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 5  │ net.encoder.layer_stack.0.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 6  │ net.encoder.layer_stack.0.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 7  │ net.encoder.layer_stack.0.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 8  │ net.encoder.layer_stack.0.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 9  │ net.encoder.layer_stack.0.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 10 │ net.encoder.layer_stack.0.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 11 │ net.encoder.layer_stack.0.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 12 │ net.encoder.layer_stack.0.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 13 │ net.encoder.layer_stack.0.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 14 │ net.encoder.layer_stack.0.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 15 │ net.encoder.layer_stack.0.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 16 │ net.encoder.layer_stack.0.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 17 │ net.encoder.layer_stack.0.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 18 │ net.encoder.layer_stack.0.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 19 │ net.encoder.layer_stack.1                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 20 │ net.encoder.layer_stack.1.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 21 │ net.encoder.layer_stack.1.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 22 │ net.encoder.layer_stack.1.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 23 │ net.encoder.layer_stack.1.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 24 │ net.encoder.layer_stack.1.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 25 │ net.encoder.layer_stack.1.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 26 │ net.encoder.layer_stack.1.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 27 │ net.encoder.layer_stack.1.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 28 │ net.encoder.layer_stack.1.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 29 │ net.encoder.layer_stack.1.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 30 │ net.encoder.layer_stack.1.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 31 │ net.encoder.layer_stack.1.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 32 │ net.encoder.layer_stack.1.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 33 │ net.encoder.layer_stack.1.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 34 │ net.linear                                           │ L… │ 1… │ t… │ 0 │
# │ 35 │ net.time_predictor                                   │ T… │ 64 │ t… │ 0 │
# │ 36 │ net.time_predictor.linear                            │ L… │ 64 │ t… │ 0 │
# │ 37 │ net.class_predictor                                  │ T… │ 1… │ t… │ 0 │
# │ 38 │ net.mark_linear                                      │ L… │ 1… │ t… │ 0 │
# │ 39 │ net.activation                                       │ T… │  0 │ t… │ 0 │
# │ 40 │ net.prob_dist                                        │ L… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 41 │ net.prob_dist.decoder                                │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 42 │ net.prob_dist.decoder.net                            │ S… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 43 │ net.prob_dist.decoder.net.0                          │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 44 │ net.prob_dist.decoder.net.1                          │ T… │  0 │ t… │ 0 │
# │ 45 │ net.prob_dist.decoder.net.2                          │ L… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 46 │ train_nll                                            │ M… │  0 │ t… │ 0 │
# │ 47 │ val_nll                                              │ M… │  0 │ t… │ 0 │
# │ 48 │ test_nll                                             │ M… │  0 │ t… │ 0 │
# │ 49 │ train_rmse                                           │ M… │  0 │ t… │ 0 │
# │ 50 │ val_rmse                                             │ M… │  0 │ t… │ 0 │
# │ 51 │ test_rmse                                            │ M… │  0 │ t… │ 0 │
# │ 52 │ train_acc                                            │ M… │  0 │ t… │ 0 │
# │ 53 │ val_acc                                              │ M… │  0 │ t… │ 0 │
# │ 54 │ test_acc                                             │ M… │  0 │ t… │ 0 │
# │ 55 │ val_nll_best                                         │ M… │  0 │ t… │ 0 │
# │ 56 │ val_rmse_best                                        │ M… │  0 │ t… │ 0 │
# └────┴──────────────────────────────────────────────────────┴────┴────┴────┴───┘
# Trainable params: 56.3 K
# Non-trainable params: 0
# Total params: 56.3 K
# Total estimated model params size (MB): 0
# Modules in train mode: 57
# Modules in eval mode: 0
# Total FLOPs: 0
# `Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 199/199 ━━━━━━━━━━━━━━━━ 2/2 0:00:00 • 0:00:00 28.88it/s val/nll: 1.392
#                                                                val/rmse: 2.317
#                                                                val/acc: 0.471
#                                                                val/nll_best:
#                                                                1.375
#                                                                val/rmse_best:
#                                                                1.694 train/nll:
#                                                                1.509
# [2025-12-27 18:35:14,159][src.utils.utils][INFO] - Output dir: /content/meta-tpp/logs/stationary_hawkes_thp_mix_colab_run/seed42
# [2025-12-27 18:35:16,015][src.utils.utils][INFO] - Metric name is None! Skipping metric value retrieval...
# [W1227 18:35:17.303753763 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# ======================================================================
# ✓ Training completed successfully!
# ======================================================================

# %%
# ==============================================================================
# CELL 7b: Manual Testing with proper optimizer setup
# ==============================================================================
import torch
import lightning as L
from torch.utils.data import DataLoader
from functools import partial

# Fix for PyTorch 2.6 checkpoint loading
from omegaconf import ListConfig, DictConfig
torch.serialization.add_safe_globals([ListConfig, DictConfig])

from src.data.tpp_dataset import TPPDataset
from src.models.tpp_module import TPPLitModule
from src.models.tpp.tpp_network import TransformerMix

# Find the best checkpoint
import glob
ckpt_pattern = os.path.join(METATPP_DIR, 'logs', 'stationary_hawkes_thp_mix_colab_run', 'seed42', 'checkpoints', '*.ckpt')
ckpts = glob.glob(ckpt_pattern)
ckpts = [c for c in ckpts if 'last' not in c]
best_ckpt = sorted(ckpts)[-1] if ckpts else None

print(f"Best checkpoint: {best_ckpt}")

# Load data
data_dir = os.path.join(METATPP_DIR, 'data')
test_ds = TPPDataset(data_dir, 'stationary_hawkes', num_classes=2, mode='test')
test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2)

# Create model
net = TransformerMix(
    name='thp_mix', num_classes=2, d_model=64, d_inner=64, n_layers=2,
    cattn_n_layers=1, n_head=1, d_k=64, d_v=64, dropout=0.1,
    attn_l=0, base_l=0, perm_invar=False, use_avg=True, share_weights=True,
    attn_only=False, concat=False, num_latent=64, vi_method=None,
    num_z_samples=32, compute_acc=True,
    activation={'name': 'tanh', 'in_features': 64, 'trainable': True}
)

# Create optimizer as a partial function (this is what Hydra does)
optimizer = partial(
    torch.optim.Adam,
    lr=0.0001,
    weight_decay=0.0001,
    eps=1e-5,
    betas=(0.9, 0.999)
)

model = TPPLitModule(net=net, optimizer=optimizer)

# Load checkpoint
if best_ckpt:
    ckpt = torch.load(best_ckpt, map_location='cuda', weights_only=False)
    model.load_state_dict(ckpt['state_dict'])
    print("✓ Checkpoint loaded")

# Set model to eval mode
model.eval()

# Test
trainer = L.Trainer(accelerator='gpu', devices=1, logger=False, enable_progress_bar=True)
test_results = trainer.test(model, test_loader)

print("\n" + "=" * 70)
print("Meta-TPP Test Results")
print("=" * 70)
for k, v in test_results[0].items():
    print(f"  {k}: {v:.4f}")
# Out:
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 0:00:00 • 0:00:00 55.31it/s
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.4528118968009949     │
# │         test/nll          │    1.4785860776901245     │
# │         test/rmse         │    2.0900042057037354     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
# Meta-TPP Test Results
# ======================================================================
#   test/nll: 1.4786
#   test/rmse: 2.0900
#   test/acc: 0.4528

# %% [markdown]
# ### Cell 8: Extract and Save Results

# %%
# ==============================================================================
# CELL 9: Extract and Save Results Properly
# ==============================================================================
import pandas as pd

# test_results is returned from trainer.test() - it's a list of dicts
# Print what we actually got to debug
print("=" * 70)
print("Raw test_results:")
print(test_results)
print("=" * 70)

# Extract metrics from test_results (it's a list with one dict)
if test_results and len(test_results) > 0:
    metrics = test_results[0]

    # Meta-TPP uses keys like 'test/nll', 'test/rmse', 'test/acc'
    # or 'test_nll', 'test_rmse', 'test_acc'

    # Try different possible key formats
    def get_metric(metrics, *possible_keys):
        for key in possible_keys:
            if key in metrics:
                val = metrics[key]
                # Handle tensor values
                if hasattr(val, 'item'):
                    return val.item()
                return val
        return float('nan')

    nll = get_metric(metrics, 'test/nll', 'test_nll', 'test_loss')
    rmse = get_metric(metrics, 'test/rmse', 'test_rmse')
    acc = get_metric(metrics, 'test/acc', 'test_acc', 'test_accuracy')

    # Log-likelihood is negative NLL
    log_likelihood = -nll if not pd.isna(nll) else float('nan')

    print(f"\nExtracted metrics:")
    print(f"  NLL: {nll}")
    print(f"  Log-Likelihood: {log_likelihood}")
    print(f"  RMSE: {rmse}")
    print(f"  Accuracy: {acc}")
else:
    print("No test results found!")
    log_likelihood = float('nan')
    acc = float('nan')
    rmse = float('nan')

# Create result entry
metatpp_result = {
    'model': 'Meta-TPP',
    'dataset': 'stationary_hawkes',
    'log_likelihood': log_likelihood,
    'accuracy': acc * 100 if not pd.isna(acc) and acc <= 1 else acc,  # Convert to percentage if needed
    'rmse': rmse,
    'status': 'success'
}

# Save results
results_df = pd.DataFrame([metatpp_result])
metatpp_results_path = os.path.join(RESULTS_DIR, 'metatpp_stationary_results.csv')
results_df.to_csv(metatpp_results_path, index=False)

print("\n" + "=" * 70)
print("Meta-TPP Results (Task 3b)")
print("=" * 70)
print(results_df.to_string(index=False))
print(f"\n✓ Saved to: {metatpp_results_path}")

# Also print in Table-1-like format for easy comparison
print("\n" + "=" * 70)
print("Table-1-like Format:")
print("=" * 70)
print(f"Model: Meta-TPP")
print(f"Dataset: stationary_hawkes")
print(f"Log-Likelihood: {log_likelihood:.3f}" if not pd.isna(log_likelihood) else "Log-Likelihood: N/A")
print(f"Accuracy: {metatpp_result['accuracy']:.1f}%" if not pd.isna(metatpp_result['accuracy']) else "Accuracy: N/A")
print(f"RMSE: {rmse:.3f}" if not pd.isna(rmse) else "RMSE: N/A")
# Out:
# ======================================================================
# Raw test_results:
# [{'test/nll': 1.4785860776901245, 'test/rmse': 2.0900042057037354, 'test/acc': 0.4528118968009949}]
# ======================================================================
#
# Extracted metrics:
#   NLL: 1.4785860776901245
#   Log-Likelihood: -1.4785860776901245
#   RMSE: 2.0900042057037354
#   Accuracy: 0.4528118968009949
#
# ======================================================================
# Meta-TPP Results (Task 3b)
# ======================================================================
#    model           dataset  log_likelihood  accuracy     rmse  status
# Meta-TPP stationary_hawkes       -1.478586  45.28119 2.090004 success
#
# ✓ Saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/metatpp_stationary_results.csv
#
# ======================================================================
# Table-1-like Format:
# ======================================================================
# Model: Meta-TPP
# Dataset: stationary_hawkes
# Log-Likelihood: -1.479
# Accuracy: 45.3%
# RMSE: 2.090
