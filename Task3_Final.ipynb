# %% [markdown]
# ## Package Installation

# %%
import os
import sys
import types

# Install core dependencies
# !pip install easy-tpp lightning pytorch-lightning hydra-core omegaconf torchmetrics stribor -q

print("✓ Core dependencies installed")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 56.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 43.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 65.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.1 MB/s eta 0:00:00
# ✓ Core dependencies installed

# %%
# Import required libraries
import os

# Set PyTorch memory allocation config BEFORE importing torch
# This helps prevent OOM errors with large models like AttNHP
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

import yaml
import pandas as pd
import numpy as np
from datetime import datetime
from easy_tpp.config_factory import Config
from easy_tpp.runner import Runner
from google.colab import drive
import json
from IPython.display import display, clear_output
import time

# %%
# ==============================================================================
# FULLYNN GRADIENT FIX - Monkey Patch
# ==============================================================================
# FullyNN uses torch.autograd.grad() to compute intensity derivatives, but during
# validation/evaluation, EasyTPP runs under torch.no_grad() context which disables
# gradient tracking. This patch wraps the computation in torch.enable_grad().
# ==============================================================================

import torch
from easy_tpp.model.torch_model import torch_fullynn

def patched_compute_intensities_at_sample_times(self, time_seqs, time_delta_seqs, type_seqs, sample_dtimes, **kwargs):
    """Patched version that enables gradients during intensity computation.

    FullyNN requires gradient computation for intensity derivatives via autograd.grad().
    During validation, EasyTPP disables gradients with torch.no_grad(), causing failures.
    This patch wraps the computation in torch.enable_grad() to fix the issue.
    """
    compute_last_step_only = kwargs.get('compute_last_step_only', False)

    # Enable gradients for this computation even during evaluation
    with torch.enable_grad():
        # Forward pass to get hidden states
        hidden_states = self.forward(
            time_seqs=time_seqs,
            time_delta_seqs=time_delta_seqs,
            type_seqs=type_seqs,
        )

        num_samples = sample_dtimes.size()[-1]
        batch_size, seq_len, hidden_size = hidden_states.shape

        # Expand hidden states for all sample times
        hidden_states_ = hidden_states[..., None, :].expand(batch_size, seq_len, num_samples, hidden_size)

        # Clone sample_dtimes to avoid in-place modification issues
        sample_dtimes_grad = sample_dtimes.clone().detach().requires_grad_(True)

        # Compute intensities (this uses autograd.grad internally)
        _, derivative_integral_lambda = self.layer_intensity.forward(
            hidden_states=hidden_states_,
            time_delta_seqs=sample_dtimes_grad,
        )

    # Detach the result since we don't need gradients flowing back
    derivative_integral_lambda = derivative_integral_lambda.detach()

    if compute_last_step_only:
        return derivative_integral_lambda[:, -1:, :, :]
    return derivative_integral_lambda

# Apply the monkey patch
torch_fullynn.FullyNN.compute_intensities_at_sample_times = patched_compute_intensities_at_sample_times
print("✓ FullyNN patched for gradient computation during evaluation")
print("  This fixes the 'element 0 of tensors does not require grad' error")
# Out:
# ✓ FullyNN patched for gradient computation during evaluation
#   This fixes the 'element 0 of tensors does not require grad' error

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Base directory (your Drive location)
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
CHECKPOINT_DIR = os.path.join(BASE_DIR, 'checkpoints')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task3')

# Create results directory if it doesn't exist
os.makedirs(RESULTS_DIR, exist_ok=True)

print(f"✓ Base Directory: {BASE_DIR}")
print(f"✓ Dataset Directory: {DATASET_DIR}")
print(f"✓ Checkpoint Directory: {CHECKPOINT_DIR}")
print(f"✓ Results Directory: {RESULTS_DIR}")
# Out:
# Mounted at /content/drive
# ✓ Base Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025
# ✓ Dataset Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets
# ✓ Checkpoint Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints
# ✓ Results Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3

# %% [markdown]
# ## Configuration Dictionary

# %% [markdown]
# ### Data Configuration

# %%
# Data specifications for each dataset
data_spec_dict = {
    "stationary_hawkes": {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, "stationary_hawkes", "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, "stationary_hawkes", "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, "stationary_hawkes", "test.pkl"),
        "data_specs": {
            "num_event_types": 2,
            "pad_token_id": 2,
            "padding_side": "right",
            "max_seq_len": 20,
            "strict_pad_leng": True
        }
    }
}

print("✓ Data specifications loaded for Hawkes Stationary")
# Out:
# ✓ Data specifications loaded for Hawkes Stationary

# %% [markdown]
# ### Model Configuration

# %%
# ==============================================================================
# MODEL SPECIFICATIONS
# ==============================================================================

# Common thinning parameters
default_thinning = {
    "num_seq": 10,
    "num_sample": 1,
    "num_exp": 500,
    "look_ahead_time": 10,
    "patience_counter": 5,
    "over_sample_rate": 5,
    "num_samples_boundary": 5,
    "dtime_max": 5
}

# Memory-optimized thinning for OOM-prone models
memory_optimized_thinning = {
    "num_seq": 10,
    "num_sample": 1,
    "num_exp": 100,  # Reduced from 500
    "look_ahead_time": 10,
    "patience_counter": 5,
    "over_sample_rate": 5,
    "num_samples_boundary": 5,
    "dtime_max": 5
}

model_spec_dict = {
    # RMTPP: hidden=32, time_emb=16, layers=2
    "RMTPP": {
        "model_id": "RMTPP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "seed": 2019,
        "thinning": default_thinning.copy()
    },

    # NHP: hidden=64, time_emb=16, layers=2
    "NHP": {
        "model_id": "NHP",
        "hidden_size": 64,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "seed": 2019,
        "thinning": default_thinning.copy()
    },

    # FullyNN: hidden=32, time_emb=16, layers=2
    "FullyNN": {
        "model_id": "FullyNN",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "model_specs": {
            "num_mlp_layers": 3,
            "proper_marked_intensities": True
        },
        "thinning": default_thinning.copy()
    },

    # SAHP: hidden=32, time_emb=16, layers=2, heads=2
    "SAHP": {
        "model_id": "SAHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": default_thinning.copy()
    },

    # THP: hidden=64, time_emb=16, layers=2, heads=2
    "THP": {
        "model_id": "THP",
        "hidden_size": 64,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": default_thinning.copy()
    },

    # IntensityFree: hidden=32, time_emb=16, layers=2
    "IntensityFree": {
        "model_id": "IntensityFree",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_mix_components": 3,
        "model_specs": {
            "num_mix_components": 3
        },
        "thinning": {
            **default_thinning,
            "num_step_gen": 10
        }
    },

    # AttNHP: hidden=32, time_emb=16, layers=1, heads=2
    "AttNHP": {
        "model_id": "AttNHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 1,  # NOTE: Only 1 layer per paper
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": default_thinning.copy()
    }
}

print("✓ Model specifications loaded for 7 models:")
print("\n" + "="*70)
print(f"{'Model':<15} {'hidden_size':<12} {'time_emb':<10} {'layers':<8} {'heads':<8}")
print("-"*70)
for model_id, spec in model_spec_dict.items():
    h = spec.get('hidden_size', '-')
    t = spec.get('time_embed_size', '-')
    l = spec.get('num_layers', '-')
    heads = spec.get('num_heads', '-')
    print(f"{model_id:<15} {h:<12} {t:<10} {l:<8} {heads:<8}")
print("="*70)
# Out:
# ✓ Model specifications loaded for 7 models:
#
# ======================================================================
# Model           hidden_size  time_emb   layers   heads
# ----------------------------------------------------------------------
# RMTPP           32           16         2        -
# NHP             64           16         2        -
# FullyNN         32           16         2        -
# SAHP            32           16         2        2
# THP             64           16         2        2
# IntensityFree   32           16         2        -
# AttNHP          32           16         1        2
# ======================================================================

# %% [markdown]
# ### Training Configuration

# %%
# Trainer configuration (shared across all experiments)
trainer_config = {
    "batch_size": 256,
    "max_epoch": 200,
    "shuffle": False,
    "optimizer": "adam",
    "learning_rate": 1e-3,
    "valid_freq": 1,
    "use_tfb": False,
    "metrics": ["acc", "rmse"],
    "seed": 2019,
    "gpu": 0
}

print("✓ Trainer configuration loaded")
print(f"  - Batch size: {trainer_config['batch_size']}")
print(f"  - Max epochs: {trainer_config['max_epoch']}")
print(f"  - Learning rate: {trainer_config['learning_rate']}")
# Out:
# ✓ Trainer configuration loaded
#   - Batch size: 256
#   - Max epochs: 200
#   - Learning rate: 0.001

# %% [markdown]
# ## Helper Functions

# %%
def create_experiment_config(model_id, data_id, data_spec, model_spec, trainer_cfg):
    """Create a complete experiment configuration."""
    experiment_id = f"{model_id}_{data_id}_train"

    config = {
        "pipeline_config_id": "runner_config",
        "data": {
            data_id: data_spec
        },
        experiment_id: {
            "base_config": {
                "stage": "train",
                "backend": "torch",
                "dataset_id": data_id,
                "runner_id": "std_tpp",
                "model_id": model_id,
                "base_dir": CHECKPOINT_DIR
            },
            "trainer_config": trainer_cfg,
            "model_config": model_spec
        }
    }

    return config, experiment_id

def extract_results_from_logs(log_path):
    """Extract best results from training logs.

    Args:
        log_path: Can be either a log file or a directory containing log files
    """
    try:
        # Determine if log_path is a file or directory
        if os.path.isfile(log_path):
            # It's a file - read it directly
            log_file = log_path
        elif os.path.isdir(log_path):
            # It's a directory - find .log files inside
            log_files = [f for f in os.listdir(log_path) if f.endswith('.log')]
            if not log_files:
                return None
            log_file = os.path.join(log_path, log_files[0])
        else:
            print(f"  Warning: Log path does not exist: {log_path}")
            return None

        # Read the log file
        with open(log_file, 'r') as f:
            lines = f.readlines()

        # Find the LAST test metrics (final epoch results)
        best_ll = None
        best_acc = None
        best_rmse = None

        for line in lines:
            if 'test loglike is' in line:
                try:
                    parts = line.split(',')
                    # Extract log-likelihood
                    ll_part = [p for p in parts if 'test loglike is' in p][0]
                    best_ll = float(ll_part.split('test loglike is')[1].strip())

                    # Extract accuracy
                    acc_parts = [p for p in parts if 'acc is' in p]
                    if acc_parts:
                        best_acc = float(acc_parts[0].split('acc is')[1].strip())

                    # Extract RMSE
                    rmse_parts = [p for p in parts if 'rmse is' in p]
                    if rmse_parts:
                        best_rmse = float(rmse_parts[0].split('rmse is')[1].strip())
                except (IndexError, ValueError) as e:
                    print(f"  Warning: Could not parse line: {e}")
                    continue

        if best_ll is None:
            return None

        return {
            'log_likelihood': best_ll,
            'accuracy': best_acc,
            'rmse': best_rmse
        }
    except Exception as e:
        print(f"  Warning: Could not extract results from logs: {e}")
        return None
def find_latest_checkpoint_dir(base_dir, model_id, data_id):
    """Find the most recent checkpoint directory for an experiment."""
    try:
        # EasyTPP creates directories with random names but puts
        # {model_id}_{data_id}_train_output.yaml inside them
        target_yaml = f"{model_id}_{data_id}_train_output.yaml"

        matching_dirs = []
        for d in os.listdir(base_dir):
            dir_path = os.path.join(base_dir, d)
            if os.path.isdir(dir_path):
                # Check if the target yaml file exists in this directory
                yaml_path = os.path.join(dir_path, target_yaml)
                if os.path.exists(yaml_path):
                    matching_dirs.append(dir_path)

        if not matching_dirs:
            return None

        # Return the most recently modified directory
        latest = max(matching_dirs, key=os.path.getmtime)
        return latest
    except Exception as e:
        print(f"  Warning: Error finding checkpoint dir: {e}")
        return None
print("✓ Helper functions loaded")
# Out:
# ✓ Helper functions loaded

# %%
def run_model_on_all_datasets(
    model_id,
    model_number,
    total_models,
    aggressive_gpu_clearing=False
):
    """
    Run a single TPP model on all configured datasets.

    This function encapsulates the complete workflow for running a model:
    - Creates and saves experiment configs for each dataset
    - Runs training and evaluation
    - Extracts metrics from logs
    - Saves results (both intermediate and model-specific)
    - Handles errors gracefully
    - Manages GPU memory

    Parameters
    ----------
    model_id : str
        The model identifier (e.g., 'RMTPP', 'NHP', 'AttNHP')
        Must exist as a key in model_spec_dict
    model_number : int
        Current model number (1-7) for progress tracking
    total_models : int
        Total number of models (typically 7) for progress tracking
    aggressive_gpu_clearing : bool, default=False
        If True, performs GPU memory clearing after EACH dataset.
        Use this for memory-intensive models like AttNHP.
        If False, only clears GPU memory after all datasets complete.

    Returns
    -------
    model_results : list of dict
        List containing result dictionaries for each dataset.
        Each dict contains: model, dataset, log_likelihood, accuracy,
        rmse, status, and time_seconds

    Side Effects
    ------------
    - Appends results to the global results_list
    - Saves intermediate results to 'intermediate_results.csv' after each dataset
    - Saves model-specific results to '{model_id}_results.csv'
    - Creates experiment config files in the configs directory
    - Clears GPU memory (timing depends on aggressive_gpu_clearing flag)

    Notes
    -----
    This function relies on several global variables and functions:
    - data_spec_dict: Dictionary of dataset configurations
    - model_spec_dict: Dictionary of model configurations
    - trainer_config: Training configuration
    - results_list: Global list to store all results
    - total_experiments: Total number of experiments
    - BASE_DIR, CHECKPOINT_DIR, RESULTS_DIR: Directory paths
    - create_experiment_config(): Function to create config dicts
    - find_latest_checkpoint_dir(): Function to locate checkpoints
    - extract_results_from_logs(): Function to parse training logs

    Example
    -------
    >>> # Run RMTPP on all datasets (standard memory management)
    >>> rmtpp_results = run_model_on_all_datasets('RMTPP', 1, 7)

    >>> # Run AttNHP with aggressive memory clearing
    >>> attnhp_results = run_model_on_all_datasets('AttNHP', 7, 7,
    ...                                             aggressive_gpu_clearing=True)
    """
    import time
    import os
    import yaml
    import pandas as pd
    import torch
    import gc
    from easy_tpp.config_factory import Config
    from easy_tpp.runner import Runner

    print("\n" + "=" * 70)
    print(f"[MODEL {model_number}/{total_models}] Running {model_id} on all datasets")
    print("=" * 70)

    model_start_time = time.time()
    model_results = []

    for data_id, data_spec in data_spec_dict.items():
        experiment_name = f"{model_id}_{data_id}"
        experiment_num = len(results_list) + 1

        print(f"\n[{experiment_num}/{total_experiments}] Running {model_id} on {data_id} dataset")
        print("=" * 70)

        try:
            # Create config
            config_dict, experiment_id = create_experiment_config(
                model_id=model_id,
                data_id=data_id,
                data_spec=data_spec,
                model_spec=model_spec_dict[model_id],
                trainer_cfg=trainer_config
            )

            # Save config
            CONFIG_DIR = os.path.join(BASE_DIR, 'configs')
            os.makedirs(CONFIG_DIR, exist_ok=True)
            config_path = os.path.join(CONFIG_DIR, f"{experiment_name}.yaml")
            with open(config_path, 'w') as f:
                yaml.dump(config_dict, f)

            # Build and run
            config = Config.build_from_yaml_file(config_path, experiment_id=experiment_id)
            runner = Runner.build_from_config(config)
            runner.run()

            # Find checkpoint directory
            checkpoint_dir = find_latest_checkpoint_dir(CHECKPOINT_DIR, model_id, data_id)

            # Extract results from logs
            if checkpoint_dir:
                log_dir = os.path.join(checkpoint_dir, 'log')
                metrics = extract_results_from_logs(log_dir)

                if metrics:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': metrics['log_likelihood'],
                        'accuracy': metrics['accuracy'],
                        'rmse': metrics['rmse'],
                        'status': 'success',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"✓ {model_id} on {data_id} completed successfully!")
                    print(f"  - Log-Likelihood: {metrics['log_likelihood']:.4f}")
                    if metrics['accuracy'] and metrics['accuracy'] > 0:
                        print(f"  - Accuracy: {metrics['accuracy']:.4f}")
                    if metrics['rmse'] and metrics['rmse'] > 0:
                        print(f"  - RMSE: {metrics['rmse']:.4f}")
                else:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': None,
                        'accuracy': None,
                        'rmse': None,
                        'status': 'completed_no_metrics',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"⚠ {model_id} on {data_id} completed but no metrics found")
            else:
                result = {
                    'model': model_id,
                    'dataset': data_id,
                    'log_likelihood': None,
                    'accuracy': None,
                    'rmse': None,
                    'status': 'no_checkpoint',
                    'time_seconds': time.time() - model_start_time
                }
                print(f"⚠ {model_id} on {data_id} - no checkpoint directory found")

        except Exception as e:
            result = {
                'model': model_id,
                'dataset': data_id,
                'log_likelihood': None,
                'accuracy': None,
                'rmse': None,
                'status': 'failed',
                'error': str(e),
                'time_seconds': time.time() - model_start_time
            }
            print(f"✗ Error running {model_id} on {data_id}: {str(e)}")

        results_list.append(result)
        model_results.append(result)

        # Save intermediate results after each experiment
        intermediate_df = pd.DataFrame(results_list)
        intermediate_df.to_csv(os.path.join(RESULTS_DIR, 'intermediate_results.csv'), index=False)

        # Aggressive GPU memory clearing (for memory-intensive models like AttNHP)
        if aggressive_gpu_clearing:
            try:
                del runner
                del config
            except:
                pass
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
                torch.cuda.synchronize()

    # Save model-specific results
    model_df = pd.DataFrame(model_results)
    model_csv_path = os.path.join(RESULTS_DIR, f'{model_id}_results.csv')
    model_df.to_csv(model_csv_path, index=False)

    # Model summary
    model_elapsed = time.time() - model_start_time
    successful = sum(1 for r in model_results if r['status'] == 'success')
    failed = sum(1 for r in model_results if r['status'] == 'failed')

    print(f"\n" + "=" * 70)
    print(f"✓ {model_id} completed on all datasets")
    print(f"  - Time: {model_elapsed/60:.1f} minutes")
    print(f"  - Successful: {successful}/{len(data_spec_dict)}")
    print(f"  - Failed: {failed}/{len(data_spec_dict)}")
    print(f"  - Results saved to: {model_csv_path}")
    print("=" * 70)

    # Clear GPU memory for next model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        print(f"✓ GPU memory cleared for next model")

    return model_results

# %% [markdown]
# ## Run Models On Data

# %%
# Initialize results storage
results_list = []
total_experiments = len(model_spec_dict) * len(data_spec_dict)

print(f"Starting {total_experiments} experiments...")
print(f"Running {len(model_spec_dict)} models on {len(data_spec_dict)} datasets")
print(f"Results will be saved incrementally to: {RESULTS_DIR}")
print("=" * 70)
# Out:
# Starting 7 experiments...
# Running 7 models on 1 datasets
# Results will be saved incrementally to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3
# ======================================================================

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
all_model_results = {}

for i, model_id in enumerate(model_ids, start=1):
    aggressive = (model_id == 'AttNHP')
    all_model_results[model_id] = run_model_on_all_datasets(
        model_id, i, len(model_ids), aggressive
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# 2026-01-01 14:47:03,783 - base_runner.py[pid:1722;line:110:train] - INFO: End RMTPP train! Cost time: 0.184m
# ✓ RMTPP on stationary_hawkes completed successfully!
#   - Log-Likelihood: -1.1404
#   - Accuracy: 0.5456
#   - RMSE: 1.2044
#
# ======================================================================
# ✓ RMTPP completed on all datasets
#   - Time: 1.6 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/RMTPP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model
#
# ======================================================================
# [MODEL 2/7] Running NHP on all datasets
# ======================================================================
#
# [2/7] Running NHP on stationary_hawkes dataset
# ======================================================================
# 2026-01-01 14:48:15,736 - config.py[pid:1722;line:34:build_from_yaml_file] - CRITICAL: Load pipeline config class RunnerConfig
# 2026-01-01 14:48:15,743 - runner_config.py[pid:1722;line:140:update_config] - CRITICAL: train model NHP using GPU with torch backend
# 2026-01-01 14:48:15,755 - runner_config.py[pid:1722;line:35:__init__] - INFO: Save the config to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/1722_132216826630784_260101-144815/NHP_stationary_hawkes_train_output.yaml
# 2026-01-01 14:48:15,758 - base_runner.py[pid:1722;line:176:save_log] - INFO: Save the log to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/1722_132216826630784_260101-144815/log
# 0.6100027294188909 0.745759392243132
# min_dt: 0.00012170050202264804
# max_dt: 7.493633863438951
# 2026-01-01 14:48:15,782 - tpp_runner.py[pid:1722;line:60:_init_model] - INFO: Num of model parameters 58116
# 2026-01-01 14:48:15,799 - base_runner.py[pid:1722;line:98:train] - INFO: Data 'stationary_hawkes' loaded...
# 2026-01-01 14:48:15,800 - base_runner.py[pid:1722;line:103:train] - INFO: Start NHP training...
# 2026-01-01 14:48:16,063 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 0 (train) ]: train loglike is -1.227882302998569, num_events is 8997
# 2026-01-01 14:48:16,169 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 0 (valid) ]:  valid loglike is -1.1726754063821567, num_events is 3074, acc is 0.5432661027976577, rmse is 1.002266326424713
# 2026-01-01 14:48:16,294 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 0 (test) ]: test loglike is -1.1757955323054703, num_events is 3094, acc is 0.5633484162895928, rmse is 1.0231444874464637
# 2026-01-01 14:48:16,296 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1727 (updated at epoch-0), best updated at this epoch
# 2026-01-01 14:48:16,452 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 1 (train) ]: train loglike is -1.2031524749786386, num_events is 8997
# 2026-01-01 14:48:16,554 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 1 (valid) ]:  valid loglike is -1.1591881061422413, num_events is 3074, acc is 0.5374105400130124, rmse is 0.9716063162450933
# 2026-01-01 14:48:16,681 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 1 (test) ]: test loglike is -1.1594171998727376, num_events is 3094, acc is 0.5685197155785391, rmse is 0.9727713465155108
# 2026-01-01 14:48:16,682 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1592 (updated at epoch-1), best updated at this epoch
# 2026-01-01 14:48:16,842 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 2 (train) ]: train loglike is -1.1900614820825692, num_events is 8997
# 2026-01-01 14:48:16,944 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 2 (valid) ]:  valid loglike is -1.1526828783242518, num_events is 3074, acc is 0.5432661027976577, rmse is 0.9570634970415837
# 2026-01-01 14:48:17,072 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 2 (test) ]: test loglike is -1.150686608026624, num_events is 3094, acc is 0.5685197155785391, rmse is 0.9493693648049211
# 2026-01-01 14:48:17,073 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1527 (updated at epoch-2), best updated at this epoch
# 2026-01-01 14:48:17,231 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 3 (train) ]: train loglike is -1.1833509661640687, num_events is 8997
# 2026-01-01 14:48:17,338 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 3 (valid) ]:  valid loglike is -1.1487142032978204, num_events is 3074, acc is 0.549772283669486, rmse is 0.9489123857323892
# 2026-01-01 14:48:17,465 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 3 (test) ]: test loglike is -1.1452429980405623, num_events is 3094, acc is 0.5740142210730446, rmse is 0.9432438926191414
# 2026-01-01 14:48:17,466 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1487 (updated at epoch-3), best updated at this epoch
# 2026-01-01 14:48:17,624 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 4 (train) ]: train loglike is -1.178809603201067, num_events is 8997
# 2026-01-01 14:48:17,728 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 4 (valid) ]:  valid loglike is -1.1459242176063353, num_events is 3074, acc is 0.5527000650618087, rmse is 0.9512053329820092
# 2026-01-01 14:48:17,856 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 4 (test) ]: test loglike is -1.1415575319671138, num_events is 3094, acc is 0.5762766645119586, rmse is 0.968151408063946
# 2026-01-01 14:48:17,858 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1459 (updated at epoch-4), best updated at this epoch
# 2026-01-01 14:48:18,017 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 5 (train) ]: train loglike is -1.1753468468439132, num_events is 8997
# 2026-01-01 14:48:18,118 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 5 (valid) ]:  valid loglike is -1.1444423777295463, num_events is 3074, acc is 0.5481457384515289, rmse is 0.9720576897690639
# 2026-01-01 14:48:18,247 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 5 (test) ]: test loglike is -1.1395600608031675, num_events is 3094, acc is 0.5817711700064642, rmse is 0.9878921162161745
# 2026-01-01 14:48:18,249 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1444 (updated at epoch-5), best updated at this epoch
# 2026-01-01 14:48:18,408 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 6 (train) ]: train loglike is -1.1732002708585154, num_events is 8997
# 2026-01-01 14:48:18,509 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 6 (valid) ]:  valid loglike is -1.143957591010288, num_events is 3074, acc is 0.5504229017566689, rmse is 0.9839194957652827
# 2026-01-01 14:48:18,636 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 6 (test) ]: test loglike is -1.1387866068903523, num_events is 3094, acc is 0.577246283128636, rmse is 0.9717513983653755
# 2026-01-01 14:48:18,637 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1440 (updated at epoch-6), best updated at this epoch
# 2026-01-01 14:48:18,796 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 7 (train) ]: train loglike is -1.1720996571339752, num_events is 8997
# 2026-01-01 14:48:18,900 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 7 (valid) ]:  valid loglike is -1.143565488776838, num_events is 3074, acc is 0.5484710474951203, rmse is 0.9677603379596255
# 2026-01-01 14:48:19,048 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 7 (test) ]: test loglike is -1.138240407340821, num_events is 3094, acc is 0.581447963800905, rmse is 1.0079187322212415
# 2026-01-01 14:48:19,049 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1436 (updated at epoch-7), best updated at this epoch
# 2026-01-01 14:48:19,209 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 8 (train) ]: train loglike is -1.171211964317967, num_events is 8997
# 2026-01-01 14:48:19,312 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 8 (valid) ]:  valid loglike is -1.142377983693884, num_events is 3074, acc is 0.5507482108002603, rmse is 0.993264455709751
# 2026-01-01 14:48:19,441 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 8 (test) ]: test loglike is -1.136993033391241, num_events is 3094, acc is 0.579185520361991, rmse is 1.0141629696212102
# 2026-01-01 14:48:19,442 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1424 (updated at epoch-8), best updated at this epoch
# 2026-01-01 14:48:19,600 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 9 (train) ]: train loglike is -1.1697532939582291, num_events is 8997
# 2026-01-01 14:48:19,702 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 9 (valid) ]:  valid loglike is -1.139990901512687, num_events is 3074, acc is 0.5510735198438517, rmse is 0.9930801808987172
# 2026-01-01 14:48:19,830 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 9 (test) ]: test loglike is -1.1346231175763575, num_events is 3094, acc is 0.5833872010342599, rmse is 1.0215115327201716
# 2026-01-01 14:48:19,831 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1400 (updated at epoch-9), best updated at this epoch
# 2026-01-01 14:48:19,989 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 10 (train) ]: train loglike is -1.1673936613853924, num_events is 8997
# 2026-01-01 14:48:20,091 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 10 (valid) ]:  valid loglike is -1.1365669761761956, num_events is 3074, acc is 0.5527000650618087, rmse is 1.0125732327320274
# 2026-01-01 14:48:20,220 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 10 (test) ]: test loglike is -1.131282636251616, num_events is 3094, acc is 0.5795087265675501, rmse is 1.0224500459701462
# 2026-01-01 14:48:20,221 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1366 (updated at epoch-10), best updated at this epoch
# 2026-01-01 14:48:20,381 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 11 (train) ]: train loglike is -1.1642930320306422, num_events is 8997
# 2026-01-01 14:48:20,485 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 11 (valid) ]:  valid loglike is -1.1326278458187622, num_events is 3074, acc is 0.5507482108002603, rmse is 0.9679459497364528
# 2026-01-01 14:48:20,612 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 11 (test) ]: test loglike is -1.1274861469527715, num_events is 3094, acc is 0.5808015513897867, rmse is 1.0065095712461163
# 2026-01-01 14:48:20,613 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1326 (updated at epoch-11), best updated at this epoch
# 2026-01-01 14:48:20,771 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 12 (train) ]: train loglike is -1.1608879392089029, num_events is 8997
# 2026-01-01 14:48:20,873 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 12 (valid) ]:  valid loglike is -1.1287386713667047, num_events is 3074, acc is 0.5523747560182173, rmse is 0.9912304217161805
# 2026-01-01 14:48:21,002 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 12 (test) ]: test loglike is -1.1237893970689237, num_events is 3094, acc is 0.583710407239819, rmse is 0.9875542328809229
# 2026-01-01 14:48:21,003 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1287 (updated at epoch-12), best updated at this epoch
# 2026-01-01 14:48:21,161 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 13 (train) ]: train loglike is -1.157599679493859, num_events is 8997
# 2026-01-01 14:48:21,263 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 13 (valid) ]:  valid loglike is -1.1252619309633214, num_events is 3074, acc is 0.5523747560182173, rmse is 1.0234560727665978
# 2026-01-01 14:48:21,391 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 13 (test) ]: test loglike is -1.1205338204993536, num_events is 3094, acc is 0.5808015513897867, rmse is 0.9969818835376301
# 2026-01-01 14:48:21,392 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1253 (updated at epoch-13), best updated at this epoch
# 2026-01-01 14:48:21,551 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 14 (train) ]: train loglike is -1.1546335893431492, num_events is 8997
# 2026-01-01 14:48:21,653 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 14 (valid) ]:  valid loglike is -1.1223210450807173, num_events is 3074, acc is 0.5527000650618087, rmse is 1.015841886430998
# 2026-01-01 14:48:21,782 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 14 (test) ]: test loglike is -1.1178070837710083, num_events is 3094, acc is 0.5811247575953459, rmse is 1.0515187439469638
# 2026-01-01 14:48:21,784 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1223 (updated at epoch-14), best updated at this epoch
# 2026-01-01 14:48:21,940 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 15 (train) ]: train loglike is -1.1520018120189368, num_events is 8997
# 2026-01-01 14:48:22,042 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 15 (valid) ]:  valid loglike is -1.1199419844359955, num_events is 3074, acc is 0.5556278464541314, rmse is 0.9908942794249231
# 2026-01-01 14:48:22,169 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 15 (test) ]: test loglike is -1.1155962460104234, num_events is 3094, acc is 0.5862960568842922, rmse is 1.008029157691143
# 2026-01-01 14:48:22,170 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1199 (updated at epoch-15), best updated at this epoch
# 2026-01-01 14:48:22,336 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 16 (train) ]: train loglike is -1.1497084314563188, num_events is 8997
# 2026-01-01 14:48:22,438 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 16 (valid) ]:  valid loglike is -1.1181321351964053, num_events is 3074, acc is 0.5517241379310345, rmse is 1.008818805153771
# 2026-01-01 14:48:22,564 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 16 (test) ]: test loglike is -1.1138786606890352, num_events is 3094, acc is 0.5843568196509373, rmse is 1.0258480577867035
# 2026-01-01 14:48:22,566 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1181 (updated at epoch-16), best updated at this epoch
# 2026-01-01 14:48:22,724 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 17 (train) ]: train loglike is -1.1478268092402328, num_events is 8997
# 2026-01-01 14:48:22,826 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 17 (valid) ]:  valid loglike is -1.1167363878497072, num_events is 3074, acc is 0.549772283669486, rmse is 1.0277146963922508
# 2026-01-01 14:48:22,953 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 17 (test) ]: test loglike is -1.1124895683934632, num_events is 3094, acc is 0.5830639948287007, rmse is 1.0705667181676901
# 2026-01-01 14:48:22,954 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1167 (updated at epoch-17), best updated at this epoch
# 2026-01-01 14:48:23,110 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 18 (train) ]: train loglike is -1.1463342462895618, num_events is 8997
# 2026-01-01 14:48:23,214 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 18 (valid) ]:  valid loglike is -1.1153500121990891, num_events is 3074, acc is 0.5556278464541314, rmse is 1.0311711100407779
# 2026-01-01 14:48:23,343 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 18 (test) ]: test loglike is -1.1110495805894474, num_events is 3094, acc is 0.5817711700064642, rmse is 1.0494182297373813
# 2026-01-01 14:48:23,344 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1154 (updated at epoch-18), best updated at this epoch
# 2026-01-01 14:48:23,504 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 19 (train) ]: train loglike is -1.1449850145360954, num_events is 8997
# 2026-01-01 14:48:23,606 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 19 (valid) ]:  valid loglike is -1.1137098065427782, num_events is 3074, acc is 0.5484710474951203, rmse is 1.0805729239723014
# 2026-01-01 14:48:23,734 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 19 (test) ]: test loglike is -1.1093440681561086, num_events is 3094, acc is 0.5785391079508727, rmse is 1.0600167060360024
# 2026-01-01 14:48:23,735 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1137 (updated at epoch-19), best updated at this epoch
# 2026-01-01 14:48:23,893 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 20 (train) ]: train loglike is -1.143603613313813, num_events is 8997
# 2026-01-01 14:48:23,994 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 20 (valid) ]:  valid loglike is -1.1120463304885735, num_events is 3074, acc is 0.5559531554977228, rmse is 1.0392583986773727
# 2026-01-01 14:48:24,121 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 20 (test) ]: test loglike is -1.107636504120879, num_events is 3094, acc is 0.5769230769230769, rmse is 1.0547074575079303
# 2026-01-01 14:48:24,122 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1120 (updated at epoch-20), best updated at this epoch
# 2026-01-01 14:48:24,283 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 21 (train) ]: train loglike is -1.142342057269958, num_events is 8997
# 2026-01-01 14:48:24,386 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 21 (valid) ]:  valid loglike is -1.1107488271084092, num_events is 3074, acc is 0.559206245933637, rmse is 1.0448979526783932
# 2026-01-01 14:48:24,514 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 21 (test) ]: test loglike is -1.106320638231254, num_events is 3094, acc is 0.5788623141564319, rmse is 1.0783604473570212
# 2026-01-01 14:48:24,515 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1107 (updated at epoch-21), best updated at this epoch
# 2026-01-01 14:48:24,674 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 22 (train) ]: train loglike is -1.1413992109783122, num_events is 8997
# 2026-01-01 14:48:24,777 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 22 (valid) ]:  valid loglike is -1.1099476265147203, num_events is 3074, acc is 0.5523747560182173, rmse is 1.0779120055113551
# 2026-01-01 14:48:24,922 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 22 (test) ]: test loglike is -1.105533927813914, num_events is 3094, acc is 0.5801551389786684, rmse is 1.0146925356887972
# 2026-01-01 14:48:24,923 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1099 (updated at epoch-22), best updated at this epoch
# 2026-01-01 14:48:25,083 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 23 (train) ]: train loglike is -1.1407750608709848, num_events is 8997
# 2026-01-01 14:48:25,187 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 23 (valid) ]:  valid loglike is -1.1095315390929976, num_events is 3074, acc is 0.5549772283669486, rmse is 1.044984903355272
# 2026-01-01 14:48:25,314 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 23 (test) ]: test loglike is -1.1052048824337428, num_events is 3094, acc is 0.5862960568842922, rmse is 1.0965609686000612
# 2026-01-01 14:48:25,315 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1095 (updated at epoch-23), best updated at this epoch
# 2026-01-01 14:48:25,474 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 24 (train) ]: train loglike is -1.140392690575678, num_events is 8997
# 2026-01-01 14:48:25,577 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 24 (valid) ]:  valid loglike is -1.1092599981701365, num_events is 3074, acc is 0.5533506831489915, rmse is 1.055258416271593
# 2026-01-01 14:48:25,712 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 24 (test) ]: test loglike is -1.1051417562217194, num_events is 3094, acc is 0.5808015513897867, rmse is 1.0665258237191086
# 2026-01-01 14:48:25,713 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1093 (updated at epoch-24), best updated at this epoch
# 2026-01-01 14:48:25,876 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 25 (train) ]: train loglike is -1.1401512635288151, num_events is 8997
# 2026-01-01 14:48:25,981 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 25 (valid) ]:  valid loglike is -1.1088530441810345, num_events is 3074, acc is 0.5575797007156799, rmse is 1.0939564842066496
# 2026-01-01 14:48:26,109 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 25 (test) ]: test loglike is -1.1050660836750565, num_events is 3094, acc is 0.5765998707175177, rmse is 1.0911330017431253
# 2026-01-01 14:48:26,110 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1089 (updated at epoch-25), best updated at this epoch
# 2026-01-01 14:48:26,280 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 26 (train) ]: train loglike is -1.1398848986988719, num_events is 8997
# 2026-01-01 14:48:26,385 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 26 (valid) ]:  valid loglike is -1.1082106858937866, num_events is 3074, acc is 0.5533506831489915, rmse is 1.0503030581343744
# 2026-01-01 14:48:26,515 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 26 (test) ]: test loglike is -1.1048164984142697, num_events is 3094, acc is 0.5817711700064642, rmse is 1.0630507975874772
# 2026-01-01 14:48:26,516 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1082 (updated at epoch-26), best updated at this epoch
# 2026-01-01 14:48:26,675 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 27 (train) ]: train loglike is -1.1394985937152662, num_events is 8997
# 2026-01-01 14:48:26,777 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 27 (valid) ]:  valid loglike is -1.1074813614437622, num_events is 3074, acc is 0.5527000650618087, rmse is 1.0688366771695466
# 2026-01-01 14:48:26,905 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 27 (test) ]: test loglike is -1.1044580204377423, num_events is 3094, acc is 0.5759534583063994, rmse is 1.0790350833322817
# 2026-01-01 14:48:26,906 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1075 (updated at epoch-27), best updated at this epoch
# 2026-01-01 14:48:27,063 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 28 (train) ]: train loglike is -1.1390524543337361, num_events is 8997
# 2026-01-01 14:48:27,164 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 28 (valid) ]:  valid loglike is -1.1068754574658426, num_events is 3074, acc is 0.5540013012361744, rmse is 1.0668717995923054
# 2026-01-01 14:48:27,292 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 28 (test) ]: test loglike is -1.1041473605668228, num_events is 3094, acc is 0.5801551389786684, rmse is 1.0712394968712022
# 2026-01-01 14:48:27,294 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1069 (updated at epoch-28), best updated at this epoch
# 2026-01-01 14:48:27,455 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 29 (train) ]: train loglike is -1.1386574659000916, num_events is 8997
# 2026-01-01 14:48:27,558 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 29 (valid) ]:  valid loglike is -1.1064972539342062, num_events is 3074, acc is 0.5601821730644112, rmse is 1.057071759695062
# 2026-01-01 14:48:27,687 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 29 (test) ]: test loglike is -1.1039863098183984, num_events is 3094, acc is 0.5798319327731093, rmse is 1.026859695791932
# 2026-01-01 14:48:27,688 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1065 (updated at epoch-29), best updated at this epoch
# 2026-01-01 14:48:27,849 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 30 (train) ]: train loglike is -1.1383761899582847, num_events is 8997
# 2026-01-01 14:48:27,952 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 30 (valid) ]:  valid loglike is -1.1063239569778789, num_events is 3074, acc is 0.5549772283669486, rmse is 1.032169159143236
# 2026-01-01 14:48:28,082 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 30 (test) ]: test loglike is -1.103984731663098, num_events is 3094, acc is 0.5765998707175177, rmse is 1.032932914111256
# 2026-01-01 14:48:28,083 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1063 (updated at epoch-30), best updated at this epoch
# 2026-01-01 14:48:28,246 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 31 (train) ]: train loglike is -1.1382101732478533, num_events is 8997
# 2026-01-01 14:48:28,347 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 31 (valid) ]:  valid loglike is -1.1062650264821894, num_events is 3074, acc is 0.5572543916720885, rmse is 1.018684373990994
# 2026-01-01 14:48:28,476 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 31 (test) ]: test loglike is -1.1040842343547996, num_events is 3094, acc is 0.5853264382676148, rmse is 1.0424299804137436
# 2026-01-01 14:48:28,477 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1063 (updated at epoch-31), best updated at this epoch
# 2026-01-01 14:48:28,633 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 32 (train) ]: train loglike is -1.138122402563007, num_events is 8997
# 2026-01-01 14:48:28,736 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 32 (valid) ]:  valid loglike is -1.1062308753863044, num_events is 3074, acc is 0.5543266102797658, rmse is 1.0641977582647453
# 2026-01-01 14:48:28,865 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 32 (test) ]: test loglike is -1.1042007811237475, num_events is 3094, acc is 0.5833872010342599, rmse is 1.0623558178060568
# 2026-01-01 14:48:28,866 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1062 (updated at epoch-32), best updated at this epoch
# 2026-01-01 14:48:29,025 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 33 (train) ]: train loglike is -1.138062948066022, num_events is 8997
# 2026-01-01 14:48:29,128 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 33 (valid) ]:  valid loglike is -1.1061740892617518, num_events is 3074, acc is 0.5533506831489915, rmse is 1.0691057485989388
# 2026-01-01 14:48:29,255 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 33 (test) ]: test loglike is -1.104266669107547, num_events is 3094, acc is 0.5885585003232062, rmse is 1.010811532187911
# 2026-01-01 14:48:29,256 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1062 (updated at epoch-33), best updated at this epoch
# 2026-01-01 14:48:29,415 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 34 (train) ]: train loglike is -1.1379895593453027, num_events is 8997
# 2026-01-01 14:48:29,517 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 34 (valid) ]:  valid loglike is -1.1060926031585474, num_events is 3074, acc is 0.5536759921925829, rmse is 1.0451707831451038
# 2026-01-01 14:48:29,646 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 34 (test) ]: test loglike is -1.1042565689136232, num_events is 3094, acc is 0.5746606334841629, rmse is 1.0477695187327576
# 2026-01-01 14:48:29,647 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1061 (updated at epoch-34), best updated at this epoch
# 2026-01-01 14:48:29,807 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 35 (train) ]: train loglike is -1.1378817081822412, num_events is 8997
# 2026-01-01 14:48:29,911 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 35 (valid) ]:  valid loglike is -1.1060097668957385, num_events is 3074, acc is 0.5575797007156799, rmse is 1.0226173545856037
# 2026-01-01 14:48:30,039 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 35 (test) ]: test loglike is -1.1041924169006545, num_events is 3094, acc is 0.5827407886231416, rmse is 1.0736715823059209
# 2026-01-01 14:48:30,040 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1060 (updated at epoch-35), best updated at this epoch
# 2026-01-01 14:48:30,200 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 36 (train) ]: train loglike is -1.1377457714854604, num_events is 8997
# 2026-01-01 14:48:30,304 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 36 (valid) ]:  valid loglike is -1.1059484537654523, num_events is 3074, acc is 0.5510735198438517, rmse is 1.043751489311317
# 2026-01-01 14:48:30,447 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 36 (test) ]: test loglike is -1.104123530421784, num_events is 3094, acc is 0.5785391079508727, rmse is 1.0641150296402506
# 2026-01-01 14:48:30,449 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-36), best updated at this epoch
# 2026-01-01 14:48:30,609 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 37 (train) ]: train loglike is -1.1376050860269395, num_events is 8997
# 2026-01-01 14:48:30,714 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 37 (valid) ]:  valid loglike is -1.1059120788772772, num_events is 3074, acc is 0.5543266102797658, rmse is 1.0441003725206124
# 2026-01-01 14:48:30,842 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 37 (test) ]: test loglike is -1.104093466563308, num_events is 3094, acc is 0.5785391079508727, rmse is 1.0534510986657526
# 2026-01-01 14:48:30,844 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-37), best updated at this epoch
# 2026-01-01 14:48:31,003 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 38 (train) ]: train loglike is -1.1374806956051322, num_events is 8997
# 2026-01-01 14:48:31,106 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 38 (valid) ]:  valid loglike is -1.105889682112069, num_events is 3074, acc is 0.5575797007156799, rmse is 1.035701497665521
# 2026-01-01 14:48:31,233 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 38 (test) ]: test loglike is -1.1041173756161118, num_events is 3094, acc is 0.5788623141564319, rmse is 1.0630758278539663
# 2026-01-01 14:48:31,234 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-38), best updated at this epoch
# 2026-01-01 14:48:31,398 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 39 (train) ]: train loglike is -1.1373801303993691, num_events is 8997
# 2026-01-01 14:48:31,501 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 39 (valid) ]:  valid loglike is -1.1058761805160215, num_events is 3074, acc is 0.5601821730644112, rmse is 1.0934414804074577
# 2026-01-01 14:48:31,629 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 39 (test) ]: test loglike is -1.1041857886483921, num_events is 3094, acc is 0.5801551389786684, rmse is 1.0786704744045967
# 2026-01-01 14:48:31,630 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-39), best updated at this epoch
# 2026-01-01 14:48:31,788 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 40 (train) ]: train loglike is -1.1373016130159705, num_events is 8997
# 2026-01-01 14:48:31,890 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 40 (valid) ]:  valid loglike is -1.105875703989102, num_events is 3074, acc is 0.5523747560182173, rmse is 1.0071193177425453
# 2026-01-01 14:48:32,017 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 40 (test) ]: test loglike is -1.1042727450054541, num_events is 3094, acc is 0.5762766645119586, rmse is 1.080053859820899
# 2026-01-01 14:48:32,019 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40), best updated at this epoch
# 2026-01-01 14:48:32,178 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 41 (train) ]: train loglike is -1.1372365278443508, num_events is 8997
# 2026-01-01 14:48:32,281 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 41 (valid) ]:  valid loglike is -1.1058880936890045, num_events is 3074, acc is 0.5598568640208198, rmse is 1.060604675348672
# 2026-01-01 14:48:32,401 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 41 (test) ]: test loglike is -1.1043462081346962, num_events is 3094, acc is 0.5762766645119586, rmse is 1.0833895650159822
# 2026-01-01 14:48:32,403 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:32,565 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 42 (train) ]: train loglike is -1.1371687155267034, num_events is 8997
# 2026-01-01 14:48:32,667 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 42 (valid) ]:  valid loglike is -1.1059066782388582, num_events is 3074, acc is 0.5575797007156799, rmse is 1.0758235977776165
# 2026-01-01 14:48:32,789 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 42 (test) ]: test loglike is -1.1043878714346316, num_events is 3094, acc is 0.5801551389786684, rmse is 1.085676951387136
# 2026-01-01 14:48:32,790 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:32,949 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 43 (train) ]: train loglike is -1.1370867926027426, num_events is 8997
# 2026-01-01 14:48:33,053 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 43 (valid) ]:  valid loglike is -1.1059255804733246, num_events is 3074, acc is 0.5572543916720885, rmse is 1.010231661936813
# 2026-01-01 14:48:33,175 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 43 (test) ]: test loglike is -1.104405231142938, num_events is 3094, acc is 0.5759534583063994, rmse is 1.0915367202330235
# 2026-01-01 14:48:33,176 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:33,336 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 44 (train) ]: train loglike is -1.1369941781809214, num_events is 8997
# 2026-01-01 14:48:33,438 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 44 (valid) ]:  valid loglike is -1.1059432119693395, num_events is 3074, acc is 0.5556278464541314, rmse is 1.0820312144080066
# 2026-01-01 14:48:33,559 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 44 (test) ]: test loglike is -1.104421801773594, num_events is 3094, acc is 0.5785391079508727, rmse is 1.1120850469569374
# 2026-01-01 14:48:33,560 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:33,718 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 45 (train) ]: train loglike is -1.1369031376344199, num_events is 8997
# 2026-01-01 14:48:33,820 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 45 (valid) ]:  valid loglike is -1.1059646556807092, num_events is 3074, acc is 0.549772283669486, rmse is 1.039363110886719
# 2026-01-01 14:48:33,940 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 45 (test) ]: test loglike is -1.1044592040542178, num_events is 3094, acc is 0.5778926955397543, rmse is 1.1024742765144047
# 2026-01-01 14:48:33,941 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:34,101 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 46 (train) ]: train loglike is -1.1368243895968795, num_events is 8997
# 2026-01-01 14:48:34,203 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 46 (valid) ]:  valid loglike is -1.1059975360381424, num_events is 3074, acc is 0.5530253741054001, rmse is 1.059353841756023
# 2026-01-01 14:48:34,326 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 46 (test) ]: test loglike is -1.1045236716982465, num_events is 3094, acc is 0.5753070458952811, rmse is 1.0774800750996048
# 2026-01-01 14:48:34,327 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:34,488 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 47 (train) ]: train loglike is -1.1367605526712028, num_events is 8997
# 2026-01-01 14:48:34,591 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 47 (valid) ]:  valid loglike is -1.106042011883946, num_events is 3074, acc is 0.5572543916720885, rmse is 1.0524614733137003
# 2026-01-01 14:48:34,712 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 47 (test) ]: test loglike is -1.1046026583710407, num_events is 3094, acc is 0.5804783451842276, rmse is 1.0603949584468717
# 2026-01-01 14:48:34,714 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:34,873 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 48 (train) ]: train loglike is -1.1367037032092295, num_events is 8997
# 2026-01-01 14:48:34,976 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 48 (valid) ]:  valid loglike is -1.1060853758336044, num_events is 3074, acc is 0.556929082628497, rmse is 1.0222500704616135
# 2026-01-01 14:48:35,097 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 48 (test) ]: test loglike is -1.1046751746071024, num_events is 3094, acc is 0.5707821590174531, rmse is 1.0442238183809367
# 2026-01-01 14:48:35,098 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:35,258 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 49 (train) ]: train loglike is -1.1366407346285567, num_events is 8997
# 2026-01-01 14:48:35,361 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 49 (valid) ]:  valid loglike is -1.1061114259718607, num_events is 3074, acc is 0.5500975927130775, rmse is 1.0660412807632687
# 2026-01-01 14:48:35,481 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 49 (test) ]: test loglike is -1.1047271748242566, num_events is 3094, acc is 0.5769230769230769, rmse is 1.0855785978241537
# 2026-01-01 14:48:35,482 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:35,640 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 50 (train) ]: train loglike is -1.1365632348369596, num_events is 8997
# 2026-01-01 14:48:35,741 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 50 (valid) ]:  valid loglike is -1.1061157147141347, num_events is 3074, acc is 0.5523747560182173, rmse is 1.0641369502138454
# 2026-01-01 14:48:35,864 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 50 (test) ]: test loglike is -1.1047611051632191, num_events is 3094, acc is 0.5753070458952811, rmse is 1.0121754302245165
# 2026-01-01 14:48:35,866 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:36,024 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 51 (train) ]: train loglike is -1.1364725199198344, num_events is 8997
# 2026-01-01 14:48:36,125 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 51 (valid) ]:  valid loglike is -1.1061126967103123, num_events is 3074, acc is 0.564736499674691, rmse is 1.1062873268616822
# 2026-01-01 14:48:36,244 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 51 (test) ]: test loglike is -1.1047916424682853, num_events is 3094, acc is 0.5843568196509373, rmse is 1.0559289861497576
# 2026-01-01 14:48:36,246 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:36,406 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 52 (train) ]: train loglike is -1.1363779517217545, num_events is 8997
# 2026-01-01 14:48:36,513 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 52 (valid) ]:  valid loglike is -1.1061250864102148, num_events is 3074, acc is 0.5546519193233572, rmse is 1.0211514786096958
# 2026-01-01 14:48:36,634 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 52 (test) ]: test loglike is -1.1048337003070459, num_events is 3094, acc is 0.5730446024563671, rmse is 1.064689195648065
# 2026-01-01 14:48:36,636 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:36,795 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 53 (train) ]: train loglike is -1.13628962475339, num_events is 8997
# 2026-01-01 14:48:36,897 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 53 (valid) ]:  valid loglike is -1.1061643998810589, num_events is 3074, acc is 0.5513988288874431, rmse is 1.0605269611269619
# 2026-01-01 14:48:37,017 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 53 (test) ]: test loglike is -1.1048905928056318, num_events is 3094, acc is 0.5782159017453136, rmse is 1.0667155619493491
# 2026-01-01 14:48:37,018 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:37,178 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 54 (train) ]: train loglike is -1.1362107139011615, num_events is 8997
# 2026-01-01 14:48:37,281 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 54 (valid) ]:  valid loglike is -1.1062213448479181, num_events is 3074, acc is 0.5536759921925829, rmse is 1.075195671457556
# 2026-01-01 14:48:37,401 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 54 (test) ]: test loglike is -1.1049542713720104, num_events is 3094, acc is 0.5801551389786684, rmse is 1.0857551808208987
# 2026-01-01 14:48:37,402 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:37,561 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 55 (train) ]: train loglike is -1.1361379628713044, num_events is 8997
# 2026-01-01 14:48:37,663 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 55 (valid) ]:  valid loglike is -1.1062755100744144, num_events is 3074, acc is 0.5536759921925829, rmse is 1.0355948374961081
# 2026-01-01 14:48:37,785 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 55 (test) ]: test loglike is -1.1050124263948369, num_events is 3094, acc is 0.574983839689722, rmse is 1.0366272796878104
# 2026-01-01 14:48:37,787 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:37,951 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 56 (train) ]: train loglike is -1.136065306816682, num_events is 8997
# 2026-01-01 14:48:38,053 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 56 (valid) ]:  valid loglike is -1.1063128380164282, num_events is 3074, acc is 0.5543266102797658, rmse is 1.036206259025509
# 2026-01-01 14:48:38,173 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 56 (test) ]: test loglike is -1.1050597710538543, num_events is 3094, acc is 0.5804783451842276, rmse is 1.0628565162830839
# 2026-01-01 14:48:38,174 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:38,335 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 57 (train) ]: train loglike is -1.1359886753700887, num_events is 8997
# 2026-01-01 14:48:38,437 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 57 (valid) ]:  valid loglike is -1.106338411627765, num_events is 3074, acc is 0.549772283669486, rmse is 1.0400890813733996
# 2026-01-01 14:48:38,558 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 57 (test) ]: test loglike is -1.1051030125090902, num_events is 3094, acc is 0.5785391079508727, rmse is 1.0738613789142468
# 2026-01-01 14:48:38,559 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:38,721 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 58 (train) ]: train loglike is -1.1359087197902773, num_events is 8997
# 2026-01-01 14:48:38,826 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 58 (valid) ]:  valid loglike is -1.1063691476140616, num_events is 3074, acc is 0.5530253741054001, rmse is 1.0700157829034191
# 2026-01-01 14:48:38,947 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 58 (test) ]: test loglike is -1.1051534345709437, num_events is 3094, acc is 0.577246283128636, rmse is 1.026691588588548
# 2026-01-01 14:48:38,949 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:39,109 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 59 (train) ]: train loglike is -1.135830188838988, num_events is 8997
# 2026-01-01 14:48:39,212 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 59 (valid) ]:  valid loglike is -1.1064173562540665, num_events is 3074, acc is 0.5504229017566689, rmse is 1.0953007436623907
# 2026-01-01 14:48:39,334 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 59 (test) ]: test loglike is -1.105216876414027, num_events is 3094, acc is 0.5775694893341952, rmse is 1.0911492195962122
# 2026-01-01 14:48:39,335 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# 2026-01-01 14:48:39,507 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 60 (train) ]: train loglike is -1.1357576277596004, num_events is 8997
# 2026-01-01 14:48:39,613 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 60 (valid) ]:  valid loglike is -1.1064812108612556, num_events is 3074, acc is 0.5494469746258946, rmse is 1.068855907548019
# 2026-01-01 14:48:39,733 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 60 (test) ]: test loglike is -1.1052901028199742, num_events is 3094, acc is 0.577246283128636, rmse is 1.0552971448368909
# 2026-01-01 14:48:39,734 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1059 (updated at epoch-40)
# ...
# 2026-01-01 14:53:12,409 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 180 (train) ]: train loglike is -1.1491936385479187, num_events is 8997
# 2026-01-01 14:53:12,711 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 180 (valid) ]:  valid loglike is -1.1318191002155173, num_events is 3074, acc is 0.5400130123617437, rmse is 0.8824996842315064
# 2026-01-01 14:53:13,136 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 180 (test) ]: test loglike is -1.1291874772745636, num_events is 3094, acc is 0.5481577246283129, rmse is 0.8706168950175093
# 2026-01-01 14:53:13,138 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1318 (updated at epoch-180), best updated at this epoch
# 2026-01-01 14:53:13,226 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 181 (train) ]: train loglike is -1.149097252252487, num_events is 8997
# 2026-01-01 14:53:13,527 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 181 (valid) ]:  valid loglike is -1.1317762922139314, num_events is 3074, acc is 0.5383864671437866, rmse is 0.8632799540182243
# 2026-01-01 14:53:13,951 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 181 (test) ]: test loglike is -1.1291398169844862, num_events is 3094, acc is 0.5471881060116355, rmse is 0.874027420655645
# 2026-01-01 14:53:13,953 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1318 (updated at epoch-181), best updated at this epoch
# 2026-01-01 14:53:14,036 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 182 (train) ]: train loglike is -1.1490012729937757, num_events is 8997
# 2026-01-01 14:53:14,340 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 182 (valid) ]:  valid loglike is -1.1317338813181115, num_events is 3074, acc is 0.5400130123617437, rmse is 0.8630222352734148
# 2026-01-01 14:53:14,765 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 182 (test) ]: test loglike is -1.1290929457720589, num_events is 3094, acc is 0.5468648998060762, rmse is 0.882022730606774
# 2026-01-01 14:53:14,767 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1317 (updated at epoch-182), best updated at this epoch
# 2026-01-01 14:53:14,852 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 183 (train) ]: train loglike is -1.1489059449938175, num_events is 8997
# 2026-01-01 14:53:15,143 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 183 (valid) ]:  valid loglike is -1.1316918675280578, num_events is 3074, acc is 0.5403383214053351, rmse is 0.8733603810417662
# 2026-01-01 14:53:15,563 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 183 (test) ]: test loglike is -1.129046863637282, num_events is 3094, acc is 0.5497737556561086, rmse is 0.8743190794928131
# 2026-01-01 14:53:15,565 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1317 (updated at epoch-183), best updated at this epoch
# 2026-01-01 14:53:15,652 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 184 (train) ]: train loglike is -1.148811268252612, num_events is 8997
# 2026-01-01 14:53:15,945 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 184 (valid) ]:  valid loglike is -1.1316502508437702, num_events is 3074, acc is 0.5406636304489265, rmse is 0.8839561592017879
# 2026-01-01 14:53:16,363 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 184 (test) ]: test loglike is -1.1290017283956852, num_events is 3094, acc is 0.5517129928894635, rmse is 0.8733238069504593
# 2026-01-01 14:53:16,364 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1317 (updated at epoch-184), best updated at this epoch
# 2026-01-01 14:53:16,450 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 185 (train) ]: train loglike is -1.1487170121160177, num_events is 8997
# 2026-01-01 14:53:16,750 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 185 (valid) ]:  valid loglike is -1.1316091901075553, num_events is 3074, acc is 0.5380611581001952, rmse is 0.8531009046873956
# 2026-01-01 14:53:17,173 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 185 (test) ]: test loglike is -1.128957303323974, num_events is 3094, acc is 0.5475113122171946, rmse is 0.8713642687685639
# 2026-01-01 14:53:17,174 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1316 (updated at epoch-185), best updated at this epoch
# 2026-01-01 14:53:17,257 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 186 (train) ]: train loglike is -1.1486233801023953, num_events is 8997
# 2026-01-01 14:53:17,558 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 186 (valid) ]:  valid loglike is -1.131568447055953, num_events is 3074, acc is 0.544242029928432, rmse is 0.874426545528185
# 2026-01-01 14:53:17,984 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 186 (test) ]: test loglike is -1.1289137462376777, num_events is 3094, acc is 0.5439560439560439, rmse is 0.8927851930046315
# 2026-01-01 14:53:17,985 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1316 (updated at epoch-186), best updated at this epoch
# 2026-01-01 14:53:18,072 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 187 (train) ]: train loglike is -1.148530250100728, num_events is 8997
# 2026-01-01 14:53:18,371 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 187 (valid) ]:  valid loglike is -1.131528101110117, num_events is 3074, acc is 0.5400130123617437, rmse is 0.8619999698204659
# 2026-01-01 14:53:18,792 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 187 (test) ]: test loglike is -1.1288707415057369, num_events is 3094, acc is 0.5449256625727213, rmse is 0.8980656400731712
# 2026-01-01 14:53:18,794 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1315 (updated at epoch-187), best updated at this epoch
# 2026-01-01 14:53:18,881 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 188 (train) ]: train loglike is -1.1484377306541416, num_events is 8997
# 2026-01-01 14:53:19,182 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 188 (valid) ]:  valid loglike is -1.131488152270047, num_events is 3074, acc is 0.5361093038386467, rmse is 0.8729878120627323
# 2026-01-01 14:53:19,606 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 188 (test) ]: test loglike is -1.1288287625747415, num_events is 3094, acc is 0.5500969618616678, rmse is 0.897475341075614
# 2026-01-01 14:53:19,607 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1315 (updated at epoch-188), best updated at this epoch
# 2026-01-01 14:53:19,698 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 189 (train) ]: train loglike is -1.1483457267874013, num_events is 8997
# 2026-01-01 14:53:20,008 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 189 (valid) ]:  valid loglike is -1.1314486799568966, num_events is 3074, acc is 0.5400130123617437, rmse is 0.8676780696152455
# 2026-01-01 14:53:20,438 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 189 (test) ]: test loglike is -1.128787335998101, num_events is 3094, acc is 0.5462184873949579, rmse is 0.8878838073824052
# 2026-01-01 14:53:20,439 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1314 (updated at epoch-189), best updated at this epoch
# 2026-01-01 14:53:20,527 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 190 (train) ]: train loglike is -1.148254197796835, num_events is 8997
# 2026-01-01 14:53:20,825 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 190 (valid) ]:  valid loglike is -1.131409525328359, num_events is 3074, acc is 0.5377358490566038, rmse is 0.8588391640681734
# 2026-01-01 14:53:21,247 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 190 (test) ]: test loglike is -1.1287466984991112, num_events is 3094, acc is 0.5442792501616031, rmse is 0.8869901458585525
# 2026-01-01 14:53:21,249 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1314 (updated at epoch-190), best updated at this epoch
# 2026-01-01 14:53:21,335 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 191 (train) ]: train loglike is -1.1481633743365844, num_events is 8997
# 2026-01-01 14:53:21,624 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 191 (valid) ]:  valid loglike is -1.1313709266478935, num_events is 3074, acc is 0.5474951203643461, rmse is 0.8743451595734191
# 2026-01-01 14:53:22,048 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 191 (test) ]: test loglike is -1.1287068500777715, num_events is 3094, acc is 0.5475113122171946, rmse is 0.8807843430340347
# 2026-01-01 14:53:22,050 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1314 (updated at epoch-191), best updated at this epoch
# 2026-01-01 14:53:22,137 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 192 (train) ]: train loglike is -1.148073012184617, num_events is 8997
# 2026-01-01 14:53:22,438 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 192 (valid) ]:  valid loglike is -1.1313325662308882, num_events is 3074, acc is 0.5461938841899805, rmse is 0.863278616420848
# 2026-01-01 14:53:22,861 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 192 (test) ]: test loglike is -1.128667632918552, num_events is 3094, acc is 0.5478345184227538, rmse is 0.8778283093934021
# 2026-01-01 14:53:22,863 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1313 (updated at epoch-192), best updated at this epoch
# 2026-01-01 14:53:22,944 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 193 (train) ]: train loglike is -1.147983152044605, num_events is 8997
# 2026-01-01 14:53:23,234 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 193 (valid) ]:  valid loglike is -1.1312946823408019, num_events is 3074, acc is 0.5400130123617437, rmse is 0.8772121965596219
# 2026-01-01 14:53:23,656 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 193 (test) ]: test loglike is -1.1286291259292178, num_events is 3094, acc is 0.5520361990950227, rmse is 0.8821018235717833
# 2026-01-01 14:53:23,657 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1313 (updated at epoch-193), best updated at this epoch
# 2026-01-01 14:53:23,745 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 194 (train) ]: train loglike is -1.1478938481881114, num_events is 8997
# 2026-01-01 14:53:24,044 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 194 (valid) ]:  valid loglike is -1.1312571955564819, num_events is 3074, acc is 0.544242029928432, rmse is 0.8668105302590274
# 2026-01-01 14:53:24,463 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 194 (test) ]: test loglike is -1.128591329109769, num_events is 3094, acc is 0.5494505494505495, rmse is 0.8822435297356407
# 2026-01-01 14:53:24,465 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1313 (updated at epoch-194), best updated at this epoch
# 2026-01-01 14:53:24,548 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 195 (train) ]: train loglike is -1.1478052227261517, num_events is 8997
# 2026-01-01 14:53:24,847 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 195 (valid) ]:  valid loglike is -1.1312200264567747, num_events is 3074, acc is 0.538711776187378, rmse is 0.8604770450510942
# 2026-01-01 14:53:25,266 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 195 (test) ]: test loglike is -1.1285542424602053, num_events is 3094, acc is 0.5465416936005171, rmse is 0.8906993554281065
# 2026-01-01 14:53:25,269 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1312 (updated at epoch-195), best updated at this epoch
# 2026-01-01 14:53:25,353 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 196 (train) ]: train loglike is -1.1477171535477104, num_events is 8997
# 2026-01-01 14:53:25,652 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 196 (valid) ]:  valid loglike is -1.1311832544628335, num_events is 3074, acc is 0.5400130123617437, rmse is 0.8692016921119329
# 2026-01-01 14:53:26,075 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 196 (test) ]: test loglike is -1.1285178659805268, num_events is 3094, acc is 0.5436328377504848, rmse is 0.8677605334697471
# 2026-01-01 14:53:26,077 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1312 (updated at epoch-196), best updated at this epoch
# 2026-01-01 14:53:26,162 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 197 (train) ]: train loglike is -1.1476295456775523, num_events is 8997
# 2026-01-01 14:53:26,459 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 197 (valid) ]:  valid loglike is -1.131146720732352, num_events is 3074, acc is 0.538711776187378, rmse is 0.8787809092198173
# 2026-01-01 14:53:26,880 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 197 (test) ]: test loglike is -1.1284819629474385, num_events is 3094, acc is 0.5481577246283129, rmse is 0.8831399111703615
# 2026-01-01 14:53:26,881 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1311 (updated at epoch-197), best updated at this epoch
# 2026-01-01 14:53:26,967 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 198 (train) ]: train loglike is -1.1475427111771632, num_events is 8997
# 2026-01-01 14:53:27,260 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 198 (valid) ]:  valid loglike is -1.1311105046864833, num_events is 3074, acc is 0.5448926480156149, rmse is 0.862304157636224
# 2026-01-01 14:53:27,681 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 198 (test) ]: test loglike is -1.1284468489920005, num_events is 3094, acc is 0.5488041370394312, rmse is 0.8916013917428687
# 2026-01-01 14:53:27,683 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1311 (updated at epoch-198), best updated at this epoch
# 2026-01-01 14:53:27,771 - tpp_runner.py[pid:1722;line:96:_train_model] - INFO: [ Epoch 199 (train) ]: train loglike is -1.1474564193924017, num_events is 8997
# 2026-01-01 14:53:28,071 - tpp_runner.py[pid:1722;line:107:_train_model] - INFO: [ Epoch 199 (valid) ]:  valid loglike is -1.131074685746381, num_events is 3074, acc is 0.5432661027976577, rmse is 0.8770619088373638
# 2026-01-01 14:53:28,486 - tpp_runner.py[pid:1722;line:122:_train_model] - INFO: [ Epoch 199 (test) ]: test loglike is -1.128412287390918, num_events is 3094, acc is 0.5497737556561086, rmse is 0.8968867835137205
# 2026-01-01 14:53:28,488 - tpp_runner.py[pid:1722;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1311 (updated at epoch-199), best updated at this epoch
# 2026-01-01 14:53:28,489 - base_runner.py[pid:1722;line:110:train] - INFO: End AttNHP train! Cost time: 2.668m
# ✓ AttNHP on stationary_hawkes completed successfully!
#   - Log-Likelihood: -1.1284
#   - Accuracy: 0.5498
#   - RMSE: 0.8969
#
# ======================================================================
# ✓ AttNHP completed on all datasets
#   - Time: 2.7 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/AttNHP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model

# %% [markdown]
# ## Save Model Results

# %% [markdown]
# ### Function Definition

# %%
import pandas as pd
from typing import Optional, List

def format_results_table(
    results_df: pd.DataFrame,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    log_likelihood_col: str = 'log_likelihood',
    rmse_col: str = 'rmse',
    accuracy_col: str = 'accuracy',
    type_error_from_accuracy: bool = True,
    format_type: str = 'combined'
) -> pd.DataFrame:
    """
    Format results into EasyTPP paper style with mean/std for metrics.
    NOW HANDLES PARTIAL NaN VALUES - shows available metrics even when others are NaN.

    Parameters
    ----------
    results_df : pd.DataFrame
        DataFrame containing columns: 'model', 'dataset', 'log_likelihood', 'rmse', 'accuracy'
    models : List[str], optional
        List of model names to include. If None, uses all models in results_df
    datasets : List[str], optional
        List of dataset names to include. If None, uses all datasets in results_df
    log_likelihood_col : str, default='log_likelihood'
        Column name for log-likelihood values
    rmse_col : str, default='rmse'
        Column name for RMSE values
    accuracy_col : str, default='accuracy'
        Column name for accuracy values
    type_error_from_accuracy : bool, default=True
        If True, compute Type Error Rate as (1 - accuracy) * 100
    format_type : str, default='combined'
        Output format type:
        - 'combined': "log_like/rmse/type_error% ± std_log/std_rmse/std_type"
        - 'log_likelihood': "log_like ± std_log"
        - 'rmse': "rmse ± std_rmse"
        - 'type_error': "type_error% ± std_type"

    Returns
    -------
    pd.DataFrame
        Formatted table with rows as models and columns as datasets
    """
    # Filter models and datasets if specified
    if models is not None:
        results_df = results_df[results_df['model'].isin(models)].copy()
    if datasets is not None:
        results_df = results_df[results_df['dataset'].isin(datasets)].copy()

    # Compute type error rate if needed
    if type_error_from_accuracy:
        results_df['type_error_rate'] = (1 - results_df[accuracy_col]) * 100

    # Get unique models and datasets (sorted)
    all_models = sorted(results_df['model'].unique())
    all_datasets = sorted(results_df['dataset'].unique())

    # Compute mean and std for each model-dataset combination
    agg_dict = {
        log_likelihood_col: ['mean', 'std'],
        rmse_col: ['mean', 'std'],
        'type_error_rate': ['mean', 'std']
    }

    grouped = results_df.groupby(['model', 'dataset']).agg(agg_dict).reset_index()

    # Flatten column names
    grouped.columns = ['model', 'dataset',
                       'log_like_mean', 'log_like_std',
                       'rmse_mean', 'rmse_std',
                       'type_error_mean', 'type_error_std']

    # Fill NaN std with 0 (for single runs)
    grouped['log_like_std'] = grouped['log_like_std'].fillna(0)
    grouped['rmse_std'] = grouped['rmse_std'].fillna(0)
    grouped['type_error_std'] = grouped['type_error_std'].fillna(0)

    # Create formatted strings based on format_type
    def format_cell(row):
        """Format a single cell based on format_type - HANDLES PARTIAL NaN VALUES"""
        log_like_mean = row['log_like_mean']
        log_like_std = row['log_like_std']
        rmse_mean = row['rmse_mean']
        rmse_std = row['rmse_std']
        type_mean = row['type_error_mean']
        type_std = row['type_error_std']

        if format_type == 'log_likelihood':
            # Log-likelihood only format
            if pd.isna(log_like_mean):
                return 'NaN'
            if log_like_std == 0:
                return f"{log_like_mean:.3f}"
            return f"{log_like_mean:.3f} ± {log_like_std:.3f}"

        elif format_type == 'rmse':
            # RMSE only format
            if pd.isna(rmse_mean):
                return 'NaN'
            if rmse_std == 0:
                return f"{rmse_mean:.3f}"
            return f"{rmse_mean:.3f} ± {rmse_std:.3f}"

        elif format_type == 'type_error':
            # Type Error only format
            if pd.isna(type_mean):
                return 'NaN'
            if type_std == 0:
                return f"{type_mean:.1f}%"
            return f"{type_mean:.1f}% ± {type_std:.3f}"

        else:  # format_type == 'combined' (default)
            # FIXED: Show available metrics even when some are NaN
            # Build mean string
            log_str = f"{log_like_mean:.3f}" if not pd.isna(log_like_mean) else "NaN"
            rmse_str = f"{rmse_mean:.3f}" if not pd.isna(rmse_mean) else "NaN"
            type_str = f"{type_mean:.1f}%" if not pd.isna(type_mean) else "NaN%"
            mean_str = f"{log_str}/{rmse_str}/{type_str}"

            # Build std string (only if at least one mean is not NaN)
            if not pd.isna(log_like_mean) or not pd.isna(rmse_mean) or not pd.isna(type_mean):
                log_std_str = f"{log_like_std:.3f}" if not pd.isna(log_like_mean) else "nan"
                rmse_std_str = f"{rmse_std:.3f}" if not pd.isna(rmse_mean) else "nan"
                type_std_str = f"{type_std:.3f}" if not pd.isna(type_mean) else "nan"
                std_str = f"{log_std_str}/{rmse_std_str}/{type_std_str}"
                return f"{mean_str} ± {std_str}"
            else:
                # All NaN case (shouldn't happen often)
                return 'NaN/NaN/NaN%'

    grouped['formatted'] = grouped.apply(format_cell, axis=1)

    # Pivot to create the final table
    formatted_table = grouped.pivot(index='model', columns='dataset', values='formatted')

    # Ensure all models and datasets are present (fill missing with N/A)
    formatted_table = formatted_table.reindex(index=all_models, columns=all_datasets, fill_value='N/A')

    return formatted_table


def save_results_easytpp_format(
    results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    save_csv: bool = True,
    save_latex: bool = True,
    save_markdown: bool = True,
    save_individual_metrics: bool = True,
    **format_kwargs
) -> dict:
    """
    Save formatted results in multiple formats (CSV, LaTeX, Markdown).

    Parameters
    ----------
    results_df : pd.DataFrame
        Results DataFrame with columns: model, dataset, log_likelihood, rmse, accuracy
    output_path : str
        Base path for output files (without extension)
    models : List[str], optional
        List of models to include
    datasets : List[str], optional
        List of datasets to include
    save_csv : bool, default=True
        Save as CSV
    save_latex : bool, default=True
        Save as LaTeX table
    save_markdown : bool, default=True
        Save as Markdown table
    save_individual_metrics : bool, default=True
        Save separate tables for each metric (log-likelihood, RMSE, Type Error)
    **format_kwargs
        Additional keyword arguments passed to format_results_table

    Returns
    -------
    dict
        Dictionary containing all generated tables
    """
    output_tables = {}

    # Generate combined table (with log-likelihood/RMSE/Type Error)
    combined_table = format_results_table(
        results_df,
        models=models,
        datasets=datasets,
        format_type='combined',
        **format_kwargs
    )
    output_tables['combined'] = combined_table

    # Save combined table
    if save_csv:
        combined_table.to_csv(f"{output_path}.csv")
        print(f"✓ Results saved to: {output_path}.csv")

    if save_latex:
        with open(f"{output_path}.tex", 'w') as f:
            f.write(combined_table.to_latex())
        print(f"✓ LaTeX table saved to: {output_path}.tex")

    if save_markdown:
        with open(f"{output_path}.md", 'w') as f:
            f.write(combined_table.to_markdown())
        print(f"✓ Markdown table saved to: {output_path}.md")

    return output_tables


def create_comparison_table(
    stationary_results_df: pd.DataFrame,
    nonstationary_results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None
) -> pd.DataFrame:
    """
    Create a side-by-side comparison table for stationary vs non-stationary results.

    Parameters
    ----------
    stationary_results_df : pd.DataFrame
        Results from stationary Hawkes data
    nonstationary_results_df : pd.DataFrame
        Results from non-stationary Hawkes data
    output_path : str
        Base path for output files
    models : List[str], optional
        List of models to include

    Returns
    -------
    pd.DataFrame
        Comparison table with degradation analysis
    """
    # Format both tables
    stat_table = format_results_table(stationary_results_df, models=models)
    nonstat_table = format_results_table(nonstationary_results_df, models=models)

    # Compute degradation statistics
    stat_grouped = stationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'stat_log_like',
        'rmse': 'stat_rmse',
        'accuracy': 'stat_type_error'
    })

    nonstat_grouped = nonstationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'nonstat_log_like',
        'rmse': 'nonstat_rmse',
        'accuracy': 'nonstat_type_error'
    })

    degradation = stat_grouped.join(nonstat_grouped)

    # Calculate degradation percentages
    degradation['log_like_degradation_%'] = (
        (degradation['nonstat_log_like'] - degradation['stat_log_like']) /
        abs(degradation['stat_log_like']) * 100
    )
    degradation['rmse_degradation_%'] = (
        (degradation['nonstat_rmse'] - degradation['stat_rmse']) /
        degradation['stat_rmse'] * 100
    )
    degradation['type_error_degradation_%'] = (
        degradation['nonstat_type_error'] - degradation['stat_type_error']
    )

    # Save comparison
    degradation.to_csv(f"{output_path}_degradation.csv")
    print(f"✓ Degradation analysis saved to: {output_path}_degradation.csv")

    return degradation

# %% [markdown]
# ### Function Execution

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
data_ids = ['stationary_hawkes']

# %%
import pandas as pd

def flatten_model_results(all_model_results):
    """
    Properly convert all_model_results dictionary to DataFrame.

    The issue: pd.DataFrame(dict) treats keys as COLUMN names, not data rows.
    This function flattens it correctly.
    """
    all_results = []
    for model_name, results_list in all_model_results.items():
        all_results.extend(results_list)
    return pd.DataFrame(all_results)

results_df = flatten_model_results(all_model_results)
results_df = results_df[
    results_df['status'] == 'success'
]

# Check the structure
print("✓ DataFrame created successfully!")
print(f"  Shape: {results_df.shape}")
print(f"  Columns: {list(results_df.columns)}")
print(f"\nFirst few rows:")
print(results_df.head())

formatted_table = format_results_table(
    results_df,
    models=model_ids,
    datasets=data_ids
)

print("\n✓ Formatted table:")
print(formatted_table)

# Save to files
saved_table = save_results_easytpp_format(
    results_df,
    output_path=f'{RESULTS_DIR}/Task3_results',
    models=model_ids,
    datasets=data_ids
)
# Out:
# ✓ DataFrame created successfully!
#   Shape: (7, 7)
#   Columns: ['model', 'dataset', 'log_likelihood', 'accuracy', 'rmse', 'status', 'time_seconds']
#
# First few rows:
#      model            dataset  log_likelihood  accuracy      rmse   status  \
# 0    RMTPP  stationary_hawkes       -1.140369  0.545572  1.204448  success
# 1      NHP  stationary_hawkes       -1.172214  0.542986  1.025308  success
# 2  FullyNN  stationary_hawkes       -1.262615  0.540724  1.072807  success
# 3     SAHP  stationary_hawkes       -1.138142  0.567550  1.064994  success
# 4      THP  stationary_hawkes       -1.176766  0.524887  1.145459  success
#
#    time_seconds
# 0     96.894344
# 1     78.661341
# 2     28.888121
# 3     14.124639
# 4     13.849385
#
# ✓ Formatted table:
# dataset                             stationary_hawkes
# model
# AttNHP         -1.128/0.897/45.0% ± 0.000/0.000/0.000
# FullyNN        -1.263/1.073/45.9% ± 0.000/0.000/0.000
# IntensityFree  -1.122/1.125/42.1% ± 0.000/0.000/0.000
# NHP            -1.172/1.025/45.7% ± 0.000/0.000/0.000
# RMTPP          -1.140/1.204/45.4% ± 0.000/0.000/0.000
# SAHP           -1.138/1.065/43.2% ± 0.000/0.000/0.000
# THP            -1.177/1.145/47.5% ± 0.000/0.000/0.000
# ✓ Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.csv
# ✓ LaTeX table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.tex
# ✓ Markdown table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.md

# %% [markdown]
# ## Data Conversion: EasyTPP → Meta-TPP Format
#
# Convert stationary Hawkes pickle files to npz format for Meta-TPP:
# - **EasyTPP format**: `{time_seqs: List[List[float]], type_seqs: List[List[int]]}`
# - **Meta-TPP format**: `.npz` with `TIMES`, `MARKS`, `MASKS` arrays

# %%
import pickle
import numpy as np
import json
import os


def convert_sparklen_hawkes_to_metatpp(dataset_dir, output_dir, dataset_name='stationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes dataset to Meta-TPP format.

    Your data format (from Sparklen):
    {
        'dim_process': 2,
        'train': [
            [
                {'idx_event': 1, 'type_event': 0, 'time_since_start': 0.876, ...},
                {'idx_event': 2, 'type_event': 1, 'time_since_start': 1.883, ...},
                ...
            ],
            ...
        ]
    }
    """
    os.makedirs(output_dir, exist_ok=True)

    print("="*70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("="*70)

    # Define file paths and their corresponding keys
    splits = {
        'train': ('train.pkl', 'train'),
        'dev': ('dev.pkl', 'dev'),
        'test': ('test.pkl', 'test')
    }

    all_times = []
    all_marks = []
    all_masks = []
    split_indices = {}

    current_idx = 0

    for split_name, (filename, data_key) in splits.items():
        pickle_path = os.path.join(dataset_dir, filename)

        print(f"\n{split_name.upper()} split:")

        # Load pickle file
        with open(pickle_path, 'rb') as f:
            data = pickle.load(f)

        # Extract sequences
        sequences = data[data_key]
        num_seqs = len(sequences)

        # Extract times and marks from event dictionaries
        time_seqs = []
        type_seqs = []

        for seq in sequences:
            # Each seq is a list of event dicts
            times = [event['time_since_start'] for event in seq]
            marks = [event['type_event'] for event in seq]

            time_seqs.append(times)
            type_seqs.append(marks)

        # Find max sequence length
        max_len = max(len(seq) for seq in time_seqs)

        # Create padded arrays
        times = np.zeros((num_seqs, max_len), dtype=np.float32)
        marks = np.zeros((num_seqs, max_len), dtype=np.int64)
        masks = np.zeros((num_seqs, max_len), dtype=np.float32)

        for i, (time_seq, type_seq) in enumerate(zip(time_seqs, type_seqs)):
            seq_len = len(time_seq)
            times[i, :seq_len] = time_seq
            marks[i, :seq_len] = type_seq
            masks[i, :seq_len] = 1.0

        all_times.append(times)
        all_marks.append(marks)
        all_masks.append(masks)

        split_indices[split_name] = (current_idx, current_idx + num_seqs)
        current_idx += num_seqs

        print(f"  - Sequences: {num_seqs}")
        print(f"  - Max length: {max_len}")
        print(f"  - Avg length: {np.mean([len(seq) for seq in time_seqs]):.1f}")

    # Pad to global max length
    global_max_len = max(arr.shape[1] for arr in all_times)

    def pad_to_length(arrays, target_len):
        padded = []
        for arr in arrays:
            if arr.shape[1] < target_len:
                pad_width = ((0, 0), (0, target_len - arr.shape[1]))
                padded.append(np.pad(arr, pad_width, mode='constant', constant_values=0))
            else:
                padded.append(arr)
        return padded

    all_times = pad_to_length(all_times, global_max_len)
    all_marks = pad_to_length(all_marks, global_max_len)
    all_masks = pad_to_length(all_masks, global_max_len)

    # Concatenate
    times_combined = np.concatenate(all_times, axis=0)
    marks_combined = np.concatenate(all_marks, axis=0)
    masks_combined = np.concatenate(all_masks, axis=0)

    # Save npz
    output_path = os.path.join(output_dir, f'{dataset_name}.npz')
    np.savez(
        output_path,
        times=times_combined,
        marks=marks_combined,
        masks=masks_combined
    )

    # Save split info
    split_info_path = os.path.join(output_dir, f'{dataset_name}_split_info.json')
    with open(split_info_path, 'w') as f:
        json.dump({
            'train': split_indices['train'],
            'val': split_indices['dev'],
            'test': split_indices['test'],
            'num_event_types': int(data['dim_process']),
            'global_max_len': int(global_max_len)
        }, f, indent=2)

    print(f"\n{'='*70}")
    print(f"✓ Conversion complete!")
    print(f"  - Output NPZ: {output_path}")
    print(f"  - Split info: {split_info_path}")
    print(f"  - Total sequences: {times_combined.shape[0]}")
    print(f"  - Sequence length: {times_combined.shape[1]}")
    print(f"  - Train: {split_indices['train']}")
    print(f"  - Val: {split_indices['dev']}")
    print(f"  - Test: {split_indices['test']}")
    print("="*70)

    return output_path


# ============================================================================
# RUN CONVERSION
# ============================================================================

# Convert the stationary Hawkes dataset
hawkes_input_dir = os.path.join(DATASET_DIR, 'stationary_hawkes')
metatpp_dataset_dir = os.path.join(DATASET_DIR, 'metatpp_format')

# Convert the stationary Hawkes dataset
converted_npz_path = convert_sparklen_hawkes_to_metatpp(
    dataset_dir=hawkes_input_dir,
    output_dir=metatpp_dataset_dir,
    dataset_name='stationary_hawkes'
)
# Out:
# ======================================================================
# Converting stationary_hawkes to Meta-TPP format
# ======================================================================
#
# TRAIN split:
#   - Sequences: 300
#   - Max length: 63
#   - Avg length: 31.0
#
# DEV split:
#   - Sequences: 100
#   - Max length: 55
#   - Avg length: 31.7
#
# TEST split:
#   - Sequences: 100
#   - Max length: 66
#   - Avg length: 31.9
#
# ======================================================================
# ✓ Conversion complete!
#   - Output NPZ: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/stationary_hawkes.npz
#   - Split info: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/stationary_hawkes_split_info.json
#   - Total sequences: 500
#   - Sequence length: 66
#   - Train: (0, 300)
#   - Val: (300, 400)
#   - Test: (400, 500)
# ======================================================================

# %% [markdown]
# ## Meta TPP

# %% [markdown]
# ### Cell 1: Install Dependencies (CRITICAL - Run First, Then Restart Runtime)

# %%
# ==============================================================================
# CELL 1: Install Dependencies with Correct Versions
# ==============================================================================
# IMPORTANT: After running this cell, you MUST restart the runtime!
# Runtime → Restart runtime (or Ctrl+M .)

# Uninstall any existing stribor (Colab installs 0.2.0 which breaks)
# !pip uninstall stribor -y -q 2>/dev/null

# Install stribor 0.1.0 (does NOT require torchtyping)
# !pip install stribor==0.1.0 -q

# Install nfe (neural-flows-experiments) from GitHub
# !SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True pip install git+https://github.com/mbilos/neural-flows-experiments -q

# Install other Meta-TPP dependencies
# !pip install lightning pytorch-lightning hydra-core omegaconf hydra-colorlog pyrootutils torchmetrics rich -q

# Verify stribor version
import subprocess
result = subprocess.run(['pip', 'show', 'stribor'], capture_output=True, text=True)
version_line = [l for l in result.stdout.split('\n') if 'Version' in l][0]
print(f"✓ Installed: stribor {version_line.split(': ')[1]}")

print("\n" + "=" * 70)
print("⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime")
print("   Then continue to Cell 2 (do NOT re-run this cell)")
print("=" * 70)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 69.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for nfe (setup.py) ... done
#   Building wheel for reverse_geocoder (setup.py) ... done
#   Building wheel for sklearn (setup.py) ... done
# ✓ Installed: stribor 0.1.0
#
# ======================================================================
# ⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime
#    Then continue to Cell 2 (do NOT re-run this cell)
# ======================================================================

# %% [markdown]
# ### Cell 2: Verify Imports (Run After Restart)

# %%
# ==============================================================================
# CELL 2: Verify Imports After Runtime Restart
# ==============================================================================
# Run this AFTER restarting the runtime

import stribor

# This import should now work without torchtyping errors
import torch
print(f"✓ PyTorch version: {torch.__version__}")

# Test that stribor's distributions work
try:
    from stribor.dist import Normal
    print("✓ stribor.dist imports work")
except Exception as e:
    print(f"✗ Error: {e}")

print("\n✓ All imports successful - ready to proceed!")
# Out:
# ✓ PyTorch version: 2.9.0+cu126
# ✓ stribor.dist imports work
#
# ✓ All imports successful - ready to proceed!

# %% [markdown]
# ### Cell 3: Setup Paths and Clone Meta-TPP

# %%
# ==============================================================================
# CELL 3: Setup Paths and Clone Meta-TPP
# ==============================================================================
import os
import sys

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Base directories
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task3')
METATPP_DIR = '/content/meta-tpp'

os.makedirs(RESULTS_DIR, exist_ok=True)

# Clone Meta-TPP
if not os.path.exists(METATPP_DIR):
    # !git clone https://github.com/BorealisAI/meta-tpp.git {METATPP_DIR}
    print("✓ Meta-TPP cloned")
else:
    print("✓ Meta-TPP already exists")

# Add to Python path
if METATPP_DIR not in sys.path:
    sys.path.insert(0, METATPP_DIR)

# Change to Meta-TPP directory (required for Hydra)
os.chdir(METATPP_DIR)
print(f"✓ Working directory: {os.getcwd()}")

# Create data directories
os.makedirs(os.path.join(METATPP_DIR, 'data', 'synthetic'), exist_ok=True)
print("✓ Data directories ready")

# ==============================================================================
# Create .project-root indicator file (required by pyrootutils)
# ==============================================================================
project_root_file = os.path.join(METATPP_DIR, '.project-root')
if not os.path.exists(project_root_file):
    with open(project_root_file, 'w') as f:
        f.write('')  # Empty file is fine, just needs to exist
    print(f"✓ Created .project-root indicator file")
else:
    print(f"✓ .project-root already exists")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into '/content/meta-tpp'...
# remote: Enumerating objects: 3610, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 3610 (delta 159), reused 211 (delta 155), pack-reused 3384 (from 1)
# Receiving objects: 100% (3610/3610), 3.45 MiB | 2.22 MiB/s, done.
# Resolving deltas: 100% (2132/2132), done.
# ✓ Meta-TPP cloned
# ✓ Working directory: /content/meta-tpp
# ✓ Data directories ready
# ✓ Created .project-root indicator file

# %% [markdown]
# ### Cell 4: Convert Stationary Hawkes Data to Meta-TPP Format

# %%
# ==============================================================================
# CELL 4: Convert Stationary Hawkes Data to Meta-TPP Format
# ==============================================================================
import numpy as np
import pickle

def convert_hawkes_to_metatpp_format(dataset_dir, output_path, dataset_name='stationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes pickle files to Meta-TPP npz format.

    Meta-TPP expects:
    - Single npz file with all sequences
    - Keys: 'times', 'marks', 'masks'
    - Shape: (num_sequences, max_seq_len)
    - Split by indices: 60% train, 20% val, 20% test (or custom)
    """
    print("=" * 70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("=" * 70)

    all_times = []
    all_marks = []
    splits = ['train', 'dev', 'test']
    split_files = {'train': 'train.pkl', 'dev': 'dev.pkl', 'test': 'test.pkl'}

    for split in splits:
        pkl_path = os.path.join(dataset_dir, split_files[split])
        print(f"\nLoading {split}...")

        with open(pkl_path, 'rb') as f:
            data = pickle.load(f)

        # Handle different pickle structures
        if split in data:
            sequences = data[split]
        elif 'train' in data or 'dev' in data or 'test' in data:
            sequences = data.get(split, data.get('train', []))
        else:
            sequences = data if isinstance(data, list) else list(data.values())[0]

        print(f"  - {len(sequences)} sequences")

        for seq in sequences:
            if isinstance(seq, list) and len(seq) > 0 and isinstance(seq[0], dict):
                # Format: [{'time_since_start': t, 'type_event': m}, ...]
                times = [event['time_since_start'] for event in seq]
                marks = [event['type_event'] for event in seq]
            else:
                # Assume it's already (times, marks) format
                times = [e[0] if isinstance(e, (list, tuple)) else e for e in seq]
                marks = [e[1] if isinstance(e, (list, tuple)) else 0 for e in seq]

            all_times.append(times)
            all_marks.append(marks)

    # Find max sequence length
    max_len = max(len(t) for t in all_times)
    num_seqs = len(all_times)

    print(f"\n  Total sequences: {num_seqs}")
    print(f"  Max sequence length: {max_len}")

    # Create padded arrays
    times_arr = np.zeros((num_seqs, max_len), dtype=np.float32)
    marks_arr = np.zeros((num_seqs, max_len), dtype=np.int64)
    masks_arr = np.zeros((num_seqs, max_len), dtype=np.float32)

    for i, (t, m) in enumerate(zip(all_times, all_marks)):
        seq_len = len(t)
        times_arr[i, :seq_len] = t
        marks_arr[i, :seq_len] = m
        masks_arr[i, :seq_len] = 1.0

    # Save as npz
    np.savez(output_path, times=times_arr, marks=marks_arr, masks=masks_arr)

    print(f"\n✓ Saved to: {output_path}")
    print(f"  - times: {times_arr.shape}, dtype={times_arr.dtype}")
    print(f"  - marks: {marks_arr.shape}, dtype={marks_arr.dtype}")
    print(f"  - masks: {masks_arr.shape}, dtype={masks_arr.dtype}")
    print(f"  - Split: [0:{int(num_seqs*0.6)}] train, [{int(num_seqs*0.6)}:{int(num_seqs*0.8)}] val, [{int(num_seqs*0.8)}:] test")
    print("=" * 70)

    return output_path

# Convert the data
hawkes_input_dir = os.path.join(DATASET_DIR, 'stationary_hawkes')
metatpp_data_path = os.path.join(METATPP_DIR, 'data', 'synthetic', 'stationary_hawkes.npz')

convert_hawkes_to_metatpp_format(hawkes_input_dir, metatpp_data_path)

# Verify
data = np.load(metatpp_data_path)
print("\n✓ Verification:")
for key in data.keys():
    print(f"  {key}: shape={data[key].shape}, dtype={data[key].dtype}")
# Out:
# ======================================================================
# Converting stationary_hawkes to Meta-TPP format
# ======================================================================
#
# Loading train...
#   - 300 sequences
#
# Loading dev...
#   - 100 sequences
#
# Loading test...
#   - 100 sequences
#
#   Total sequences: 500
#   Max sequence length: 66
#
# ✓ Saved to: /content/meta-tpp/data/synthetic/stationary_hawkes.npz
#   - times: (500, 66), dtype=float32
#   - marks: (500, 66), dtype=int64
#   - masks: (500, 66), dtype=float32
#   - Split: [0:300] train, [300:400] val, [400:] test
# ======================================================================
#
# ✓ Verification:
#   times: shape=(500, 66), dtype=float32
#   marks: shape=(500, 66), dtype=int64
#   masks: shape=(500, 66), dtype=float32

# %% [markdown]
# ### Cell 5: Create Dataset Config and Patch TPPDataset

# %%
# ==============================================================================
# CELL 5: Create Dataset Config and Register Dataset
# ==============================================================================
import yaml

# Create dataset config YAML
dataset_config = {
    'dataset': 'stationary_hawkes',
    'num_classes': 2  # Your Hawkes data has 2 event types
}

config_dir = os.path.join(METATPP_DIR, 'configs', 'data', 'datasets')
config_path = os.path.join(config_dir, 'stationary_hawkes.yaml')

with open(config_path, 'w') as f:
    yaml.dump(dataset_config, f)

print(f"✓ Created dataset config: {config_path}")

# Patch TPPDataset to include our new dataset
tpp_dataset_path = os.path.join(METATPP_DIR, 'src', 'data', 'tpp_dataset.py')

with open(tpp_dataset_path, 'r') as f:
    content = f.read()

# Add stationary_hawkes to synthetic_data list if not already there
if 'stationary_hawkes' not in content:
    old_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\"]"
    new_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\", 'stationary_hawkes']"

    if old_line in content:
        content = content.replace(old_line, new_line)
        with open(tpp_dataset_path, 'w') as f:
            f.write(content)
        print("✓ Added 'stationary_hawkes' to synthetic_data list")
    else:
        # Try alternative format
        import re
        pattern = r"(synthetic_data\s*=\s*\[.*?\])"
        match = re.search(pattern, content, re.DOTALL)
        if match:
            old = match.group(1)
            if 'stationary_hawkes' not in old:
                new = old.rstrip(']') + ", 'stationary_hawkes']"
                content = content.replace(old, new)
                with open(tpp_dataset_path, 'w') as f:
                    f.write(content)
                print("✓ Added 'stationary_hawkes' to synthetic_data list")
else:
    print("✓ 'stationary_hawkes' already registered")

# Reload the module
import importlib
if 'src.data.tpp_dataset' in sys.modules:
    del sys.modules['src.data.tpp_dataset']

print("✓ Dataset configuration complete")
# Out:
# ✓ Created dataset config: /content/meta-tpp/configs/data/datasets/stationary_hawkes.yaml
# ✓ Added 'stationary_hawkes' to synthetic_data list
# ✓ Dataset configuration complete

# %% [markdown]
# ### Cell 6: Test Data Loading

# %%
# ==============================================================================
# CELL 6: Test Data Loading
# ==============================================================================
# Verify the data can be loaded by Meta-TPP's dataset class

from src.data.tpp_dataset import TPPDataset

# Test loading
data_dir = os.path.join(METATPP_DIR, 'data')

print("Testing data loading...")
try:
    train_ds = TPPDataset(data_dir, 'stationary_hawkes', num_classes=2, mode='train')
    val_ds = TPPDataset(data_dir, 'stationary_hawkes', num_classes=2, mode='val')
    test_ds = TPPDataset(data_dir, 'stationary_hawkes', num_classes=2, mode='test')

    print(f"\n✓ Train: {len(train_ds)} sequences")
    print(f"✓ Val: {len(val_ds)} sequences")
    print(f"✓ Test: {len(test_ds)} sequences")

    # Test a sample
    sample = train_ds[0]
    print(f"\nSample batch keys: {list(sample.keys())}")
    print(f"  times shape: {sample['times'].shape}")
    print(f"  marks shape: {sample['marks'].shape}")
    print(f"  masks shape: {sample['masks'].shape}")

    print("\n✓ Data loading test passed!")
except Exception as e:
    print(f"✗ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Testing data loading...
# time shape: torch.Size([300, 66, 1]), marks shape: torch.Size([300, 66, 1]), masks shape: torch.Size([300, 66, 1])
# time shape: torch.Size([100, 66, 1]), marks shape: torch.Size([100, 66, 1]), masks shape: torch.Size([100, 66, 1])
# time shape: torch.Size([100, 66, 1]), marks shape: torch.Size([100, 66, 1]), masks shape: torch.Size([100, 66, 1])
#
# ✓ Train: 300 sequences
# ✓ Val: 100 sequences
# ✓ Test: 100 sequences
#
# Sample batch keys: ['times', 'marks', 'masks', 'missing_masks']
#   times shape: torch.Size([66, 1])
#   marks shape: torch.Size([66, 1])
#   masks shape: torch.Size([66, 1])
#
# ✓ Data loading test passed!

# %% [markdown]
# ### Cell 7: Train Meta-TPP Using Hydra

# %%
# ==============================================================================
# CELL 7: Train Meta-TPP Using Hydra
# ==============================================================================
import subprocess
import os

# Ensure we're in the Meta-TPP directory
os.chdir(METATPP_DIR)

# Training command using Hydra
# This replicates: python src/train.py data/datasets=stationary_hawkes
cmd = [
    'python', 'src/train.py',
    'data/datasets=stationary_hawkes',
    'model=thp_mix',
    'trainer.max_epochs=200',
    'trainer.accelerator=gpu',
    'trainer.devices=1',
    'data.batch_size=256',
    'tag=colab_run',
    'test=False',
    'seed=42'
]

print("=" * 70)
print("Starting Meta-TPP Training")
print("=" * 70)
print(f"Command: {' '.join(cmd)}")
print("=" * 70 + "\n")

# Run training
process = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

# Stream output
for line in iter(process.stdout.readline, ''):
    print(line, end='')

process.wait()

if process.returncode == 0:
    print("\n" + "=" * 70)
    print("✓ Training completed successfully!")
    print("=" * 70)
else:
    print(f"\n✗ Training failed with return code: {process.returncode}")
# Out:
# ======================================================================
# Starting Meta-TPP Training
# ======================================================================
# Command: python src/train.py data/datasets=stationary_hawkes model=thp_mix trainer.max_epochs=200 trainer.accelerator=gpu trainer.devices=1 data.batch_size=256 tag=colab_run test=False seed=42
# ======================================================================
#
# [2026-01-01 14:56:15,097][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2026-01-01 14:56:15,102][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# [2026-01-01 14:56:15,102][src.utils.rich_utils][WARNING] - Field 'logger' not found in config. Skipping 'logger' config printing...
# CONFIG
# ├── data
# │   └── _target_: src.data.tpp_dataset.TPPDataModule
# │       data_dir: /content/meta-tpp/data/
# │       batch_size: 256
# │       num_workers: 4
# │       pin_memory: false
# │       train_rate: 1.0
# │       eval_rate: 1.0
# │       noise_rate: 0.0
# │       seq_rate: 1.0
# │       missing_rate: 0.0
# │       use_mark: true
# │       run_bootstrap: false
# │       datasets:
# │         dataset: stationary_hawkes
# │         num_classes: 2
# │
# ├── model
# │   └── _target_: src.models.tpp_module.TPPLitModule
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.0001
# │         weight_decay: 0.0001
# │         eps: 1.0e-05
# │         betas:
# │         - 0.9
# │         - 0.999
# │       net:
# │         _target_: src.models.tpp.tpp_network.TransformerMix
# │         name: thp_mix
# │         num_classes: 2
# │         d_model: 64
# │         d_inner: 64
# │         n_layers: 2
# │         cattn_n_layers: 1
# │         n_head: 1
# │         d_k: 64
# │         d_v: 64
# │         dropout: 0.1
# │         attn_l: 0
# │         base_l: 0
# │         perm_invar: false
# │         use_avg: true
# │         share_weights: true
# │         attn_only: false
# │         concat: false
# │         num_latent: 64
# │         vi_method: None
# │         num_z_samples: 32
# │         compute_acc: true
# │         activation:
# │           name: tanh
# │           in_features: 64
# │           trainable: true
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: lightning.pytorch.callbacks.ModelCheckpoint
# │         dirpath: /content/meta-tpp/logs/stationary_hawkes_thp_mix_colab_run/se
# │         filename: epoch_{epoch:03d}
# │         monitor: val/rmse
# │         verbose: false
# │         save_last: true
# │         save_top_k: 1
# │         mode: min
# │         auto_insert_metric_name: false
# │         save_weights_only: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: null
# │       early_stopping:
# │         _target_: lightning.pytorch.callbacks.EarlyStopping
# │         monitor: val/nll
# │         min_delta: 0.0
# │         patience: 500
# │         verbose: false
# │         mode: min
# │         strict: true
# │         check_finite: true
# │         stopping_threshold: null
# │         divergence_threshold: null
# │         check_on_train_epoch_end: null
# │       model_summary:
# │         _target_: lightning.pytorch.callbacks.RichModelSummary
# │         max_depth: -1
# │       rich_progress_bar:
# │         _target_: lightning.pytorch.callbacks.RichProgressBar
# │
# ├── trainer
# │   └── _target_: lightning.pytorch.trainer.Trainer
# │       default_root_dir: /content/meta-tpp/logs/stationary_hawkes_thp_mix_colab
# │       min_epochs: 1
# │       max_epochs: 200
# │       accelerator: gpu
# │       devices: 1
# │       check_val_every_n_epoch: 1
# │       deterministic: false
# │
# ├── paths
# │   └── root_dir: /content/meta-tpp
# │       data_dir: /content/meta-tpp/data/
# │       log_dir: /content/meta-tpp/logs/
# │       output_dir: /content/meta-tpp/logs/stationary_hawkes_thp_mix_colab_run/s
# │       work_dir: /content/meta-tpp
# │       ckpt_dir: /content/meta-tpp/checkpoints/
# │
# ├── extras
# │   └── ignore_warnings: false
# │       enforce_tags: true
# │       print_config: true
# │
# ├── task_name
# │   └── stationary_hawkes_thp_mix_colab_run
# ├── tags
# │   └── ['dev']
# ├── tag
# │   └── colab_run
# ├── train
# │   └── True
# ├── test
# │   └── False
# ├── compile
# │   └── False
# ├── ckpt_path
# │   └── None
# └── seed
#     └── 42
# Seed set to 42
# [2026-01-01 14:56:15,164][__main__][INFO] - Instantiating datamodule <src.data.tpp_dataset.TPPDataModule>
# [2026-01-01 14:56:15,167][__main__][INFO] - Instantiating model <src.models.tpp_module.TPPLitModule>
# The number of trainable model parameters: 56284
# [2026-01-01 14:56:15,358][__main__][INFO] - Instantiating callbacks...
# [2026-01-01 14:56:15,359][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.ModelCheckpoint>
# [2026-01-01 14:56:15,373][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.EarlyStopping>
# [2026-01-01 14:56:15,374][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichModelSummary>
# [2026-01-01 14:56:15,375][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichProgressBar>
# [2026-01-01 14:56:15,375][__main__][INFO] - Instantiating loggers...
# [2026-01-01 14:56:15,375][src.utils.instantiators][WARNING] - No logger configs found! Skipping...
# [2026-01-01 14:56:15,375][__main__][INFO] - Instantiating trainer <lightning.pytorch.trainer.Trainer>
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# [2026-01-01 14:56:15,418][__main__][INFO] - Starting training!
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1551: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return _C._get_float32_matmul_precision()
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# time shape: torch.Size([300, 66, 1]), marks shape: torch.Size([300, 66, 1]), masks shape: torch.Size([300, 66, 1])
# time shape: torch.Size([100, 66, 1]), marks shape: torch.Size([100, 66, 1]), masks shape: torch.Size([100, 66, 1])
# time shape: torch.Size([100, 66, 1]), marks shape: torch.Size([100, 66, 1]), masks shape: torch.Size([100, 66, 1])
# ┏━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━┳━━━━┳━━━┓
# ┃    ┃ Name                                                 ┃ T… ┃ P… ┃ M… ┃ … ┃
# ┡━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━╇━━━━╇━━━┩
# │ 0  │ net                                                  │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 1  │ net.encoder                                          │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 2  │ net.encoder.event_emb                                │ E… │ 1… │ t… │ 0 │
# │ 3  │ net.encoder.layer_stack                              │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 4  │ net.encoder.layer_stack.0                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 5  │ net.encoder.layer_stack.0.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 6  │ net.encoder.layer_stack.0.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 7  │ net.encoder.layer_stack.0.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 8  │ net.encoder.layer_stack.0.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 9  │ net.encoder.layer_stack.0.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 10 │ net.encoder.layer_stack.0.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 11 │ net.encoder.layer_stack.0.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 12 │ net.encoder.layer_stack.0.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 13 │ net.encoder.layer_stack.0.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 14 │ net.encoder.layer_stack.0.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 15 │ net.encoder.layer_stack.0.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 16 │ net.encoder.layer_stack.0.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 17 │ net.encoder.layer_stack.0.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 18 │ net.encoder.layer_stack.0.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 19 │ net.encoder.layer_stack.1                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 20 │ net.encoder.layer_stack.1.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 21 │ net.encoder.layer_stack.1.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 22 │ net.encoder.layer_stack.1.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 23 │ net.encoder.layer_stack.1.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 24 │ net.encoder.layer_stack.1.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 25 │ net.encoder.layer_stack.1.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 26 │ net.encoder.layer_stack.1.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 27 │ net.encoder.layer_stack.1.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 28 │ net.encoder.layer_stack.1.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 29 │ net.encoder.layer_stack.1.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 30 │ net.encoder.layer_stack.1.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 31 │ net.encoder.layer_stack.1.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 32 │ net.encoder.layer_stack.1.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 33 │ net.encoder.layer_stack.1.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 34 │ net.linear                                           │ L… │ 1… │ t… │ 0 │
# │ 35 │ net.time_predictor                                   │ T… │ 64 │ t… │ 0 │
# │ 36 │ net.time_predictor.linear                            │ L… │ 64 │ t… │ 0 │
# │ 37 │ net.class_predictor                                  │ T… │ 1… │ t… │ 0 │
# │ 38 │ net.mark_linear                                      │ L… │ 1… │ t… │ 0 │
# │ 39 │ net.activation                                       │ T… │  0 │ t… │ 0 │
# │ 40 │ net.prob_dist                                        │ L… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 41 │ net.prob_dist.decoder                                │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 42 │ net.prob_dist.decoder.net                            │ S… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 43 │ net.prob_dist.decoder.net.0                          │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 44 │ net.prob_dist.decoder.net.1                          │ T… │  0 │ t… │ 0 │
# │ 45 │ net.prob_dist.decoder.net.2                          │ L… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 46 │ train_nll                                            │ M… │  0 │ t… │ 0 │
# │ 47 │ val_nll                                              │ M… │  0 │ t… │ 0 │
# │ 48 │ test_nll                                             │ M… │  0 │ t… │ 0 │
# │ 49 │ train_rmse                                           │ M… │  0 │ t… │ 0 │
# │ 50 │ val_rmse                                             │ M… │  0 │ t… │ 0 │
# │ 51 │ test_rmse                                            │ M… │  0 │ t… │ 0 │
# │ 52 │ train_acc                                            │ M… │  0 │ t… │ 0 │
# │ 53 │ val_acc                                              │ M… │  0 │ t… │ 0 │
# │ 54 │ test_acc                                             │ M… │  0 │ t… │ 0 │
# │ 55 │ val_nll_best                                         │ M… │  0 │ t… │ 0 │
# │ 56 │ val_rmse_best                                        │ M… │  0 │ t… │ 0 │
# └────┴──────────────────────────────────────────────────────┴────┴────┴────┴───┘
# Trainable params: 56.3 K
# Non-trainable params: 0
# Total params: 56.3 K
# Total estimated model params size (MB): 0
# Modules in train mode: 57
# Modules in eval mode: 0
# Total FLOPs: 0
# `Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 199/199 ━━━━━━━━━━━━━━━━ 2/2 0:00:00 • 0:00:00 28.20it/s val/nll: 1.392
#                                                                val/rmse: 2.317
#                                                                val/acc: 0.471
#                                                                val/nll_best:
#                                                                1.375
#                                                                val/rmse_best:
#                                                                1.694 train/nll:
#                                                                1.509
# [2026-01-01 14:57:51,460][src.utils.utils][INFO] - Output dir: /content/meta-tpp/logs/stationary_hawkes_thp_mix_colab_run/seed42
# [2026-01-01 14:57:53,520][src.utils.utils][INFO] - Metric name is None! Skipping metric value retrieval...
# [W101 14:57:54.241023673 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# ======================================================================
# ✓ Training completed successfully!
# ======================================================================

# %%
# ==============================================================================
# CELL 7b: Manual Testing with proper optimizer setup
# ==============================================================================
import torch
import lightning as L
from torch.utils.data import DataLoader
from functools import partial

# Fix for PyTorch 2.6 checkpoint loading
from omegaconf import ListConfig, DictConfig
torch.serialization.add_safe_globals([ListConfig, DictConfig])

from src.data.tpp_dataset import TPPDataset
from src.models.tpp_module import TPPLitModule
from src.models.tpp.tpp_network import TransformerMix

# Find the best checkpoint
import glob
ckpt_pattern = os.path.join(METATPP_DIR, 'logs', 'stationary_hawkes_thp_mix_colab_run', 'seed42', 'checkpoints', '*.ckpt')
ckpts = glob.glob(ckpt_pattern)
ckpts = [c for c in ckpts if 'last' not in c]
best_ckpt = sorted(ckpts)[-1] if ckpts else None

print(f"Best checkpoint: {best_ckpt}")

# Load data
data_dir = os.path.join(METATPP_DIR, 'data')
test_ds = TPPDataset(data_dir, 'stationary_hawkes', num_classes=2, mode='test')
test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2)

# Create model
net = TransformerMix(
    name='thp_mix', num_classes=2, d_model=64, d_inner=64, n_layers=2,
    cattn_n_layers=1, n_head=1, d_k=64, d_v=64, dropout=0.1,
    attn_l=0, base_l=0, perm_invar=False, use_avg=True, share_weights=True,
    attn_only=False, concat=False, num_latent=64, vi_method=None,
    num_z_samples=32, compute_acc=True,
    activation={'name': 'tanh', 'in_features': 64, 'trainable': True}
)

# Create optimizer as a partial function (this is what Hydra does)
optimizer = partial(
    torch.optim.Adam,
    lr=0.0001,
    weight_decay=0.0001,
    eps=1e-5,
    betas=(0.9, 0.999)
)

model = TPPLitModule(net=net, optimizer=optimizer)

# Load checkpoint
if best_ckpt:
    ckpt = torch.load(best_ckpt, map_location='cuda', weights_only=False)
    model.load_state_dict(ckpt['state_dict'])
    print("✓ Checkpoint loaded")

# Set model to eval mode
model.eval()

# Test
trainer = L.Trainer(accelerator='gpu', devices=1, logger=False, enable_progress_bar=True)
test_results = trainer.test(model, test_loader)

print("\n" + "=" * 70)
print("Meta-TPP Test Results")
print("=" * 70)
for k, v in test_results[0].items():
    print(f"  {k}: {v:.4f}")
# Out:
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 0:00:00 • 0:00:00 44.84it/s
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.4528118968009949     │
# │         test/nll          │    1.4785860776901245     │
# │         test/rmse         │    2.0900042057037354     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
# Meta-TPP Test Results
# ======================================================================
#   test/nll: 1.4786
#   test/rmse: 2.0900
#   test/acc: 0.4528

# %% [markdown]
# ### Cell 8: Extract and Save Results

# %%
# ==============================================================================
# CELL 9: Extract and Save Results Properly
# ==============================================================================
import pandas as pd

# test_results is returned from trainer.test() - it's a list of dicts
# Print what we actually got to debug
print("=" * 70)
print("Raw test_results:")
print(test_results)
print("=" * 70)

# Extract metrics from test_results (it's a list with one dict)
if test_results and len(test_results) > 0:
    metrics = test_results[0]

    # Meta-TPP uses keys like 'test/nll', 'test/rmse', 'test/acc'
    # or 'test_nll', 'test_rmse', 'test_acc'

    # Try different possible key formats
    def get_metric(metrics, *possible_keys):
        for key in possible_keys:
            if key in metrics:
                val = metrics[key]
                # Handle tensor values
                if hasattr(val, 'item'):
                    return val.item()
                return val
        return float('nan')

    nll = get_metric(metrics, 'test/nll', 'test_nll', 'test_loss')
    rmse = get_metric(metrics, 'test/rmse', 'test_rmse')
    acc = get_metric(metrics, 'test/acc', 'test_acc', 'test_accuracy')

    # Log-likelihood is negative NLL
    log_likelihood = -nll if not pd.isna(nll) else float('nan')

    print(f"\nExtracted metrics:")
    print(f"  NLL: {nll}")
    print(f"  Log-Likelihood: {log_likelihood}")
    print(f"  RMSE: {rmse}")
    print(f"  Accuracy: {acc}")
else:
    print("No test results found!")
    log_likelihood = float('nan')
    acc = float('nan')
    rmse = float('nan')

# Create result entry
metatpp_result = {
    'model': 'Meta-TPP',
    'dataset': 'stationary_hawkes',
    'log_likelihood': log_likelihood,
    'accuracy': acc * 100 if not pd.isna(acc) and acc <= 1 else acc,  # Convert to percentage if needed
    'rmse': rmse,
    'status': 'success'
}

# Save results
results_df = pd.DataFrame([metatpp_result])
metatpp_results_path = os.path.join(RESULTS_DIR, 'metatpp_stationary_results.csv')
results_df.to_csv(metatpp_results_path, index=False)

print("\n" + "=" * 70)
print("Meta-TPP Results (Task 3b)")
print("=" * 70)
print(results_df.to_string(index=False))
print(f"\n✓ Saved to: {metatpp_results_path}")

# Also print in Table-1-like format for easy comparison
print("\n" + "=" * 70)
print("Table-1-like Format:")
print("=" * 70)
print(f"Model: Meta-TPP")
print(f"Dataset: stationary_hawkes")
print(f"Log-Likelihood: {log_likelihood:.3f}" if not pd.isna(log_likelihood) else "Log-Likelihood: N/A")
print(f"Accuracy: {metatpp_result['accuracy']:.1f}%" if not pd.isna(metatpp_result['accuracy']) else "Accuracy: N/A")
print(f"RMSE: {rmse:.3f}" if not pd.isna(rmse) else "RMSE: N/A")
# Out:
# ======================================================================
# Raw test_results:
# [{'test/nll': 1.4785860776901245, 'test/rmse': 2.0900042057037354, 'test/acc': 0.4528118968009949}]
# ======================================================================
#
# Extracted metrics:
#   NLL: 1.4785860776901245
#   Log-Likelihood: -1.4785860776901245
#   RMSE: 2.0900042057037354
#   Accuracy: 0.4528118968009949
#
# ======================================================================
# Meta-TPP Results (Task 3b)
# ======================================================================
#    model           dataset  log_likelihood  accuracy     rmse  status
# Meta-TPP stationary_hawkes       -1.478586  45.28119 2.090004 success
#
# ✓ Saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/metatpp_stationary_results.csv
#
# ======================================================================
# Table-1-like Format:
# ======================================================================
# Model: Meta-TPP
# Dataset: stationary_hawkes
# Log-Likelihood: -1.479
# Accuracy: 45.3%
# RMSE: 2.090

# %% [markdown]
# ## Reformat Final Results

# %%
# ==============================================================================
# TASK 3: COMBINE EASYTPP + META-TPP RESULTS AND GENERATE FINAL TABLE
# ==============================================================================
# This cell reloads all results from Google Drive, parses the existing format,
# combines with Meta-TPP, and outputs RMSE/ErrorRate% format.
# ==============================================================================

import pandas as pd
import numpy as np
import os
import re

# Paths
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task3')

# ==============================================================================
# STEP 1: Load results files
# ==============================================================================
print("=" * 70)
print("LOADING RESULTS FROM GOOGLE DRIVE")
print("=" * 70)

easytpp_path = os.path.join(RESULTS_DIR, 'Task3_results.csv')
metatpp_path = os.path.join(RESULTS_DIR, 'metatpp_stationary_results.csv')

# Load EasyTPP results
if os.path.exists(easytpp_path):
    easytpp_df = pd.read_csv(easytpp_path)
    print(f"✓ Loaded EasyTPP results: {len(easytpp_df)} rows")
    print(f"  Columns: {list(easytpp_df.columns)}")
else:
    print(f"✗ EasyTPP results not found at: {easytpp_path}")
    easytpp_df = pd.DataFrame()

# Load Meta-TPP results
if os.path.exists(metatpp_path):
    metatpp_df = pd.read_csv(metatpp_path)
    print(f"✓ Loaded Meta-TPP results: {len(metatpp_df)} rows")
    print(f"  Columns: {list(metatpp_df.columns)}")
else:
    print(f"✗ Meta-TPP results not found at: {metatpp_path}")
    metatpp_df = pd.DataFrame()

# ==============================================================================
# STEP 2: Parse EasyTPP results (format: "LL/RMSE/Acc% ± std_LL/std_RMSE/std_Acc")
# ==============================================================================
print("\n" + "=" * 70)
print("PARSING EASYTPP RESULTS")
print("=" * 70)

def parse_easytpp_cell(cell_value):
    """
    Parse cell value like '-1.166/0.877/43.9% ± 0.000/0.000/0.000'
    Returns: (log_likelihood, rmse, accuracy)
    """
    try:
        # Split on ± to get mean values
        mean_part = cell_value.split('±')[0].strip()

        # Split on / to get individual values
        parts = mean_part.split('/')

        log_likelihood = float(parts[0])
        rmse = float(parts[1])
        # Remove % sign and convert to float
        accuracy = float(parts[2].replace('%', ''))

        return log_likelihood, rmse, accuracy
    except Exception as e:
        print(f"  Warning: Could not parse '{cell_value}': {e}")
        return None, None, None

# Get dataset columns (all columns except 'model')
dataset_cols = [col for col in easytpp_df.columns if col != 'model']
print(f"  Dataset columns found: {dataset_cols}")

# Parse EasyTPP results into structured format
easytpp_parsed = []
for _, row in easytpp_df.iterrows():
    model = row['model']
    for dataset in dataset_cols:
        cell_value = row[dataset]
        ll, rmse, acc = parse_easytpp_cell(cell_value)
        if rmse is not None:
            easytpp_parsed.append({
                'model': model,
                'dataset': dataset,
                'log_likelihood': ll,
                'rmse': rmse,
                'accuracy': acc  # This is already in percentage (0-100)
            })

easytpp_parsed_df = pd.DataFrame(easytpp_parsed)
print(f"✓ Parsed {len(easytpp_parsed_df)} EasyTPP results")

# ==============================================================================
# STEP 3: Parse Meta-TPP results
# ==============================================================================
print("\n" + "=" * 70)
print("PARSING META-TPP RESULTS")
print("=" * 70)

metatpp_parsed = []
if not metatpp_df.empty:
    for _, row in metatpp_df.iterrows():
        acc = row['accuracy']
        # Convert to percentage if needed (check if it's 0-1 scale)
        if pd.notna(acc) and acc <= 1:
            acc = acc * 100

        metatpp_parsed.append({
            'model': row['model'],
            'dataset': row['dataset'],
            'log_likelihood': row['log_likelihood'],
            'rmse': row['rmse'],
            'accuracy': acc
        })

metatpp_parsed_df = pd.DataFrame(metatpp_parsed)
print(f"✓ Parsed {len(metatpp_parsed_df)} Meta-TPP results")

# ==============================================================================
# STEP 4: Combine all results
# ==============================================================================
print("\n" + "=" * 70)
print("COMBINING RESULTS")
print("=" * 70)

# Combine dataframes
dfs_to_concat = [df for df in [easytpp_parsed_df, metatpp_parsed_df] if not df.empty]
if dfs_to_concat:
    combined_df = pd.concat(dfs_to_concat, ignore_index=True)
else:
    combined_df = pd.DataFrame()

# Calculate error rate (100 - accuracy)
combined_df['error_rate'] = 100 - combined_df['accuracy']

print(f"✓ Combined results: {len(combined_df)} total experiments")
print(f"  Models: {sorted(combined_df['model'].unique().tolist())}")
print(f"  Datasets: {sorted(combined_df['dataset'].unique().tolist())}")

# ==============================================================================
# STEP 5: Save combined results (detailed version)
# ==============================================================================
combined_path = os.path.join(RESULTS_DIR, 'Task3_combined_results.csv')
combined_df.to_csv(combined_path, index=False)
print(f"✓ Saved detailed results to: {combined_path}")

# ==============================================================================
# STEP 6: Generate report table (RMSE/ErrorRate% format)
# ==============================================================================
print("\n" + "=" * 70)
print("TABLE FOR REPORT")
print("=" * 70)

def format_report_table(df):
    """
    Format results as RMSE/ErrorRate% table for report.
    Format: RMSE/ErrorRate% (e.g., "0.877/56.1%")
    """
    if df.empty:
        print("No data to format!")
        return pd.DataFrame()

    # Get unique models and datasets
    models = sorted(df['model'].unique())
    datasets = sorted(df['dataset'].unique())

    # Build table data
    table_data = []
    for model in models:
        row = {'model': model}
        for dataset in datasets:
            mask = (df['model'] == model) & (df['dataset'] == dataset)
            if mask.any():
                entry = df[mask].iloc[0]
                rmse = entry['rmse']
                error_rate = entry['error_rate']
                row[dataset] = f"{rmse:.3f}/{error_rate:.1f}%"
            else:
                row[dataset] = "N/A"
        table_data.append(row)

    return pd.DataFrame(table_data)

# Generate and display table
report_table = format_report_table(combined_df)

# Print as markdown table
print(report_table.to_markdown(index=False))

# ==============================================================================
# STEP 7: Save the report table
# ==============================================================================
report_table_path = os.path.join(RESULTS_DIR, 'Task3_report_table.csv')
report_table.to_csv(report_table_path, index=False)
print(f"\n✓ Report table saved to: {report_table_path}")

# ==============================================================================
# STEP 8: Display detailed results summary
# ==============================================================================
print("\n" + "=" * 70)
print("DETAILED RESULTS SUMMARY")
print("=" * 70)

print(f"\n{'Model':<15} {'Dataset':<20} {'RMSE':<10} {'Acc%':<10} {'ErrRate%':<10}")
print("-" * 70)

for _, row in combined_df.sort_values(['dataset', 'model']).iterrows():
    print(f"{row['model']:<15} {row['dataset']:<20} {row['rmse']:<10.3f} {row['accuracy']:<10.1f} {row['error_rate']:<10.1f}")

print("\n" + "=" * 70)
print(f"Total models: {combined_df['model'].nunique()}")
print(f"Total datasets: {combined_df['dataset'].nunique()}")
print(f"Total experiments: {len(combined_df)}")
print("=" * 70)
# Out:
# ======================================================================
# LOADING RESULTS FROM GOOGLE DRIVE
# ======================================================================
# ✓ Loaded EasyTPP results: 7 rows
#   Columns: ['model', 'stationary_hawkes']
# ✓ Loaded Meta-TPP results: 1 rows
#   Columns: ['model', 'dataset', 'log_likelihood', 'accuracy', 'rmse', 'status']
#
# ======================================================================
# PARSING EASYTPP RESULTS
# ======================================================================
#   Dataset columns found: ['stationary_hawkes']
# ✓ Parsed 7 EasyTPP results
#
# ======================================================================
# PARSING META-TPP RESULTS
# ======================================================================
# ✓ Parsed 1 Meta-TPP results
#
# ======================================================================
# COMBINING RESULTS
# ======================================================================
# ✓ Combined results: 8 total experiments
#   Models: ['AttNHP', 'FullyNN', 'IntensityFree', 'Meta-TPP', 'NHP', 'RMTPP', 'SAHP', 'THP']
#   Datasets: ['stationary_hawkes']
# ✓ Saved detailed results to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_combined_results.csv
#
# ======================================================================
# TABLE FOR REPORT
# ======================================================================
# | model         | stationary_hawkes   |
# |:--------------|:--------------------|
# | AttNHP        | 0.897/55.0%         |
# | FullyNN       | 1.073/54.1%         |
# | IntensityFree | 1.125/57.9%         |
# | Meta-TPP      | 2.090/54.7%         |
# | NHP           | 1.025/54.3%         |
# | RMTPP         | 1.204/54.6%         |
# | SAHP          | 1.065/56.8%         |
# | THP           | 1.145/52.5%         |
#
# ✓ Report table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_report_table.csv
#
# ======================================================================
# DETAILED RESULTS SUMMARY
# ======================================================================
#
# Model           Dataset              RMSE       Acc%       ErrRate%
# ----------------------------------------------------------------------
# AttNHP          stationary_hawkes    0.897      45.0       55.0
# FullyNN         stationary_hawkes    1.073      45.9       54.1
# IntensityFree   stationary_hawkes    1.125      42.1       57.9
# Meta-TPP        stationary_hawkes    2.090      45.3       54.7
# NHP             stationary_hawkes    1.025      45.7       54.3
# RMTPP           stationary_hawkes    1.204      45.4       54.6
# SAHP            stationary_hawkes    1.065      43.2       56.8
# THP             stationary_hawkes    1.145      47.5       52.5
#
# ======================================================================
# Total models: 8
# Total datasets: 1
# Total experiments: 8
# ======================================================================
