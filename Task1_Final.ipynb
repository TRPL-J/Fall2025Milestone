# %% [markdown]
# ## Package Installation

# %%
import os
import sys
import types

# Install core dependencies (includes upgrades from Task3)
# !pip install easy-tpp lightning pytorch-lightning hydra-core omegaconf torchmetrics stribor -q

print("✓ Core dependencies installed")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 65.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 65.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 67.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.4 MB/s eta 0:00:00
# ✓ Core dependencies installed

# %%
# Import required libraries
import os

# Set PyTorch memory allocation config BEFORE importing torch
# This helps prevent OOM errors with large models like AttNHP
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

import yaml
import pandas as pd
import numpy as np
from datetime import datetime
from easy_tpp.config_factory import Config
from easy_tpp.runner import Runner
from google.colab import drive
import json
from IPython.display import display, clear_output
import time

# %%
# ==============================================================================
# FULLYNN GRADIENT FIX - Monkey Patch
# ==============================================================================
# FullyNN uses torch.autograd.grad() to compute intensity derivatives, but during
# validation/evaluation, EasyTPP runs under torch.no_grad() context which disables
# gradient tracking. This patch wraps the computation in torch.enable_grad().
# ==============================================================================

import torch
from easy_tpp.model.torch_model import torch_fullynn

def patched_compute_intensities_at_sample_times(self, time_seqs, time_delta_seqs, type_seqs, sample_dtimes, **kwargs):
    """Patched version that enables gradients during intensity computation.

    FullyNN requires gradient computation for intensity derivatives via autograd.grad().
    During validation, EasyTPP disables gradients with torch.no_grad(), causing failures.
    This patch wraps the computation in torch.enable_grad() to fix the issue.
    """
    compute_last_step_only = kwargs.get('compute_last_step_only', False)

    # Enable gradients for this computation even during evaluation
    with torch.enable_grad():
        # Forward pass to get hidden states
        hidden_states = self.forward(
            time_seqs=time_seqs,
            time_delta_seqs=time_delta_seqs,
            type_seqs=type_seqs,
        )

        num_samples = sample_dtimes.size()[-1]
        batch_size, seq_len, hidden_size = hidden_states.shape

        # Expand hidden states for all sample times
        hidden_states_ = hidden_states[..., None, :].expand(batch_size, seq_len, num_samples, hidden_size)

        # Clone sample_dtimes to avoid in-place modification issues
        sample_dtimes_grad = sample_dtimes.clone().detach().requires_grad_(True)

        # Compute intensities (this uses autograd.grad internally)
        _, derivative_integral_lambda = self.layer_intensity.forward(
            hidden_states=hidden_states_,
            time_delta_seqs=sample_dtimes_grad,
        )

    # Detach the result since we don't need gradients flowing back
    derivative_integral_lambda = derivative_integral_lambda.detach()

    if compute_last_step_only:
        return derivative_integral_lambda[:, -1:, :, :]
    return derivative_integral_lambda

# Apply the monkey patch
torch_fullynn.FullyNN.compute_intensities_at_sample_times = patched_compute_intensities_at_sample_times
print("✓ FullyNN patched for gradient computation during evaluation")
print("  This fixes the 'element 0 of tensors does not require grad' error")
# Out:
# ✓ FullyNN patched for gradient computation during evaluation
#   This fixes the 'element 0 of tensors does not require grad' error

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Base directory (your Drive location)
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
CHECKPOINT_DIR = os.path.join(BASE_DIR, 'checkpoints')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task1')

# Create results directory if it doesn't exist
os.makedirs(RESULTS_DIR, exist_ok=True)

print(f"✓ Base Directory: {BASE_DIR}")
print(f"✓ Dataset Directory: {DATASET_DIR}")
print(f"✓ Checkpoint Directory: {CHECKPOINT_DIR}")
print(f"✓ Results Directory: {RESULTS_DIR}")
# Out:
# Mounted at /content/drive
# ✓ Base Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025
# ✓ Dataset Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets
# ✓ Checkpoint Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints
# ✓ Results Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task1

# %% [markdown]
# ## Configuration Dictionary

# %% [markdown]
# ### Dataset Configuration

# %%
# Data specifications for each dataset
data_spec_dict = {
    "taxi": {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, "taxi", "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, "taxi", "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, "taxi", "test.pkl"),
        "data_specs": {
            "num_event_types": 10,
            "pad_token_id": 10,
            "padding_side": "right",
            "max_seq_len": 100,
            "strict_pad_leng": True
        }
    },
    "amazon": {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, "amazon", "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, "amazon", "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, "amazon", "test.pkl"),
        "data_specs": {
            "num_event_types": 16,
            "pad_token_id": 16,
            "padding_side": "right",
            "max_seq_len": 100,
            "strict_pad_leng": True
        }
    },
    "taobao": {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, "taobao", "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, "taobao", "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, "taobao", "test.pkl"),
        "data_specs": {
            "num_event_types": 17,
            "pad_token_id": 17,
            "padding_side": "right",
            "max_seq_len": 150,
            "strict_pad_leng": True
        }
    },
    "stackoverflow": {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, "stackoverflow", "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, "stackoverflow", "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, "stackoverflow", "test.pkl"),
        "data_specs": {
            "num_event_types": 22,
            "pad_token_id": 22,
            "padding_side": "right",
            "max_seq_len": 100,
            "strict_pad_leng": True
        }
    },
    "retweet": {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, "retweet", "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, "retweet", "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, "retweet", "test.pkl"),
        "data_specs": {
            "num_event_types": 3,
            "pad_token_id": 3,
            "padding_side": "right",
            "max_seq_len": 100,
            "strict_pad_leng": True
        }
    }
}

print("✓ Data specifications loaded for 5 datasets")
# Out:
# ✓ Data specifications loaded for 5 datasets

# %% [markdown]
# ### Model Configuration

# %%
# Model specifications
model_spec_dict = {
    "RMTPP": {
        "model_id": "RMTPP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_heads": 2,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "NHP": {
        "model_id": "NHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_heads": 2,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "FullyNN": {
        "model_id": "FullyNN",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "num_heads": 2,
        "seed": 2019,
        "model_specs": {
            "num_mlp_layers": 3,
            "proper_marked_intensities": True
        },
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "SAHP": {
        "model_id": "SAHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "THP": {
        "model_id": "THP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "IntensityFree": {
        "model_id": "IntensityFree",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "num_heads": 2,
        "seed": 2019,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_mix_components": 3,
        "model_specs": {
            "num_mix_components": 3
        },
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5,
            "num_step_gen": 10
        }
    },
    "AttNHP": {
        "model_id": "AttNHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 4,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    }
}

print("✓ Model specifications loaded for 7 models")
# Out:
# ✓ Model specifications loaded for 7 models

# %% [markdown]
# ### Training Configuration

# %%
# Trainer configuration (shared across all experiments)
trainer_config = {
    "batch_size": 256,
    "max_epoch": 200,
    "shuffle": False,
    "optimizer": "adam",
    "learning_rate": 1e-3,
    "valid_freq": 1,
    "use_tfb": False,
    "metrics": ["acc", "rmse"],
    "seed": 2019,
    "gpu": 0
}

print("✓ Trainer configuration loaded")
print(f"  - Batch size: {trainer_config['batch_size']}")
print(f"  - Max epochs: {trainer_config['max_epoch']}")
print(f"  - Learning rate: {trainer_config['learning_rate']}")
# Out:
# ✓ Trainer configuration loaded
#   - Batch size: 256
#   - Max epochs: 200
#   - Learning rate: 0.001

# %% [markdown]
# ## Helper Functions

# %%
def create_experiment_config(model_id, data_id, data_spec, model_spec, trainer_cfg):
    """Create a complete experiment configuration."""
    experiment_id = f"{model_id}_{data_id}_train"

    config = {
        "pipeline_config_id": "runner_config",
        "data": {
            data_id: data_spec
        },
        experiment_id: {
            "base_config": {
                "stage": "train",
                "backend": "torch",
                "dataset_id": data_id,
                "runner_id": "std_tpp",
                "model_id": model_id,
                "base_dir": CHECKPOINT_DIR
            },
            "trainer_config": trainer_cfg,
            "model_config": model_spec
        }
    }

    return config, experiment_id

def extract_results_from_logs(log_path):
    """Extract best results from training logs.

    Args:
        log_path: Can be either a log file or a directory containing log files
    """
    try:
        # Determine if log_path is a file or directory
        if os.path.isfile(log_path):
            # It's a file - read it directly
            log_file = log_path
        elif os.path.isdir(log_path):
            # It's a directory - find .log files inside
            log_files = [f for f in os.listdir(log_path) if f.endswith('.log')]
            if not log_files:
                return None
            log_file = os.path.join(log_path, log_files[0])
        else:
            print(f"  Warning: Log path does not exist: {log_path}")
            return None

        # Read the log file
        with open(log_file, 'r') as f:
            lines = f.readlines()

        # Find the LAST test metrics (final epoch results)
        best_ll = None
        best_acc = None
        best_rmse = None

        for line in lines:
            if 'test loglike is' in line:
                try:
                    parts = line.split(',')
                    # Extract log-likelihood
                    ll_part = [p for p in parts if 'test loglike is' in p][0]
                    best_ll = float(ll_part.split('test loglike is')[1].strip())

                    # Extract accuracy
                    acc_parts = [p for p in parts if 'acc is' in p]
                    if acc_parts:
                        best_acc = float(acc_parts[0].split('acc is')[1].strip())

                    # Extract RMSE
                    rmse_parts = [p for p in parts if 'rmse is' in p]
                    if rmse_parts:
                        best_rmse = float(rmse_parts[0].split('rmse is')[1].strip())
                except (IndexError, ValueError) as e:
                    print(f"  Warning: Could not parse line: {e}")
                    continue

        if best_ll is None:
            return None

        return {
            'log_likelihood': best_ll,
            'accuracy': best_acc,
            'rmse': best_rmse
        }
    except Exception as e:
        print(f"  Warning: Could not extract results from logs: {e}")
        return None

def find_latest_checkpoint_dir(base_dir, model_id, data_id):
    """Find the most recent checkpoint directory for an experiment."""
    try:
        # EasyTPP creates directories with random names but puts
        # {model_id}_{data_id}_train_output.yaml inside them
        target_yaml = f"{model_id}_{data_id}_train_output.yaml"

        matching_dirs = []
        for d in os.listdir(base_dir):
            dir_path = os.path.join(base_dir, d)
            if os.path.isdir(dir_path):
                # Check if the target yaml file exists in this directory
                yaml_path = os.path.join(dir_path, target_yaml)
                if os.path.exists(yaml_path):
                    matching_dirs.append(dir_path)

        if not matching_dirs:
            return None

        # Return the most recently modified directory
        latest = max(matching_dirs, key=os.path.getmtime)
        return latest
    except Exception as e:
        print(f"  Warning: Error finding checkpoint dir: {e}")
        return None
print("✓ Helper functions loaded")
# Out:
# ✓ Helper functions loaded

# %%
def run_model_on_all_datasets(
    model_id,
    model_number,
    total_models,
    aggressive_gpu_clearing=False
):
    """
    Run a single TPP model on all configured datasets.

    This function encapsulates the complete workflow for running a model:
    - Creates and saves experiment configs for each dataset
    - Runs training and evaluation
    - Extracts metrics from logs
    - Saves results (both intermediate and model-specific)
    - Handles errors gracefully
    - Manages GPU memory

    Parameters
    ----------
    model_id : str
        The model identifier (e.g., 'RMTPP', 'NHP', 'AttNHP')
        Must exist as a key in model_spec_dict
    model_number : int
        Current model number (1-7) for progress tracking
    total_models : int
        Total number of models (typically 7) for progress tracking
    aggressive_gpu_clearing : bool, default=False
        If True, performs GPU memory clearing after EACH dataset.
        Use this for memory-intensive models like AttNHP.
        If False, only clears GPU memory after all datasets complete.

    Returns
    -------
    model_results : list of dict
        List containing result dictionaries for each dataset.
        Each dict contains: model, dataset, log_likelihood, accuracy,
        rmse, status, and time_seconds

    Side Effects
    ------------
    - Appends results to the global results_list
    - Saves intermediate results to 'intermediate_results.csv' after each dataset
    - Saves model-specific results to '{model_id}_results.csv'
    - Creates experiment config files in the configs directory
    - Clears GPU memory (timing depends on aggressive_gpu_clearing flag)

    Notes
    -----
    This function relies on several global variables and functions:
    - data_spec_dict: Dictionary of dataset configurations
    - model_spec_dict: Dictionary of model configurations
    - trainer_config: Training configuration
    - results_list: Global list to store all results
    - total_experiments: Total number of experiments
    - BASE_DIR, CHECKPOINT_DIR, RESULTS_DIR: Directory paths
    - create_experiment_config(): Function to create config dicts
    - find_latest_checkpoint_dir(): Function to locate checkpoints
    - extract_results_from_logs(): Function to parse training logs

    Example
    -------
    >>> # Run RMTPP on all datasets (standard memory management)
    >>> rmtpp_results = run_model_on_all_datasets('RMTPP', 1, 7)

    >>> # Run AttNHP with aggressive memory clearing
    >>> attnhp_results = run_model_on_all_datasets('AttNHP', 7, 7,
    ...                                             aggressive_gpu_clearing=True)
    """
    import time
    import os
    import yaml
    import pandas as pd
    import torch
    import gc
    from easy_tpp.config_factory import Config
    from easy_tpp.runner import Runner

    print("\n" + "=" * 70)
    print(f"[MODEL {model_number}/{total_models}] Running {model_id} on all datasets")
    print("=" * 70)

    model_start_time = time.time()
    model_results = []

    for data_id, data_spec in data_spec_dict.items():
        experiment_name = f"{model_id}_{data_id}"
        experiment_num = len(results_list) + 1

        print(f"\n[{experiment_num}/{total_experiments}] Running {model_id} on {data_id} dataset")
        print("=" * 70)

        try:
            # Create config
            config_dict, experiment_id = create_experiment_config(
                model_id=model_id,
                data_id=data_id,
                data_spec=data_spec,
                model_spec=model_spec_dict[model_id],
                trainer_cfg=trainer_config
            )

            # Save config
            CONFIG_DIR = os.path.join(BASE_DIR, 'configs')
            os.makedirs(CONFIG_DIR, exist_ok=True)
            config_path = os.path.join(CONFIG_DIR, f"{experiment_name}.yaml")
            with open(config_path, 'w') as f:
                yaml.dump(config_dict, f)

            # Build and run
            config = Config.build_from_yaml_file(config_path, experiment_id=experiment_id)
            runner = Runner.build_from_config(config)
            runner.run()

            # Find checkpoint directory
            checkpoint_dir = find_latest_checkpoint_dir(CHECKPOINT_DIR, model_id, data_id)

            # Extract results from logs
            if checkpoint_dir:
                log_dir = os.path.join(checkpoint_dir, 'log')
                metrics = extract_results_from_logs(log_dir)

                if metrics:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': metrics['log_likelihood'],
                        'accuracy': metrics['accuracy'],
                        'rmse': metrics['rmse'],
                        'status': 'success',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"✓ {model_id} on {data_id} completed successfully!")
                    print(f"  - Log-Likelihood: {metrics['log_likelihood']:.4f}")
                    if metrics['accuracy'] and metrics['accuracy'] > 0:
                        print(f"  - Accuracy: {metrics['accuracy']:.4f}")
                    if metrics['rmse'] and metrics['rmse'] > 0:
                        print(f"  - RMSE: {metrics['rmse']:.4f}")
                else:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': None,
                        'accuracy': None,
                        'rmse': None,
                        'status': 'completed_no_metrics',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"⚠ {model_id} on {data_id} completed but no metrics found")
            else:
                result = {
                    'model': model_id,
                    'dataset': data_id,
                    'log_likelihood': None,
                    'accuracy': None,
                    'rmse': None,
                    'status': 'no_checkpoint',
                    'time_seconds': time.time() - model_start_time
                }
                print(f"⚠ {model_id} on {data_id} - no checkpoint directory found")

        except Exception as e:
            result = {
                'model': model_id,
                'dataset': data_id,
                'log_likelihood': None,
                'accuracy': None,
                'rmse': None,
                'status': 'failed',
                'error': str(e),
                'time_seconds': time.time() - model_start_time
            }
            print(f"✗ Error running {model_id} on {data_id}: {str(e)}")

        results_list.append(result)
        model_results.append(result)

        # Save intermediate results after each experiment
        intermediate_df = pd.DataFrame(results_list)
        intermediate_df.to_csv(os.path.join(RESULTS_DIR, 'intermediate_results.csv'), index=False)

        # Aggressive GPU memory clearing (for memory-intensive models like AttNHP)
        if aggressive_gpu_clearing:
            try:
                del runner
                del config
            except:
                pass
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
                torch.cuda.synchronize()

    # Save model-specific results
    model_df = pd.DataFrame(model_results)
    model_csv_path = os.path.join(RESULTS_DIR, f'{model_id}_results.csv')
    model_df.to_csv(model_csv_path, index=False)

    # Model summary
    model_elapsed = time.time() - model_start_time
    successful = sum(1 for r in model_results if r['status'] == 'success')
    failed = sum(1 for r in model_results if r['status'] == 'failed')

    print(f"\n" + "=" * 70)
    print(f"✓ {model_id} completed on all datasets")
    print(f"  - Time: {model_elapsed/60:.1f} minutes")
    print(f"  - Successful: {successful}/{len(data_spec_dict)}")
    print(f"  - Failed: {failed}/{len(data_spec_dict)}")
    print(f"  - Results saved to: {model_csv_path}")
    print("=" * 70)

    # Clear GPU memory for next model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        print(f"✓ GPU memory cleared for next model")

    return model_results

# %% [markdown]
# ## Run Models On Data

# %%
# Initialize results storage
results_list = []
total_experiments = len(model_spec_dict) * len(data_spec_dict)

print(f"Starting {total_experiments} experiments...")
print(f"Running {len(model_spec_dict)} models on {len(data_spec_dict)} datasets")
print(f"Results will be saved incrementally to: {RESULTS_DIR}")
print("=" * 70)
# Out:
# Starting 35 experiments...
# Running 7 models on 5 datasets
# Results will be saved incrementally to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task1
# ======================================================================

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
all_model_results = {}

for i, model_id in enumerate(model_ids, start=1):
    aggressive = (model_id == 'AttNHP')
    all_model_results[model_id] = run_model_on_all_datasets(
        model_id, i, len(model_ids), aggressive
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-12-27 20:45:03,866 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 191 (train) ]: train loglike is 0.45573251441398116, num_events is 281923
# 2025-12-27 20:45:03,917 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 191 (valid) ]:  valid loglike is 0.4618953040096355, num_events is 40073, acc is 0.34197589399346195, rmse is 0.4643988676383742
# 2025-12-27 20:45:04,022 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 191 (test) ]: test loglike is 0.4625595009051235, num_events is 82197, acc is 0.34962346557660257, rmse is 0.4632546300784409
# 2025-12-27 20:45:04,025 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4619 (updated at epoch-191), best updated at this epoch
# 2025-12-27 20:45:04,365 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 192 (train) ]: train loglike is 0.4558624989483498, num_events is 281923
# 2025-12-27 20:45:04,415 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 192 (valid) ]:  valid loglike is 0.46200574089006313, num_events is 40073, acc is 0.3418511217028922, rmse is 0.46519749067572497
# 2025-12-27 20:45:04,523 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 192 (test) ]: test loglike is 0.46268290780267224, num_events is 82197, acc is 0.3496964609413969, rmse is 0.4652722539453473
# 2025-12-27 20:45:04,526 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4620 (updated at epoch-192), best updated at this epoch
# 2025-12-27 20:45:04,856 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 193 (train) ]: train loglike is 0.45598761514080033, num_events is 281923
# 2025-12-27 20:45:04,908 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 193 (valid) ]:  valid loglike is 0.4621136494257355, num_events is 40073, acc is 0.34167644049609464, rmse is 0.46556869576955445
# 2025-12-27 20:45:05,017 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 193 (test) ]: test loglike is 0.4628002183873043, num_events is 82197, acc is 0.34972079272966167, rmse is 0.4630643771792436
# 2025-12-27 20:45:05,020 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4621 (updated at epoch-193), best updated at this epoch
# 2025-12-27 20:45:05,352 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 194 (train) ]: train loglike is 0.45611208097975225, num_events is 281923
# 2025-12-27 20:45:05,403 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 194 (valid) ]:  valid loglike is 0.4622108475274811, num_events is 40073, acc is 0.34152671374741095, rmse is 0.4662852820059024
# 2025-12-27 20:45:05,507 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 194 (test) ]: test loglike is 0.4629127989459583, num_events is 82197, acc is 0.3496842950472645, rmse is 0.46286992159597434
# 2025-12-27 20:45:05,510 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4622 (updated at epoch-194), best updated at this epoch
# 2025-12-27 20:45:05,842 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 195 (train) ]: train loglike is 0.4562346167583048, num_events is 281923
# 2025-12-27 20:45:05,892 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 195 (valid) ]:  valid loglike is 0.4623198283250256, num_events is 40073, acc is 0.3416265315798667, rmse is 0.46416094893081006
# 2025-12-27 20:45:05,995 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 195 (test) ]: test loglike is 0.4630266552007867, num_events is 82197, acc is 0.349793788094456, rmse is 0.4635268741851284
# 2025-12-27 20:45:05,998 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4623 (updated at epoch-195), best updated at this epoch
# 2025-12-27 20:45:06,327 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 196 (train) ]: train loglike is 0.4563589360295741, num_events is 281923
# 2025-12-27 20:45:06,379 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 196 (valid) ]:  valid loglike is 0.46242666459882587, num_events is 40073, acc is 0.3416265315798667, rmse is 0.46375674104494136
# 2025-12-27 20:45:06,496 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 196 (test) ]: test loglike is 0.4631404208648506, num_events is 82197, acc is 0.34981811988272077, rmse is 0.4635805463582601
# 2025-12-27 20:45:06,499 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4624 (updated at epoch-196), best updated at this epoch
# 2025-12-27 20:45:06,828 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 197 (train) ]: train loglike is 0.4564771743657344, num_events is 281923
# 2025-12-27 20:45:06,880 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 197 (valid) ]:  valid loglike is 0.4625123846246226, num_events is 40073, acc is 0.3416265315798667, rmse is 0.465980431361091
# 2025-12-27 20:45:06,985 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 197 (test) ]: test loglike is 0.46324197756704166, num_events is 82197, acc is 0.34985461756511793, rmse is 0.4709847093267525
# 2025-12-27 20:45:06,988 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4625 (updated at epoch-197), best updated at this epoch
# 2025-12-27 20:45:07,322 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 198 (train) ]: train loglike is 0.45659010465692873, num_events is 281923
# 2025-12-27 20:45:07,376 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 198 (valid) ]:  valid loglike is 0.4626158578952786, num_events is 40073, acc is 0.3416265315798667, rmse is 0.46710248717117114
# 2025-12-27 20:45:07,481 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 198 (test) ]: test loglike is 0.46336189300742425, num_events is 82197, acc is 0.3498911152475151, rmse is 0.46431192713217984
# 2025-12-27 20:45:07,484 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4626 (updated at epoch-198), best updated at this epoch
# 2025-12-27 20:45:07,826 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 199 (train) ]: train loglike is 0.4567085612208941, num_events is 281923
# 2025-12-27 20:45:07,882 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 199 (valid) ]:  valid loglike is 0.46270998542893593, num_events is 40073, acc is 0.34167644049609464, rmse is 0.4675373028010944
# 2025-12-27 20:45:07,990 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 199 (test) ]: test loglike is 0.4634671921477517, num_events is 82197, acc is 0.34991544703577987, rmse is 0.4641398302135478
# 2025-12-27 20:45:07,993 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is 0.4627 (updated at epoch-199), best updated at this epoch
# 2025-12-27 20:45:07,996 - base_runner.py[pid:5428;line:110:train] - INFO: End IntensityFree train! Cost time: 1.663m
# ✓ IntensityFree on amazon completed successfully!
#   - Log-Likelihood: 0.4635
#   - Accuracy: 0.3499
#   - RMSE: 0.4641
#
# [28/35] Running IntensityFree on taobao dataset
# ======================================================================
# 2025-12-27 20:45:08,881 - config.py[pid:5428;line:34:build_from_yaml_file] - CRITICAL: Load pipeline config class RunnerConfig
# 2025-12-27 20:45:08,891 - runner_config.py[pid:5428;line:140:update_config] - CRITICAL: train model IntensityFree using GPU with torch backend
# 2025-12-27 20:45:08,905 - runner_config.py[pid:5428;line:35:__init__] - INFO: Save the config to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/5428_139348884681344_251227-204508/IntensityFree_taobao_train_output.yaml
# 2025-12-27 20:45:08,910 - base_runner.py[pid:5428;line:176:save_log] - INFO: Save the log to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/5428_139348884681344_251227-204508/log
# 0.22157282176421386 0.4903059329367309
# min_dt: 0.0
# max_dt: 1.9998000000196043
# 2025-12-27 20:45:09,019 - tpp_runner.py[pid:5428;line:60:_init_model] - INFO: Num of model parameters 7899
# 2025-12-27 20:45:09,093 - base_runner.py[pid:5428;line:98:train] - INFO: Data 'taobao' loaded...
# 2025-12-27 20:45:09,096 - base_runner.py[pid:5428;line:103:train] - INFO: Start IntensityFree training...
# 2025-12-27 20:45:09,166 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 0 (train) ]: train loglike is -29.58374280114674, num_events is 73905
# 2025-12-27 20:45:09,181 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 0 (valid) ]:  valid loglike is -20.519705621045333, num_events is 11537, acc is 0.025309872583860624, rmse is 2.0811823686960964
# 2025-12-27 20:45:09,213 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 0 (test) ]: test loglike is -19.431647961008764, num_events is 27955, acc is 0.028939366839563583, rmse is 2.042863925658741
# 2025-12-27 20:45:09,216 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -20.5197 (updated at epoch-0), best updated at this epoch
# 2025-12-27 20:45:09,285 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 1 (train) ]: train loglike is -16.750180526309112, num_events is 73905
# 2025-12-27 20:45:09,299 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 1 (valid) ]:  valid loglike is -11.748748591488255, num_events is 11537, acc is 0.03441102539655023, rmse is 6.514977324484624
# 2025-12-27 20:45:09,333 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 1 (test) ]: test loglike is -11.04371869969594, num_events is 27955, acc is 0.041173314255052766, rmse is 5.470999242204772
# 2025-12-27 20:45:09,336 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -11.7487 (updated at epoch-1), best updated at this epoch
# 2025-12-27 20:45:09,401 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 2 (train) ]: train loglike is -9.79274882027603, num_events is 73905
# 2025-12-27 20:45:09,416 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 2 (valid) ]:  valid loglike is -7.133082690474127, num_events is 11537, acc is 0.21218687700442057, rmse is 31.133639664154064
# 2025-12-27 20:45:09,450 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 2 (test) ]: test loglike is -6.69273972679306, num_events is 27955, acc is 0.2597746378107673, rmse is 74.14108650718178
# 2025-12-27 20:45:09,454 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -7.1331 (updated at epoch-2), best updated at this epoch
# 2025-12-27 20:45:09,523 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 3 (train) ]: train loglike is -6.134163348693001, num_events is 73905
# 2025-12-27 20:45:09,537 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 3 (valid) ]:  valid loglike is -4.671721959781572, num_events is 11537, acc is 0.3487908468405998, rmse is 147.13236798465397
# 2025-12-27 20:45:09,570 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 3 (test) ]: test loglike is -4.394258909407977, num_events is 27955, acc is 0.3701305669826507, rmse is 905.3416691805743
# 2025-12-27 20:45:09,573 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.6717 (updated at epoch-3), best updated at this epoch
# 2025-12-27 20:45:09,638 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 4 (train) ]: train loglike is -4.1325508148129355, num_events is 73905
# 2025-12-27 20:45:09,652 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 4 (valid) ]:  valid loglike is -3.277535727442143, num_events is 11537, acc is 0.37964808875790934, rmse is 2001.4779581436874
# 2025-12-27 20:45:09,686 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 4 (test) ]: test loglike is -3.0947736876229657, num_events is 27955, acc is 0.40146664281881594, rmse is 4003.6464653819917
# 2025-12-27 20:45:09,690 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -3.2775 (updated at epoch-4), best updated at this epoch
# 2025-12-27 20:45:09,756 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 5 (train) ]: train loglike is -2.9614197392609176, num_events is 73905
# 2025-12-27 20:45:09,771 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 5 (valid) ]:  valid loglike is -2.4340863905261334, num_events is 11537, acc is 0.39568345323741005, rmse is 13660.937822842772
# 2025-12-27 20:45:09,803 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 5 (test) ]: test loglike is -2.2966675656188515, num_events is 27955, acc is 0.4161330710069755, rmse is 249179.81119287404
# 2025-12-27 20:45:09,807 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -2.4341 (updated at epoch-5), best updated at this epoch
# 2025-12-27 20:45:09,877 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 6 (train) ]: train loglike is -2.2311097690341484, num_events is 73905
# 2025-12-27 20:45:09,891 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 6 (valid) ]:  valid loglike is -1.8999286263760076, num_events is 11537, acc is 0.40894513305018637, rmse is 84612.80530316
# 2025-12-27 20:45:09,924 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 6 (test) ]: test loglike is -1.775470762162404, num_events is 27955, acc is 0.4277231264532284, rmse is 323431.92715027195
# 2025-12-27 20:45:09,927 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.8999 (updated at epoch-6), best updated at this epoch
# 2025-12-27 20:45:09,994 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 7 (train) ]: train loglike is -1.7550759513374434, num_events is 73905
# 2025-12-27 20:45:10,008 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 7 (valid) ]:  valid loglike is -1.55123258321054, num_events is 11537, acc is 0.41743954234203, rmse is 587493.076669091
# 2025-12-27 20:45:10,041 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 7 (test) ]: test loglike is -1.4241474160481131, num_events is 27955, acc is 0.4340189590413164, rmse is 114840149.24783306
# 2025-12-27 20:45:10,044 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.5512 (updated at epoch-7), best updated at this epoch
# 2025-12-27 20:45:10,124 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 8 (train) ]: train loglike is -1.4380456355498612, num_events is 73905
# 2025-12-27 20:45:10,137 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 8 (valid) ]:  valid loglike is -1.320833920213227, num_events is 11537, acc is 0.4195198058420733, rmse is 2991279.745023223
# 2025-12-27 20:45:10,169 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 8 (test) ]: test loglike is -1.1868665181765337, num_events is 27955, acc is 0.4358433196208192, rmse is 11989295.988307055
# 2025-12-27 20:45:10,172 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.3208 (updated at epoch-8), best updated at this epoch
# 2025-12-27 20:45:10,240 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 9 (train) ]: train loglike is -1.2263485528032187, num_events is 73905
# 2025-12-27 20:45:10,255 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 9 (valid) ]:  valid loglike is -1.1694839158793446, num_events is 11537, acc is 0.42021322700875446, rmse is 357906085.85646874
# 2025-12-27 20:45:10,287 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 9 (test) ]: test loglike is -1.0290046223841889, num_events is 27955, acc is 0.4355571454122697, rmse is 136937567.18202737
# 2025-12-27 20:45:10,290 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1695 (updated at epoch-9), best updated at this epoch
# 2025-12-27 20:45:10,356 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 10 (train) ]: train loglike is -1.0870304748481476, num_events is 73905
# 2025-12-27 20:45:10,369 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 10 (valid) ]:  valid loglike is -1.0713108165575973, num_events is 11537, acc is 0.42047325994625984, rmse is 136178534.4446992
# 2025-12-27 20:45:10,401 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 10 (test) ]: test loglike is -0.9254804736406725, num_events is 27955, acc is 0.4357360042926131, rmse is 5314883876.901275
# 2025-12-27 20:45:10,404 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0713 (updated at epoch-10), best updated at this epoch
# 2025-12-27 20:45:10,471 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 11 (train) ]: train loglike is -0.9965969859162522, num_events is 73905
# 2025-12-27 20:45:10,485 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 11 (valid) ]:  valid loglike is -1.0074270214852215, num_events is 11537, acc is 0.42047325994625984, rmse is 516592217.747574
# 2025-12-27 20:45:10,516 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 11 (test) ]: test loglike is -0.8575433383451082, num_events is 27955, acc is 0.4357360042926131, rmse is 6993670957.022128
# 2025-12-27 20:45:10,519 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0074 (updated at epoch-11), best updated at this epoch
# 2025-12-27 20:45:10,584 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 12 (train) ]: train loglike is -0.9377252102704697, num_events is 73905
# 2025-12-27 20:45:10,601 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 12 (valid) ]:  valid loglike is -0.9642353135563838, num_events is 11537, acc is 0.42047325994625984, rmse is 232153105.71848688
# 2025-12-27 20:45:10,632 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 12 (test) ]: test loglike is -0.8114282789863173, num_events is 27955, acc is 0.4357360042926131, rmse is 2688137619.809997
# 2025-12-27 20:45:10,635 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9642 (updated at epoch-12), best updated at this epoch
# 2025-12-27 20:45:10,701 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 13 (train) ]: train loglike is -0.897796089508385, num_events is 73905
# 2025-12-27 20:45:10,715 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 13 (valid) ]:  valid loglike is -0.9326169335615845, num_events is 11537, acc is 0.420559937592095, rmse is 22269103.589427974
# 2025-12-27 20:45:10,747 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 13 (test) ]: test loglike is -0.7777713345108209, num_events is 27955, acc is 0.4357360042926131, rmse is 565966489.5120814
# 2025-12-27 20:45:10,750 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9326 (updated at epoch-13), best updated at this epoch
# 2025-12-27 20:45:10,817 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 14 (train) ]: train loglike is -0.8684376450209518, num_events is 73905
# 2025-12-27 20:45:10,830 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 14 (valid) ]:  valid loglike is -0.9070922290781832, num_events is 11537, acc is 0.420559937592095, rmse is 1148141281.0205755
# 2025-12-27 20:45:10,865 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 14 (test) ]: test loglike is -0.7508648106331605, num_events is 27955, acc is 0.4357360042926131, rmse is 136471151.50212628
# 2025-12-27 20:45:10,868 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9071 (updated at epoch-14), best updated at this epoch
# 2025-12-27 20:45:10,934 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 15 (train) ]: train loglike is -0.8447045070926147, num_events is 73905
# 2025-12-27 20:45:10,948 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 15 (valid) ]:  valid loglike is -0.8847361681437982, num_events is 11537, acc is 0.420559937592095, rmse is 113024181.37202886
# 2025-12-27 20:45:10,980 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 15 (test) ]: test loglike is -0.7275882836254695, num_events is 27955, acc is 0.4357360042926131, rmse is 881004105.5126188
# 2025-12-27 20:45:10,983 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8847 (updated at epoch-15), best updated at this epoch
# 2025-12-27 20:45:11,051 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 16 (train) ]: train loglike is -0.8239239164589465, num_events is 73905
# 2025-12-27 20:45:11,066 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 16 (valid) ]:  valid loglike is -0.8641239869550144, num_events is 11537, acc is 0.420559937592095, rmse is 13177179112.680387
# 2025-12-27 20:45:11,099 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 16 (test) ]: test loglike is -0.706359900397961, num_events is 27955, acc is 0.4357360042926131, rmse is 875200475.83739
# 2025-12-27 20:45:11,103 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8641 (updated at epoch-16), best updated at this epoch
# 2025-12-27 20:45:11,172 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 17 (train) ]: train loglike is -0.8047173184879448, num_events is 73905
# 2025-12-27 20:45:11,186 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 17 (valid) ]:  valid loglike is -0.8445781778191904, num_events is 11537, acc is 0.42047325994625984, rmse is 80349568.13426839
# 2025-12-27 20:45:11,222 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 17 (test) ]: test loglike is -0.6863910050751207, num_events is 27955, acc is 0.4357360042926131, rmse is 95304233.06378266
# 2025-12-27 20:45:11,226 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8446 (updated at epoch-17), best updated at this epoch
# 2025-12-27 20:45:11,297 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 18 (train) ]: train loglike is -0.7863764361368691, num_events is 73905
# 2025-12-27 20:45:11,314 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 18 (valid) ]:  valid loglike is -0.8257433962468579, num_events is 11537, acc is 0.420559937592095, rmse is 256397933190.6502
# 2025-12-27 20:45:11,353 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 18 (test) ]: test loglike is -0.6672653664930245, num_events is 27955, acc is 0.4357360042926131, rmse is 13658015333.659986
# 2025-12-27 20:45:11,356 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8257 (updated at epoch-18), best updated at this epoch
# 2025-12-27 20:45:11,424 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 19 (train) ]: train loglike is -0.7685156359013472, num_events is 73905
# 2025-12-27 20:45:11,437 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 19 (valid) ]:  valid loglike is -0.8073912669563145, num_events is 11537, acc is 0.420559937592095, rmse is 919468764.3589902
# 2025-12-27 20:45:11,469 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 19 (test) ]: test loglike is -0.6487420840972098, num_events is 27955, acc is 0.4357360042926131, rmse is 383976939.77291214
# 2025-12-27 20:45:11,472 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8074 (updated at epoch-19), best updated at this epoch
# 2025-12-27 20:45:11,543 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 20 (train) ]: train loglike is -0.7509069061950308, num_events is 73905
# 2025-12-27 20:45:11,561 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 20 (valid) ]:  valid loglike is -0.7893496197018289, num_events is 11537, acc is 0.420559937592095, rmse is 119994454214.36133
# 2025-12-27 20:45:11,592 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 20 (test) ]: test loglike is -0.6306728307771419, num_events is 27955, acc is 0.4357360042926131, rmse is 702736557.0598999
# 2025-12-27 20:45:11,596 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.7893 (updated at epoch-20), best updated at this epoch
# 2025-12-27 20:45:11,668 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 21 (train) ]: train loglike is -0.733406634982727, num_events is 73905
# 2025-12-27 20:45:11,682 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 21 (valid) ]:  valid loglike is -0.771480565923767, num_events is 11537, acc is 0.42073329288376526, rmse is 7760927.881281812
# 2025-12-27 20:45:11,715 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 21 (test) ]: test loglike is -0.6129641946878912, num_events is 27955, acc is 0.4357360042926131, rmse is 432482175.0876992
# 2025-12-27 20:45:11,718 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.7715 (updated at epoch-21), best updated at this epoch
# 2025-12-27 20:45:11,785 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 22 (train) ]: train loglike is -0.7159207287728968, num_events is 73905
# 2025-12-27 20:45:11,799 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 22 (valid) ]:  valid loglike is -0.7536744888727572, num_events is 11537, acc is 0.4208199705296004, rmse is 25258441.09617151
# 2025-12-27 20:45:11,829 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 22 (test) ]: test loglike is -0.595554728022715, num_events is 27955, acc is 0.4364156680379181, rmse is 184747339.33252636
# 2025-12-27 20:45:11,833 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.7537 (updated at epoch-22), best updated at this epoch
# 2025-12-27 20:45:11,897 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 23 (train) ]: train loglike is -0.6983840701851194, num_events is 73905
# 2025-12-27 20:45:11,911 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 23 (valid) ]:  valid loglike is -0.735845642010488, num_events is 11537, acc is 0.4208199705296004, rmse is 9152573.215440976
# 2025-12-27 20:45:11,943 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 23 (test) ]: test loglike is -0.5783999780618404, num_events is 27955, acc is 0.4364156680379181, rmse is 82812515.80711196
# 2025-12-27 20:45:11,947 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.7358 (updated at epoch-23), best updated at this epoch
# 2025-12-27 20:45:12,012 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 24 (train) ]: train loglike is -0.6807480772005657, num_events is 73905
# 2025-12-27 20:45:12,027 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 24 (valid) ]:  valid loglike is -0.717929017102583, num_events is 11537, acc is 0.4208199705296004, rmse is 8181259.767165067
# 2025-12-27 20:45:12,063 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 24 (test) ]: test loglike is -0.5614633171615095, num_events is 27955, acc is 0.4364156680379181, rmse is 58684827.85576999
# 2025-12-27 20:45:12,066 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.7179 (updated at epoch-24), best updated at this epoch
# 2025-12-27 20:45:12,133 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 25 (train) ]: train loglike is -0.6629740673798394, num_events is 73905
# 2025-12-27 20:45:12,146 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 25 (valid) ]:  valid loglike is -0.6998756886809829, num_events is 11537, acc is 0.42090664817543555, rmse is 17632210.38467805
# 2025-12-27 20:45:12,178 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 25 (test) ]: test loglike is -0.5447134100842872, num_events is 27955, acc is 0.43648721159005544, rmse is 17179012.898030683
# 2025-12-27 20:45:12,181 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.6999 (updated at epoch-25), best updated at this epoch
# 2025-12-27 20:45:12,248 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 26 (train) ]: train loglike is -0.6450306964593218, num_events is 73905
# 2025-12-27 20:45:12,262 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 26 (valid) ]:  valid loglike is -0.6816503593059288, num_events is 11537, acc is 0.4209933258212707, rmse is 174884008.6363364
# 2025-12-27 20:45:12,295 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 26 (test) ]: test loglike is -0.5281248253331247, num_events is 27955, acc is 0.43655875514219283, rmse is 17270721.12546677
# 2025-12-27 20:45:12,298 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.6817 (updated at epoch-26), best updated at this epoch
# 2025-12-27 20:45:12,364 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 27 (train) ]: train loglike is -0.626893791114596, num_events is 73905
# 2025-12-27 20:45:12,378 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 27 (valid) ]:  valid loglike is -0.6632304707815073, num_events is 11537, acc is 0.42108000346710583, rmse is 12931208.3893579
# 2025-12-27 20:45:12,412 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 27 (test) ]: test loglike is -0.5116806551544893, num_events is 27955, acc is 0.4365945269182615, rmse is 1108508544.6615345
# 2025-12-27 20:45:12,415 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.6632 (updated at epoch-27), best updated at this epoch
# 2025-12-27 20:45:12,481 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 28 (train) ]: train loglike is -0.6085488703099101, num_events is 73905
# 2025-12-27 20:45:12,494 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 28 (valid) ]:  valid loglike is -0.6446082779860449, num_events is 11537, acc is 0.4212533587587761, rmse is 14379126.314211497
# 2025-12-27 20:45:12,526 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 28 (test) ]: test loglike is -0.49537398274011807, num_events is 27955, acc is 0.4367376140225362, rmse is 4372409.836533565
# 2025-12-27 20:45:12,529 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.6446 (updated at epoch-28), best updated at this epoch
# 2025-12-27 20:45:12,593 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 29 (train) ]: train loglike is -0.5899960178700169, num_events is 73905
# 2025-12-27 20:45:12,607 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 29 (valid) ]:  valid loglike is -0.6257946579483401, num_events is 11537, acc is 0.42134003640461126, rmse is 621080.0876699784
# 2025-12-27 20:45:12,637 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 29 (test) ]: test loglike is -0.4792088603615185, num_events is 27955, acc is 0.4369164729028796, rmse is 10376524.523119796
# 2025-12-27 20:45:12,641 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.6258 (updated at epoch-29), best updated at this epoch
# 2025-12-27 20:45:12,707 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 30 (train) ]: train loglike is -0.5712549041196786, num_events is 73905
# 2025-12-27 20:45:12,721 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 30 (valid) ]:  valid loglike is -0.6068219878163734, num_events is 11537, acc is 0.42168674698795183, rmse is 3579185.749515502
# 2025-12-27 20:45:12,757 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 30 (test) ]: test loglike is -0.46320018710315686, num_events is 27955, acc is 0.4370237882310857, rmse is 36424003.92335481
# 2025-12-27 20:45:12,760 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.6068 (updated at epoch-30), best updated at this epoch
# 2025-12-27 20:45:12,828 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 31 (train) ]: train loglike is -0.5523678304152079, num_events is 73905
# 2025-12-27 20:45:12,842 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 31 (valid) ]:  valid loglike is -0.5877435523343374, num_events is 11537, acc is 0.42264020109213835, rmse is 3740427.410978359
# 2025-12-27 20:45:12,873 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 31 (test) ]: test loglike is -0.4473717700601413, num_events is 27955, acc is 0.4372026471114291, rmse is 3251834.3064019224
# 2025-12-27 20:45:12,876 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.5877 (updated at epoch-31), best updated at this epoch
# 2025-12-27 20:45:12,942 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 32 (train) ]: train loglike is -0.5333965677537886, num_events is 73905
# 2025-12-27 20:45:12,956 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 32 (valid) ]:  valid loglike is -0.5686257140748244, num_events is 11537, acc is 0.4238536881338303, rmse is 1712333.6814120193
# 2025-12-27 20:45:12,987 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 32 (test) ]: test loglike is -0.43174893592939545, num_events is 27955, acc is 0.4379896261849401, rmse is 17973614.08127099
# 2025-12-27 20:45:12,992 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.5686 (updated at epoch-32), best updated at this epoch
# 2025-12-27 20:45:13,059 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 33 (train) ]: train loglike is -0.5144117221789692, num_events is 73905
# 2025-12-27 20:45:13,072 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 33 (valid) ]:  valid loglike is -0.549535936010228, num_events is 11537, acc is 0.42645401750888445, rmse is 269920385.6693342
# 2025-12-27 20:45:13,107 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 33 (test) ]: test loglike is -0.4163485749977643, num_events is 27955, acc is 0.4397424432123055, rmse is 2937819.536901462
# 2025-12-27 20:45:13,110 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.5495 (updated at epoch-33), best updated at this epoch
# 2025-12-27 20:45:13,176 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 34 (train) ]: train loglike is -0.4954790073418261, num_events is 73905
# 2025-12-27 20:45:13,190 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 34 (valid) ]:  valid loglike is -0.5305306771149345, num_events is 11537, acc is 0.4300944786339603, rmse is 9088396.470491512
# 2025-12-27 20:45:13,224 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 34 (test) ]: test loglike is -0.4011720147335003, num_events is 27955, acc is 0.44221069576104455, rmse is 14182754.014030404
# 2025-12-27 20:45:13,227 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.5305 (updated at epoch-34), best updated at this epoch
# 2025-12-27 20:45:13,294 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 35 (train) ]: train loglike is -0.4766493222103915, num_events is 73905
# 2025-12-27 20:45:13,308 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 35 (valid) ]:  valid loglike is -0.5116511177353298, num_events is 11537, acc is 0.43503510444656324, rmse is 5711219.532513332
# 2025-12-27 20:45:13,341 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 35 (test) ]: test loglike is -0.3862053341866392, num_events is 27955, acc is 0.4443212305490968, rmse is 8303704.504502666
# 2025-12-27 20:45:13,345 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.5117 (updated at epoch-35), best updated at this epoch
# 2025-12-27 20:45:13,413 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 36 (train) ]: train loglike is -0.45795713403649, num_events is 73905
# 2025-12-27 20:45:13,429 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 36 (valid) ]:  valid loglike is -0.4929247255433605, num_events is 11537, acc is 0.43832885498829854, rmse is 165011.18794452987
# 2025-12-27 20:45:13,460 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 36 (test) ]: test loglike is -0.3714264030640762, num_events is 27955, acc is 0.4466463959935611, rmse is 2508039.229180117
# 2025-12-27 20:45:13,463 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.4929 (updated at epoch-36), best updated at this epoch
# 2025-12-27 20:45:13,530 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 37 (train) ]: train loglike is -0.43942437187098304, num_events is 73905
# 2025-12-27 20:45:13,543 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 37 (valid) ]:  valid loglike is -0.47436969945880647, num_events is 11537, acc is 0.44058247378001214, rmse is 204942.36206906266
# 2025-12-27 20:45:13,574 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 37 (test) ]: test loglike is -0.35681132693726525, num_events is 27955, acc is 0.44904310499016276, rmse is 5228361.139502822
# 2025-12-27 20:45:13,582 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.4744 (updated at epoch-37), best updated at this epoch
# 2025-12-27 20:45:13,649 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 38 (train) ]: train loglike is -0.4210653296924155, num_events is 73905
# 2025-12-27 20:45:13,666 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 38 (valid) ]:  valid loglike is -0.4559979745871977, num_events is 11537, acc is 0.4441362572592528, rmse is 854212.3665875751
# 2025-12-27 20:45:13,698 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 38 (test) ]: test loglike is -0.34233841218028976, num_events is 27955, acc is 0.4525129672688249, rmse is 62469554.93533885
# 2025-12-27 20:45:13,701 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.4560 (updated at epoch-38), best updated at this epoch
# 2025-12-27 20:45:13,765 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 39 (train) ]: train loglike is -0.4028896861627681, num_events is 73905
# 2025-12-27 20:45:13,778 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 39 (valid) ]:  valid loglike is -0.43781716908100027, num_events is 11537, acc is 0.4489035277801855, rmse is 2920271.281633226
# 2025-12-27 20:45:13,809 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 39 (test) ]: test loglike is -0.3279901397055536, num_events is 27955, acc is 0.45830799499195135, rmse is 764031335.662812
# 2025-12-27 20:45:13,812 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.4378 (updated at epoch-39), best updated at this epoch
# 2025-12-27 20:45:13,881 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 40 (train) ]: train loglike is -0.38490430624024824, num_events is 73905
# 2025-12-27 20:45:13,895 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 40 (valid) ]:  valid loglike is -0.4198316422163474, num_events is 11537, acc is 0.4520239230302505, rmse is 18431120.181112997
# 2025-12-27 20:45:13,926 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 40 (test) ]: test loglike is -0.3137532348305312, num_events is 27955, acc is 0.46481845823645146, rmse is 17734148.12370724
# 2025-12-27 20:45:13,929 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.4198 (updated at epoch-40), best updated at this epoch
# 2025-12-27 20:45:13,994 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 41 (train) ]: train loglike is -0.36711302397820683, num_events is 73905
# 2025-12-27 20:45:14,009 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 41 (valid) ]:  valid loglike is -0.4020424943930398, num_events is 11537, acc is 0.4568778711970183, rmse is 2731187.0807024413
# 2025-12-27 20:45:14,040 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 41 (test) ]: test loglike is -0.299617951143579, num_events is 27955, acc is 0.4727597925236988, rmse is 675295.7946739133
# 2025-12-27 20:45:14,043 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.4020 (updated at epoch-41), best updated at this epoch
# 2025-12-27 20:45:14,106 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 42 (train) ]: train loglike is -0.3495166908379264, num_events is 73905
# 2025-12-27 20:45:14,120 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 42 (valid) ]:  valid loglike is -0.3844482019805842, num_events is 11537, acc is 0.4712663604056514, rmse is 723586.5763738885
# 2025-12-27 20:45:14,150 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 42 (test) ]: test loglike is -0.2855771273028081, num_events is 27955, acc is 0.48542300125201215, rmse is 1337933.6741204278
# 2025-12-27 20:45:14,153 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.3844 (updated at epoch-42), best updated at this epoch
# 2025-12-27 20:45:14,217 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 43 (train) ]: train loglike is -0.33211294382852935, num_events is 73905
# 2025-12-27 20:45:14,230 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 43 (valid) ]:  valid loglike is -0.3670442787336396, num_events is 11537, acc is 0.4793273814683193, rmse is 199145.50453551815
# 2025-12-27 20:45:14,262 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 43 (test) ]: test loglike is -0.2716255582353336, num_events is 27955, acc is 0.4930781613307101, rmse is 68053637.95642345
# 2025-12-27 20:45:14,265 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.3670 (updated at epoch-43), best updated at this epoch
# 2025-12-27 20:45:14,331 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 44 (train) ]: train loglike is -0.3148958158044626, num_events is 73905
# 2025-12-27 20:45:14,345 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 44 (valid) ]:  valid loglike is -0.34982405876879824, num_events is 11537, acc is 0.4850481060934385, rmse is 183161.44636448225
# 2025-12-27 20:45:14,375 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 44 (test) ]: test loglike is -0.25775936633652297, num_events is 27955, acc is 0.5001609729923091, rmse is 2304521.5680645066
# 2025-12-27 20:45:14,378 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.3498 (updated at epoch-44), best updated at this epoch
# 2025-12-27 20:45:14,443 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 45 (train) ]: train loglike is -0.29785624440149755, num_events is 73905
# 2025-12-27 20:45:14,456 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 45 (valid) ]:  valid loglike is -0.33277852727230867, num_events is 11537, acc is 0.49154892953107393, rmse is 560145.2896337006
# 2025-12-27 20:45:14,488 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 45 (test) ]: test loglike is -0.24397535520255767, num_events is 27955, acc is 0.5060275442675729, rmse is 522207.071239509
# 2025-12-27 20:45:14,491 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.3328 (updated at epoch-45), best updated at this epoch
# 2025-12-27 20:45:14,557 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 46 (train) ]: train loglike is -0.28098196436527995, num_events is 73905
# 2025-12-27 20:45:14,571 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 46 (valid) ]:  valid loglike is -0.3158966802461645, num_events is 11537, acc is 0.4964895553436769, rmse is 29700027.154068712
# 2025-12-27 20:45:14,601 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 46 (test) ]: test loglike is -0.2302707825634949, num_events is 27955, acc is 0.5109282775889823, rmse is 206860.72051507793
# 2025-12-27 20:45:14,604 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.3159 (updated at epoch-46), best updated at this epoch
# 2025-12-27 20:45:14,673 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 47 (train) ]: train loglike is -0.26425813556596556, num_events is 73905
# 2025-12-27 20:45:14,686 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 47 (valid) ]:  valid loglike is -0.2991656938003814, num_events is 11537, acc is 0.5002166941145878, rmse is 43692630.531106316
# 2025-12-27 20:45:14,731 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 47 (test) ]: test loglike is -0.21664304588289215, num_events is 27955, acc is 0.5150062600608121, rmse is 511628.0602810848
# 2025-12-27 20:45:14,734 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.2992 (updated at epoch-47), best updated at this epoch
# 2025-12-27 20:45:14,799 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 48 (train) ]: train loglike is -0.24766798275554708, num_events is 73905
# 2025-12-27 20:45:14,813 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 48 (valid) ]:  valid loglike is -0.2825710722837393, num_events is 11537, acc is 0.5029037011354771, rmse is 2187798.820860869
# 2025-12-27 20:45:14,843 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 48 (test) ]: test loglike is -0.2030894989575881, num_events is 27955, acc is 0.5186907529958863, rmse is 1914072.6678861284
# 2025-12-27 20:45:14,847 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.2826 (updated at epoch-48), best updated at this epoch
# 2025-12-27 20:45:14,913 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 49 (train) ]: train loglike is -0.23119390560062658, num_events is 73905
# 2025-12-27 20:45:14,927 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 49 (valid) ]:  valid loglike is -0.2660971138375444, num_events is 11537, acc is 0.5042038658230042, rmse is 1416492.2976908355
# 2025-12-27 20:45:14,959 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 49 (test) ]: test loglike is -0.1896071287839832, num_events is 27955, acc is 0.5212663208728313, rmse is 799700.9853301848
# 2025-12-27 20:45:14,963 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.2661 (updated at epoch-49), best updated at this epoch
# 2025-12-27 20:45:15,031 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 50 (train) ]: train loglike is -0.214818400083686, num_events is 73905
# 2025-12-27 20:45:15,047 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 50 (valid) ]:  valid loglike is -0.24972710084944094, num_events is 11537, acc is 0.5067175175522233, rmse is 752856.0514318418
# 2025-12-27 20:45:15,079 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 50 (test) ]: test loglike is -0.17619251189132087, num_events is 27955, acc is 0.5241280629583259, rmse is 14799132.696821118
# 2025-12-27 20:45:15,082 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.2497 (updated at epoch-50), best updated at this epoch
# 2025-12-27 20:45:15,148 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 51 (train) ]: train loglike is -0.19852487094250207, num_events is 73905
# 2025-12-27 20:45:15,161 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 51 (valid) ]:  valid loglike is -0.23344378666870721, num_events is 11537, acc is 0.5083643928230909, rmse is 2339899.5706059327
# ...
# 2025-12-28 07:23:04,584 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 179 (valid) ]:  valid loglike is -4.112738665705359, num_events is 61288, acc is 0.593558282208589, rmse is 20.467149752930837
# 2025-12-28 07:23:57,106 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 179 (test) ]: test loglike is -4.111734903222155, num_events is 59634, acc is 0.5908374417278733, rmse is 20.777467749279015
# 2025-12-28 07:23:57,111 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:24:09,408 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 180 (train) ]: train loglike is -4.111825785263118, num_events is 360731
# 2025-12-28 07:24:57,620 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 180 (valid) ]:  valid loglike is -4.112722030617739, num_events is 61288, acc is 0.5931340556063177, rmse is 20.462722291494412
# 2025-12-28 07:25:47,870 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 180 (test) ]: test loglike is -4.111724160608881, num_events is 59634, acc is 0.5904349867525237, rmse is 20.78240102674096
# 2025-12-28 07:25:47,875 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:26:00,100 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 181 (train) ]: train loglike is -4.11191602763945, num_events is 360731
# 2025-12-28 07:26:53,514 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 181 (valid) ]:  valid loglike is -4.112956833923444, num_events is 61288, acc is 0.5931014227907584, rmse is 20.48219723936263
# 2025-12-28 07:27:39,495 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 181 (test) ]: test loglike is -4.111823660789147, num_events is 59634, acc is 0.5907200590267297, rmse is 20.796313048445022
# 2025-12-28 07:27:39,499 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:27:51,837 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 182 (train) ]: train loglike is -4.111796718308622, num_events is 360731
# 2025-12-28 07:28:40,451 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 182 (valid) ]:  valid loglike is -4.112887680398283, num_events is 61288, acc is 0.5937051298786059, rmse is 20.472352571743297
# 2025-12-28 07:29:34,367 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 182 (test) ]: test loglike is -4.111836368514606, num_events is 59634, acc is 0.5909715933863232, rmse is 20.828717252274163
# 2025-12-28 07:29:34,371 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:29:46,636 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 183 (train) ]: train loglike is -4.111725648156538, num_events is 360731
# 2025-12-28 07:30:36,126 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 183 (valid) ]:  valid loglike is -4.112889783685224, num_events is 61288, acc is 0.5928566766740634, rmse is 20.454358137292623
# 2025-12-28 07:31:26,096 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 183 (test) ]: test loglike is -4.111924667555422, num_events is 59634, acc is 0.5908206727705672, rmse is 20.7832902042312
# 2025-12-28 07:31:26,101 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:31:38,394 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 184 (train) ]: train loglike is -4.111623280336491, num_events is 360731
# 2025-12-28 07:32:29,729 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 184 (valid) ]:  valid loglike is -4.1129002363839575, num_events is 61288, acc is 0.592872993081843, rmse is 20.477303988276898
# 2025-12-28 07:33:21,000 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 184 (test) ]: test loglike is -4.112015783257035, num_events is 59634, acc is 0.5897139215883557, rmse is 20.828687539633815
# 2025-12-28 07:33:21,004 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:33:33,272 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 185 (train) ]: train loglike is -4.111560167929842, num_events is 360731
# 2025-12-28 07:34:23,249 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 185 (valid) ]:  valid loglike is -4.113020378683429, num_events is 61288, acc is 0.5931340556063177, rmse is 20.445496168321412
# 2025-12-28 07:35:05,823 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 185 (test) ]: test loglike is -4.112048600630513, num_events is 59634, acc is 0.5905691384109736, rmse is 20.768030607557865
# 2025-12-28 07:35:05,827 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:35:18,079 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 186 (train) ]: train loglike is -4.1115080060522935, num_events is 360731
# 2025-12-28 07:36:07,432 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 186 (valid) ]:  valid loglike is -4.113063336725786, num_events is 61288, acc is 0.5924813992951312, rmse is 20.44544799397579
# 2025-12-28 07:36:53,497 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 186 (test) ]: test loglike is -4.112077094757185, num_events is 59634, acc is 0.5894959251433746, rmse is 20.789211822459677
# 2025-12-28 07:36:53,502 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:37:05,686 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 187 (train) ]: train loglike is -4.111540048193806, num_events is 360731
# 2025-12-28 07:37:55,715 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 187 (valid) ]:  valid loglike is -4.1130560070894795, num_events is 61288, acc is 0.5921387547317583, rmse is 20.447207464434484
# 2025-12-28 07:38:42,995 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 187 (test) ]: test loglike is -4.112091898602308, num_events is 59634, acc is 0.5904182177952175, rmse is 20.8095455752038
# 2025-12-28 07:38:42,999 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:38:55,273 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 188 (train) ]: train loglike is -4.111472474360223, num_events is 360731
# 2025-12-28 07:39:46,872 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 188 (valid) ]:  valid loglike is -4.113156454974873, num_events is 61288, acc is 0.5937377626941652, rmse is 20.46601648128716
# 2025-12-28 07:40:40,319 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 188 (test) ]: test loglike is -4.112204565034209, num_events is 59634, acc is 0.5904182177952175, rmse is 20.78754364519442
# 2025-12-28 07:40:40,323 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:40:52,640 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 189 (train) ]: train loglike is -4.111481722075279, num_events is 360731
# 2025-12-28 07:41:40,783 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 189 (valid) ]:  valid loglike is -4.113075064143878, num_events is 61288, acc is 0.5931014227907584, rmse is 20.400179492508077
# 2025-12-28 07:42:34,059 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 189 (test) ]: test loglike is -4.1120643215279875, num_events is 59634, acc is 0.5902840661367676, rmse is 20.753633808414484
# 2025-12-28 07:42:34,064 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:42:46,241 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 190 (train) ]: train loglike is -4.111532118873725, num_events is 360731
# 2025-12-28 07:43:38,326 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 190 (valid) ]:  valid loglike is -4.113197500938194, num_events is 61288, acc is 0.5926282469651482, rmse is 20.454746094715677
# 2025-12-28 07:44:25,031 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 190 (test) ]: test loglike is -4.112205220071603, num_events is 59634, acc is 0.5897809974175806, rmse is 20.77720204100084
# 2025-12-28 07:44:25,035 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:44:37,247 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 191 (train) ]: train loglike is -4.111302955026131, num_events is 360731
# 2025-12-28 07:45:29,164 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 191 (valid) ]:  valid loglike is -4.112944660353577, num_events is 61288, acc is 0.5914371491972328, rmse is 20.436566543846176
# 2025-12-28 07:46:21,949 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 191 (test) ]: test loglike is -4.112119606684106, num_events is 59634, acc is 0.5896636147164369, rmse is 20.777664463584582
# 2025-12-28 07:46:21,955 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:46:34,097 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 192 (train) ]: train loglike is -4.111295254462466, num_events is 360731
# 2025-12-28 07:47:23,959 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 192 (valid) ]:  valid loglike is -4.113131534211428, num_events is 61288, acc is 0.5927587782273854, rmse is 20.443232766522
# 2025-12-28 07:48:13,323 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 192 (test) ]: test loglike is -4.112393346811383, num_events is 59634, acc is 0.5902169903075427, rmse is 20.768270308473472
# 2025-12-28 07:48:13,327 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:48:25,524 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 193 (train) ]: train loglike is -4.111276444999875, num_events is 360731
# 2025-12-28 07:49:16,159 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 193 (valid) ]:  valid loglike is -4.113019677587782, num_events is 61288, acc is 0.5929545751207415, rmse is 20.4394506154796
# 2025-12-28 07:50:00,864 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 193 (test) ]: test loglike is -4.112163821708254, num_events is 59634, acc is 0.5908877485997921, rmse is 20.759155708344508
# 2025-12-28 07:50:00,869 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:50:13,056 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 194 (train) ]: train loglike is -4.111288661134006, num_events is 360731
# 2025-12-28 07:51:05,428 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 194 (valid) ]:  valid loglike is -4.113265762159803, num_events is 61288, acc is 0.5926608797807075, rmse is 20.46541222802176
# 2025-12-28 07:51:53,787 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 194 (test) ]: test loglike is -4.112313694264178, num_events is 59634, acc is 0.5896636147164369, rmse is 20.798669907126296
# 2025-12-28 07:51:53,792 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:52:05,941 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 195 (train) ]: train loglike is -4.111108832871655, num_events is 360731
# 2025-12-28 07:52:56,261 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 195 (valid) ]:  valid loglike is -4.113162509891822, num_events is 61288, acc is 0.5923182352173345, rmse is 20.466132979941353
# 2025-12-28 07:53:46,854 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 195 (test) ]: test loglike is -4.112308715979978, num_events is 59634, acc is 0.59045175570983, rmse is 20.824323619226018
# 2025-12-28 07:53:46,858 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:53:59,057 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 196 (train) ]: train loglike is -4.111057125799765, num_events is 360731
# 2025-12-28 07:54:49,464 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 196 (valid) ]:  valid loglike is -4.113296164216486, num_events is 61288, acc is 0.591959274246182, rmse is 20.45423062611864
# 2025-12-28 07:55:37,433 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 196 (test) ]: test loglike is -4.112337930647785, num_events is 59634, acc is 0.589529463057987, rmse is 20.787698704929593
# 2025-12-28 07:55:37,438 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:55:49,575 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 197 (train) ]: train loglike is -4.11097129747478, num_events is 360731
# 2025-12-28 07:56:40,182 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 197 (valid) ]:  valid loglike is -4.113186028463973, num_events is 61288, acc is 0.5920734891006396, rmse is 20.423995463209963
# 2025-12-28 07:57:23,651 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 197 (test) ]: test loglike is -4.112327777568166, num_events is 59634, acc is 0.5892946976556998, rmse is 20.786497902221257
# 2025-12-28 07:57:23,657 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:57:35,876 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 198 (train) ]: train loglike is -4.111026997632065, num_events is 360731
# 2025-12-28 07:58:28,038 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 198 (valid) ]:  valid loglike is -4.1134084032559395, num_events is 61288, acc is 0.5928077274507244, rmse is 20.439285509372493
# 2025-12-28 07:59:18,693 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 198 (test) ]: test loglike is -4.112470772231445, num_events is 59634, acc is 0.5902840661367676, rmse is 20.781224400925502
# 2025-12-28 07:59:18,699 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 07:59:30,934 - tpp_runner.py[pid:5428;line:96:_train_model] - INFO: [ Epoch 199 (train) ]: train loglike is -4.110897323875859, num_events is 360731
# 2025-12-28 08:00:21,759 - tpp_runner.py[pid:5428;line:107:_train_model] - INFO: [ Epoch 199 (valid) ]:  valid loglike is -4.113198903129487, num_events is 61288, acc is 0.5924161336640126, rmse is 20.460815496960336
# 2025-12-28 08:01:07,593 - tpp_runner.py[pid:5428;line:122:_train_model] - INFO: [ Epoch 199 (test) ]: test loglike is -4.112355289138747, num_events is 59634, acc is 0.5895462320152933, rmse is 20.787213162746117
# 2025-12-28 08:01:07,599 - tpp_runner.py[pid:5428;line:124:_train_model] - CRITICAL: current best loglike on valid set is -4.1118 (updated at epoch-146)
# 2025-12-28 08:01:07,602 - base_runner.py[pid:5428;line:110:train] - INFO: End AttNHP train! Cost time: 374.185m
# ✓ AttNHP on retweet completed successfully!
#   - Log-Likelihood: -4.1124
#   - Accuracy: 0.5895
#   - RMSE: 20.7872
#
# ======================================================================
# ✓ AttNHP completed on all datasets
#   - Time: 673.4 minutes
#   - Successful: 4/5
#   - Failed: 1/5
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task1/AttNHP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model

# %% [markdown]
# ## Save Model Results

# %% [markdown]
# ### Function Definition

# %%
"""
Result Formatting and Saving Functions for EasyTPP-style Tables

This module provides functions to format and save model evaluation results
in the style of Table 1 from the EasyTPP paper, with mean/std values for
RMSE and Type Error Rate across multiple datasets.
"""

import pandas as pd
import numpy as np
from typing import Dict, List, Union, Optional


def format_results_table(
    results_df: pd.DataFrame,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    rmse_col: str = 'rmse',
    accuracy_col: str = 'accuracy',
    type_error_from_accuracy: bool = True
) -> pd.DataFrame:
    """
    Format results into EasyTPP paper style with mean/std for RMSE and Type Error Rate.

    Parameters
    ----------
    results_df : pd.DataFrame
        DataFrame containing columns: 'model', 'dataset', 'rmse', 'accuracy'
        Can have multiple runs per model-dataset combination for computing std
    models : List[str], optional
        List of model names to include. If None, uses all models in results_df
    datasets : List[str], optional
        List of dataset names to include. If None, uses all datasets in results_df
    rmse_col : str, default='rmse'
        Column name for RMSE values
    accuracy_col : str, default='accuracy'
        Column name for accuracy values
    type_error_from_accuracy : bool, default=True
        If True, compute Type Error Rate as (1 - accuracy) * 100
        If False, assumes results_df has a 'type_error_rate' column

    Returns
    -------
    pd.DataFrame
        Formatted table with:
        - Rows: models
        - Columns: datasets
        - Values: "mean_rmse/mean_type_error% ± std_rmse/std_type_error"

    Examples
    --------
    >>> # Single run per model-dataset
    >>> df = pd.DataFrame({
    ...     'model': ['RMTPP', 'RMTPP', 'NHP', 'NHP'],
    ...     'dataset': ['amazon', 'taxi', 'amazon', 'taxi'],
    ...     'rmse': [0.620, 22.31, 0.621, 21.90],
    ...     'accuracy': [0.319, 0.559, 0.329, 0.600]
    ... })
    >>> table = format_results_table(df)

    >>> # Multiple runs per model-dataset (for computing std)
    >>> df_multi = pd.DataFrame({
    ...     'model': ['RMTPP', 'RMTPP', 'RMTPP'],
    ...     'dataset': ['amazon', 'amazon', 'amazon'],
    ...     'rmse': [0.620, 0.619, 0.621],
    ...     'accuracy': [0.319, 0.320, 0.318]
    ... })
    >>> table = format_results_table(df_multi)
    """
    # Filter models and datasets if specified
    if models is not None:
        results_df = results_df[results_df['model'].isin(models)].copy()
    if datasets is not None:
        results_df = results_df[results_df['dataset'].isin(datasets)].copy()

    # Compute type error rate if needed
    if type_error_from_accuracy:
        results_df['type_error_rate'] = (1 - results_df[accuracy_col]) * 100

    # Get unique models and datasets (sorted)
    all_models = sorted(results_df['model'].unique())
    all_datasets = sorted(results_df['dataset'].unique())

    # Compute mean and std for each model-dataset combination
    grouped = results_df.groupby(['model', 'dataset']).agg({
        rmse_col: ['mean', 'std'],
        'type_error_rate': ['mean', 'std']
    }).reset_index()

    # Flatten column names
    grouped.columns = ['model', 'dataset', 'rmse_mean', 'rmse_std',
                       'type_error_mean', 'type_error_std']

    # Fill NaN std with 0 (for single runs)
    grouped['rmse_std'] = grouped['rmse_std'].fillna(0)
    grouped['type_error_std'] = grouped['type_error_std'].fillna(0)

    # Create formatted strings for each cell
    def format_cell(row):
        """Format a single cell as: mean_rmse/mean_type% ± std_rmse/std_type"""
        rmse_mean = row['rmse_mean']
        rmse_std = row['rmse_std']
        type_mean = row['type_error_mean']
        type_std = row['type_error_std']

        # Format mean values
        mean_str = f"{rmse_mean:.3f}/{type_mean:.1f}%"

        # Format std values
        std_str = f"{rmse_std:.3f}/{type_std:.3f}"

        return f"{mean_str} ± {std_str}"

    grouped['formatted'] = grouped.apply(format_cell, axis=1)

    # Pivot to create the final table
    formatted_table = grouped.pivot(index='model', columns='dataset', values='formatted')

    # Ensure all models and datasets are present (fill missing with N/A)
    formatted_table = formatted_table.reindex(index=all_models, columns=all_datasets, fill_value='N/A')

    return formatted_table


def save_results_easytpp_format(
    results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    save_csv: bool = True,
    save_latex: bool = True,
    save_markdown: bool = True,
    **format_kwargs
) -> pd.DataFrame:
    """
    Save results in EasyTPP paper format to multiple file formats.

    Parameters
    ----------
    results_df : pd.DataFrame
        DataFrame containing columns: 'model', 'dataset', 'rmse', 'accuracy'
    output_path : str
        Base path for output files (without extension)
        E.g., 'results/task1_results' will create:
        - results/task1_results.csv
        - results/task1_results.tex
        - results/task1_results.md
    models : List[str], optional
        List of model names to include
    datasets : List[str], optional
        List of dataset names to include
    save_csv : bool, default=True
        Whether to save as CSV
    save_latex : bool, default=True
        Whether to save as LaTeX table
    save_markdown : bool, default=True
        Whether to save as Markdown table
    **format_kwargs
        Additional keyword arguments passed to format_results_table()

    Returns
    -------
    pd.DataFrame
        The formatted results table

    Examples
    --------
    >>> df = pd.DataFrame({
    ...     'model': ['RMTPP', 'NHP'],
    ...     'dataset': ['amazon', 'taxi'],
    ...     'rmse': [0.620, 21.90],
    ...     'accuracy': [0.319, 0.600]
    ... })
    >>> table = save_results_easytpp_format(df, 'results/task1')
    """
    import os

    # Format the table
    formatted_table = format_results_table(
        results_df, models=models, datasets=datasets, **format_kwargs
    )

    # Create output directory if it doesn't exist
    output_dir = os.path.dirname(output_path)
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)

    # Save as CSV
    if save_csv:
        csv_path = f"{output_path}.csv"
        formatted_table.to_csv(csv_path)
        print(f"✓ Results saved to: {csv_path}")

    # Save as LaTeX
    if save_latex:
        latex_path = f"{output_path}.tex"
        latex_str = formatted_table.to_latex(
            escape=False,
            column_format='l' + 'c' * len(formatted_table.columns),
            caption="Model Performance: Time RMSE / Type Error Rate (Mean ± Std)",
            label="tab:results"
        )
        with open(latex_path, 'w') as f:
            f.write(latex_str)
        print(f"✓ LaTeX table saved to: {latex_path}")

    # Save as Markdown
    if save_markdown:
        md_path = f"{output_path}.md"
        md_str = formatted_table.to_markdown()
        with open(md_path, 'w') as f:
            f.write(md_str)
        print(f"✓ Markdown table saved to: {md_path}")

    return formatted_table

def create_comparison_table(
    stationary_results_df: pd.DataFrame,
    nonstationary_results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None
) -> pd.DataFrame:
    """
    Create a side-by-side comparison table for stationary vs non-stationary results.

    Parameters
    ----------
    stationary_results_df : pd.DataFrame
        Results from stationary Hawkes data
    nonstationary_results_df : pd.DataFrame
        Results from non-stationary Hawkes data
    output_path : str
        Base path for output files
    models : List[str], optional
        List of models to include

    Returns
    -------
    pd.DataFrame
        Comparison table with degradation analysis

    Examples
    --------
    >>> stat_df = pd.DataFrame({...})  # stationary results
    >>> nonstat_df = pd.DataFrame({...})  # non-stationary results
    >>> comparison = create_comparison_table(stat_df, nonstat_df, 'results/comparison')
    """
    # Format both tables
    stat_table = format_results_table(stationary_results_df, models=models)
    nonstat_table = format_results_table(nonstationary_results_df, models=models)

    # Compute degradation statistics
    stat_grouped = stationary_results_df.groupby('model').agg({
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={'rmse': 'stat_rmse', 'accuracy': 'stat_type_error'})

    nonstat_grouped = nonstationary_results_df.groupby('model').agg({
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={'rmse': 'nonstat_rmse', 'accuracy': 'nonstat_type_error'})

    degradation = stat_grouped.join(nonstat_grouped)
    degradation['rmse_degradation_%'] = (
        (degradation['nonstat_rmse'] - degradation['stat_rmse']) /
        degradation['stat_rmse'] * 100
    )
    degradation['type_error_degradation_%'] = (
        degradation['nonstat_type_error'] - degradation['stat_type_error']
    )

    # Save comparison
    degradation.to_csv(f"{output_path}_degradation.csv")
    print(f"✓ Degradation analysis saved to: {output_path}_degradation.csv")

    return degradation

# %% [markdown]
# ### Function Execution

# %%
model_ids = ['RMTPP', 'NHP', 'SAHP', 'THP', 'AttNHP', 'FullyNN','IntensityFree']
data_ids = ['amazon', 'retweet', 'taxi','taobao', 'stackoverflow']

# %%
import pandas as pd

def flatten_model_results(all_model_results):
    """
    Properly convert all_model_results dictionary to DataFrame.

    The issue: pd.DataFrame(dict) treats keys as COLUMN names, not data rows.
    This function flattens it correctly.
    """
    all_results = []
    for model_name, results_list in all_model_results.items():
        all_results.extend(results_list)
    return pd.DataFrame(all_results)

results_df = flatten_model_results(all_model_results)
results_df = results_df[
    results_df['status'] == 'success'
]

# Check the structure
print("✓ DataFrame created successfully!")
print(f"  Shape: {results_df.shape}")
print(f"  Columns: {list(results_df.columns)}")
print(f"\nFirst few rows:")
print(results_df.head())

formatted_table = format_results_table(
    results_df,
    models=model_ids,
    datasets=data_ids
)

print("\n✓ Formatted table:")
print(formatted_table)

# Save to files
saved_table = save_results_easytpp_format(
    results_df,
    output_path=f'{RESULTS_DIR}/Task1_results',
    models=model_ids,
    datasets=data_ids
)
# Out:
# ✓ DataFrame created successfully!
#   Shape: (30, 8)
#   Columns: ['model', 'dataset', 'log_likelihood', 'accuracy', 'rmse', 'status', 'time_seconds', 'error']
#
# First few rows:
#    model        dataset  log_likelihood  accuracy       rmse   status  \
# 0  RMTPP           taxi        0.306759  0.911720   0.395955  success
# 1  RMTPP         amazon       -2.191249  0.329525   0.460787  success
# 2  RMTPP         taobao       -0.571186  0.435700   0.266665  success
# 3  RMTPP  stackoverflow       -2.756299  0.425011   1.417137  success
# 4  RMTPP        retweet       -4.226499  0.553392  25.647717  success
#
#    time_seconds error
# 0     93.595191   NaN
# 1    205.396454   NaN
# 2    232.595419   NaN
# 3    271.393489   NaN
# 4    399.904712   NaN
#
# ✓ Formatted table:
# dataset                              amazon                     retweet  \
# model
# AttNHP         1126.644/80.6% ± 0.000/0.000  20.787/41.0% ± 0.000/0.000
# FullyNN                                 NaN  21.159/46.0% ± 0.000/0.000
# IntensityFree     0.464/65.0% ± 0.000/0.000  31.982/39.9% ± 0.000/0.000
# NHP               0.474/67.9% ± 0.000/0.000  22.636/39.9% ± 0.000/0.000
# RMTPP             0.461/67.0% ± 0.000/0.000  25.648/44.7% ± 0.000/0.000
# SAHP              0.549/68.1% ± 0.000/0.000  21.796/40.8% ± 0.000/0.000
# THP               0.469/65.4% ± 0.000/0.000  25.931/40.2% ± 0.000/0.000
#
# dataset                    stackoverflow                     taobao  \
# model
# AttNHP                               NaN  0.131/56.4% ± 0.000/0.000
# FullyNN                              NaN                        NaN
# IntensityFree                        NaN  0.735/39.0% ± 0.000/0.000
# NHP            1.417/55.4% ± 0.000/0.000  0.820/41.3% ± 0.000/0.000
# RMTPP          1.417/57.5% ± 0.000/0.000  0.267/56.4% ± 0.000/0.000
# SAHP           1.271/55.9% ± 0.000/0.000  0.232/46.3% ± 0.000/0.000
# THP            1.428/54.6% ± 0.000/0.000  0.318/42.1% ± 0.000/0.000
#
# dataset                             taxi
# model
# AttNHP         4.641/21.9% ± 0.000/0.000
# FullyNN        1.000/57.1% ± 0.000/0.000
# IntensityFree   9.155/8.4% ± 0.000/0.000
# NHP             0.404/8.6% ± 0.000/0.000
# RMTPP           0.396/8.8% ± 0.000/0.000
# SAHP            0.344/8.9% ± 0.000/0.000
# THP             0.366/8.7% ± 0.000/0.000
# ✓ Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task1/Task1_results.csv
# ✓ LaTeX table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task1/Task1_results.tex
# ✓ Markdown table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task1/Task1_results.md
