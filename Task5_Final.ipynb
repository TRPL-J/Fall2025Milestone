# %% [markdown]
# ## Package Installation

# %%
import os
import sys
import types

# Install core dependencies
# !pip install easy-tpp lightning pytorch-lightning hydra-core omegaconf torchmetrics stribor -q

print("✓ Core dependencies installed")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 64.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.8 MB/s eta 0:00:00
# ✓ Core dependencies installed

# %%
# Import required libraries
import os

# Set PyTorch memory allocation config BEFORE importing torch
# This helps prevent OOM errors with large models like AttNHP
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

import yaml
import pandas as pd
import numpy as np
from datetime import datetime
from easy_tpp.config_factory import Config
from easy_tpp.runner import Runner
from google.colab import drive
import json
from IPython.display import display, clear_output
import time

# %%
# ==============================================================================
# FULLYNN GRADIENT FIX - Monkey Patch
# ==============================================================================
# FullyNN uses torch.autograd.grad() to compute intensity derivatives, but during
# validation/evaluation, EasyTPP runs under torch.no_grad() context which disables
# gradient tracking. This patch wraps the computation in torch.enable_grad().
# ==============================================================================

import torch
from easy_tpp.model.torch_model import torch_fullynn

def patched_compute_intensities_at_sample_times(self, time_seqs, time_delta_seqs, type_seqs, sample_dtimes, **kwargs):
    """Patched version that enables gradients during intensity computation.

    FullyNN requires gradient computation for intensity derivatives via autograd.grad().
    During validation, EasyTPP disables gradients with torch.no_grad(), causing failures.
    This patch wraps the computation in torch.enable_grad() to fix the issue.
    """
    compute_last_step_only = kwargs.get('compute_last_step_only', False)

    # Enable gradients for this computation even during evaluation
    with torch.enable_grad():
        # Forward pass to get hidden states
        hidden_states = self.forward(
            time_seqs=time_seqs,
            time_delta_seqs=time_delta_seqs,
            type_seqs=type_seqs,
        )

        num_samples = sample_dtimes.size()[-1]
        batch_size, seq_len, hidden_size = hidden_states.shape

        # Expand hidden states for all sample times
        hidden_states_ = hidden_states[..., None, :].expand(batch_size, seq_len, num_samples, hidden_size)

        # Clone sample_dtimes to avoid in-place modification issues
        sample_dtimes_grad = sample_dtimes.clone().detach().requires_grad_(True)

        # Compute intensities (this uses autograd.grad internally)
        _, derivative_integral_lambda = self.layer_intensity.forward(
            hidden_states=hidden_states_,
            time_delta_seqs=sample_dtimes_grad,
        )

    # Detach the result since we don't need gradients flowing back
    derivative_integral_lambda = derivative_integral_lambda.detach()

    if compute_last_step_only:
        return derivative_integral_lambda[:, -1:, :, :]
    return derivative_integral_lambda

# Apply the monkey patch
torch_fullynn.FullyNN.compute_intensities_at_sample_times = patched_compute_intensities_at_sample_times
print("✓ FullyNN patched for gradient computation during evaluation")
print("  This fixes the 'element 0 of tensors does not require grad' error")
# Out:
# ✓ FullyNN patched for gradient computation during evaluation
#   This fixes the 'element 0 of tensors does not require grad' error

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Base directory (your Drive location)
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
CHECKPOINT_DIR = os.path.join(BASE_DIR, 'checkpoints')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task3')

# Create results directory if it doesn't exist
os.makedirs(RESULTS_DIR, exist_ok=True)

print(f"✓ Base Directory: {BASE_DIR}")
print(f"✓ Dataset Directory: {DATASET_DIR}")
print(f"✓ Checkpoint Directory: {CHECKPOINT_DIR}")
print(f"✓ Results Directory: {RESULTS_DIR}")
# Out:
# Mounted at /content/drive
# ✓ Base Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025
# ✓ Dataset Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets
# ✓ Checkpoint Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints
# ✓ Results Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3

# %% [markdown]
# ## Configuration Dictionary

# %% [markdown]
# ### Data Configuration

# %%
# Data specifications for each dataset
dataset_name = 'nonstationary_hawkes'
data_spec_dict = {
    dataset_name: {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, dataset_name, "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, dataset_name, "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, dataset_name, "test.pkl"),
        "data_specs": {
            "num_event_types": 2,
            "pad_token_id": 2,
            "padding_side": "right",
            "max_seq_len": 20,
            "strict_pad_leng": True
        }
    }
}

print("✓ Data specifications loaded for Hawkes Stationary")
# Out:
# ✓ Data specifications loaded for Hawkes Stationary

# %% [markdown]
# ### Model Configuration

# %%
# Model specifications
model_spec_dict = {
    "RMTPP": {
        "model_id": "RMTPP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_heads": 2,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "NHP": {
        "model_id": "NHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_heads": 2,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "FullyNN": {
        "model_id": "FullyNN",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "num_heads": 2,
        "seed": 2019,
        "model_specs": {
            "num_mlp_layers": 3,
            "proper_marked_intensities": True
        },
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "SAHP": {
        "model_id": "SAHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "THP": {
        "model_id": "THP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "IntensityFree": {
        "model_id": "IntensityFree",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "num_heads": 2,
        "seed": 2019,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_mix_components": 3,
        "model_specs": {
            "num_mix_components": 3
        },
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5,
            "num_step_gen": 10
        }
    },
    "AttNHP": {
        "model_id": "AttNHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 4,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    }
}

print("✓ Model specifications loaded for 7 models")
# Out:
# ✓ Model specifications loaded for 7 models

# %% [markdown]
# ### Training Configuration

# %%
# Trainer configuration (shared across all experiments)
trainer_config = {
    "batch_size": 256,
    "max_epoch": 200,
    "shuffle": False,
    "optimizer": "adam",
    "learning_rate": 1e-3,
    "valid_freq": 1,
    "use_tfb": False,
    "metrics": ["acc", "rmse"],
    "seed": 2019,
    "gpu": 0
}

print("✓ Trainer configuration loaded")
print(f"  - Batch size: {trainer_config['batch_size']}")
print(f"  - Max epochs: {trainer_config['max_epoch']}")
print(f"  - Learning rate: {trainer_config['learning_rate']}")
# Out:
# ✓ Trainer configuration loaded
#   - Batch size: 256
#   - Max epochs: 200
#   - Learning rate: 0.001

# %% [markdown]
# ## Helper Functions

# %%
def create_experiment_config(model_id, data_id, data_spec, model_spec, trainer_cfg):
    """Create a complete experiment configuration."""
    experiment_id = f"{model_id}_{data_id}_train"

    config = {
        "pipeline_config_id": "runner_config",
        "data": {
            data_id: data_spec
        },
        experiment_id: {
            "base_config": {
                "stage": "train",
                "backend": "torch",
                "dataset_id": data_id,
                "runner_id": "std_tpp",
                "model_id": model_id,
                "base_dir": CHECKPOINT_DIR
            },
            "trainer_config": trainer_cfg,
            "model_config": model_spec
        }
    }

    return config, experiment_id

def extract_results_from_logs(log_path):
    """Extract best results from training logs.

    Args:
        log_path: Can be either a log file or a directory containing log files
    """
    try:
        # Determine if log_path is a file or directory
        if os.path.isfile(log_path):
            # It's a file - read it directly
            log_file = log_path
        elif os.path.isdir(log_path):
            # It's a directory - find .log files inside
            log_files = [f for f in os.listdir(log_path) if f.endswith('.log')]
            if not log_files:
                return None
            log_file = os.path.join(log_path, log_files[0])
        else:
            print(f"  Warning: Log path does not exist: {log_path}")
            return None

        # Read the log file
        with open(log_file, 'r') as f:
            lines = f.readlines()

        # Find the LAST test metrics (final epoch results)
        best_ll = None
        best_acc = None
        best_rmse = None

        for line in lines:
            if 'test loglike is' in line:
                try:
                    parts = line.split(',')
                    # Extract log-likelihood
                    ll_part = [p for p in parts if 'test loglike is' in p][0]
                    best_ll = float(ll_part.split('test loglike is')[1].strip())

                    # Extract accuracy
                    acc_parts = [p for p in parts if 'acc is' in p]
                    if acc_parts:
                        best_acc = float(acc_parts[0].split('acc is')[1].strip())

                    # Extract RMSE
                    rmse_parts = [p for p in parts if 'rmse is' in p]
                    if rmse_parts:
                        best_rmse = float(rmse_parts[0].split('rmse is')[1].strip())
                except (IndexError, ValueError) as e:
                    print(f"  Warning: Could not parse line: {e}")
                    continue

        if best_ll is None:
            return None

        return {
            'log_likelihood': best_ll,
            'accuracy': best_acc,
            'rmse': best_rmse
        }
    except Exception as e:
        print(f"  Warning: Could not extract results from logs: {e}")
        return None
def find_latest_checkpoint_dir(base_dir, model_id, data_id):
    """Find the most recent checkpoint directory for an experiment."""
    try:
        # EasyTPP creates directories with random names but puts
        # {model_id}_{data_id}_train_output.yaml inside them
        target_yaml = f"{model_id}_{data_id}_train_output.yaml"

        matching_dirs = []
        for d in os.listdir(base_dir):
            dir_path = os.path.join(base_dir, d)
            if os.path.isdir(dir_path):
                # Check if the target yaml file exists in this directory
                yaml_path = os.path.join(dir_path, target_yaml)
                if os.path.exists(yaml_path):
                    matching_dirs.append(dir_path)

        if not matching_dirs:
            return None

        # Return the most recently modified directory
        latest = max(matching_dirs, key=os.path.getmtime)
        return latest
    except Exception as e:
        print(f"  Warning: Error finding checkpoint dir: {e}")
        return None
print("✓ Helper functions loaded")
# Out:
# ✓ Helper functions loaded

# %%
def run_model_on_all_datasets(
    model_id,
    model_number,
    total_models,
    aggressive_gpu_clearing=False
):
    """
    Run a single TPP model on all configured datasets.

    This function encapsulates the complete workflow for running a model:
    - Creates and saves experiment configs for each dataset
    - Runs training and evaluation
    - Extracts metrics from logs
    - Saves results (both intermediate and model-specific)
    - Handles errors gracefully
    - Manages GPU memory

    Parameters
    ----------
    model_id : str
        The model identifier (e.g., 'RMTPP', 'NHP', 'AttNHP')
        Must exist as a key in model_spec_dict
    model_number : int
        Current model number (1-7) for progress tracking
    total_models : int
        Total number of models (typically 7) for progress tracking
    aggressive_gpu_clearing : bool, default=False
        If True, performs GPU memory clearing after EACH dataset.
        Use this for memory-intensive models like AttNHP.
        If False, only clears GPU memory after all datasets complete.

    Returns
    -------
    model_results : list of dict
        List containing result dictionaries for each dataset.
        Each dict contains: model, dataset, log_likelihood, accuracy,
        rmse, status, and time_seconds

    Side Effects
    ------------
    - Appends results to the global results_list
    - Saves intermediate results to 'intermediate_results.csv' after each dataset
    - Saves model-specific results to '{model_id}_results.csv'
    - Creates experiment config files in the configs directory
    - Clears GPU memory (timing depends on aggressive_gpu_clearing flag)

    Notes
    -----
    This function relies on several global variables and functions:
    - data_spec_dict: Dictionary of dataset configurations
    - model_spec_dict: Dictionary of model configurations
    - trainer_config: Training configuration
    - results_list: Global list to store all results
    - total_experiments: Total number of experiments
    - BASE_DIR, CHECKPOINT_DIR, RESULTS_DIR: Directory paths
    - create_experiment_config(): Function to create config dicts
    - find_latest_checkpoint_dir(): Function to locate checkpoints
    - extract_results_from_logs(): Function to parse training logs

    Example
    -------
    >>> # Run RMTPP on all datasets (standard memory management)
    >>> rmtpp_results = run_model_on_all_datasets('RMTPP', 1, 7)

    >>> # Run AttNHP with aggressive memory clearing
    >>> attnhp_results = run_model_on_all_datasets('AttNHP', 7, 7,
    ...                                             aggressive_gpu_clearing=True)
    """
    import time
    import os
    import yaml
    import pandas as pd
    import torch
    import gc
    from easy_tpp.config_factory import Config
    from easy_tpp.runner import Runner

    print("\n" + "=" * 70)
    print(f"[MODEL {model_number}/{total_models}] Running {model_id} on all datasets")
    print("=" * 70)

    model_start_time = time.time()
    model_results = []

    for data_id, data_spec in data_spec_dict.items():
        experiment_name = f"{model_id}_{data_id}"
        experiment_num = len(results_list) + 1

        print(f"\n[{experiment_num}/{total_experiments}] Running {model_id} on {data_id} dataset")
        print("=" * 70)

        try:
            # Create config
            config_dict, experiment_id = create_experiment_config(
                model_id=model_id,
                data_id=data_id,
                data_spec=data_spec,
                model_spec=model_spec_dict[model_id],
                trainer_cfg=trainer_config
            )

            # Save config
            CONFIG_DIR = os.path.join(BASE_DIR, 'configs')
            os.makedirs(CONFIG_DIR, exist_ok=True)
            config_path = os.path.join(CONFIG_DIR, f"{experiment_name}.yaml")
            with open(config_path, 'w') as f:
                yaml.dump(config_dict, f)

            # Build and run
            config = Config.build_from_yaml_file(config_path, experiment_id=experiment_id)
            runner = Runner.build_from_config(config)
            runner.run()

            # Find checkpoint directory
            checkpoint_dir = find_latest_checkpoint_dir(CHECKPOINT_DIR, model_id, data_id)

            # Extract results from logs
            if checkpoint_dir:
                log_dir = os.path.join(checkpoint_dir, 'log')
                metrics = extract_results_from_logs(log_dir)

                if metrics:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': metrics['log_likelihood'],
                        'accuracy': metrics['accuracy'],
                        'rmse': metrics['rmse'],
                        'status': 'success',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"✓ {model_id} on {data_id} completed successfully!")
                    print(f"  - Log-Likelihood: {metrics['log_likelihood']:.4f}")
                    if metrics['accuracy'] and metrics['accuracy'] > 0:
                        print(f"  - Accuracy: {metrics['accuracy']:.4f}")
                    if metrics['rmse'] and metrics['rmse'] > 0:
                        print(f"  - RMSE: {metrics['rmse']:.4f}")
                else:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': None,
                        'accuracy': None,
                        'rmse': None,
                        'status': 'completed_no_metrics',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"⚠ {model_id} on {data_id} completed but no metrics found")
            else:
                result = {
                    'model': model_id,
                    'dataset': data_id,
                    'log_likelihood': None,
                    'accuracy': None,
                    'rmse': None,
                    'status': 'no_checkpoint',
                    'time_seconds': time.time() - model_start_time
                }
                print(f"⚠ {model_id} on {data_id} - no checkpoint directory found")

        except Exception as e:
            result = {
                'model': model_id,
                'dataset': data_id,
                'log_likelihood': None,
                'accuracy': None,
                'rmse': None,
                'status': 'failed',
                'error': str(e),
                'time_seconds': time.time() - model_start_time
            }
            print(f"✗ Error running {model_id} on {data_id}: {str(e)}")

        results_list.append(result)
        model_results.append(result)

        # Save intermediate results after each experiment
        intermediate_df = pd.DataFrame(results_list)
        intermediate_df.to_csv(os.path.join(RESULTS_DIR, 'intermediate_results.csv'), index=False)

        # Aggressive GPU memory clearing (for memory-intensive models like AttNHP)
        if aggressive_gpu_clearing:
            try:
                del runner
                del config
            except:
                pass
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
                torch.cuda.synchronize()

    # Save model-specific results
    model_df = pd.DataFrame(model_results)
    model_csv_path = os.path.join(RESULTS_DIR, f'{model_id}_results.csv')
    model_df.to_csv(model_csv_path, index=False)

    # Model summary
    model_elapsed = time.time() - model_start_time
    successful = sum(1 for r in model_results if r['status'] == 'success')
    failed = sum(1 for r in model_results if r['status'] == 'failed')

    print(f"\n" + "=" * 70)
    print(f"✓ {model_id} completed on all datasets")
    print(f"  - Time: {model_elapsed/60:.1f} minutes")
    print(f"  - Successful: {successful}/{len(data_spec_dict)}")
    print(f"  - Failed: {failed}/{len(data_spec_dict)}")
    print(f"  - Results saved to: {model_csv_path}")
    print("=" * 70)

    # Clear GPU memory for next model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        print(f"✓ GPU memory cleared for next model")

    return model_results

# %% [markdown]
# ## Run Models On Data

# %%
# Initialize results storage
results_list = []
total_experiments = len(model_spec_dict) * len(data_spec_dict)

print(f"Starting {total_experiments} experiments...")
print(f"Running {len(model_spec_dict)} models on {len(data_spec_dict)} datasets")
print(f"Results will be saved incrementally to: {RESULTS_DIR}")
print("=" * 70)
# Out:
# Starting 7 experiments...
# Running 7 models on 1 datasets
# Results will be saved incrementally to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3
# ======================================================================

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
all_model_results = {}

for i, model_id in enumerate(model_ids, start=1):
    aggressive = (model_id == 'AttNHP')
    all_model_results[model_id] = run_model_on_all_datasets(
        model_id, i, len(model_ids), aggressive
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-12-27 17:49:03,484 - tpp_runner.py[pid:3157;line:60:_init_model] - INFO: Num of model parameters 2342
# 2025-12-27 17:49:03,928 - base_runner.py[pid:3157;line:98:train] - INFO: Data 'nonstationary_hawkes' loaded...
# 2025-12-27 17:49:03,929 - base_runner.py[pid:3157;line:103:train] - INFO: Start RMTPP training...
# 2025-12-27 17:49:05,106 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 0 (train) ]: train loglike is -1.2063269993485592, num_events is 32620
# 2025-12-27 17:49:05,327 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 0 (valid) ]:  valid loglike is -1.1100988263248848, num_events is 10850, acc is 0.49806451612903224, rmse is 0.9226806218331444
# 2025-12-27 17:49:05,355 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 0 (test) ]: test loglike is -1.1090106285245447, num_events is 10817, acc is 0.4932975871313673, rmse is 0.9458147651345402
# 2025-12-27 17:49:05,355 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.1101 (updated at epoch-0), best updated at this epoch
# 2025-12-27 17:49:05,385 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 1 (train) ]: train loglike is -1.0926891184233216, num_events is 32620
# 2025-12-27 17:49:05,399 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 1 (valid) ]:  valid loglike is -1.0519408842165898, num_events is 10850, acc is 0.5818433179723502, rmse is 0.9475806058915772
# 2025-12-27 17:49:05,417 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 1 (test) ]: test loglike is -1.0491575579816492, num_events is 10817, acc is 0.5809374133308681, rmse is 0.950794032813032
# 2025-12-27 17:49:05,418 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0519 (updated at epoch-1), best updated at this epoch
# 2025-12-27 17:49:05,446 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 2 (train) ]: train loglike is -1.0360825473731607, num_events is 32620
# 2025-12-27 17:49:05,460 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 2 (valid) ]:  valid loglike is -1.0333167122695852, num_events is 10850, acc is 0.551705069124424, rmse is 1.059794948878772
# 2025-12-27 17:49:05,478 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 2 (test) ]: test loglike is -1.029957366009522, num_events is 10817, acc is 0.5593972450771934, rmse is 1.0294161824623012
# 2025-12-27 17:49:05,479 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0333 (updated at epoch-2), best updated at this epoch
# 2025-12-27 17:49:05,508 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 3 (train) ]: train loglike is -1.018553190623084, num_events is 32620
# 2025-12-27 17:49:05,521 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 3 (valid) ]:  valid loglike is -1.0266904881912442, num_events is 10850, acc is 0.5101382488479262, rmse is 1.1200197504064302
# 2025-12-27 17:49:05,539 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 3 (test) ]: test loglike is -1.0231294634602939, num_events is 10817, acc is 0.5178885088286955, rmse is 1.0932726241840411
# 2025-12-27 17:49:05,540 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0267 (updated at epoch-3), best updated at this epoch
# 2025-12-27 17:49:05,568 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 4 (train) ]: train loglike is -1.0130212724172287, num_events is 32620
# 2025-12-27 17:49:05,582 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 4 (valid) ]:  valid loglike is -1.030126008064516, num_events is 10850, acc is 0.5095852534562212, rmse is 1.1759199647930185
# 2025-12-27 17:49:05,594 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 4 (test) ]: test loglike is -1.0264971009175372, num_events is 10817, acc is 0.520014791531848, rmse is 1.2136322302307736
# 2025-12-27 17:49:05,594 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0267 (updated at epoch-3)
# 2025-12-27 17:49:05,622 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 5 (train) ]: train loglike is -1.0170761323574493, num_events is 32620
# 2025-12-27 17:49:05,636 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 5 (valid) ]:  valid loglike is -1.0275563436059907, num_events is 10850, acc is 0.5069124423963134, rmse is 1.277244607929669
# 2025-12-27 17:49:05,648 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 5 (test) ]: test loglike is -1.0243144832786355, num_events is 10817, acc is 0.5185356383470463, rmse is 1.239045115884379
# 2025-12-27 17:49:05,648 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0267 (updated at epoch-3)
# 2025-12-27 17:49:05,675 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 6 (train) ]: train loglike is -1.0152535050869864, num_events is 32620
# 2025-12-27 17:49:05,688 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 6 (valid) ]:  valid loglike is -1.0217730234735023, num_events is 10850, acc is 0.5131797235023041, rmse is 1.2425916546378206
# 2025-12-27 17:49:05,707 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 6 (test) ]: test loglike is -1.0189600462524266, num_events is 10817, acc is 0.523435333271702, rmse is 1.2414090861252791
# 2025-12-27 17:49:05,708 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0218 (updated at epoch-6), best updated at this epoch
# 2025-12-27 17:49:05,736 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 7 (train) ]: train loglike is -1.0105776807269313, num_events is 32620
# 2025-12-27 17:49:05,750 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 7 (valid) ]:  valid loglike is -1.0169131624423964, num_events is 10850, acc is 0.5604608294930875, rmse is 1.235597650180237
# 2025-12-27 17:49:05,768 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 7 (test) ]: test loglike is -1.0144309521470833, num_events is 10817, acc is 0.5703059998151059, rmse is 1.2116749210194684
# 2025-12-27 17:49:05,769 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0169 (updated at epoch-7), best updated at this epoch
# 2025-12-27 17:49:05,797 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 8 (train) ]: train loglike is -1.0062574694158108, num_events is 32620
# 2025-12-27 17:49:05,811 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 8 (valid) ]:  valid loglike is -1.01109375, num_events is 10850, acc is 0.5672811059907834, rmse is 1.2334585379059004
# 2025-12-27 17:49:05,828 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 8 (test) ]: test loglike is -1.0094407060356383, num_events is 10817, acc is 0.5573634094480909, rmse is 1.2425740111072796
# 2025-12-27 17:49:05,829 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0111 (updated at epoch-8), best updated at this epoch
# 2025-12-27 17:49:05,858 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 9 (train) ]: train loglike is -1.0018721289900752, num_events is 32620
# 2025-12-27 17:49:05,872 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 9 (valid) ]:  valid loglike is -1.0077574164746543, num_events is 10850, acc is 0.5575115207373272, rmse is 1.220218677724537
# 2025-12-27 17:49:05,890 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 9 (test) ]: test loglike is -1.0064658783627622, num_events is 10817, acc is 0.5548673384487381, rmse is 1.2396291593357365
# 2025-12-27 17:49:05,891 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0078 (updated at epoch-9), best updated at this epoch
# 2025-12-27 17:49:05,919 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 10 (train) ]: train loglike is -0.9984728861702943, num_events is 32620
# 2025-12-27 17:49:05,933 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 10 (valid) ]:  valid loglike is -1.0038101238479262, num_events is 10850, acc is 0.5689400921658986, rmse is 1.1894143416378795
# 2025-12-27 17:49:05,952 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 10 (test) ]: test loglike is -1.002259717054174, num_events is 10817, acc is 0.5651289636682999, rmse is 1.195038012125843
# 2025-12-27 17:49:05,952 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0038 (updated at epoch-10), best updated at this epoch
# 2025-12-27 17:49:05,981 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 11 (train) ]: train loglike is -0.9941615962455932, num_events is 32620
# 2025-12-27 17:49:05,995 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 11 (valid) ]:  valid loglike is -1.0022992871543779, num_events is 10850, acc is 0.5737327188940092, rmse is 1.161183557812779
# 2025-12-27 17:49:06,013 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 11 (test) ]: test loglike is -1.0006176981256356, num_events is 10817, acc is 0.5743736710733105, rmse is 1.1466397386329061
# 2025-12-27 17:49:06,014 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0023 (updated at epoch-11), best updated at this epoch
# 2025-12-27 17:49:06,041 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 12 (train) ]: train loglike is -0.9922389925659105, num_events is 32620
# 2025-12-27 17:49:06,055 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 12 (valid) ]:  valid loglike is -0.9992708633352535, num_events is 10850, acc is 0.5932718894009217, rmse is 1.142298707230916
# 2025-12-27 17:49:06,074 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 12 (test) ]: test loglike is -0.9974707058334104, num_events is 10817, acc is 0.5886105204770269, rmse is 1.158825198287397
# 2025-12-27 17:49:06,075 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9993 (updated at epoch-12), best updated at this epoch
# 2025-12-27 17:49:06,104 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 13 (train) ]: train loglike is -0.9889421960022609, num_events is 32620
# 2025-12-27 17:49:06,118 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 13 (valid) ]:  valid loglike is -0.995750738047235, num_events is 10850, acc is 0.6124423963133641, rmse is 1.108126483569674
# 2025-12-27 17:49:06,136 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 13 (test) ]: test loglike is -0.9939107712397153, num_events is 10817, acc is 0.6054358879541463, rmse is 1.1294087174222585
# 2025-12-27 17:49:06,137 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9958 (updated at epoch-13), best updated at this epoch
# 2025-12-27 17:49:06,166 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 14 (train) ]: train loglike is -0.9855110996417076, num_events is 32620
# 2025-12-27 17:49:06,181 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 14 (valid) ]:  valid loglike is -0.994459245391705, num_events is 10850, acc is 0.6226728110599078, rmse is 1.1315947745047257
# 2025-12-27 17:49:06,201 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 14 (test) ]: test loglike is -0.9925787750184895, num_events is 10817, acc is 0.6167144309882592, rmse is 1.110629552962326
# 2025-12-27 17:49:06,202 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9945 (updated at epoch-14), best updated at this epoch
# 2025-12-27 17:49:06,230 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 15 (train) ]: train loglike is -0.9840269611482603, num_events is 32620
# 2025-12-27 17:49:06,245 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 15 (valid) ]:  valid loglike is -0.9926437391993087, num_events is 10850, acc is 0.6505990783410138, rmse is 1.0985824791131866
# 2025-12-27 17:49:06,263 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 15 (test) ]: test loglike is -0.9902337430375797, num_events is 10817, acc is 0.6498104834981973, rmse is 1.0858251114026645
# 2025-12-27 17:49:06,264 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9926 (updated at epoch-15), best updated at this epoch
# 2025-12-27 17:49:06,293 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 16 (train) ]: train loglike is -0.9815810492987431, num_events is 32620
# 2025-12-27 17:49:06,307 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 16 (valid) ]:  valid loglike is -0.9913566568260369, num_events is 10850, acc is 0.6459907834101383, rmse is 1.0865002862856428
# 2025-12-27 17:49:06,325 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 16 (test) ]: test loglike is -0.9885793557016733, num_events is 10817, acc is 0.6393639641305353, rmse is 1.1114213268730266
# 2025-12-27 17:49:06,325 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9914 (updated at epoch-16), best updated at this epoch
# 2025-12-27 17:49:06,355 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 17 (train) ]: train loglike is -0.9797500395175506, num_events is 32620
# 2025-12-27 17:49:06,374 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 17 (valid) ]:  valid loglike is -0.9885168850806452, num_events is 10850, acc is 0.6503225806451612, rmse is 1.1065738986822713
# 2025-12-27 17:49:06,397 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 17 (test) ]: test loglike is -0.9859022726090876, num_events is 10817, acc is 0.6532310252380512, rmse is 1.078957551299152
# 2025-12-27 17:49:06,398 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9885 (updated at epoch-17), best updated at this epoch
# 2025-12-27 17:49:06,427 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 18 (train) ]: train loglike is -0.9772027441945126, num_events is 32620
# 2025-12-27 17:49:06,442 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 18 (valid) ]:  valid loglike is -0.9864618735599079, num_events is 10850, acc is 0.6571428571428571, rmse is 1.0724034731890573
# 2025-12-27 17:49:06,460 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 18 (test) ]: test loglike is -0.9841651884764723, num_events is 10817, acc is 0.6558195433114542, rmse is 1.0827660926955802
# 2025-12-27 17:49:06,461 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9865 (updated at epoch-18), best updated at this epoch
# 2025-12-27 17:49:06,489 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 19 (train) ]: train loglike is -0.9756533568362967, num_events is 32620
# 2025-12-27 17:49:06,504 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 19 (valid) ]:  valid loglike is -0.9842166798675115, num_events is 10850, acc is 0.6512442396313364, rmse is 1.1099806372465726
# 2025-12-27 17:49:06,523 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 19 (test) ]: test loglike is -0.9817863916462513, num_events is 10817, acc is 0.6589627438291578, rmse is 1.1297139654560786
# 2025-12-27 17:49:06,524 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9842 (updated at epoch-19), best updated at this epoch
# 2025-12-27 17:49:06,554 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 20 (train) ]: train loglike is -0.9732713316935546, num_events is 32620
# 2025-12-27 17:49:06,568 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 20 (valid) ]:  valid loglike is -0.9823892029089861, num_events is 10850, acc is 0.6458064516129032, rmse is 1.0642822535201855
# 2025-12-27 17:49:06,587 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 20 (test) ]: test loglike is -0.9796445807236295, num_events is 10817, acc is 0.6507349542386983, rmse is 1.1144723401704597
# 2025-12-27 17:49:06,588 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9824 (updated at epoch-20), best updated at this epoch
# 2025-12-27 17:49:06,617 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 21 (train) ]: train loglike is -0.9710674947788933, num_events is 32620
# 2025-12-27 17:49:06,631 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 21 (valid) ]:  valid loglike is -0.9801883820564516, num_events is 10850, acc is 0.6504147465437788, rmse is 1.0949710699053745
# 2025-12-27 17:49:06,650 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 21 (test) ]: test loglike is -0.9774718036424147, num_events is 10817, acc is 0.6458352593140427, rmse is 1.0767575426368567
# 2025-12-27 17:49:06,651 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9802 (updated at epoch-21), best updated at this epoch
# 2025-12-27 17:49:06,680 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 22 (train) ]: train loglike is -0.9689279187902361, num_events is 32620
# 2025-12-27 17:49:06,694 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 22 (valid) ]:  valid loglike is -0.9778629032258065, num_events is 10850, acc is 0.6588940092165899, rmse is 1.1239902333602358
# 2025-12-27 17:49:06,713 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 22 (test) ]: test loglike is -0.9754025781177775, num_events is 10817, acc is 0.6515669779051493, rmse is 1.1589558277267473
# 2025-12-27 17:49:06,714 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9779 (updated at epoch-22), best updated at this epoch
# 2025-12-27 17:49:06,752 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 23 (train) ]: train loglike is -0.9670271994510653, num_events is 32620
# 2025-12-27 17:49:06,770 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 23 (valid) ]:  valid loglike is -0.9753609230990783, num_events is 10850, acc is 0.6549308755760369, rmse is 1.0953949320032839
# 2025-12-27 17:49:06,789 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 23 (test) ]: test loglike is -0.972941716453268, num_events is 10817, acc is 0.6540630489045022, rmse is 1.1337589234502752
# 2025-12-27 17:49:06,790 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9754 (updated at epoch-23), best updated at this epoch
# 2025-12-27 17:49:06,819 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 24 (train) ]: train loglike is -0.964690724272877, num_events is 32620
# 2025-12-27 17:49:06,834 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 24 (valid) ]:  valid loglike is -0.9731907042050691, num_events is 10850, acc is 0.6537327188940092, rmse is 1.130615974213418
# 2025-12-27 17:49:06,853 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 24 (test) ]: test loglike is -0.9707222644332995, num_events is 10817, acc is 0.6583156143108071, rmse is 1.1193731558950184
# 2025-12-27 17:49:06,853 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9732 (updated at epoch-24), best updated at this epoch
# 2025-12-27 17:49:06,883 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 25 (train) ]: train loglike is -0.9625201329945202, num_events is 32620
# 2025-12-27 17:49:06,898 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 25 (valid) ]:  valid loglike is -0.9706171694988479, num_events is 10850, acc is 0.6509677419354839, rmse is 1.1158945151623563
# 2025-12-27 17:49:06,916 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 25 (test) ]: test loglike is -0.9682680835143755, num_events is 10817, acc is 0.6550799667190533, rmse is 1.1867068412498014
# 2025-12-27 17:49:06,917 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9706 (updated at epoch-25), best updated at this epoch
# 2025-12-27 17:49:06,945 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 26 (train) ]: train loglike is -0.9600952372969037, num_events is 32620
# 2025-12-27 17:49:06,960 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 26 (valid) ]:  valid loglike is -0.9679322976670507, num_events is 10850, acc is 0.6576036866359447, rmse is 1.146531170651276
# 2025-12-27 17:49:06,979 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 26 (test) ]: test loglike is -0.965734726732227, num_events is 10817, acc is 0.6637699916797634, rmse is 1.1459763707622024
# 2025-12-27 17:49:06,980 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9679 (updated at epoch-26), best updated at this epoch
# 2025-12-27 17:49:07,009 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 27 (train) ]: train loglike is -0.9575589290504292, num_events is 32620
# 2025-12-27 17:49:07,023 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 27 (valid) ]:  valid loglike is -0.9647811059907834, num_events is 10850, acc is 0.6652534562211981, rmse is 1.1466166072972028
# 2025-12-27 17:49:07,043 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 27 (test) ]: test loglike is -0.9625827690209855, num_events is 10817, acc is 0.6623832855690117, rmse is 1.1487470811737863
# 2025-12-27 17:49:07,043 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9648 (updated at epoch-27), best updated at this epoch
# 2025-12-27 17:49:07,073 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 28 (train) ]: train loglike is -0.954251220254062, num_events is 32620
# 2025-12-27 17:49:07,088 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 28 (valid) ]:  valid loglike is -0.9598402397753456, num_events is 10850, acc is 0.6642396313364055, rmse is 1.1647623013262134
# 2025-12-27 17:49:07,118 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 28 (test) ]: test loglike is -0.9577557497746603, num_events is 10817, acc is 0.6692243690487196, rmse is 1.1624287001072233
# 2025-12-27 17:49:07,119 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9598 (updated at epoch-28), best updated at this epoch
# 2025-12-27 17:49:07,148 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 29 (train) ]: train loglike is -0.9492170435603158, num_events is 32620
# 2025-12-27 17:49:07,163 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 29 (valid) ]:  valid loglike is -0.9522958669354838, num_events is 10850, acc is 0.680184331797235, rmse is 1.1162561816819987
# 2025-12-27 17:49:07,181 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 29 (test) ]: test loglike is -0.9507110841152815, num_events is 10817, acc is 0.6811500416011833, rmse is 1.152757874756329
# 2025-12-27 17:49:07,182 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9523 (updated at epoch-29), best updated at this epoch
# 2025-12-27 17:49:07,210 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 30 (train) ]: train loglike is -0.9428147513028816, num_events is 32620
# 2025-12-27 17:49:07,224 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 30 (valid) ]:  valid loglike is -0.9532457877304148, num_events is 10850, acc is 0.6772350230414746, rmse is 1.0630229979735775
# 2025-12-27 17:49:07,237 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 30 (test) ]: test loglike is -0.950736362612092, num_events is 10817, acc is 0.6788388647499307, rmse is 1.0578172462942832
# 2025-12-27 17:49:07,238 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9523 (updated at epoch-29)
# 2025-12-27 17:49:07,264 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 31 (train) ]: train loglike is -0.942595997710377, num_events is 32620
# 2025-12-27 17:49:07,277 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 31 (valid) ]:  valid loglike is -0.948973394297235, num_events is 10850, acc is 0.6863594470046083, rmse is 1.0854623095174896
# 2025-12-27 17:49:07,297 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 31 (test) ]: test loglike is -0.9469283376282703, num_events is 10817, acc is 0.6792086530461311, rmse is 1.1175232771099146
# 2025-12-27 17:49:07,298 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9490 (updated at epoch-31), best updated at this epoch
# 2025-12-27 17:49:07,327 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 32 (train) ]: train loglike is -0.9387821050160944, num_events is 32620
# 2025-12-27 17:49:07,341 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 32 (valid) ]:  valid loglike is -0.9468933611751152, num_events is 10850, acc is 0.6817511520737327, rmse is 1.1118286247214155
# 2025-12-27 17:49:07,359 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 32 (test) ]: test loglike is -0.94460244508066, num_events is 10817, acc is 0.676527687898678, rmse is 1.1168118961847604
# 2025-12-27 17:49:07,360 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9469 (updated at epoch-32), best updated at this epoch
# 2025-12-27 17:49:07,389 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 33 (train) ]: train loglike is -0.9365508303475628, num_events is 32620
# 2025-12-27 17:49:07,404 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 33 (valid) ]:  valid loglike is -0.9459538810483871, num_events is 10850, acc is 0.676405529953917, rmse is 1.1050098288934411
# 2025-12-27 17:49:07,422 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 33 (test) ]: test loglike is -0.9437174268512527, num_events is 10817, acc is 0.6759730054543773, rmse is 1.1179296724818224
# 2025-12-27 17:49:07,423 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9460 (updated at epoch-33), best updated at this epoch
# 2025-12-27 17:49:07,451 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 34 (train) ]: train loglike is -0.9353842542918455, num_events is 32620
# 2025-12-27 17:49:07,465 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 34 (valid) ]:  valid loglike is -0.94227048531106, num_events is 10850, acc is 0.6775115207373272, rmse is 1.1397710993544636
# 2025-12-27 17:49:07,484 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 34 (test) ]: test loglike is -0.9406614371475456, num_events is 10817, acc is 0.6803180179347323, rmse is 1.1432652820516864
# 2025-12-27 17:49:07,485 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9423 (updated at epoch-34), best updated at this epoch
# 2025-12-27 17:49:07,513 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 35 (train) ]: train loglike is -0.9326237438208921, num_events is 32620
# 2025-12-27 17:49:07,527 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 35 (valid) ]:  valid loglike is -0.939207769297235, num_events is 10850, acc is 0.6817511520737327, rmse is 1.1295749881393815
# 2025-12-27 17:49:07,546 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 35 (test) ]: test loglike is -0.9375125489680596, num_events is 10817, acc is 0.6805029120828325, rmse is 1.111731020896539
# 2025-12-27 17:49:07,546 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9392 (updated at epoch-35), best updated at this epoch
# 2025-12-27 17:49:07,576 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 36 (train) ]: train loglike is -0.9297359688745401, num_events is 32620
# 2025-12-27 17:49:07,590 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 36 (valid) ]:  valid loglike is -0.9377201540898618, num_events is 10850, acc is 0.6856221198156682, rmse is 1.1240030485741637
# 2025-12-27 17:49:07,608 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 36 (test) ]: test loglike is -0.9358503072420726, num_events is 10817, acc is 0.6880835721549413, rmse is 1.1174892666515468
# 2025-12-27 17:49:07,609 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9377 (updated at epoch-36), best updated at this epoch
# 2025-12-27 17:49:07,637 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 37 (train) ]: train loglike is -0.9278797816236205, num_events is 32620
# 2025-12-27 17:49:07,652 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 37 (valid) ]:  valid loglike is -0.9356545218894009, num_events is 10850, acc is 0.6840552995391705, rmse is 1.1106848803306193
# 2025-12-27 17:49:07,670 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 37 (test) ]: test loglike is -0.9338905917768328, num_events is 10817, acc is 0.6889155958213923, rmse is 1.1049841919442809
# 2025-12-27 17:49:07,671 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9357 (updated at epoch-37), best updated at this epoch
# 2025-12-27 17:49:07,698 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 38 (train) ]: train loglike is -0.9258081937844881, num_events is 32620
# 2025-12-27 17:49:07,711 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 38 (valid) ]:  valid loglike is -0.9347700352822581, num_events is 10850, acc is 0.6847926267281106, rmse is 1.160252548322589
# 2025-12-27 17:49:07,732 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 38 (test) ]: test loglike is -0.932868798823611, num_events is 10817, acc is 0.6859572894517888, rmse is 1.113822123776248
# 2025-12-27 17:49:07,732 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9348 (updated at epoch-38), best updated at this epoch
# 2025-12-27 17:49:07,762 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 39 (train) ]: train loglike is -0.9245379739711067, num_events is 32620
# 2025-12-27 17:49:07,776 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 39 (valid) ]:  valid loglike is -0.9326530097926268, num_events is 10850, acc is 0.6861751152073733, rmse is 1.1520605077246426
# 2025-12-27 17:49:07,794 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 39 (test) ]: test loglike is -0.9307487454643154, num_events is 10817, acc is 0.6862346306739392, rmse is 1.1510871985638076
# 2025-12-27 17:49:07,795 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9327 (updated at epoch-39), best updated at this epoch
# 2025-12-27 17:49:07,822 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 40 (train) ]: train loglike is -0.9225391343500919, num_events is 32620
# 2025-12-27 17:49:07,835 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 40 (valid) ]:  valid loglike is -0.9299530169930875, num_events is 10850, acc is 0.6894930875576036, rmse is 1.1744176569046385
# 2025-12-27 17:49:07,855 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 40 (test) ]: test loglike is -0.9282387712917167, num_events is 10817, acc is 0.6885458075251918, rmse is 1.1892840950824342
# 2025-12-27 17:49:07,856 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9300 (updated at epoch-40), best updated at this epoch
# 2025-12-27 17:49:07,886 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 41 (train) ]: train loglike is -0.9203759975187769, num_events is 32620
# 2025-12-27 17:49:07,901 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 41 (valid) ]:  valid loglike is -0.928332013248848, num_events is 10850, acc is 0.6882027649769585, rmse is 1.1609322935405362
# 2025-12-27 17:49:07,919 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 41 (test) ]: test loglike is -0.9264843533327171, num_events is 10817, acc is 0.6906720902283443, rmse is 1.1427610814135927
# 2025-12-27 17:49:07,920 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9283 (updated at epoch-41), best updated at this epoch
# 2025-12-27 17:49:07,948 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 42 (train) ]: train loglike is -0.9186273159679644, num_events is 32620
# 2025-12-27 17:49:07,963 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 42 (valid) ]:  valid loglike is -0.9267744635656682, num_events is 10850, acc is 0.6905990783410139, rmse is 1.1331584829687267
# 2025-12-27 17:49:07,981 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 42 (test) ]: test loglike is -0.9249167254090783, num_events is 10817, acc is 0.6907645373023944, rmse is 1.1212160362697567
# 2025-12-27 17:49:07,982 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9268 (updated at epoch-42), best updated at this epoch
# 2025-12-27 17:49:08,010 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 43 (train) ]: train loglike is -0.9168028924452023, num_events is 32620
# 2025-12-27 17:49:08,024 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 43 (valid) ]:  valid loglike is -0.9254651497695853, num_events is 10850, acc is 0.6883870967741935, rmse is 1.14347044771232
# 2025-12-27 17:49:08,055 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 43 (test) ]: test loglike is -0.9237945407113802, num_events is 10817, acc is 0.6910418785245447, rmse is 1.1848417656208874
# 2025-12-27 17:49:08,056 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9255 (updated at epoch-43), best updated at this epoch
# 2025-12-27 17:49:08,085 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 44 (train) ]: train loglike is -0.9154385340425736, num_events is 32620
# 2025-12-27 17:49:08,099 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 44 (valid) ]:  valid loglike is -0.9244682459677419, num_events is 10850, acc is 0.6862672811059908, rmse is 1.1801617000787383
# 2025-12-27 17:49:08,118 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 44 (test) ]: test loglike is -0.922673529658177, num_events is 10817, acc is 0.6932606083017473, rmse is 1.16497138619701
# 2025-12-27 17:49:08,119 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9245 (updated at epoch-44), best updated at this epoch
# 2025-12-27 17:49:08,148 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 45 (train) ]: train loglike is -0.9140927668512415, num_events is 32620
# 2025-12-27 17:49:08,163 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 45 (valid) ]:  valid loglike is -0.9224514868951613, num_events is 10850, acc is 0.6966820276497696, rmse is 1.129158283084442
# 2025-12-27 17:49:08,181 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 45 (test) ]: test loglike is -0.9206719241125081, num_events is 10817, acc is 0.6923361375612462, rmse is 1.150061626643495
# 2025-12-27 17:49:08,182 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9225 (updated at epoch-45), best updated at this epoch
# 2025-12-27 17:49:08,211 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 46 (train) ]: train loglike is -0.9122175842322578, num_events is 32620
# 2025-12-27 17:49:08,225 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 46 (valid) ]:  valid loglike is -0.9204615495391705, num_events is 10850, acc is 0.6929953917050691, rmse is 1.149431528859391
# 2025-12-27 17:49:08,244 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 46 (test) ]: test loglike is -0.918820454781825, num_events is 10817, acc is 0.6916890080428955, rmse is 1.1662271318328115
# 2025-12-27 17:49:08,244 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9205 (updated at epoch-46), best updated at this epoch
# 2025-12-27 17:49:08,274 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 47 (train) ]: train loglike is -0.9105769173197041, num_events is 32620
# 2025-12-27 17:49:08,288 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 47 (valid) ]:  valid loglike is -0.9190111967165898, num_events is 10850, acc is 0.6903225806451613, rmse is 1.103658456647604
# 2025-12-27 17:49:08,307 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 47 (test) ]: test loglike is -0.9172774733925765, num_events is 10817, acc is 0.6942775261162984, rmse is 1.177802940578499
# 2025-12-27 17:49:08,308 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9190 (updated at epoch-47), best updated at this epoch
# 2025-12-27 17:49:08,337 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 48 (train) ]: train loglike is -0.9089923084476548, num_events is 32620
# 2025-12-27 17:49:08,351 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 48 (valid) ]:  valid loglike is -0.9176218677995391, num_events is 10850, acc is 0.6939170506912442, rmse is 1.1344118935940883
# 2025-12-27 17:49:08,369 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 48 (test) ]: test loglike is -0.9160618485370251, num_events is 10817, acc is 0.6950171027086993, rmse is 1.16048316343672
# 2025-12-27 17:49:08,370 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9176 (updated at epoch-48), best updated at this epoch
# 2025-12-27 17:49:08,399 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 49 (train) ]: train loglike is -0.9076440115343347, num_events is 32620
# 2025-12-27 17:49:08,413 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 49 (valid) ]:  valid loglike is -0.9163445960541474, num_events is 10850, acc is 0.6941013824884793, rmse is 1.1332511634138789
# 2025-12-27 17:49:08,431 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 49 (test) ]: test loglike is -0.9149852554139317, num_events is 10817, acc is 0.6971433854118517, rmse is 1.1182810122954154
# 2025-12-27 17:49:08,432 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9163 (updated at epoch-49), best updated at this epoch
# 2025-12-27 17:49:08,460 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 50 (train) ]: train loglike is -0.9064179196524371, num_events is 32620
# 2025-12-27 17:49:08,475 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 50 (valid) ]:  valid loglike is -0.9148604910714285, num_events is 10850, acc is 0.6988018433179723, rmse is 1.135994162799133
# 2025-12-27 17:49:08,493 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 50 (test) ]: test loglike is -0.9134505798164926, num_events is 10817, acc is 0.6966811500416011, rmse is 1.1352225646750431
# 2025-12-27 17:49:08,494 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9149 (updated at epoch-50), best updated at this epoch
# 2025-12-27 17:49:08,523 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 51 (train) ]: train loglike is -0.9048434895434166, num_events is 32620
# 2025-12-27 17:49:08,537 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 51 (valid) ]:  valid loglike is -0.9132453377016129, num_events is 10850, acc is 0.700184331797235, rmse is 1.1383019465578907
# 2025-12-27 17:49:08,555 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 51 (test) ]: test loglike is -0.9119356756147731, num_events is 10817, acc is 0.7001016917814551, rmse is 1.1113034168074363
# 2025-12-27 17:49:08,556 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9132 (updated at epoch-51), best updated at this epoch
# 2025-12-27 17:49:08,585 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 52 (train) ]: train loglike is -0.9034256626973483, num_events is 32620
# 2025-12-27 17:49:08,600 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 52 (valid) ]:  valid loglike is -0.9119328737039171, num_events is 10850, acc is 0.7013824884792627, rmse is 1.1633008820801096
# 2025-12-27 17:49:08,618 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 52 (test) ]: test loglike is -0.9106477362022742, num_events is 10817, acc is 0.6998243505593048, rmse is 1.1475637109973245
# 2025-12-27 17:49:08,619 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9119 (updated at epoch-52), best updated at this epoch
# 2025-12-27 17:49:08,648 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 53 (train) ]: train loglike is -0.9021095636064914, num_events is 32620
# 2025-12-27 17:49:08,662 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 53 (valid) ]:  valid loglike is -0.9108183323732719, num_events is 10850, acc is 0.7021198156682028, rmse is 1.1343414629590851
# 2025-12-27 17:49:08,680 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 53 (test) ]: test loglike is -0.9095791780299528, num_events is 10817, acc is 0.7037995747434593, rmse is 1.1415878405020683
# 2025-12-27 17:49:08,681 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9108 (updated at epoch-53), best updated at this epoch
# 2025-12-27 17:49:08,710 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 54 (train) ]: train loglike is -0.90093147656729, num_events is 32620
# 2025-12-27 17:49:08,725 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 54 (valid) ]:  valid loglike is -0.9095929039458526, num_events is 10850, acc is 0.7010138248847926, rmse is 1.161474532965376
# 2025-12-27 17:49:08,744 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 54 (test) ]: test loglike is -0.9085386067648147, num_events is 10817, acc is 0.7004714800776556, rmse is 1.1307644782133095
# 2025-12-27 17:49:08,744 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9096 (updated at epoch-54), best updated at this epoch
# 2025-12-27 17:49:08,773 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 55 (train) ]: train loglike is -0.8998218117719191, num_events is 32620
# 2025-12-27 17:49:08,788 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 55 (valid) ]:  valid loglike is -0.9082324668778802, num_events is 10850, acc is 0.700184331797235, rmse is 1.136821764970853
# 2025-12-27 17:49:08,806 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 55 (test) ]: test loglike is -0.9072064299828972, num_events is 10817, acc is 0.7010261625219562, rmse is 1.1000481761948901
# 2025-12-27 17:49:08,807 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9082 (updated at epoch-55), best updated at this epoch
# 2025-12-27 17:49:08,836 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 56 (train) ]: train loglike is -0.8984907588806713, num_events is 32620
# 2025-12-27 17:49:08,850 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 56 (valid) ]:  valid loglike is -0.9068959713421659, num_events is 10850, acc is 0.7015668202764977, rmse is 1.1339845177512446
# 2025-12-27 17:49:08,869 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 56 (test) ]: test loglike is -0.9059279700067024, num_events is 10817, acc is 0.700841268373856, rmse is 1.140172793091432
# 2025-12-27 17:49:08,870 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9069 (updated at epoch-56), best updated at this epoch
# 2025-12-27 17:49:08,897 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 57 (train) ]: train loglike is -0.8972372142761342, num_events is 32620
# 2025-12-27 17:49:08,911 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 57 (valid) ]:  valid loglike is -0.9057364271313364, num_events is 10850, acc is 0.7031336405529954, rmse is 1.1495160396854398
# 2025-12-27 17:49:08,931 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 57 (test) ]: test loglike is -0.9048468628663215, num_events is 10817, acc is 0.7041693630396598, rmse is 1.1470316087778103
# 2025-12-27 17:49:08,932 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9057 (updated at epoch-57), best updated at this epoch
# 2025-12-27 17:49:08,961 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 58 (train) ]: train loglike is -0.896133028050276, num_events is 32620
# 2025-12-27 17:49:08,976 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 58 (valid) ]:  valid loglike is -0.904751944124424, num_events is 10850, acc is 0.7015668202764977, rmse is 1.1468152257741
# 2025-12-27 17:49:08,996 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 58 (test) ]: test loglike is -0.9039080375508459, num_events is 10817, acc is 0.7030599981510586, rmse is 1.1121113300724526
# 2025-12-27 17:49:08,997 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9048 (updated at epoch-58), best updated at this epoch
# 2025-12-27 17:49:09,026 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 59 (train) ]: train loglike is -0.8950937464074954, num_events is 32620
# 2025-12-27 17:49:09,040 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 59 (valid) ]:  valid loglike is -0.9036836657546083, num_events is 10850, acc is 0.7069124423963133, rmse is 1.105555752492867
# 2025-12-27 17:49:09,059 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 59 (test) ]: test loglike is -0.9029342737415642, num_events is 10817, acc is 0.7049089396320607, rmse is 1.1064745457878646
# 2025-12-27 17:49:09,059 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9037 (updated at epoch-59), best updated at this epoch
# 2025-12-27 17:49:09,089 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 60 (train) ]: train loglike is -0.8940846567721107, num_events is 32620
# 2025-12-27 17:49:09,103 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 60 (valid) ]:  valid loglike is -0.9025001800115208, num_events is 10850, acc is 0.7058064516129032, rmse is 1.1874009748302152
# 2025-12-27 17:49:09,121 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 60 (test) ]: test loglike is -0.9018181378270316, num_events is 10817, acc is 0.7056485162244615, rmse is 1.120525340846239
# 2025-12-27 17:49:09,122 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9025 (updated at epoch-60), best updated at this epoch
# 2025-12-27 17:49:09,152 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 61 (train) ]: train loglike is -0.8929768630728847, num_events is 32620
# 2025-12-27 17:49:09,166 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 61 (valid) ]:  valid loglike is -0.9013568368375576, num_events is 10850, acc is 0.7047004608294931, rmse is 1.1460853979906886
# 2025-12-27 17:49:09,184 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 61 (test) ]: test loglike is -0.9007259262041232, num_events is 10817, acc is 0.70435425718776, rmse is 1.1471399496915202
# 2025-12-27 17:49:09,185 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9014 (updated at epoch-61), best updated at this epoch
# 2025-12-27 17:49:09,217 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 62 (train) ]: train loglike is -0.8918856697386572, num_events is 32620
# ...
# 2025-12-27 17:54:35,570 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 183 (test) ]: test loglike is -0.8592681080706296, num_events is 10817, acc is 0.7088841638162152, rmse is 1.7848412202693855
# 2025-12-27 17:54:35,572 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8591 (updated at epoch-183), best updated at this epoch
# 2025-12-27 17:54:35,610 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 184 (train) ]: train loglike is -0.8494532357688918, num_events is 32620
# 2025-12-27 17:54:35,626 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 184 (valid) ]:  valid loglike is -0.8588115639400922, num_events is 10850, acc is 0.7126267281105991, rmse is 1.4859366765697473
# 2025-12-27 17:54:35,646 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 184 (test) ]: test loglike is -0.8590278720705833, num_events is 10817, acc is 0.7090690579643154, rmse is 1.3981132148978839
# 2025-12-27 17:54:35,647 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8588 (updated at epoch-184), best updated at this epoch
# 2025-12-27 17:54:35,682 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 185 (train) ]: train loglike is -0.8491995001628602, num_events is 32620
# 2025-12-27 17:54:35,698 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 185 (valid) ]:  valid loglike is -0.8585599978398617, num_events is 10850, acc is 0.7130875576036866, rmse is 1.603109572609906
# 2025-12-27 17:54:35,717 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 185 (test) ]: test loglike is -0.8587890805560692, num_events is 10817, acc is 0.7089766108902653, rmse is 1.2792985519221285
# 2025-12-27 17:54:35,718 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8586 (updated at epoch-185), best updated at this epoch
# 2025-12-27 17:54:35,756 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 186 (train) ]: train loglike is -0.8489471416835913, num_events is 32620
# 2025-12-27 17:54:35,771 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 186 (valid) ]:  valid loglike is -0.8583098718317972, num_events is 10850, acc is 0.7133640552995392, rmse is 1.3254035399422082
# 2025-12-27 17:54:35,790 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 186 (test) ]: test loglike is -0.8585516432467413, num_events is 10817, acc is 0.7091615050383655, rmse is 1.5302741193650653
# 2025-12-27 17:54:35,791 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8583 (updated at epoch-186), best updated at this epoch
# 2025-12-27 17:54:35,825 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 187 (train) ]: train loglike is -0.8486961752998544, num_events is 32620
# 2025-12-27 17:54:35,841 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 187 (valid) ]:  valid loglike is -0.858061275921659, num_events is 10850, acc is 0.7136405529953918, rmse is 1.8284700140438972
# 2025-12-27 17:54:35,861 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 187 (test) ]: test loglike is -0.8583155601425996, num_events is 10817, acc is 0.7093463991864658, rmse is 1.252965633668036
# 2025-12-27 17:54:35,863 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8581 (updated at epoch-187), best updated at this epoch
# 2025-12-27 17:54:35,899 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 188 (train) ]: train loglike is -0.8484465111990344, num_events is 32620
# 2025-12-27 17:54:35,915 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 188 (valid) ]:  valid loglike is -0.8578140300979262, num_events is 10850, acc is 0.7137327188940092, rmse is 1.4992109085646117
# 2025-12-27 17:54:35,934 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 188 (test) ]: test loglike is -0.8580807409632986, num_events is 10817, acc is 0.7099935287048165, rmse is 1.6846337721450944
# 2025-12-27 17:54:35,935 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8578 (updated at epoch-188), best updated at this epoch
# 2025-12-27 17:54:35,971 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 189 (train) ]: train loglike is -0.8481980895060546, num_events is 32620
# 2025-12-27 17:54:35,985 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 189 (valid) ]:  valid loglike is -0.8575682243663595, num_events is 10850, acc is 0.7137327188940092, rmse is 1.441533547503223
# 2025-12-27 17:54:36,005 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 189 (test) ]: test loglike is -0.8578472759891836, num_events is 10817, acc is 0.7102708699269669, rmse is 1.2404544198333292
# 2025-12-27 17:54:36,007 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8576 (updated at epoch-189), best updated at this epoch
# 2025-12-27 17:54:36,042 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 190 (train) ]: train loglike is -0.8479508503458384, num_events is 32620
# 2025-12-27 17:54:36,057 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 190 (valid) ]:  valid loglike is -0.8573235887096774, num_events is 10850, acc is 0.7139170506912442, rmse is 1.4383368964715253
# 2025-12-27 17:54:36,087 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 190 (test) ]: test loglike is -0.8576148943792179, num_events is 10817, acc is 0.7099935287048165, rmse is 1.2741122486059984
# 2025-12-27 17:54:36,088 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8573 (updated at epoch-190), best updated at this epoch
# 2025-12-27 17:54:36,122 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 191 (train) ]: train loglike is -0.8477048386246935, num_events is 32620
# 2025-12-27 17:54:36,138 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 191 (valid) ]:  valid loglike is -0.8570801231278802, num_events is 10850, acc is 0.7141013824884792, rmse is 1.5456052946063252
# 2025-12-27 17:54:36,158 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 191 (test) ]: test loglike is -0.8573837766940926, num_events is 10817, acc is 0.7101784228529167, rmse is 1.330022159632385
# 2025-12-27 17:54:36,160 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8571 (updated at epoch-191), best updated at this epoch
# 2025-12-27 17:54:36,195 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 192 (train) ]: train loglike is -0.8474597399984672, num_events is 32620
# 2025-12-27 17:54:36,213 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 192 (valid) ]:  valid loglike is -0.8568377376152074, num_events is 10850, acc is 0.7140092165898617, rmse is 1.2875339692119876
# 2025-12-27 17:54:36,231 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 192 (test) ]: test loglike is -0.8571537423731164, num_events is 10817, acc is 0.710455764075067, rmse is 1.4052680790708854
# 2025-12-27 17:54:36,233 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8568 (updated at epoch-192), best updated at this epoch
# 2025-12-27 17:54:36,270 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 193 (train) ]: train loglike is -0.8472158688113121, num_events is 32620
# 2025-12-27 17:54:36,285 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 193 (valid) ]:  valid loglike is -0.8565965221774193, num_events is 10850, acc is 0.7141013824884792, rmse is 1.912236833961828
# 2025-12-27 17:54:36,305 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 193 (test) ]: test loglike is -0.8569247914162892, num_events is 10817, acc is 0.710455764075067, rmse is 1.3103892160798754
# 2025-12-27 17:54:36,307 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8566 (updated at epoch-193), best updated at this epoch
# 2025-12-27 17:54:36,343 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 194 (train) ]: train loglike is -0.8469729556253832, num_events is 32620
# 2025-12-27 17:54:36,358 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 194 (valid) ]:  valid loglike is -0.8563563868087558, num_events is 10850, acc is 0.7140092165898617, rmse is 1.382252694233348
# 2025-12-27 17:54:36,379 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 194 (test) ]: test loglike is -0.856696923823611, num_events is 10817, acc is 0.7105482111491171, rmse is 1.2660892709220843
# 2025-12-27 17:54:36,380 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8564 (updated at epoch-194), best updated at this epoch
# 2025-12-27 17:54:36,417 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 195 (train) ]: train loglike is -0.8467309854719114, num_events is 32620
# 2025-12-27 17:54:36,432 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 195 (valid) ]:  valid loglike is -0.8561169714861752, num_events is 10850, acc is 0.7139170506912442, rmse is 1.6550426723881153
# 2025-12-27 17:54:36,452 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 195 (test) ]: test loglike is -0.8564699590343903, num_events is 10817, acc is 0.7105482111491171, rmse is 1.3899457663567598
# 2025-12-27 17:54:36,453 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8561 (updated at epoch-195), best updated at this epoch
# 2025-12-27 17:54:36,488 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 196 (train) ]: train loglike is -0.8464899733196658, num_events is 32620
# 2025-12-27 17:54:36,503 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 196 (valid) ]:  valid loglike is -0.8558786362327189, num_events is 10850, acc is 0.7139170506912442, rmse is 1.4898869034227036
# 2025-12-27 17:54:36,523 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 196 (test) ]: test loglike is -0.8562440776093186, num_events is 10817, acc is 0.7108255523712674, rmse is 1.3558856806109019
# 2025-12-27 17:54:36,525 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8559 (updated at epoch-196), best updated at this epoch
# 2025-12-27 17:54:36,560 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 197 (train) ]: train loglike is -0.8462497844497241, num_events is 32620
# 2025-12-27 17:54:36,575 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 197 (valid) ]:  valid loglike is -0.8556409310195853, num_events is 10850, acc is 0.7137327188940092, rmse is 1.317711516197487
# 2025-12-27 17:54:36,593 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 197 (test) ]: test loglike is -0.8560190989877046, num_events is 10817, acc is 0.7111028935934177, rmse is 1.3672922013083568
# 2025-12-27 17:54:36,595 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8556 (updated at epoch-197), best updated at this epoch
# 2025-12-27 17:54:36,639 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 198 (train) ]: train loglike is -0.8460103589870095, num_events is 32620
# 2025-12-27 17:54:36,654 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 198 (valid) ]:  valid loglike is -0.8554039458525345, num_events is 10850, acc is 0.7138248847926267, rmse is 1.416232432396734
# 2025-12-27 17:54:36,674 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 198 (test) ]: test loglike is -0.8557948426088564, num_events is 10817, acc is 0.7111028935934177, rmse is 1.300904724583702
# 2025-12-27 17:54:36,675 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8554 (updated at epoch-198), best updated at this epoch
# 2025-12-27 17:54:36,711 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 199 (train) ]: train loglike is -0.8457716071189071, num_events is 32620
# 2025-12-27 17:54:36,726 - tpp_runner.py[pid:3157;line:107:_train_model] - INFO: [ Epoch 199 (valid) ]:  valid loglike is -0.8551675907258065, num_events is 10850, acc is 0.7140092165898617, rmse is 1.3430095077562143
# 2025-12-27 17:54:36,749 - tpp_runner.py[pid:3157;line:122:_train_model] - INFO: [ Epoch 199 (test) ]: test loglike is -0.8555714890334658, num_events is 10817, acc is 0.7111028935934177, rmse is 1.2445656806847674
# 2025-12-27 17:54:36,750 - tpp_runner.py[pid:3157;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8552 (updated at epoch-199), best updated at this epoch
# 2025-12-27 17:54:36,751 - base_runner.py[pid:3157;line:110:train] - INFO: End IntensityFree train! Cost time: 0.243m
# ✓ IntensityFree on nonstationary_hawkes completed successfully!
#   - Log-Likelihood: -0.8556
#   - Accuracy: 0.7111
#   - RMSE: 1.2446
#
# ======================================================================
# ✓ IntensityFree completed on all datasets
#   - Time: 0.3 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/IntensityFree_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model
#
# ======================================================================
# [MODEL 7/7] Running AttNHP on all datasets
# ======================================================================
#
# [7/7] Running AttNHP on nonstationary_hawkes dataset
# ======================================================================
# 2025-12-27 17:54:37,293 - config.py[pid:3157;line:34:build_from_yaml_file] - CRITICAL: Load pipeline config class RunnerConfig
# 2025-12-27 17:54:37,299 - runner_config.py[pid:3157;line:140:update_config] - CRITICAL: train model AttNHP using GPU with torch backend
# 2025-12-27 17:54:37,329 - runner_config.py[pid:3157;line:35:__init__] - INFO: Save the config to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/3157_135781651575424_251227-175437/AttNHP_nonstationary_hawkes_train_output.yaml
# 2025-12-27 17:54:37,333 - base_runner.py[pid:3157;line:176:save_log] - INFO: Save the log to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/3157_135781651575424_251227-175437/log
# 0.5189538021705272 0.7216217648548782
# min_dt: 4.934766515507505e-05
# max_dt: 8.303566563742564
# 2025-12-27 17:54:37,407 - tpp_runner.py[pid:3157;line:60:_init_model] - INFO: Num of model parameters 39556
# 2025-12-27 17:54:37,445 - base_runner.py[pid:3157;line:98:train] - INFO: Data 'nonstationary_hawkes' loaded...
# 2025-12-27 17:54:37,447 - base_runner.py[pid:3157;line:103:train] - INFO: Start AttNHP training...
# 2025-12-27 17:54:38,481 - tpp_runner.py[pid:3157;line:96:_train_model] - INFO: [ Epoch 0 (train) ]: train loglike is -1.1234280397378908, num_events is 32620
# ✗ Error running AttNHP on nonstationary_hawkes: CUDA out of memory. Tried to allocate 19.07 GiB. GPU 0 has a total capacity of 39.56 GiB of which 18.53 GiB is free. Process 32073 has 21.02 GiB memory in use. Of the allocated memory 20.44 GiB is allocated by PyTorch, and 78.26 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# ======================================================================
# ✓ AttNHP completed on all datasets
#   - Time: 0.1 minutes
#   - Successful: 0/1
#   - Failed: 1/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/AttNHP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model

# %% [markdown]
# ## Save Model Results

# %% [markdown]
# ### Function Definition

# %%
import pandas as pd
from typing import Optional, List

def format_results_table(
    results_df: pd.DataFrame,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    log_likelihood_col: str = 'log_likelihood',
    rmse_col: str = 'rmse',
    accuracy_col: str = 'accuracy',
    type_error_from_accuracy: bool = True,
    format_type: str = 'combined'
) -> pd.DataFrame:
    """
    Parameters
    ----------
    results_df : pd.DataFrame
        DataFrame containing columns: 'model', 'dataset', 'log_likelihood', 'rmse', 'accuracy'
    models : List[str], optional
        List of model names to include. If None, uses all models in results_df
    datasets : List[str], optional
        List of dataset names to include. If None, uses all datasets in results_df
    log_likelihood_col : str, default='log_likelihood'
        Column name for log-likelihood values
    rmse_col : str, default='rmse'
        Column name for RMSE values
    accuracy_col : str, default='accuracy'
        Column name for accuracy values
    type_error_from_accuracy : bool, default=True
        If True, compute Type Error Rate as (1 - accuracy) * 100
    format_type : str, default='combined'
        Output format type:
        - 'combined': "log_like/rmse/type_error% ± std_log/std_rmse/std_type"
        - 'log_likelihood': "log_like ± std_log"
        - 'rmse': "rmse ± std_rmse"
        - 'type_error': "type_error% ± std_type"

    Returns
    -------
    pd.DataFrame
        Formatted table with rows as models and columns as datasets
    """
    # Filter models and datasets if specified
    if models is not None:
        results_df = results_df[results_df['model'].isin(models)].copy()
    if datasets is not None:
        results_df = results_df[results_df['dataset'].isin(datasets)].copy()

    # Compute type error rate if needed
    if type_error_from_accuracy:
        results_df['type_error_rate'] = (1 - results_df[accuracy_col]) * 100

    # Get unique models and datasets (sorted)
    all_models = sorted(results_df['model'].unique())
    all_datasets = sorted(results_df['dataset'].unique())

    # Compute mean and std for each model-dataset combination
    agg_dict = {
        log_likelihood_col: ['mean', 'std'],
        rmse_col: ['mean', 'std'],
        'type_error_rate': ['mean', 'std']
    }

    grouped = results_df.groupby(['model', 'dataset']).agg(agg_dict).reset_index()

    # Flatten column names
    grouped.columns = ['model', 'dataset',
                       'log_like_mean', 'log_like_std',
                       'rmse_mean', 'rmse_std',
                       'type_error_mean', 'type_error_std']

    # Fill NaN std with 0 (for single runs)
    grouped['log_like_std'] = grouped['log_like_std'].fillna(0)
    grouped['rmse_std'] = grouped['rmse_std'].fillna(0)
    grouped['type_error_std'] = grouped['type_error_std'].fillna(0)

    # Create formatted strings based on format_type
    def format_cell(row):
        """Format a single cell based on format_type - HANDLES PARTIAL NaN VALUES"""
        log_like_mean = row['log_like_mean']
        log_like_std = row['log_like_std']
        rmse_mean = row['rmse_mean']
        rmse_std = row['rmse_std']
        type_mean = row['type_error_mean']
        type_std = row['type_error_std']

        if format_type == 'log_likelihood':
            # Log-likelihood only format
            if pd.isna(log_like_mean):
                return 'NaN'
            if log_like_std == 0:
                return f"{log_like_mean:.3f}"
            return f"{log_like_mean:.3f} ± {log_like_std:.3f}"

        elif format_type == 'rmse':
            # RMSE only format
            if pd.isna(rmse_mean):
                return 'NaN'
            if rmse_std == 0:
                return f"{rmse_mean:.3f}"
            return f"{rmse_mean:.3f} ± {rmse_std:.3f}"

        elif format_type == 'type_error':
            # Type Error only format
            if pd.isna(type_mean):
                return 'NaN'
            if type_std == 0:
                return f"{type_mean:.1f}%"
            return f"{type_mean:.1f}% ± {type_std:.3f}"

        else:  # format_type == 'combined' (default)
            # FIXED: Show available metrics even when some are NaN
            # Build mean string
            log_str = f"{log_like_mean:.3f}" if not pd.isna(log_like_mean) else "NaN"
            rmse_str = f"{rmse_mean:.3f}" if not pd.isna(rmse_mean) else "NaN"
            type_str = f"{type_mean:.1f}%" if not pd.isna(type_mean) else "NaN%"
            mean_str = f"{log_str}/{rmse_str}/{type_str}"

            # Build std string (only if at least one mean is not NaN)
            if not pd.isna(log_like_mean) or not pd.isna(rmse_mean) or not pd.isna(type_mean):
                log_std_str = f"{log_like_std:.3f}" if not pd.isna(log_like_mean) else "nan"
                rmse_std_str = f"{rmse_std:.3f}" if not pd.isna(rmse_mean) else "nan"
                type_std_str = f"{type_std:.3f}" if not pd.isna(type_mean) else "nan"
                std_str = f"{log_std_str}/{rmse_std_str}/{type_std_str}"
                return f"{mean_str} ± {std_str}"
            else:
                # All NaN case (shouldn't happen often)
                return 'NaN/NaN/NaN%'

    grouped['formatted'] = grouped.apply(format_cell, axis=1)

    # Pivot to create the final table
    formatted_table = grouped.pivot(index='model', columns='dataset', values='formatted')

    # Ensure all models and datasets are present (fill missing with N/A)
    formatted_table = formatted_table.reindex(index=all_models, columns=all_datasets, fill_value='N/A')

    return formatted_table


def save_results_easytpp_format(
    results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    save_csv: bool = True,
    save_latex: bool = True,
    save_markdown: bool = True,
    save_individual_metrics: bool = True,
    **format_kwargs
) -> dict:
    """
    Save formatted results in multiple formats (CSV, LaTeX, Markdown).

    Parameters
    ----------
    results_df : pd.DataFrame
        Results DataFrame with columns: model, dataset, log_likelihood, rmse, accuracy
    output_path : str
        Base path for output files (without extension)
    models : List[str], optional
        List of models to include
    datasets : List[str], optional
        List of datasets to include
    save_csv : bool, default=True
        Save as CSV
    save_latex : bool, default=True
        Save as LaTeX table
    save_markdown : bool, default=True
        Save as Markdown table
    save_individual_metrics : bool, default=True
        Save separate tables for each metric (log-likelihood, RMSE, Type Error)
    **format_kwargs
        Additional keyword arguments passed to format_results_table

    Returns
    -------
    dict
        Dictionary containing all generated tables
    """
    output_tables = {}

    # Generate combined table (with log-likelihood/RMSE/Type Error)
    combined_table = format_results_table(
        results_df,
        models=models,
        datasets=datasets,
        format_type='combined',
        **format_kwargs
    )
    output_tables['combined'] = combined_table

    # Save combined table
    if save_csv:
        combined_table.to_csv(f"{output_path}.csv")
        print(f"✓ Results saved to: {output_path}.csv")

    if save_latex:
        with open(f"{output_path}.tex", 'w') as f:
            f.write(combined_table.to_latex())
        print(f"✓ LaTeX table saved to: {output_path}.tex")

    if save_markdown:
        with open(f"{output_path}.md", 'w') as f:
            f.write(combined_table.to_markdown())
        print(f"✓ Markdown table saved to: {output_path}.md")

    return output_tables


def create_comparison_table(
    stationary_results_df: pd.DataFrame,
    nonstationary_results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None
) -> pd.DataFrame:
    """
    Create a side-by-side comparison table for stationary vs non-stationary results.

    Parameters
    ----------
    stationary_results_df : pd.DataFrame
        Results from stationary Hawkes data
    nonstationary_results_df : pd.DataFrame
        Results from non-stationary Hawkes data
    output_path : str
        Base path for output files
    models : List[str], optional
        List of models to include

    Returns
    -------
    pd.DataFrame
        Comparison table with degradation analysis
    """
    # Format both tables
    stat_table = format_results_table(stationary_results_df, models=models)
    nonstat_table = format_results_table(nonstationary_results_df, models=models)

    # Compute degradation statistics
    stat_grouped = stationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'stat_log_like',
        'rmse': 'stat_rmse',
        'accuracy': 'stat_type_error'
    })

    nonstat_grouped = nonstationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'nonstat_log_like',
        'rmse': 'nonstat_rmse',
        'accuracy': 'nonstat_type_error'
    })

    degradation = stat_grouped.join(nonstat_grouped)

    # Calculate degradation percentages
    degradation['log_like_degradation_%'] = (
        (degradation['nonstat_log_like'] - degradation['stat_log_like']) /
        abs(degradation['stat_log_like']) * 100
    )
    degradation['rmse_degradation_%'] = (
        (degradation['nonstat_rmse'] - degradation['stat_rmse']) /
        degradation['stat_rmse'] * 100
    )
    degradation['type_error_degradation_%'] = (
        degradation['nonstat_type_error'] - degradation['stat_type_error']
    )

    # Save comparison
    degradation.to_csv(f"{output_path}_degradation.csv")
    print(f"✓ Degradation analysis saved to: {output_path}_degradation.csv")

    return degradation

# %% [markdown]
# ### Function Execution

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
data_ids = ['nonstationary_hawkes']

# %%
import pandas as pd

def flatten_model_results(all_model_results):
    """
    Properly convert all_model_results dictionary to DataFrame.

    The issue: pd.DataFrame(dict) treats keys as COLUMN names, not data rows.
    This function flattens it correctly.
    """
    all_results = []
    for model_name, results_list in all_model_results.items():
        all_results.extend(results_list)
    return pd.DataFrame(all_results)

results_df = flatten_model_results(all_model_results)
results_df = results_df[
    results_df['status'] == 'success'
]

# Check the structure
print("✓ DataFrame created successfully!")
print(f"  Shape: {results_df.shape}")
print(f"  Columns: {list(results_df.columns)}")
print(f"\nFirst few rows:")
print(results_df.head())

formatted_table = format_results_table(
    results_df,
    models=model_ids,
    datasets=data_ids
)

print("\n✓ Formatted table:")
print(formatted_table)

# Save to files
saved_table = save_results_easytpp_format(
    results_df,
    output_path=f'{RESULTS_DIR}/Task3_results',
    models=model_ids,
    datasets=data_ids
)
# Out:
# ✓ DataFrame created successfully!
#   Shape: (6, 8)
#   Columns: ['model', 'dataset', 'log_likelihood', 'accuracy', 'rmse', 'status', 'time_seconds', 'error']
#
# First few rows:
#      model               dataset  log_likelihood  accuracy      rmse   status  \
# 0    RMTPP  nonstationary_hawkes       -0.857463  0.728853  1.111820  success
# 1      NHP  nonstationary_hawkes       -0.819737  0.721827  1.047376  success
# 2  FullyNN  nonstationary_hawkes       -1.118245  0.502727  1.076472  success
# 3     SAHP  nonstationary_hawkes       -0.877497  0.707313  1.008119  success
# 4      THP  nonstationary_hawkes       -0.861670  0.726819  1.017348  success
#
#    time_seconds error
# 0     50.829686   NaN
# 1    189.605509   NaN
# 2     53.524981   NaN
# 3     18.506867   NaN
# 4     17.769019   NaN
#
# ✓ Formatted table:
# dataset                          nonstationary_hawkes
# model
# FullyNN        -1.118/1.076/49.7% ± 0.000/0.000/0.000
# IntensityFree  -0.856/1.245/28.9% ± 0.000/0.000/0.000
# NHP            -0.820/1.047/27.8% ± 0.000/0.000/0.000
# RMTPP          -0.857/1.112/27.1% ± 0.000/0.000/0.000
# SAHP           -0.877/1.008/29.3% ± 0.000/0.000/0.000
# THP            -0.862/1.017/27.3% ± 0.000/0.000/0.000
# ✓ Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.csv
# ✓ LaTeX table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.tex
# ✓ Markdown table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/Task3_results.md

# %% [markdown]
# ## Data Conversion: EasyTPP → Meta-TPP Format
#
# Convert stationary Hawkes pickle files to npz format for Meta-TPP:
# - **EasyTPP format**: `{time_seqs: List[List[float]], type_seqs: List[List[int]]}`
# - **Meta-TPP format**: `.npz` with `TIMES`, `MARKS`, `MASKS` arrays

# %%
import pickle
import numpy as np
import json
import os


def convert_sparklen_hawkes_to_metatpp(dataset_dir, output_dir, dataset_name='stationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes dataset to Meta-TPP format.

    Your data format (from Sparklen):
    {
        'dim_process': 2,
        'train': [
            [
                {'idx_event': 1, 'type_event': 0, 'time_since_start': 0.876, ...},
                {'idx_event': 2, 'type_event': 1, 'time_since_start': 1.883, ...},
                ...
            ],
            ...
        ]
    }
    """
    os.makedirs(output_dir, exist_ok=True)

    print("="*70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("="*70)

    # Define file paths and their corresponding keys
    splits = {
        'train': ('train.pkl', 'train'),
        'dev': ('dev.pkl', 'dev'),
        'test': ('test.pkl', 'test')
    }

    all_times = []
    all_marks = []
    all_masks = []
    split_indices = {}

    current_idx = 0

    for split_name, (filename, data_key) in splits.items():
        pickle_path = os.path.join(dataset_dir, filename)

        print(f"\n{split_name.upper()} split:")

        # Load pickle file
        with open(pickle_path, 'rb') as f:
            data = pickle.load(f)

        # Extract sequences
        sequences = data[data_key]
        num_seqs = len(sequences)

        # Extract times and marks from event dictionaries
        time_seqs = []
        type_seqs = []

        for seq in sequences:
            # Each seq is a list of event dicts
            times = [event['time_since_start'] for event in seq]
            marks = [event['type_event'] for event in seq]

            time_seqs.append(times)
            type_seqs.append(marks)

        # Find max sequence length
        max_len = max(len(seq) for seq in time_seqs)

        # Create padded arrays
        times = np.zeros((num_seqs, max_len), dtype=np.float32)
        marks = np.zeros((num_seqs, max_len), dtype=np.int64)
        masks = np.zeros((num_seqs, max_len), dtype=np.float32)

        for i, (time_seq, type_seq) in enumerate(zip(time_seqs, type_seqs)):
            seq_len = len(time_seq)
            times[i, :seq_len] = time_seq
            marks[i, :seq_len] = type_seq
            masks[i, :seq_len] = 1.0

        all_times.append(times)
        all_marks.append(marks)
        all_masks.append(masks)

        split_indices[split_name] = (current_idx, current_idx + num_seqs)
        current_idx += num_seqs

        print(f"  - Sequences: {num_seqs}")
        print(f"  - Max length: {max_len}")
        print(f"  - Avg length: {np.mean([len(seq) for seq in time_seqs]):.1f}")

    # Pad to global max length
    global_max_len = max(arr.shape[1] for arr in all_times)

    def pad_to_length(arrays, target_len):
        padded = []
        for arr in arrays:
            if arr.shape[1] < target_len:
                pad_width = ((0, 0), (0, target_len - arr.shape[1]))
                padded.append(np.pad(arr, pad_width, mode='constant', constant_values=0))
            else:
                padded.append(arr)
        return padded

    all_times = pad_to_length(all_times, global_max_len)
    all_marks = pad_to_length(all_marks, global_max_len)
    all_masks = pad_to_length(all_masks, global_max_len)

    # Concatenate
    times_combined = np.concatenate(all_times, axis=0)
    marks_combined = np.concatenate(all_marks, axis=0)
    masks_combined = np.concatenate(all_masks, axis=0)

    # Save npz
    output_path = os.path.join(output_dir, f'{dataset_name}.npz')
    np.savez(
        output_path,
        times=times_combined,
        marks=marks_combined,
        masks=masks_combined
    )

    # Save split info
    split_info_path = os.path.join(output_dir, f'{dataset_name}_split_info.json')
    with open(split_info_path, 'w') as f:
        json.dump({
            'train': split_indices['train'],
            'val': split_indices['dev'],
            'test': split_indices['test'],
            'num_event_types': int(data['dim_process']),
            'global_max_len': int(global_max_len)
        }, f, indent=2)

    print(f"\n{'='*70}")
    print(f"✓ Conversion complete!")
    print(f"  - Output NPZ: {output_path}")
    print(f"  - Split info: {split_info_path}")
    print(f"  - Total sequences: {times_combined.shape[0]}")
    print(f"  - Sequence length: {times_combined.shape[1]}")
    print(f"  - Train: {split_indices['train']}")
    print(f"  - Val: {split_indices['dev']}")
    print(f"  - Test: {split_indices['test']}")
    print("="*70)

    return output_path


# ============================================================================
# RUN CONVERSION
# ============================================================================

# Convert the stationary Hawkes dataset
hawkes_input_dir = os.path.join(DATASET_DIR, dataset_name)
metatpp_dataset_dir = os.path.join(DATASET_DIR, 'metatpp_format')

# Convert the stationary Hawkes dataset
converted_npz_path = convert_sparklen_hawkes_to_metatpp(
    dataset_dir=hawkes_input_dir,
    output_dir=metatpp_dataset_dir,
    dataset_name=dataset_name
)
# Out:
# ======================================================================
# Converting nonstationary_hawkes to Meta-TPP format
# ======================================================================
#
# TRAIN split:
#   - Sequences: 300
#   - Max length: 163
#   - Avg length: 109.7
#
# DEV split:
#   - Sequences: 100
#   - Max length: 161
#   - Avg length: 109.5
#
# TEST split:
#   - Sequences: 100
#   - Max length: 152
#   - Avg length: 109.2
#
# ======================================================================
# ✓ Conversion complete!
#   - Output NPZ: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/nonstationary_hawkes.npz
#   - Split info: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/nonstationary_hawkes_split_info.json
#   - Total sequences: 500
#   - Sequence length: 163
#   - Train: (0, 300)
#   - Val: (300, 400)
#   - Test: (400, 500)
# ======================================================================

# %% [markdown]
# ## Meta TPP

# %% [markdown]
# ### Cell 1: Install Dependencies (CRITICAL - Run First, Then Restart Runtime)

# %%
# ==============================================================================
# CELL 1: Install Dependencies with Correct Versions
# ==============================================================================
# IMPORTANT: After running this cell, you MUST restart the runtime!
# Runtime → Restart runtime (or Ctrl+M .)

# Uninstall any existing stribor (Colab installs 0.2.0 which breaks)
# !pip uninstall stribor -y -q 2>/dev/null

# Install stribor 0.1.0 (does NOT require torchtyping)
# !pip install stribor==0.1.0 -q

# Install nfe (neural-flows-experiments) from GitHub
# !SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True pip install git+https://github.com/mbilos/neural-flows-experiments -q

# Install other Meta-TPP dependencies
# !pip install lightning pytorch-lightning hydra-core omegaconf hydra-colorlog pyrootutils torchmetrics rich -q

# Verify stribor version
import subprocess
result = subprocess.run(['pip', 'show', 'stribor'], capture_output=True, text=True)
version_line = [l for l in result.stdout.split('\n') if 'Version' in l][0]
print(f"✓ Installed: stribor {version_line.split(': ')[1]}")

print("\n" + "=" * 70)
print("⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime")
print("   Then continue to Cell 2 (do NOT re-run this cell)")
print("=" * 70)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 26.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for nfe (setup.py) ... done
#   Building wheel for reverse_geocoder (setup.py) ... done
#   Building wheel for sklearn (setup.py) ... done
# ✓ Installed: stribor 0.1.0
#
# ======================================================================
# ⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime
#    Then continue to Cell 2 (do NOT re-run this cell)
# ======================================================================

# %% [markdown]
# ### Cell 2: Verify Imports (Run After Restart)

# %%
# ==============================================================================
# CELL 2: Verify Imports After Runtime Restart
# ==============================================================================
# Run this AFTER restarting the runtime

import stribor

# This import should now work without torchtyping errors
import torch
print(f"✓ PyTorch version: {torch.__version__}")

# Test that stribor's distributions work
try:
    from stribor.dist import Normal
    print("✓ stribor.dist imports work")
except Exception as e:
    print(f"✗ Error: {e}")

print("\n✓ All imports successful - ready to proceed!")
# Out:
# ✓ PyTorch version: 2.9.0+cu126
# ✓ stribor.dist imports work
#
# ✓ All imports successful - ready to proceed!

# %% [markdown]
# ### Cell 3: Setup Paths and Clone Meta-TPP

# %%
# ==============================================================================
# CELL 3: Setup Paths and Clone Meta-TPP
# ==============================================================================
import os
import sys

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Base directories
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task3')
METATPP_DIR = '/content/meta-tpp'

os.makedirs(RESULTS_DIR, exist_ok=True)

# Clone Meta-TPP
if not os.path.exists(METATPP_DIR):
    # !git clone https://github.com/BorealisAI/meta-tpp.git {METATPP_DIR}
    print("✓ Meta-TPP cloned")
else:
    print("✓ Meta-TPP already exists")

# Add to Python path
if METATPP_DIR not in sys.path:
    sys.path.insert(0, METATPP_DIR)

# Change to Meta-TPP directory (required for Hydra)
os.chdir(METATPP_DIR)
print(f"✓ Working directory: {os.getcwd()}")

# Create data directories
os.makedirs(os.path.join(METATPP_DIR, 'data', 'synthetic'), exist_ok=True)
print("✓ Data directories ready")

# ==============================================================================
# Create .project-root indicator file (required by pyrootutils)
# ==============================================================================
project_root_file = os.path.join(METATPP_DIR, '.project-root')
if not os.path.exists(project_root_file):
    with open(project_root_file, 'w') as f:
        f.write('')  # Empty file is fine, just needs to exist
    print(f"✓ Created .project-root indicator file")
else:
    print(f"✓ .project-root already exists")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into '/content/meta-tpp'...
# remote: Enumerating objects: 3610, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 3610 (delta 159), reused 211 (delta 155), pack-reused 3384 (from 1)
# Receiving objects: 100% (3610/3610), 3.45 MiB | 19.85 MiB/s, done.
# Resolving deltas: 100% (2132/2132), done.
# ✓ Meta-TPP cloned
# ✓ Working directory: /content/meta-tpp
# ✓ Data directories ready
# ✓ Created .project-root indicator file

# %% [markdown]
# ### Cell 4: Convert Stationary Hawkes Data to Meta-TPP Format

# %%
# ==============================================================================
# CELL 4: Convert Stationary Hawkes Data to Meta-TPP Format
# ==============================================================================
import numpy as np
import pickle

def convert_hawkes_to_metatpp_format(dataset_dir, output_path, dataset_name='nonstationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes pickle files to Meta-TPP npz format.

    Meta-TPP expects:
    - Single npz file with all sequences
    - Keys: 'times', 'marks', 'masks'
    - Shape: (num_sequences, max_seq_len)
    - Split by indices: 60% train, 20% val, 20% test (or custom)
    """
    print("=" * 70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("=" * 70)

    all_times = []
    all_marks = []
    splits = ['train', 'dev', 'test']
    split_files = {'train': 'train.pkl', 'dev': 'dev.pkl', 'test': 'test.pkl'}

    for split in splits:
        pkl_path = os.path.join(dataset_dir, split_files[split])
        print(f"\nLoading {split}...")

        with open(pkl_path, 'rb') as f:
            data = pickle.load(f)

        # Handle different pickle structures
        if split in data:
            sequences = data[split]
        elif 'train' in data or 'dev' in data or 'test' in data:
            sequences = data.get(split, data.get('train', []))
        else:
            sequences = data if isinstance(data, list) else list(data.values())[0]

        print(f"  - {len(sequences)} sequences")

        for seq in sequences:
            if isinstance(seq, list) and len(seq) > 0 and isinstance(seq[0], dict):
                # Format: [{'time_since_start': t, 'type_event': m}, ...]
                times = [event['time_since_start'] for event in seq]
                marks = [event['type_event'] for event in seq]
            else:
                # Assume it's already (times, marks) format
                times = [e[0] if isinstance(e, (list, tuple)) else e for e in seq]
                marks = [e[1] if isinstance(e, (list, tuple)) else 0 for e in seq]

            all_times.append(times)
            all_marks.append(marks)

    # Find max sequence length
    max_len = max(len(t) for t in all_times)
    num_seqs = len(all_times)

    print(f"\n  Total sequences: {num_seqs}")
    print(f"  Max sequence length: {max_len}")

    # Create padded arrays
    times_arr = np.zeros((num_seqs, max_len), dtype=np.float32)
    marks_arr = np.zeros((num_seqs, max_len), dtype=np.int64)
    masks_arr = np.zeros((num_seqs, max_len), dtype=np.float32)

    for i, (t, m) in enumerate(zip(all_times, all_marks)):
        seq_len = len(t)
        times_arr[i, :seq_len] = t
        marks_arr[i, :seq_len] = m
        masks_arr[i, :seq_len] = 1.0

    # Save as npz
    np.savez(output_path, times=times_arr, marks=marks_arr, masks=masks_arr)

    print(f"\n✓ Saved to: {output_path}")
    print(f"  - times: {times_arr.shape}, dtype={times_arr.dtype}")
    print(f"  - marks: {marks_arr.shape}, dtype={marks_arr.dtype}")
    print(f"  - masks: {masks_arr.shape}, dtype={masks_arr.dtype}")
    print(f"  - Split: [0:{int(num_seqs*0.6)}] train, [{int(num_seqs*0.6)}:{int(num_seqs*0.8)}] val, [{int(num_seqs*0.8)}:] test")
    print("=" * 70)

    return output_path

# Convert the data
hawkes_input_dir = os.path.join(DATASET_DIR, dataset_name)
metatpp_data_path = os.path.join(METATPP_DIR, 'data', 'synthetic', 'nonstationary_hawkes.npz')

convert_hawkes_to_metatpp_format(hawkes_input_dir, metatpp_data_path)

# Verify
data = np.load(metatpp_data_path)
print("\n✓ Verification:")
for key in data.keys():
    print(f"  {key}: shape={data[key].shape}, dtype={data[key].dtype}")
# Out:
# ======================================================================
# Converting nonstationary_hawkes to Meta-TPP format
# ======================================================================
#
# Loading train...
#   - 300 sequences
#
# Loading dev...
#   - 100 sequences
#
# Loading test...
#   - 100 sequences
#
#   Total sequences: 500
#   Max sequence length: 163
#
# ✓ Saved to: /content/meta-tpp/data/synthetic/nonstationary_hawkes.npz
#   - times: (500, 163), dtype=float32
#   - marks: (500, 163), dtype=int64
#   - masks: (500, 163), dtype=float32
#   - Split: [0:300] train, [300:400] val, [400:] test
# ======================================================================
#
# ✓ Verification:
#   times: shape=(500, 163), dtype=float32
#   marks: shape=(500, 163), dtype=int64
#   masks: shape=(500, 163), dtype=float32

# %% [markdown]
# ### Cell 5: Create Dataset Config and Patch TPPDataset

# %%
# ==============================================================================
# CELL 5: Create Dataset Config and Register Dataset
# ==============================================================================
import yaml

# Create dataset config YAML
dataset_config = {
    'dataset': dataset_name,
    'num_classes': 2
}

config_dir = os.path.join(METATPP_DIR, 'configs', 'data', 'datasets')
config_path = os.path.join(config_dir, 'nonstationary_hawkes.yaml')

with open(config_path, 'w') as f:
    yaml.dump(dataset_config, f)

print(f"✓ Created dataset config: {config_path}")

# Patch TPPDataset to include our new dataset
tpp_dataset_path = os.path.join(METATPP_DIR, 'src', 'data', 'tpp_dataset.py')

with open(tpp_dataset_path, 'r') as f:
    content = f.read()

# Add nonstationary_hawkes to synthetic_data list if not already there
if 'nonstationary_hawkes' not in content:
    old_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\"]"
    new_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\", 'nonstationary_hawkes']"

    if old_line in content:
        content = content.replace(old_line, new_line)
        with open(tpp_dataset_path, 'w') as f:
            f.write(content)
        print("✓ Added 'nonstationary_hawkes' to synthetic_data list")
    else:
        # Try alternative format
        import re
        pattern = r"(synthetic_data\s*=\s*\[.*?\])"
        match = re.search(pattern, content, re.DOTALL)
        if match:
            old = match.group(1)
            if 'nonstationary_hawkes' not in old:
                new = old.rstrip(']') + ", 'nonstationary_hawkes']"
                content = content.replace(old, new)
                with open(tpp_dataset_path, 'w') as f:
                    f.write(content)
                print("✓ Added 'nonstationary_hawkes' to synthetic_data list")
else:
    print("✓ 'nonstationary_hawkes' already registered")

# Reload the module
import importlib
if 'src.data.tpp_dataset' in sys.modules:
    del sys.modules['src.data.tpp_dataset']

print("✓ Dataset configuration complete")
# Out:
# ✓ Created dataset config: /content/meta-tpp/configs/data/datasets/nonstationary_hawkes.yaml
# ✓ Added 'nonstationary_hawkes' to synthetic_data list
# ✓ Dataset configuration complete

# %% [markdown]
# ### Cell 6: Test Data Loading

# %%
# ==============================================================================
# CELL 6: Test Data Loading
# ==============================================================================
# Verify the data can be loaded by Meta-TPP's dataset class

from src.data.tpp_dataset import TPPDataset

# Test loading
data_dir = os.path.join(METATPP_DIR, 'data')

print("Testing data loading...")
try:
    train_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='train')
    val_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='val')
    test_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='test')

    print(f"\n✓ Train: {len(train_ds)} sequences")
    print(f"✓ Val: {len(val_ds)} sequences")
    print(f"✓ Test: {len(test_ds)} sequences")

    # Test a sample
    sample = train_ds[0]
    print(f"\nSample batch keys: {list(sample.keys())}")
    print(f"  times shape: {sample['times'].shape}")
    print(f"  marks shape: {sample['marks'].shape}")
    print(f"  masks shape: {sample['masks'].shape}")

    print("\n✓ Data loading test passed!")
except Exception as e:
    print(f"✗ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Testing data loading...
# time shape: torch.Size([300, 163, 1]), marks shape: torch.Size([300, 163, 1]), masks shape: torch.Size([300, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
#
# ✓ Train: 300 sequences
# ✓ Val: 100 sequences
# ✓ Test: 100 sequences
#
# Sample batch keys: ['times', 'marks', 'masks', 'missing_masks']
#   times shape: torch.Size([163, 1])
#   marks shape: torch.Size([163, 1])
#   masks shape: torch.Size([163, 1])
#
# ✓ Data loading test passed!

# %% [markdown]
# ### Cell 7: Train Meta-TPP Using Hydra

# %%
# ==============================================================================
# CELL 7: Train Meta-TPP Using Hydra
# ==============================================================================
import subprocess
import os

# Ensure we're in the Meta-TPP directory
os.chdir(METATPP_DIR)

# Training command using Hydra
# This replicates: python src/train.py data/datasets=nonstationary_hawkes
cmd = [
    'python', 'src/train.py',
    'data/datasets=nonstationary_hawkes',
    'model=thp_mix',
    'trainer.max_epochs=200',
    'trainer.accelerator=gpu',
    'trainer.devices=1',
    'data.batch_size=256',
    'tag=colab_run',
    'test=False',
    'seed=42'
]

print("=" * 70)
print("Starting Meta-TPP Training")
print("=" * 70)
print(f"Command: {' '.join(cmd)}")
print("=" * 70 + "\n")

# Run training
process = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

# Stream output
for line in iter(process.stdout.readline, ''):
    print(line, end='')

process.wait()

if process.returncode == 0:
    print("\n" + "=" * 70)
    print("✓ Training completed successfully!")
    print("=" * 70)
else:
    print(f"\n✗ Training failed with return code: {process.returncode}")
# Out:
# ======================================================================
# Starting Meta-TPP Training
# ======================================================================
# Command: python src/train.py data/datasets=nonstationary_hawkes model=thp_mix trainer.max_epochs=200 trainer.accelerator=gpu trainer.devices=1 data.batch_size=256 tag=colab_run test=False seed=42
# ======================================================================
#
# [2025-12-27 17:57:14,653][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2025-12-27 17:57:14,657][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# [2025-12-27 17:57:14,658][src.utils.rich_utils][WARNING] - Field 'logger' not found in config. Skipping 'logger' config printing...
# CONFIG
# ├── data
# │   └── _target_: src.data.tpp_dataset.TPPDataModule
# │       data_dir: /content/meta-tpp/data/
# │       batch_size: 256
# │       num_workers: 4
# │       pin_memory: false
# │       train_rate: 1.0
# │       eval_rate: 1.0
# │       noise_rate: 0.0
# │       seq_rate: 1.0
# │       missing_rate: 0.0
# │       use_mark: true
# │       run_bootstrap: false
# │       datasets:
# │         dataset: nonstationary_hawkes
# │         num_classes: 2
# │
# ├── model
# │   └── _target_: src.models.tpp_module.TPPLitModule
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.0001
# │         weight_decay: 0.0001
# │         eps: 1.0e-05
# │         betas:
# │         - 0.9
# │         - 0.999
# │       net:
# │         _target_: src.models.tpp.tpp_network.TransformerMix
# │         name: thp_mix
# │         num_classes: 2
# │         d_model: 64
# │         d_inner: 64
# │         n_layers: 2
# │         cattn_n_layers: 1
# │         n_head: 1
# │         d_k: 64
# │         d_v: 64
# │         dropout: 0.1
# │         attn_l: 0
# │         base_l: 0
# │         perm_invar: false
# │         use_avg: true
# │         share_weights: true
# │         attn_only: false
# │         concat: false
# │         num_latent: 64
# │         vi_method: None
# │         num_z_samples: 32
# │         compute_acc: true
# │         activation:
# │           name: tanh
# │           in_features: 64
# │           trainable: true
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: lightning.pytorch.callbacks.ModelCheckpoint
# │         dirpath: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_run
# │         filename: epoch_{epoch:03d}
# │         monitor: val/rmse
# │         verbose: false
# │         save_last: true
# │         save_top_k: 1
# │         mode: min
# │         auto_insert_metric_name: false
# │         save_weights_only: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: null
# │       early_stopping:
# │         _target_: lightning.pytorch.callbacks.EarlyStopping
# │         monitor: val/nll
# │         min_delta: 0.0
# │         patience: 500
# │         verbose: false
# │         mode: min
# │         strict: true
# │         check_finite: true
# │         stopping_threshold: null
# │         divergence_threshold: null
# │         check_on_train_epoch_end: null
# │       model_summary:
# │         _target_: lightning.pytorch.callbacks.RichModelSummary
# │         max_depth: -1
# │       rich_progress_bar:
# │         _target_: lightning.pytorch.callbacks.RichProgressBar
# │
# ├── trainer
# │   └── _target_: lightning.pytorch.trainer.Trainer
# │       default_root_dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_co
# │       min_epochs: 1
# │       max_epochs: 200
# │       accelerator: gpu
# │       devices: 1
# │       check_val_every_n_epoch: 1
# │       deterministic: false
# │
# ├── paths
# │   └── root_dir: /content/meta-tpp
# │       data_dir: /content/meta-tpp/data/
# │       log_dir: /content/meta-tpp/logs/
# │       output_dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_ru
# │       work_dir: /content/meta-tpp
# │       ckpt_dir: /content/meta-tpp/checkpoints/
# │
# ├── extras
# │   └── ignore_warnings: false
# │       enforce_tags: true
# │       print_config: true
# │
# ├── task_name
# │   └── nonstationary_hawkes_thp_mix_colab_run
# ├── tags
# │   └── ['dev']
# ├── tag
# │   └── colab_run
# ├── train
# │   └── True
# ├── test
# │   └── False
# ├── compile
# │   └── False
# ├── ckpt_path
# │   └── None
# └── seed
#     └── 42
# Seed set to 42
# [2025-12-27 17:57:14,715][__main__][INFO] - Instantiating datamodule <src.data.tpp_dataset.TPPDataModule>
# [2025-12-27 17:57:14,718][__main__][INFO] - Instantiating model <src.models.tpp_module.TPPLitModule>
# The number of trainable model parameters: 56284
# [2025-12-27 17:57:14,898][__main__][INFO] - Instantiating callbacks...
# [2025-12-27 17:57:14,898][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.ModelCheckpoint>
# [2025-12-27 17:57:14,911][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.EarlyStopping>
# [2025-12-27 17:57:14,912][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichModelSummary>
# [2025-12-27 17:57:14,913][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichProgressBar>
# [2025-12-27 17:57:14,913][__main__][INFO] - Instantiating loggers...
# [2025-12-27 17:57:14,913][src.utils.instantiators][WARNING] - No logger configs found! Skipping...
# [2025-12-27 17:57:14,914][__main__][INFO] - Instantiating trainer <lightning.pytorch.trainer.Trainer>
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# [2025-12-27 17:57:14,954][__main__][INFO] - Starting training!
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1551: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return _C._get_float32_matmul_precision()
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# time shape: torch.Size([300, 163, 1]), marks shape: torch.Size([300, 163, 1]), masks shape: torch.Size([300, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# ┏━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━┳━━━━┳━━━┓
# ┃    ┃ Name                                                 ┃ T… ┃ P… ┃ M… ┃ … ┃
# ┡━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━╇━━━━╇━━━┩
# │ 0  │ net                                                  │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 1  │ net.encoder                                          │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 2  │ net.encoder.event_emb                                │ E… │ 1… │ t… │ 0 │
# │ 3  │ net.encoder.layer_stack                              │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 4  │ net.encoder.layer_stack.0                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 5  │ net.encoder.layer_stack.0.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 6  │ net.encoder.layer_stack.0.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 7  │ net.encoder.layer_stack.0.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 8  │ net.encoder.layer_stack.0.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 9  │ net.encoder.layer_stack.0.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 10 │ net.encoder.layer_stack.0.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 11 │ net.encoder.layer_stack.0.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 12 │ net.encoder.layer_stack.0.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 13 │ net.encoder.layer_stack.0.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 14 │ net.encoder.layer_stack.0.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 15 │ net.encoder.layer_stack.0.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 16 │ net.encoder.layer_stack.0.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 17 │ net.encoder.layer_stack.0.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 18 │ net.encoder.layer_stack.0.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 19 │ net.encoder.layer_stack.1                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 20 │ net.encoder.layer_stack.1.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 21 │ net.encoder.layer_stack.1.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 22 │ net.encoder.layer_stack.1.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 23 │ net.encoder.layer_stack.1.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 24 │ net.encoder.layer_stack.1.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 25 │ net.encoder.layer_stack.1.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 26 │ net.encoder.layer_stack.1.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 27 │ net.encoder.layer_stack.1.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 28 │ net.encoder.layer_stack.1.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 29 │ net.encoder.layer_stack.1.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 30 │ net.encoder.layer_stack.1.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 31 │ net.encoder.layer_stack.1.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 32 │ net.encoder.layer_stack.1.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 33 │ net.encoder.layer_stack.1.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 34 │ net.linear                                           │ L… │ 1… │ t… │ 0 │
# │ 35 │ net.time_predictor                                   │ T… │ 64 │ t… │ 0 │
# │ 36 │ net.time_predictor.linear                            │ L… │ 64 │ t… │ 0 │
# │ 37 │ net.class_predictor                                  │ T… │ 1… │ t… │ 0 │
# │ 38 │ net.mark_linear                                      │ L… │ 1… │ t… │ 0 │
# │ 39 │ net.activation                                       │ T… │  0 │ t… │ 0 │
# │ 40 │ net.prob_dist                                        │ L… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 41 │ net.prob_dist.decoder                                │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 42 │ net.prob_dist.decoder.net                            │ S… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 43 │ net.prob_dist.decoder.net.0                          │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 44 │ net.prob_dist.decoder.net.1                          │ T… │  0 │ t… │ 0 │
# │ 45 │ net.prob_dist.decoder.net.2                          │ L… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 46 │ train_nll                                            │ M… │  0 │ t… │ 0 │
# │ 47 │ val_nll                                              │ M… │  0 │ t… │ 0 │
# │ 48 │ test_nll                                             │ M… │  0 │ t… │ 0 │
# │ 49 │ train_rmse                                           │ M… │  0 │ t… │ 0 │
# │ 50 │ val_rmse                                             │ M… │  0 │ t… │ 0 │
# │ 51 │ test_rmse                                            │ M… │  0 │ t… │ 0 │
# │ 52 │ train_acc                                            │ M… │  0 │ t… │ 0 │
# │ 53 │ val_acc                                              │ M… │  0 │ t… │ 0 │
# │ 54 │ test_acc                                             │ M… │  0 │ t… │ 0 │
# │ 55 │ val_nll_best                                         │ M… │  0 │ t… │ 0 │
# │ 56 │ val_rmse_best                                        │ M… │  0 │ t… │ 0 │
# └────┴──────────────────────────────────────────────────────┴────┴────┴────┴───┘
# Trainable params: 56.3 K
# Non-trainable params: 0
# Total params: 56.3 K
# Total estimated model params size (MB): 0
# Modules in train mode: 57
# Modules in eval mode: 0
# Total FLOPs: 0
# `Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 199/199 ━━━━━━━━━━━━━━━━ 2/2 0:00:00 • 0:00:00 32.79it/s val/nll: 2.806
#                                                                val/rmse: 19.242
#                                                                val/acc: 0.501
#                                                                val/nll_best:
#                                                                2.806
#                                                                val/rmse_best:
#                                                                19.242 train/nll:
#                                                                2.911
# [2025-12-27 17:58:42,997][src.utils.utils][INFO] - Output dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_run/seed42
# [2025-12-27 17:58:44,790][src.utils.utils][INFO] - Metric name is None! Skipping metric value retrieval...
# [W1227 17:58:45.976832109 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# ======================================================================
# ✓ Training completed successfully!
# ======================================================================

# %%
# ==============================================================================
# CELL 7b: Manual Testing with proper optimizer setup
# ==============================================================================
import torch
import lightning as L
from torch.utils.data import DataLoader
from functools import partial

# Fix for PyTorch 2.6 checkpoint loading
from omegaconf import ListConfig, DictConfig
torch.serialization.add_safe_globals([ListConfig, DictConfig])

from src.data.tpp_dataset import TPPDataset
from src.models.tpp_module import TPPLitModule
from src.models.tpp.tpp_network import TransformerMix

# Find the best checkpoint
import glob
ckpt_pattern = os.path.join(METATPP_DIR, 'logs', 'nonstationary_hawkes_thp_mix_colab_run', 'seed42', 'checkpoints', '*.ckpt')
ckpts = glob.glob(ckpt_pattern)
ckpts = [c for c in ckpts if 'last' not in c]
best_ckpt = sorted(ckpts)[-1] if ckpts else None

print(f"Best checkpoint: {best_ckpt}")

# Load data
data_dir = os.path.join(METATPP_DIR, 'data')
test_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='test')
test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2)

# Create model
net = TransformerMix(
    name='thp_mix', num_classes=2, d_model=64, d_inner=64, n_layers=2,
    cattn_n_layers=1, n_head=1, d_k=64, d_v=64, dropout=0.1,
    attn_l=0, base_l=0, perm_invar=False, use_avg=True, share_weights=True,
    attn_only=False, concat=False, num_latent=64, vi_method=None,
    num_z_samples=32, compute_acc=True,
    activation={'name': 'tanh', 'in_features': 64, 'trainable': True}
)

# Create optimizer as a partial function (this is what Hydra does)
optimizer = partial(
    torch.optim.Adam,
    lr=0.0001,
    weight_decay=0.0001,
    eps=1e-5,
    betas=(0.9, 0.999)
)

model = TPPLitModule(net=net, optimizer=optimizer)

# Load checkpoint
if best_ckpt:
    ckpt = torch.load(best_ckpt, map_location='cuda', weights_only=False)
    model.load_state_dict(ckpt['state_dict'])
    print("✓ Checkpoint loaded")

# Set model to eval mode
model.eval()

# Test
trainer = L.Trainer(accelerator='gpu', devices=1, logger=False, enable_progress_bar=True)
test_results = trainer.test(model, test_loader)

print("\n" + "=" * 70)
print("Meta-TPP Test Results")
print("=" * 70)
for k, v in test_results[0].items():
    print(f"  {k}: {v:.4f}")
# Out:
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 0:00:00 • 0:00:00 54.11it/s
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.5061477422714233     │
# │         test/nll          │    2.7888832092285156     │
# │         test/rmse         │     20.21638298034668     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
# Meta-TPP Test Results
# ======================================================================
#   test/nll: 2.7889
#   test/rmse: 20.2164
#   test/acc: 0.5061

# %% [markdown]
# ### Cell 8: Extract and Save Results

# %%
# ==============================================================================
# CELL 9: Extract and Save Results Properly
# ==============================================================================
import pandas as pd

# test_results is returned from trainer.test() - it's a list of dicts
# Print what we actually got to debug
print("=" * 70)
print("Raw test_results:")
print(test_results)
print("=" * 70)

# Extract metrics from test_results (it's a list with one dict)
if test_results and len(test_results) > 0:
    metrics = test_results[0]

    # Meta-TPP uses keys like 'test/nll', 'test/rmse', 'test/acc'
    # or 'test_nll', 'test_rmse', 'test_acc'

    # Try different possible key formats
    def get_metric(metrics, *possible_keys):
        for key in possible_keys:
            if key in metrics:
                val = metrics[key]
                # Handle tensor values
                if hasattr(val, 'item'):
                    return val.item()
                return val
        return float('nan')

    nll = get_metric(metrics, 'test/nll', 'test_nll', 'test_loss')
    rmse = get_metric(metrics, 'test/rmse', 'test_rmse')
    acc = get_metric(metrics, 'test/acc', 'test_acc', 'test_accuracy')

    # Log-likelihood is negative NLL
    log_likelihood = -nll if not pd.isna(nll) else float('nan')

    print(f"\nExtracted metrics:")
    print(f"  NLL: {nll}")
    print(f"  Log-Likelihood: {log_likelihood}")
    print(f"  RMSE: {rmse}")
    print(f"  Accuracy: {acc}")
else:
    print("No test results found!")
    log_likelihood = float('nan')
    acc = float('nan')
    rmse = float('nan')

# Create result entry
metatpp_result = {
    'model': 'Meta-TPP',
    'dataset': 'nonstationary_hawkes',
    'log_likelihood': log_likelihood,
    'accuracy': acc * 100 if not pd.isna(acc) and acc <= 1 else acc,  # Convert to percentage if needed
    'rmse': rmse,
    'status': 'success'
}

# Save results
results_df = pd.DataFrame([metatpp_result])
metatpp_results_path = os.path.join(RESULTS_DIR, 'metatpp_stationary_results.csv')
results_df.to_csv(metatpp_results_path, index=False)

print("\n" + "=" * 70)
print("Meta-TPP Results (Task 3b)")
print("=" * 70)
print(results_df.to_string(index=False))
print(f"\n✓ Saved to: {metatpp_results_path}")

# Also print in Table-1-like format for easy comparison
print("\n" + "=" * 70)
print("Table-1-like Format:")
print("=" * 70)
print(f"Model: Meta-TPP")
print(f"Dataset: nonstationary_hawkes")
print(f"Log-Likelihood: {log_likelihood:.3f}" if not pd.isna(log_likelihood) else "Log-Likelihood: N/A")
print(f"Accuracy: {metatpp_result['accuracy']:.1f}%" if not pd.isna(metatpp_result['accuracy']) else "Accuracy: N/A")
print(f"RMSE: {rmse:.3f}" if not pd.isna(rmse) else "RMSE: N/A")
# Out:
# ======================================================================
# Raw test_results:
# [{'test/nll': 2.7888832092285156, 'test/rmse': 20.21638298034668, 'test/acc': 0.5061477422714233}]
# ======================================================================
#
# Extracted metrics:
#   NLL: 2.7888832092285156
#   Log-Likelihood: -2.7888832092285156
#   RMSE: 20.21638298034668
#   Accuracy: 0.5061477422714233
#
# ======================================================================
# Meta-TPP Results (Task 3b)
# ======================================================================
#    model              dataset  log_likelihood  accuracy      rmse  status
# Meta-TPP nonstationary_hawkes       -2.788883 50.614774 20.216383 success
#
# ✓ Saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task3/metatpp_stationary_results.csv
#
# ======================================================================
# Table-1-like Format:
# ======================================================================
# Model: Meta-TPP
# Dataset: nonstationary_hawkes
# Log-Likelihood: -2.789
# Accuracy: 50.6%
# RMSE: 20.216
