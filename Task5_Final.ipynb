# %% [markdown]
# ## Package Installation

# %%
import os
import sys
import types

# Install core dependencies
# !pip install easy-tpp lightning pytorch-lightning hydra-core omegaconf torchmetrics stribor -q

print("✓ Core dependencies installed")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 46.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 69.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.2 MB/s eta 0:00:00
# ✓ Core dependencies installed

# %%
# Import required libraries
import os

# Set PyTorch memory allocation config BEFORE importing torch
# This helps prevent OOM errors with large models like AttNHP
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

import yaml
import pandas as pd
import numpy as np
from datetime import datetime
from easy_tpp.config_factory import Config
from easy_tpp.runner import Runner
from google.colab import drive
import json
from IPython.display import display, clear_output
import time

# %%
# ==============================================================================
# FULLYNN GRADIENT FIX - Monkey Patch
# ==============================================================================
# FullyNN uses torch.autograd.grad() to compute intensity derivatives, but during
# validation/evaluation, EasyTPP runs under torch.no_grad() context which disables
# gradient tracking. This patch wraps the computation in torch.enable_grad().
# ==============================================================================

import torch
from easy_tpp.model.torch_model import torch_fullynn

def patched_compute_intensities_at_sample_times(self, time_seqs, time_delta_seqs, type_seqs, sample_dtimes, **kwargs):
    """Patched version that enables gradients during intensity computation.

    FullyNN requires gradient computation for intensity derivatives via autograd.grad().
    During validation, EasyTPP disables gradients with torch.no_grad(), causing failures.
    This patch wraps the computation in torch.enable_grad() to fix the issue.
    """
    compute_last_step_only = kwargs.get('compute_last_step_only', False)

    # Enable gradients for this computation even during evaluation
    with torch.enable_grad():
        # Forward pass to get hidden states
        hidden_states = self.forward(
            time_seqs=time_seqs,
            time_delta_seqs=time_delta_seqs,
            type_seqs=type_seqs,
        )

        num_samples = sample_dtimes.size()[-1]
        batch_size, seq_len, hidden_size = hidden_states.shape

        # Expand hidden states for all sample times
        hidden_states_ = hidden_states[..., None, :].expand(batch_size, seq_len, num_samples, hidden_size)

        # Clone sample_dtimes to avoid in-place modification issues
        sample_dtimes_grad = sample_dtimes.clone().detach().requires_grad_(True)

        # Compute intensities (this uses autograd.grad internally)
        _, derivative_integral_lambda = self.layer_intensity.forward(
            hidden_states=hidden_states_,
            time_delta_seqs=sample_dtimes_grad,
        )

    # Detach the result since we don't need gradients flowing back
    derivative_integral_lambda = derivative_integral_lambda.detach()

    if compute_last_step_only:
        return derivative_integral_lambda[:, -1:, :, :]
    return derivative_integral_lambda

# Apply the monkey patch
torch_fullynn.FullyNN.compute_intensities_at_sample_times = patched_compute_intensities_at_sample_times
print("✓ FullyNN patched for gradient computation during evaluation")
print("  This fixes the 'element 0 of tensors does not require grad' error")
# Out:
# ✓ FullyNN patched for gradient computation during evaluation
#   This fixes the 'element 0 of tensors does not require grad' error

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Base directory (your Drive location)
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
CHECKPOINT_DIR = os.path.join(BASE_DIR, 'checkpoints')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task5')

# Create results directory if it doesn't exist
os.makedirs(RESULTS_DIR, exist_ok=True)

print(f"✓ Base Directory: {BASE_DIR}")
print(f"✓ Dataset Directory: {DATASET_DIR}")
print(f"✓ Checkpoint Directory: {CHECKPOINT_DIR}")
print(f"✓ Results Directory: {RESULTS_DIR}")
# Out:
# Mounted at /content/drive
# ✓ Base Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025
# ✓ Dataset Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets
# ✓ Checkpoint Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints
# ✓ Results Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5

# %% [markdown]
# ## Configuration Dictionary

# %% [markdown]
# ### Data Configuration

# %%
# Data specifications for each dataset
dataset_name = 'nonstationary_hawkes'
data_spec_dict = {
    dataset_name: {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, dataset_name, "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, dataset_name, "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, dataset_name, "test.pkl"),
        "data_specs": {
            "num_event_types": 2,
            "pad_token_id": 2,
            "padding_side": "right",
            "max_seq_len": 20,
            "strict_pad_leng": True
        }
    }
}

print("✓ Data specifications loaded for Hawkes Stationary")
# Out:
# ✓ Data specifications loaded for Hawkes Stationary

# %% [markdown]
# ### Model Configuration

# %%
# Model specifications
model_spec_dict = {
    "RMTPP": {
        "model_id": "RMTPP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_heads": 2,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "NHP": {
        "model_id": "NHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_heads": 2,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "FullyNN": {
        "model_id": "FullyNN",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "num_heads": 2,
        "seed": 2019,
        "model_specs": {
            "num_mlp_layers": 3,
            "proper_marked_intensities": True
        },
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "SAHP": {
        "model_id": "SAHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "THP": {
        "model_id": "THP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    },
    "IntensityFree": {
        "model_id": "IntensityFree",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "num_heads": 2,
        "seed": 2019,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_mix_components": 3,
        "model_specs": {
            "num_mix_components": 3
        },
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5,
            "num_step_gen": 10
        }
    },
    "AttNHP": {
        "model_id": "AttNHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 4,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": {
            "num_seq": 10,
            "num_sample": 1,
            "num_exp": 500,
            "look_ahead_time": 10,
            "patience_counter": 5,
            "over_sample_rate": 5,
            "num_samples_boundary": 5,
            "dtime_max": 5
        }
    }
}

print("✓ Model specifications loaded for 7 models")
# Out:
# ✓ Model specifications loaded for 7 models

# %% [markdown]
# ### Training Configuration

# %%
# Trainer configuration (shared across all experiments)
trainer_config = {
    "batch_size": 256,
    "max_epoch": 200,
    "shuffle": False,
    "optimizer": "adam",
    "learning_rate": 1e-3,
    "valid_freq": 1,
    "use_tfb": False,
    "metrics": ["acc", "rmse"],
    "seed": 2019,
    "gpu": 0
}

print("✓ Trainer configuration loaded")
print(f"  - Batch size: {trainer_config['batch_size']}")
print(f"  - Max epochs: {trainer_config['max_epoch']}")
print(f"  - Learning rate: {trainer_config['learning_rate']}")
# Out:
# ✓ Trainer configuration loaded
#   - Batch size: 256
#   - Max epochs: 200
#   - Learning rate: 0.001

# %% [markdown]
# ## Helper Functions

# %%
def create_experiment_config(model_id, data_id, data_spec, model_spec, trainer_cfg):
    """Create a complete experiment configuration."""
    experiment_id = f"{model_id}_{data_id}_train"

    config = {
        "pipeline_config_id": "runner_config",
        "data": {
            data_id: data_spec
        },
        experiment_id: {
            "base_config": {
                "stage": "train",
                "backend": "torch",
                "dataset_id": data_id,
                "runner_id": "std_tpp",
                "model_id": model_id,
                "base_dir": CHECKPOINT_DIR
            },
            "trainer_config": trainer_cfg,
            "model_config": model_spec
        }
    }

    return config, experiment_id

def extract_results_from_logs(log_path):
    """Extract best results from training logs.

    Args:
        log_path: Can be either a log file or a directory containing log files
    """
    try:
        # Determine if log_path is a file or directory
        if os.path.isfile(log_path):
            # It's a file - read it directly
            log_file = log_path
        elif os.path.isdir(log_path):
            # It's a directory - find .log files inside
            log_files = [f for f in os.listdir(log_path) if f.endswith('.log')]
            if not log_files:
                return None
            log_file = os.path.join(log_path, log_files[0])
        else:
            print(f"  Warning: Log path does not exist: {log_path}")
            return None

        # Read the log file
        with open(log_file, 'r') as f:
            lines = f.readlines()

        # Find the LAST test metrics (final epoch results)
        best_ll = None
        best_acc = None
        best_rmse = None

        for line in lines:
            if 'test loglike is' in line:
                try:
                    parts = line.split(',')
                    # Extract log-likelihood
                    ll_part = [p for p in parts if 'test loglike is' in p][0]
                    best_ll = float(ll_part.split('test loglike is')[1].strip())

                    # Extract accuracy
                    acc_parts = [p for p in parts if 'acc is' in p]
                    if acc_parts:
                        best_acc = float(acc_parts[0].split('acc is')[1].strip())

                    # Extract RMSE
                    rmse_parts = [p for p in parts if 'rmse is' in p]
                    if rmse_parts:
                        best_rmse = float(rmse_parts[0].split('rmse is')[1].strip())
                except (IndexError, ValueError) as e:
                    print(f"  Warning: Could not parse line: {e}")
                    continue

        if best_ll is None:
            return None

        return {
            'log_likelihood': best_ll,
            'accuracy': best_acc,
            'rmse': best_rmse
        }
    except Exception as e:
        print(f"  Warning: Could not extract results from logs: {e}")
        return None
def find_latest_checkpoint_dir(base_dir, model_id, data_id):
    """Find the most recent checkpoint directory for an experiment."""
    try:
        # EasyTPP creates directories with random names but puts
        # {model_id}_{data_id}_train_output.yaml inside them
        target_yaml = f"{model_id}_{data_id}_train_output.yaml"

        matching_dirs = []
        for d in os.listdir(base_dir):
            dir_path = os.path.join(base_dir, d)
            if os.path.isdir(dir_path):
                # Check if the target yaml file exists in this directory
                yaml_path = os.path.join(dir_path, target_yaml)
                if os.path.exists(yaml_path):
                    matching_dirs.append(dir_path)

        if not matching_dirs:
            return None

        # Return the most recently modified directory
        latest = max(matching_dirs, key=os.path.getmtime)
        return latest
    except Exception as e:
        print(f"  Warning: Error finding checkpoint dir: {e}")
        return None
print("✓ Helper functions loaded")
# Out:
# ✓ Helper functions loaded

# %%
def run_model_on_all_datasets(
    model_id,
    model_number,
    total_models,
    aggressive_gpu_clearing=False
):
    """
    Run a single TPP model on all configured datasets.

    This function encapsulates the complete workflow for running a model:
    - Creates and saves experiment configs for each dataset
    - Runs training and evaluation
    - Extracts metrics from logs
    - Saves results (both intermediate and model-specific)
    - Handles errors gracefully
    - Manages GPU memory

    Parameters
    ----------
    model_id : str
        The model identifier (e.g., 'RMTPP', 'NHP', 'AttNHP')
        Must exist as a key in model_spec_dict
    model_number : int
        Current model number (1-7) for progress tracking
    total_models : int
        Total number of models (typically 7) for progress tracking
    aggressive_gpu_clearing : bool, default=False
        If True, performs GPU memory clearing after EACH dataset.
        Use this for memory-intensive models like AttNHP.
        If False, only clears GPU memory after all datasets complete.

    Returns
    -------
    model_results : list of dict
        List containing result dictionaries for each dataset.
        Each dict contains: model, dataset, log_likelihood, accuracy,
        rmse, status, and time_seconds

    Side Effects
    ------------
    - Appends results to the global results_list
    - Saves intermediate results to 'intermediate_results.csv' after each dataset
    - Saves model-specific results to '{model_id}_results.csv'
    - Creates experiment config files in the configs directory
    - Clears GPU memory (timing depends on aggressive_gpu_clearing flag)

    Notes
    -----
    This function relies on several global variables and functions:
    - data_spec_dict: Dictionary of dataset configurations
    - model_spec_dict: Dictionary of model configurations
    - trainer_config: Training configuration
    - results_list: Global list to store all results
    - total_experiments: Total number of experiments
    - BASE_DIR, CHECKPOINT_DIR, RESULTS_DIR: Directory paths
    - create_experiment_config(): Function to create config dicts
    - find_latest_checkpoint_dir(): Function to locate checkpoints
    - extract_results_from_logs(): Function to parse training logs

    Example
    -------
    >>> # Run RMTPP on all datasets (standard memory management)
    >>> rmtpp_results = run_model_on_all_datasets('RMTPP', 1, 7)

    >>> # Run AttNHP with aggressive memory clearing
    >>> attnhp_results = run_model_on_all_datasets('AttNHP', 7, 7,
    ...                                             aggressive_gpu_clearing=True)
    """
    import time
    import os
    import yaml
    import pandas as pd
    import torch
    import gc
    from easy_tpp.config_factory import Config
    from easy_tpp.runner import Runner

    print("\n" + "=" * 70)
    print(f"[MODEL {model_number}/{total_models}] Running {model_id} on all datasets")
    print("=" * 70)

    model_start_time = time.time()
    model_results = []

    for data_id, data_spec in data_spec_dict.items():
        experiment_name = f"{model_id}_{data_id}"
        experiment_num = len(results_list) + 1

        print(f"\n[{experiment_num}/{total_experiments}] Running {model_id} on {data_id} dataset")
        print("=" * 70)

        try:
            # Create config
            config_dict, experiment_id = create_experiment_config(
                model_id=model_id,
                data_id=data_id,
                data_spec=data_spec,
                model_spec=model_spec_dict[model_id],
                trainer_cfg=trainer_config
            )

            # Save config
            CONFIG_DIR = os.path.join(BASE_DIR, 'configs')
            os.makedirs(CONFIG_DIR, exist_ok=True)
            config_path = os.path.join(CONFIG_DIR, f"{experiment_name}.yaml")
            with open(config_path, 'w') as f:
                yaml.dump(config_dict, f)

            # Build and run
            config = Config.build_from_yaml_file(config_path, experiment_id=experiment_id)
            runner = Runner.build_from_config(config)
            runner.run()

            # Find checkpoint directory
            checkpoint_dir = find_latest_checkpoint_dir(CHECKPOINT_DIR, model_id, data_id)

            # Extract results from logs
            if checkpoint_dir:
                log_dir = os.path.join(checkpoint_dir, 'log')
                metrics = extract_results_from_logs(log_dir)

                if metrics:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': metrics['log_likelihood'],
                        'accuracy': metrics['accuracy'],
                        'rmse': metrics['rmse'],
                        'status': 'success',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"✓ {model_id} on {data_id} completed successfully!")
                    print(f"  - Log-Likelihood: {metrics['log_likelihood']:.4f}")
                    if metrics['accuracy'] and metrics['accuracy'] > 0:
                        print(f"  - Accuracy: {metrics['accuracy']:.4f}")
                    if metrics['rmse'] and metrics['rmse'] > 0:
                        print(f"  - RMSE: {metrics['rmse']:.4f}")
                else:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': None,
                        'accuracy': None,
                        'rmse': None,
                        'status': 'completed_no_metrics',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"⚠ {model_id} on {data_id} completed but no metrics found")
            else:
                result = {
                    'model': model_id,
                    'dataset': data_id,
                    'log_likelihood': None,
                    'accuracy': None,
                    'rmse': None,
                    'status': 'no_checkpoint',
                    'time_seconds': time.time() - model_start_time
                }
                print(f"⚠ {model_id} on {data_id} - no checkpoint directory found")

        except Exception as e:
            result = {
                'model': model_id,
                'dataset': data_id,
                'log_likelihood': None,
                'accuracy': None,
                'rmse': None,
                'status': 'failed',
                'error': str(e),
                'time_seconds': time.time() - model_start_time
            }
            print(f"✗ Error running {model_id} on {data_id}: {str(e)}")

        results_list.append(result)
        model_results.append(result)

        # Save intermediate results after each experiment
        intermediate_df = pd.DataFrame(results_list)
        intermediate_df.to_csv(os.path.join(RESULTS_DIR, 'intermediate_results.csv'), index=False)

        # Aggressive GPU memory clearing (for memory-intensive models like AttNHP)
        if aggressive_gpu_clearing:
            try:
                del runner
                del config
            except:
                pass
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
                torch.cuda.synchronize()

    # Save model-specific results
    model_df = pd.DataFrame(model_results)
    model_csv_path = os.path.join(RESULTS_DIR, f'{model_id}_results.csv')
    model_df.to_csv(model_csv_path, index=False)

    # Model summary
    model_elapsed = time.time() - model_start_time
    successful = sum(1 for r in model_results if r['status'] == 'success')
    failed = sum(1 for r in model_results if r['status'] == 'failed')

    print(f"\n" + "=" * 70)
    print(f"✓ {model_id} completed on all datasets")
    print(f"  - Time: {model_elapsed/60:.1f} minutes")
    print(f"  - Successful: {successful}/{len(data_spec_dict)}")
    print(f"  - Failed: {failed}/{len(data_spec_dict)}")
    print(f"  - Results saved to: {model_csv_path}")
    print("=" * 70)

    # Clear GPU memory for next model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        print(f"✓ GPU memory cleared for next model")

    return model_results

# %% [markdown]
# ## Run Models On Data

# %%
# Initialize results storage
results_list = []
total_experiments = len(model_spec_dict) * len(data_spec_dict)

print(f"Starting {total_experiments} experiments...")
print(f"Running {len(model_spec_dict)} models on {len(data_spec_dict)} datasets")
print(f"Results will be saved incrementally to: {RESULTS_DIR}")
print("=" * 70)
# Out:
# Starting 7 experiments...
# Running 7 models on 1 datasets
# Results will be saved incrementally to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5
# ======================================================================

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
all_model_results = {}

for i, model_id in enumerate(model_ids, start=1):
    aggressive = (model_id == 'AttNHP')
    all_model_results[model_id] = run_model_on_all_datasets(
        model_id, i, len(model_ids), aggressive
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-12-27 18:44:04,204 - base_runner.py[pid:2254;line:110:train] - INFO: End RMTPP train! Cost time: 0.250m
# ✓ RMTPP on nonstationary_hawkes completed successfully!
#   - Log-Likelihood: -0.8575
#   - Accuracy: 0.7289
#   - RMSE: 1.1118
#
# ======================================================================
# ✓ RMTPP completed on all datasets
#   - Time: 1.1 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/RMTPP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model
#
# ======================================================================
# [MODEL 2/7] Running NHP on all datasets
# ======================================================================
#
# [2/7] Running NHP on nonstationary_hawkes dataset
# ======================================================================
# 2025-12-27 18:44:40,466 - config.py[pid:2254;line:34:build_from_yaml_file] - CRITICAL: Load pipeline config class RunnerConfig
# 2025-12-27 18:44:40,473 - runner_config.py[pid:2254;line:140:update_config] - CRITICAL: train model NHP using GPU with torch backend
# 2025-12-27 18:44:40,486 - runner_config.py[pid:2254;line:35:__init__] - INFO: Save the config to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/2254_140511081030272_251227-184440/NHP_nonstationary_hawkes_train_output.yaml
# 2025-12-27 18:44:40,489 - base_runner.py[pid:2254;line:176:save_log] - INFO: Save the log to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/2254_140511081030272_251227-184440/log
# 0.5189538021705272 0.7216217648548782
# min_dt: 4.934766515507505e-05
# max_dt: 8.303566563742564
# 2025-12-27 18:44:40,527 - tpp_runner.py[pid:2254;line:60:_init_model] - INFO: Num of model parameters 14724
# 2025-12-27 18:44:40,579 - base_runner.py[pid:2254;line:98:train] - INFO: Data 'nonstationary_hawkes' loaded...
# 2025-12-27 18:44:40,580 - base_runner.py[pid:2254;line:103:train] - INFO: Start NHP training...
# 2025-12-27 18:44:41,091 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 0 (train) ]: train loglike is -1.0551951807748314, num_events is 32620
# 2025-12-27 18:44:41,364 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 0 (valid) ]:  valid loglike is -1.0458546947004608, num_events is 10850, acc is 0.5847926267281106, rmse is 0.9618661631017723
# 2025-12-27 18:44:41,624 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 0 (test) ]: test loglike is -1.0461330761186096, num_events is 10817, acc is 0.5858371082555237, rmse is 0.9591305979215514
# 2025-12-27 18:44:41,625 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0459 (updated at epoch-0), best updated at this epoch
# 2025-12-27 18:44:42,040 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 1 (train) ]: train loglike is -1.039111612531614, num_events is 32620
# 2025-12-27 18:44:42,315 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 1 (valid) ]:  valid loglike is -1.0317648329493088, num_events is 10850, acc is 0.6730875576036867, rmse is 0.9404490988142676
# 2025-12-27 18:44:42,578 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 1 (test) ]: test loglike is -1.0323382392876952, num_events is 10817, acc is 0.668762133678469, rmse is 0.9443254072575786
# 2025-12-27 18:44:42,579 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0318 (updated at epoch-1), best updated at this epoch
# 2025-12-27 18:44:42,981 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 2 (train) ]: train loglike is -1.0251219056560392, num_events is 32620
# 2025-12-27 18:44:43,252 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 2 (valid) ]:  valid loglike is -1.0193854406682028, num_events is 10850, acc is 0.6806451612903226, rmse is 0.9423442186504687
# 2025-12-27 18:44:43,511 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 2 (test) ]: test loglike is -1.0202552983729316, num_events is 10817, acc is 0.6783766293796801, rmse is 0.9369363845788438
# 2025-12-27 18:44:43,513 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0194 (updated at epoch-2), best updated at this epoch
# 2025-12-27 18:44:43,920 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 3 (train) ]: train loglike is -1.012819912534488, num_events is 32620
# 2025-12-27 18:44:44,191 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 3 (valid) ]:  valid loglike is -1.0083584749423964, num_events is 10850, acc is 0.6824884792626729, rmse is 0.9234474956485283
# 2025-12-27 18:44:44,452 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 3 (test) ]: test loglike is -1.009527916849635, num_events is 10817, acc is 0.6774521586391791, rmse is 0.9197172261053338
# 2025-12-27 18:44:44,453 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0084 (updated at epoch-3), best updated at this epoch
# 2025-12-27 18:44:44,868 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 4 (train) ]: train loglike is -1.0018507386189455, num_events is 32620
# 2025-12-27 18:44:45,144 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 4 (valid) ]:  valid loglike is -0.9983418238767281, num_events is 10850, acc is 0.6902304147465438, rmse is 0.903790420619835
# 2025-12-27 18:44:45,403 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 4 (test) ]: test loglike is -0.9998213351957567, num_events is 10817, acc is 0.6863270777479893, rmse is 0.9202199496524414
# 2025-12-27 18:44:45,404 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9983 (updated at epoch-4), best updated at this epoch
# 2025-12-27 18:44:45,814 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 5 (train) ]: train loglike is -0.9918842626743563, num_events is 32620
# 2025-12-27 18:44:46,083 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 5 (valid) ]:  valid loglike is -0.9890259576612903, num_events is 10850, acc is 0.6928110599078341, rmse is 0.9052223992603204
# 2025-12-27 18:44:46,343 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 5 (test) ]: test loglike is -0.9908360032240917, num_events is 10817, acc is 0.6879911250808912, rmse is 0.9032292840044431
# 2025-12-27 18:44:46,344 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9890 (updated at epoch-5), best updated at this epoch
# 2025-12-27 18:44:46,763 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 6 (train) ]: train loglike is -0.9826276057633354, num_events is 32620
# 2025-12-27 18:44:47,036 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 6 (valid) ]:  valid loglike is -0.9801584101382489, num_events is 10850, acc is 0.6932718894009217, rmse is 0.9027686658420546
# 2025-12-27 18:44:47,296 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 6 (test) ]: test loglike is -0.9823295182062957, num_events is 10817, acc is 0.6866044189701396, rmse is 0.9055485194350694
# 2025-12-27 18:44:47,297 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9802 (updated at epoch-6), best updated at this epoch
# 2025-12-27 18:44:47,708 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 7 (train) ]: train loglike is -0.9738468958365266, num_events is 32620
# 2025-12-27 18:44:47,978 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 7 (valid) ]:  valid loglike is -0.971573750720046, num_events is 10850, acc is 0.6934562211981566, rmse is 0.9120717799917376
# 2025-12-27 18:44:48,236 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 7 (test) ]: test loglike is -0.9741456048638717, num_events is 10817, acc is 0.6862346306739392, rmse is 0.8941816166391184
# 2025-12-27 18:44:48,237 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9716 (updated at epoch-7), best updated at this epoch
# 2025-12-27 18:44:48,640 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 8 (train) ]: train loglike is -0.9653935528912477, num_events is 32620
# 2025-12-27 18:44:48,908 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 8 (valid) ]:  valid loglike is -0.963213385656682, num_events is 10850, acc is 0.6933640552995392, rmse is 0.8936935822749402
# 2025-12-27 18:44:49,165 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 8 (test) ]: test loglike is -0.966230636671443, num_events is 10817, acc is 0.6864195248220394, rmse is 0.8986067640798173
# 2025-12-27 18:44:49,166 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9632 (updated at epoch-8), best updated at this epoch
# 2025-12-27 18:44:49,577 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 9 (train) ]: train loglike is -0.9572198864289546, num_events is 32620
# 2025-12-27 18:44:49,846 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 9 (valid) ]:  valid loglike is -0.9551217777937788, num_events is 10850, acc is 0.6945622119815669, rmse is 0.8883574491215088
# 2025-12-27 18:44:50,104 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 9 (test) ]: test loglike is -0.9586257814666729, num_events is 10817, acc is 0.6879911250808912, rmse is 0.8953986011270287
# 2025-12-27 18:44:50,105 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9551 (updated at epoch-9), best updated at this epoch
# 2025-12-27 18:44:50,517 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 10 (train) ]: train loglike is -0.9493717158520463, num_events is 32620
# 2025-12-27 18:44:50,788 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 10 (valid) ]:  valid loglike is -0.9474161146313365, num_events is 10850, acc is 0.695668202764977, rmse is 0.8907540101858583
# 2025-12-27 18:44:51,047 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 10 (test) ]: test loglike is -0.951432243517149, num_events is 10817, acc is 0.687806230932791, rmse is 0.8915299261890438
# 2025-12-27 18:44:51,048 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9474 (updated at epoch-10), best updated at this epoch
# 2025-12-27 18:44:51,452 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 11 (train) ]: train loglike is -0.9419548853272532, num_events is 32620
# 2025-12-27 18:44:51,723 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 11 (valid) ]:  valid loglike is -0.9402344650057604, num_events is 10850, acc is 0.6973271889400922, rmse is 0.8967745706201969
# 2025-12-27 18:44:51,981 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 11 (test) ]: test loglike is -0.944760525966072, num_events is 10817, acc is 0.6916890080428955, rmse is 0.8868342221650136
# 2025-12-27 18:44:51,982 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9402 (updated at epoch-11), best updated at this epoch
# 2025-12-27 18:44:52,383 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 12 (train) ]: train loglike is -0.9350839957512646, num_events is 32620
# 2025-12-27 18:44:52,653 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 12 (valid) ]:  valid loglike is -0.9336823156682028, num_events is 10850, acc is 0.6989861751152073, rmse is 0.8809525330659568
# 2025-12-27 18:44:52,912 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 12 (test) ]: test loglike is -0.9386824919686605, num_events is 10817, acc is 0.6935379495238976, rmse is 0.8913453994088275
# 2025-12-27 18:44:52,913 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9337 (updated at epoch-12), best updated at this epoch
# 2025-12-27 18:44:53,313 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 13 (train) ]: train loglike is -0.928832453968041, num_events is 32620
# 2025-12-27 18:44:53,587 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 13 (valid) ]:  valid loglike is -0.9278010692684332, num_events is 10850, acc is 0.7013824884792627, rmse is 0.8854890060742715
# 2025-12-27 18:44:53,860 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 13 (test) ]: test loglike is -0.9332098779698622, num_events is 10817, acc is 0.6949246556346491, rmse is 0.8931614937686373
# 2025-12-27 18:44:53,861 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9278 (updated at epoch-13), best updated at this epoch
# 2025-12-27 18:44:54,264 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 14 (train) ]: train loglike is -0.9232096154583078, num_events is 32620
# 2025-12-27 18:44:54,534 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 14 (valid) ]:  valid loglike is -0.9225711945564516, num_events is 10850, acc is 0.7022119815668203, rmse is 0.9018723563248566
# 2025-12-27 18:44:54,798 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 14 (test) ]: test loglike is -0.9283015161320144, num_events is 10817, acc is 0.6970509383378016, rmse is 0.8931964961256926
# 2025-12-27 18:44:54,799 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9226 (updated at epoch-14), best updated at this epoch
# 2025-12-27 18:44:55,203 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 15 (train) ]: train loglike is -0.9181716366971949, num_events is 32620
# 2025-12-27 18:44:55,473 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 15 (valid) ]:  valid loglike is -0.9179269873271889, num_events is 10850, acc is 0.7046082949308756, rmse is 0.8919022031377107
# 2025-12-27 18:44:55,734 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 15 (test) ]: test loglike is -0.9238803973201904, num_events is 10817, acc is 0.6993621151890542, rmse is 0.887866848309596
# 2025-12-27 18:44:55,735 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9179 (updated at epoch-15), best updated at this epoch
# 2025-12-27 18:44:56,138 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 16 (train) ]: train loglike is -0.9136393927709228, num_events is 32620
# 2025-12-27 18:44:56,405 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 16 (valid) ]:  valid loglike is -0.9137689012096775, num_events is 10850, acc is 0.7047926267281106, rmse is 0.8936010536374123
# 2025-12-27 18:44:56,664 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 16 (test) ]: test loglike is -0.9198459492292225, num_events is 10817, acc is 0.700841268373856, rmse is 0.8970554697847666
# 2025-12-27 18:44:56,665 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9138 (updated at epoch-16), best updated at this epoch
# 2025-12-27 18:44:57,083 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 17 (train) ]: train loglike is -0.9095091201716738, num_events is 32620
# 2025-12-27 18:44:57,353 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 17 (valid) ]:  valid loglike is -0.9099748883928571, num_events is 10850, acc is 0.7057142857142857, rmse is 0.8967434811194414
# 2025-12-27 18:44:57,619 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 17 (test) ]: test loglike is -0.916082251895165, num_events is 10817, acc is 0.7012110566700563, rmse is 0.8900599937120303
# 2025-12-27 18:44:57,620 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9100 (updated at epoch-17), best updated at this epoch
# 2025-12-27 18:44:58,042 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 18 (train) ]: train loglike is -0.9056628949360055, num_events is 32620
# 2025-12-27 18:44:58,313 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 18 (valid) ]:  valid loglike is -0.9064135404665898, num_events is 10850, acc is 0.7053456221198157, rmse is 0.8923862678967647
# 2025-12-27 18:44:58,578 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 18 (test) ]: test loglike is -0.9124701352616252, num_events is 10817, acc is 0.7013035037441065, rmse is 0.9003961107833925
# 2025-12-27 18:44:58,579 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9064 (updated at epoch-18), best updated at this epoch
# 2025-12-27 18:44:58,997 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 19 (train) ]: train loglike is -0.9019812363484825, num_events is 32620
# 2025-12-27 18:44:59,268 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 19 (valid) ]:  valid loglike is -0.902961909562212, num_events is 10850, acc is 0.7056221198156682, rmse is 0.90229595529925
# 2025-12-27 18:44:59,524 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 19 (test) ]: test loglike is -0.9089018948761209, num_events is 10817, acc is 0.7015808449662568, rmse is 0.9115006394116425
# 2025-12-27 18:44:59,525 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9030 (updated at epoch-19), best updated at this epoch
# 2025-12-27 18:44:59,929 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 20 (train) ]: train loglike is -0.8983571177096107, num_events is 32620
# 2025-12-27 18:45:00,199 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 20 (valid) ]:  valid loglike is -0.89952638968894, num_events is 10850, acc is 0.7060829493087558, rmse is 0.8912310802407032
# 2025-12-27 18:45:00,456 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 20 (test) ]: test loglike is -0.9053031397337524, num_events is 10817, acc is 0.7020430803365073, rmse is 0.9085000841272642
# 2025-12-27 18:45:00,457 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8995 (updated at epoch-20), best updated at this epoch
# 2025-12-27 18:45:00,863 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 21 (train) ]: train loglike is -0.8947140336402131, num_events is 32620
# 2025-12-27 18:45:01,131 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 21 (valid) ]:  valid loglike is -0.8960654881912442, num_events is 10850, acc is 0.7061751152073733, rmse is 0.9127635208618858
# 2025-12-27 18:45:01,388 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 21 (test) ]: test loglike is -0.9016542789994916, num_events is 10817, acc is 0.7016732920403069, rmse is 0.9002271294207642
# 2025-12-27 18:45:01,389 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8961 (updated at epoch-21), best updated at this epoch
# 2025-12-27 18:45:01,795 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 22 (train) ]: train loglike is -0.891026192951027, num_events is 32620
# 2025-12-27 18:45:02,064 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 22 (valid) ]:  valid loglike is -0.89259765625, num_events is 10850, acc is 0.7065437788018433, rmse is 0.9143947858164414
# 2025-12-27 18:45:02,324 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 22 (test) ]: test loglike is -0.8979938623809743, num_events is 10817, acc is 0.7018581861884071, rmse is 0.9227488921685987
# 2025-12-27 18:45:02,325 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8926 (updated at epoch-22), best updated at this epoch
# 2025-12-27 18:45:02,735 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 23 (train) ]: train loglike is -0.8873232487737585, num_events is 32620
# 2025-12-27 18:45:03,008 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 23 (valid) ]:  valid loglike is -0.8891778873847926, num_events is 10850, acc is 0.7069124423963133, rmse is 0.926993028602841
# 2025-12-27 18:45:03,268 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 23 (test) ]: test loglike is -0.8943938433137654, num_events is 10817, acc is 0.7022279744846076, rmse is 0.9180279420990926
# 2025-12-27 18:45:03,269 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8892 (updated at epoch-23), best updated at this epoch
# 2025-12-27 18:45:03,675 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 24 (train) ]: train loglike is -0.8836673215004215, num_events is 32620
# 2025-12-27 18:45:03,949 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 24 (valid) ]:  valid loglike is -0.8858606350806452, num_events is 10850, acc is 0.7072811059907834, rmse is 0.9169052385582775
# 2025-12-27 18:45:04,205 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 24 (test) ]: test loglike is -0.8909200361699178, num_events is 10817, acc is 0.7024128686327078, rmse is 0.9177530740946961
# 2025-12-27 18:45:04,206 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8859 (updated at epoch-24), best updated at this epoch
# 2025-12-27 18:45:04,607 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 25 (train) ]: train loglike is -0.8801166845493562, num_events is 32620
# 2025-12-27 18:45:04,879 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 25 (valid) ]:  valid loglike is -0.8826744311635945, num_events is 10850, acc is 0.707926267281106, rmse is 0.9231523472470412
# 2025-12-27 18:45:05,137 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 25 (test) ]: test loglike is -0.8876063863594342, num_events is 10817, acc is 0.7024128686327078, rmse is 0.9279611117237008
# 2025-12-27 18:45:05,138 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8827 (updated at epoch-25), best updated at this epoch
# 2025-12-27 18:45:05,541 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 26 (train) ]: train loglike is -0.8767022933351855, num_events is 32620
# 2025-12-27 18:45:05,811 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 26 (valid) ]:  valid loglike is -0.8796216157834101, num_events is 10850, acc is 0.707926267281106, rmse is 0.9205519580415934
# 2025-12-27 18:45:06,068 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 26 (test) ]: test loglike is -0.8844543383678469, num_events is 10817, acc is 0.7013959508181566, rmse is 0.9292228889901957
# 2025-12-27 18:45:06,069 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8796 (updated at epoch-26), best updated at this epoch
# 2025-12-27 18:45:06,472 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 27 (train) ]: train loglike is -0.8734289977391171, num_events is 32620
# 2025-12-27 18:45:06,744 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 27 (valid) ]:  valid loglike is -0.8766926483294931, num_events is 10850, acc is 0.708294930875576, rmse is 0.9285273503542147
# 2025-12-27 18:45:07,020 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 27 (test) ]: test loglike is -0.8814496279005269, num_events is 10817, acc is 0.7023204215586577, rmse is 0.9415510007076252
# 2025-12-27 18:45:07,021 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8767 (updated at epoch-27), best updated at this epoch
# 2025-12-27 18:45:07,427 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 28 (train) ]: train loglike is -0.8702904959093347, num_events is 32620
# 2025-12-27 18:45:07,698 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 28 (valid) ]:  valid loglike is -0.8738779881912443, num_events is 10850, acc is 0.7071889400921659, rmse is 0.9332507212789235
# 2025-12-27 18:45:07,961 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 28 (test) ]: test loglike is -0.8785761850559305, num_events is 10817, acc is 0.7024128686327078, rmse is 0.9234966912334016
# 2025-12-27 18:45:07,962 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8739 (updated at epoch-28), best updated at this epoch
# 2025-12-27 18:45:08,365 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 29 (train) ]: train loglike is -0.8672805309003295, num_events is 32620
# 2025-12-27 18:45:08,639 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 29 (valid) ]:  valid loglike is -0.8711704349078341, num_events is 10850, acc is 0.708294930875576, rmse is 0.9373747500886641
# 2025-12-27 18:45:08,900 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 29 (test) ]: test loglike is -0.8758204677821947, num_events is 10817, acc is 0.7021355274105574, rmse is 0.9573503921841683
# 2025-12-27 18:45:08,901 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8712 (updated at epoch-29), best updated at this epoch
# 2025-12-27 18:45:09,311 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 30 (train) ]: train loglike is -0.8643951958633507, num_events is 32620
# 2025-12-27 18:45:09,594 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 30 (valid) ]:  valid loglike is -0.8685671983006913, num_events is 10850, acc is 0.7081105990783411, rmse is 0.9365661730446476
# 2025-12-27 18:45:09,858 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 30 (test) ]: test loglike is -0.8731745314088935, num_events is 10817, acc is 0.703429786447259, rmse is 0.9390393957464959
# 2025-12-27 18:45:09,859 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8686 (updated at epoch-30), best updated at this epoch
# 2025-12-27 18:45:10,279 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 31 (train) ]: train loglike is -0.8616345207359365, num_events is 32620
# 2025-12-27 18:45:10,549 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 31 (valid) ]:  valid loglike is -0.8660766489055299, num_events is 10850, acc is 0.707926267281106, rmse is 0.9335149144768419
# 2025-12-27 18:45:10,813 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 31 (test) ]: test loglike is -0.8706436121960802, num_events is 10817, acc is 0.702597762780808, rmse is 0.9561672577485774
# 2025-12-27 18:45:10,814 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8661 (updated at epoch-31), best updated at this epoch
# 2025-12-27 18:45:11,243 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 32 (train) ]: train loglike is -0.8590095075634196, num_events is 32620
# 2025-12-27 18:45:11,511 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 32 (valid) ]:  valid loglike is -0.8637252484158986, num_events is 10850, acc is 0.707926267281106, rmse is 0.9541711218908163
# 2025-12-27 18:45:11,771 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 32 (test) ]: test loglike is -0.8682528080798743, num_events is 10817, acc is 0.7046315984099103, rmse is 0.964815689152541
# 2025-12-27 18:45:11,772 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8637 (updated at epoch-32), best updated at this epoch
# 2025-12-27 18:45:12,174 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 33 (train) ]: train loglike is -0.8565470103176732, num_events is 32620
# 2025-12-27 18:45:12,444 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 33 (valid) ]:  valid loglike is -0.8615504392281106, num_events is 10850, acc is 0.708479262672811, rmse is 0.952431661239605
# 2025-12-27 18:45:12,705 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 33 (test) ]: test loglike is -0.8660402173661829, num_events is 10817, acc is 0.7040769159656097, rmse is 0.9662095857600252
# 2025-12-27 18:45:12,706 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8616 (updated at epoch-33), best updated at this epoch
# 2025-12-27 18:45:13,110 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 34 (train) ]: train loglike is -0.8542818463557633, num_events is 32620
# 2025-12-27 18:45:13,381 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 34 (valid) ]:  valid loglike is -0.8595832733294931, num_events is 10850, acc is 0.7092165898617512, rmse is 0.9685647482650915
# 2025-12-27 18:45:13,641 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 34 (test) ]: test loglike is -0.8640385215401682, num_events is 10817, acc is 0.7037995747434593, rmse is 0.9584119401903081
# 2025-12-27 18:45:13,642 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8596 (updated at epoch-34), best updated at this epoch
# 2025-12-27 18:45:14,047 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 35 (train) ]: train loglike is -0.8522392979288014, num_events is 32620
# 2025-12-27 18:45:14,314 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 35 (valid) ]:  valid loglike is -0.8578346414170507, num_events is 10850, acc is 0.7083870967741935, rmse is 0.9685391272742495
# 2025-12-27 18:45:14,574 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 35 (test) ]: test loglike is -0.8622597278878155, num_events is 10817, acc is 0.7036146805953591, rmse is 0.9707060350794751
# 2025-12-27 18:45:14,575 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8578 (updated at epoch-35), best updated at this epoch
# 2025-12-27 18:45:14,979 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 36 (train) ]: train loglike is -0.850422897666309, num_events is 32620
# 2025-12-27 18:45:15,247 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 36 (valid) ]:  valid loglike is -0.8562970730126728, num_events is 10850, acc is 0.707741935483871, rmse is 0.9692771744490813
# 2025-12-27 18:45:15,506 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 36 (test) ]: test loglike is -0.8606959820190441, num_events is 10817, acc is 0.70435425718776, rmse is 0.9686294890606776
# 2025-12-27 18:45:15,507 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8563 (updated at epoch-36), best updated at this epoch
# 2025-12-27 18:45:15,911 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 37 (train) ]: train loglike is -0.8488186647378909, num_events is 32620
# 2025-12-27 18:45:16,180 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 37 (valid) ]:  valid loglike is -0.8549564372119816, num_events is 10850, acc is 0.7076497695852535, rmse is 0.9644499800262344
# 2025-12-27 18:45:16,440 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 37 (test) ]: test loglike is -0.8593314848733475, num_events is 10817, acc is 0.703429786447259, rmse is 0.9736352480411573
# 2025-12-27 18:45:16,442 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8550 (updated at epoch-37), best updated at this epoch
# 2025-12-27 18:45:16,849 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 38 (train) ]: train loglike is -0.847409025808553, num_events is 32620
# 2025-12-27 18:45:17,120 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 38 (valid) ]:  valid loglike is -0.8538005832373272, num_events is 10850, acc is 0.7083870967741935, rmse is 0.983904004230018
# 2025-12-27 18:45:17,379 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 38 (test) ]: test loglike is -0.8581511596329852, num_events is 10817, acc is 0.7045391513358602, rmse is 0.9623398464961644
# 2025-12-27 18:45:17,380 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8538 (updated at epoch-38), best updated at this epoch
# 2025-12-27 18:45:17,783 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 39 (train) ]: train loglike is -0.8461805688611281, num_events is 32620
# 2025-12-27 18:45:18,052 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 39 (valid) ]:  valid loglike is -0.8528156502016129, num_events is 10850, acc is 0.7080184331797235, rmse is 0.9931702106617312
# 2025-12-27 18:45:18,311 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 39 (test) ]: test loglike is -0.8571386655553758, num_events is 10817, acc is 0.7036146805953591, rmse is 0.9887791229395134
# 2025-12-27 18:45:18,313 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8528 (updated at epoch-39), best updated at this epoch
# 2025-12-27 18:45:18,713 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 40 (train) ]: train loglike is -0.84512092969229, num_events is 32620
# 2025-12-27 18:45:18,980 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 40 (valid) ]:  valid loglike is -0.851982646889401, num_events is 10850, acc is 0.7080184331797235, rmse is 0.979492445833859
# 2025-12-27 18:45:19,241 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 40 (test) ]: test loglike is -0.856272696478922, num_events is 10817, acc is 0.7055560691504114, rmse is 0.9825600110542632
# 2025-12-27 18:45:19,242 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8520 (updated at epoch-40), best updated at this epoch
# 2025-12-27 18:45:19,646 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 41 (train) ]: train loglike is -0.8442141815316524, num_events is 32620
# 2025-12-27 18:45:19,913 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 41 (valid) ]:  valid loglike is -0.8512782618087558, num_events is 10850, acc is 0.7068202764976959, rmse is 0.9887774713067188
# 2025-12-27 18:45:20,169 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 41 (test) ]: test loglike is -0.8555285155888879, num_events is 10817, acc is 0.7045391513358602, rmse is 0.9848295658479955
# 2025-12-27 18:45:20,170 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8513 (updated at epoch-41), best updated at this epoch
# 2025-12-27 18:45:20,572 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 42 (train) ]: train loglike is -0.8434398321342351, num_events is 32620
# 2025-12-27 18:45:20,844 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 42 (valid) ]:  valid loglike is -0.8506775633640553, num_events is 10850, acc is 0.7069124423963133, rmse is 0.990507076441042
# 2025-12-27 18:45:21,117 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 42 (test) ]: test loglike is -0.8548804832670795, num_events is 10817, acc is 0.7041693630396598, rmse is 0.9900027439801663
# 2025-12-27 18:45:21,118 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8507 (updated at epoch-42), best updated at this epoch
# 2025-12-27 18:45:21,531 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 43 (train) ]: train loglike is -0.842775024189531, num_events is 32620
# 2025-12-27 18:45:21,802 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 43 (valid) ]:  valid loglike is -0.8501558899769586, num_events is 10850, acc is 0.707741935483871, rmse is 0.9971815303890447
# 2025-12-27 18:45:22,064 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 43 (test) ]: test loglike is -0.854305758586022, num_events is 10817, acc is 0.7049089396320607, rmse is 1.008337773584108
# 2025-12-27 18:45:22,065 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8502 (updated at epoch-43), best updated at this epoch
# 2025-12-27 18:45:22,467 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 44 (train) ]: train loglike is -0.8421963016362661, num_events is 32620
# 2025-12-27 18:45:22,735 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 44 (valid) ]:  valid loglike is -0.849690920218894, num_events is 10850, acc is 0.7073732718894009, rmse is 0.9930972696525627
# 2025-12-27 18:45:23,001 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 44 (test) ]: test loglike is -0.8537858340748359, num_events is 10817, acc is 0.70435425718776, rmse is 1.010565770251386
# 2025-12-27 18:45:23,002 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8497 (updated at epoch-44), best updated at this epoch
# 2025-12-27 18:45:23,420 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 45 (train) ]: train loglike is -0.8416821992594651, num_events is 32620
# 2025-12-27 18:45:23,692 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 45 (valid) ]:  valid loglike is -0.8492643829205069, num_events is 10850, acc is 0.7064516129032258, rmse is 0.9759919028381078
# 2025-12-27 18:45:23,951 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 45 (test) ]: test loglike is -0.8533077996440788, num_events is 10817, acc is 0.703429786447259, rmse is 1.0007899813443568
# 2025-12-27 18:45:23,952 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8493 (updated at epoch-45), best updated at this epoch
# 2025-12-27 18:45:24,353 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 46 (train) ]: train loglike is -0.8412157724124387, num_events is 32620
# 2025-12-27 18:45:24,625 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 46 (valid) ]:  valid loglike is -0.8488653873847927, num_events is 10850, acc is 0.707741935483871, rmse is 1.0021093038357292
# 2025-12-27 18:45:24,883 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 46 (test) ]: test loglike is -0.8528647037071276, num_events is 10817, acc is 0.7045391513358602, rmse is 1.0198411530213718
# 2025-12-27 18:45:24,884 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8489 (updated at epoch-46), best updated at this epoch
# 2025-12-27 18:45:25,290 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 47 (train) ]: train loglike is -0.8407871267387722, num_events is 32620
# 2025-12-27 18:45:25,561 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 47 (valid) ]:  valid loglike is -0.8484898833525346, num_events is 10850, acc is 0.7059907834101382, rmse is 0.9815007438417281
# 2025-12-27 18:45:25,820 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 47 (test) ]: test loglike is -0.8524532961715355, num_events is 10817, acc is 0.70435425718776, rmse is 1.0019262902676807
# 2025-12-27 18:45:25,821 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8485 (updated at epoch-47), best updated at this epoch
# 2025-12-27 18:45:26,221 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 48 (train) ]: train loglike is -0.8403917416701794, num_events is 32620
# 2025-12-27 18:45:26,491 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 48 (valid) ]:  valid loglike is -0.8481377808179723, num_events is 10850, acc is 0.708479262672811, rmse is 1.0074329590193933
# 2025-12-27 18:45:26,749 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 48 (test) ]: test loglike is -0.8520713200286586, num_events is 10817, acc is 0.7045391513358602, rmse is 0.9881919890176807
# 2025-12-27 18:45:26,750 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8481 (updated at epoch-48), best updated at this epoch
# 2025-12-27 18:45:27,154 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 49 (train) ]: train loglike is -0.840026803078058, num_events is 32620
# 2025-12-27 18:45:27,424 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 49 (valid) ]:  valid loglike is -0.8478093497983871, num_events is 10850, acc is 0.7069124423963133, rmse is 1.002519194341699
# 2025-12-27 18:45:27,683 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 49 (test) ]: test loglike is -0.8517155251860498, num_events is 10817, acc is 0.7057409632985115, rmse is 0.9950086230355251
# 2025-12-27 18:45:27,685 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8478 (updated at epoch-49), best updated at this epoch
# 2025-12-27 18:45:28,090 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 50 (train) ]: train loglike is -0.839688374176119, num_events is 32620
# 2025-12-27 18:45:28,359 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 50 (valid) ]:  valid loglike is -0.8475047703052996, num_events is 10850, acc is 0.7088479262672811, rmse is 0.9907488009429103
# 2025-12-27 18:45:28,621 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 50 (test) ]: test loglike is -0.8513842865974854, num_events is 10817, acc is 0.7041693630396598, rmse is 0.991617389496265
# 2025-12-27 18:45:28,622 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8475 (updated at epoch-50), best updated at this epoch
# 2025-12-27 18:45:29,032 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 51 (train) ]: train loglike is -0.8393730121474555, num_events is 32620
# 2025-12-27 18:45:29,304 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 51 (valid) ]:  valid loglike is -0.8472235923099078, num_events is 10850, acc is 0.7074654377880184, rmse is 1.0063700711260524
# 2025-12-27 18:45:29,568 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 51 (test) ]: test loglike is -0.85107751398262, num_events is 10817, acc is 0.7066654340390127, rmse is 0.9835993190962772
# 2025-12-27 18:45:29,569 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8472 (updated at epoch-51), best updated at this epoch
# 2025-12-27 18:45:29,976 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 52 (train) ]: train loglike is -0.8390779477697732, num_events is 32620
# 2025-12-27 18:45:30,246 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 52 (valid) ]:  valid loglike is -0.8469635656682027, num_events is 10850, acc is 0.7086635944700461, rmse is 1.0062340151395333
# 2025-12-27 18:45:30,510 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 52 (test) ]: test loglike is -0.8507947559397245, num_events is 10817, acc is 0.7050013867061108, rmse is 1.0040920199149905
# 2025-12-27 18:45:30,511 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8470 (updated at epoch-52), best updated at this epoch
# 2025-12-27 18:45:30,928 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 53 (train) ]: train loglike is -0.8388000076640099, num_events is 32620
# 2025-12-27 18:45:31,201 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 53 (valid) ]:  valid loglike is -0.8467207301267281, num_events is 10850, acc is 0.7088479262672811, rmse is 1.0023683735367641
# 2025-12-27 18:45:31,466 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 53 (test) ]: test loglike is -0.8505325818156605, num_events is 10817, acc is 0.7044467042618101, rmse is 1.0130621445436612
# 2025-12-27 18:45:31,467 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8467 (updated at epoch-53), best updated at this epoch
# 2025-12-27 18:45:31,871 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 54 (train) ]: train loglike is -0.8385360483886419, num_events is 32620
# 2025-12-27 18:45:32,140 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 54 (valid) ]:  valid loglike is -0.8464917554723502, num_events is 10850, acc is 0.7065437788018433, rmse is 0.9944722528717934
# 2025-12-27 18:45:32,399 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 54 (test) ]: test loglike is -0.8502862067521032, num_events is 10817, acc is 0.7042618101137099, rmse is 0.9818593057783352
# 2025-12-27 18:45:32,400 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8465 (updated at epoch-54), best updated at this epoch
# 2025-12-27 18:45:32,806 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 55 (train) ]: train loglike is -0.8382827768144543, num_events is 32620
# 2025-12-27 18:45:33,087 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 55 (valid) ]:  valid loglike is -0.8462730414746544, num_events is 10850, acc is 0.707926267281106, rmse is 0.9861599973793891
# 2025-12-27 18:45:33,343 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 55 (test) ]: test loglike is -0.8500501236479615, num_events is 10817, acc is 0.7072201164833133, rmse is 1.0010202475154057
# 2025-12-27 18:45:33,344 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8463 (updated at epoch-55), best updated at this epoch
# 2025-12-27 18:45:33,760 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 56 (train) ]: train loglike is -0.838037857813458, num_events is 32620
# 2025-12-27 18:45:34,043 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 56 (valid) ]:  valid loglike is -0.8460611679147465, num_events is 10850, acc is 0.7071889400921659, rmse is 0.996901177265038
# 2025-12-27 18:45:34,318 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 56 (test) ]: test loglike is -0.8498193670842192, num_events is 10817, acc is 0.7030599981510586, rmse is 0.9877487886828326
# 2025-12-27 18:45:34,319 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8461 (updated at epoch-56), best updated at this epoch
# 2025-12-27 18:45:34,730 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 57 (train) ]: train loglike is -0.8377988664450491, num_events is 32620
# 2025-12-27 18:45:35,008 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 57 (valid) ]:  valid loglike is -0.8458530745967742, num_events is 10850, acc is 0.7074654377880184, rmse is 0.9849558283826562
# 2025-12-27 18:45:35,277 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 57 (test) ]: test loglike is -0.8495915897718869, num_events is 10817, acc is 0.7050013867061108, rmse is 0.9970201667004257
# 2025-12-27 18:45:35,278 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8459 (updated at epoch-57), best updated at this epoch
# 2025-12-27 18:45:35,694 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 58 (train) ]: train loglike is -0.8375646950203096, num_events is 32620
# 2025-12-27 18:45:35,967 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 58 (valid) ]:  valid loglike is -0.845647681451613, num_events is 10850, acc is 0.7073732718894009, rmse is 1.0129295424965137
# 2025-12-27 18:45:36,228 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 58 (test) ]: test loglike is -0.849366159748544, num_events is 10817, acc is 0.7039844688915596, rmse is 0.9822296434149893
# 2025-12-27 18:45:36,229 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8456 (updated at epoch-58), best updated at this epoch
# 2025-12-27 18:45:36,634 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 59 (train) ]: train loglike is -0.8373346849133967, num_events is 32620
# 2025-12-27 18:45:36,909 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 59 (valid) ]:  valid loglike is -0.8454457085253456, num_events is 10850, acc is 0.7083870967741935, rmse is 0.99027912835612
# 2025-12-27 18:45:37,169 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 59 (test) ]: test loglike is -0.8491435284159193, num_events is 10817, acc is 0.7042618101137099, rmse is 0.9975400881681487
# 2025-12-27 18:45:37,170 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8454 (updated at epoch-59), best updated at this epoch
# ...
# 2025-12-27 19:10:06,501 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 179 (test) ]: test loglike is -0.875743187806231, num_events is 10817, acc is 0.5807525191827678, rmse is 0.8397807090021672
# 2025-12-27 19:10:06,503 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8725 (updated at epoch-178)
# 2025-12-27 19:10:07,438 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 180 (train) ]: train loglike is -0.8433815212939723, num_events is 32620
# 2025-12-27 19:10:10,247 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 180 (valid) ]:  valid loglike is -0.8722839861751152, num_events is 10850, acc is 0.5790783410138249, rmse is 0.8351456360430035
# 2025-12-27 19:10:12,891 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 180 (test) ]: test loglike is -0.8757135758528243, num_events is 10817, acc is 0.5723398354442082, rmse is 0.8318685289516288
# 2025-12-27 19:10:12,892 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8723 (updated at epoch-180), best updated at this epoch
# 2025-12-27 19:10:13,824 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 181 (train) ]: train loglike is -0.8436987544187806, num_events is 32620
# 2025-12-27 19:10:16,634 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 181 (valid) ]:  valid loglike is -0.8727856782834101, num_events is 10850, acc is 0.5979723502304147, rmse is 0.8329951344175637
# 2025-12-27 19:10:19,278 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 181 (test) ]: test loglike is -0.8763239612704539, num_events is 10817, acc is 0.585282425811223, rmse is 0.8328050558923991
# 2025-12-27 19:10:19,279 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8723 (updated at epoch-180)
# 2025-12-27 19:10:20,218 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 182 (train) ]: train loglike is -0.8436917340660446, num_events is 32620
# 2025-12-27 19:10:23,028 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 182 (valid) ]:  valid loglike is -0.8727559763824885, num_events is 10850, acc is 0.5846082949308756, rmse is 0.8390396752537091
# 2025-12-27 19:10:25,657 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 182 (test) ]: test loglike is -0.8760082509013589, num_events is 10817, acc is 0.5757603771840621, rmse is 0.8331320322674659
# 2025-12-27 19:10:25,659 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8723 (updated at epoch-180)
# 2025-12-27 19:10:26,590 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 183 (train) ]: train loglike is -0.84375846483896, num_events is 32620
# 2025-12-27 19:10:29,394 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 183 (valid) ]:  valid loglike is -0.8711189516129032, num_events is 10850, acc is 0.5952073732718894, rmse is 0.8229939327343229
# 2025-12-27 19:10:32,067 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 183 (test) ]: test loglike is -0.8757579937829343, num_events is 10817, acc is 0.5840806138485717, rmse is 0.8384450335554676
# 2025-12-27 19:10:32,069 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8711 (updated at epoch-183), best updated at this epoch
# 2025-12-27 19:10:33,000 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 184 (train) ]: train loglike is -0.8427046110994022, num_events is 32620
# 2025-12-27 19:10:35,801 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 184 (valid) ]:  valid loglike is -0.8724593173963133, num_events is 10850, acc is 0.5906912442396314, rmse is 0.8275564249509224
# 2025-12-27 19:10:38,431 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 184 (test) ]: test loglike is -0.8760046396875288, num_events is 10817, acc is 0.5798280484422668, rmse is 0.8361402029606683
# 2025-12-27 19:10:38,432 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8711 (updated at epoch-183)
# 2025-12-27 19:10:39,364 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 185 (train) ]: train loglike is -0.8424120689593233, num_events is 32620
# 2025-12-27 19:10:42,170 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 185 (valid) ]:  valid loglike is -0.8707686491935483, num_events is 10850, acc is 0.5952073732718894, rmse is 0.8271745956844597
# 2025-12-27 19:10:44,845 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 185 (test) ]: test loglike is -0.874530632482435, num_events is 10817, acc is 0.5819543311454193, rmse is 0.8331443186597663
# 2025-12-27 19:10:44,846 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8708 (updated at epoch-185), best updated at this epoch
# 2025-12-27 19:10:45,779 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 186 (train) ]: train loglike is -0.8412441307456123, num_events is 32620
# 2025-12-27 19:10:48,595 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 186 (valid) ]:  valid loglike is -0.8710110347062212, num_events is 10850, acc is 0.5916129032258064, rmse is 0.8253102232401439
# 2025-12-27 19:10:51,229 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 186 (test) ]: test loglike is -0.8748311757534436, num_events is 10817, acc is 0.5859295553295738, rmse is 0.8290895627406063
# 2025-12-27 19:10:51,231 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8708 (updated at epoch-185)
# 2025-12-27 19:10:52,161 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 187 (train) ]: train loglike is -0.8411350383559741, num_events is 32620
# 2025-12-27 19:10:54,966 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 187 (valid) ]:  valid loglike is -0.8724668778801843, num_events is 10850, acc is 0.5886635944700461, rmse is 0.8346444438725865
# 2025-12-27 19:10:57,621 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 187 (test) ]: test loglike is -0.8765283559732365, num_events is 10817, acc is 0.5767772949986133, rmse is 0.8333368822788556
# 2025-12-27 19:10:57,623 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8708 (updated at epoch-185)
# 2025-12-27 19:10:58,554 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 188 (train) ]: train loglike is -0.8421128357794297, num_events is 32620
# 2025-12-27 19:11:01,384 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 188 (valid) ]:  valid loglike is -0.870826432891705, num_events is 10850, acc is 0.5933640552995392, rmse is 0.8288067980048338
# 2025-12-27 19:11:04,040 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 188 (test) ]: test loglike is -0.875435873509291, num_events is 10817, acc is 0.5815845428492188, rmse is 0.8365354881057422
# 2025-12-27 19:11:04,042 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8708 (updated at epoch-185)
# 2025-12-27 19:11:04,975 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 189 (train) ]: train loglike is -0.8405509794365037, num_events is 32620
# 2025-12-27 19:11:07,789 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 189 (valid) ]:  valid loglike is -0.8716086729550692, num_events is 10850, acc is 0.5892165898617512, rmse is 0.8254335835989186
# 2025-12-27 19:11:10,419 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 189 (test) ]: test loglike is -0.8753361137272349, num_events is 10817, acc is 0.5792733659979662, rmse is 0.8369990412510142
# 2025-12-27 19:11:10,420 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8708 (updated at epoch-185)
# 2025-12-27 19:11:11,353 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 190 (train) ]: train loglike is -0.8414608411011266, num_events is 32620
# 2025-12-27 19:11:14,157 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 190 (valid) ]:  valid loglike is -0.8715383784562212, num_events is 10850, acc is 0.5915207373271889, rmse is 0.8292007551915981
# 2025-12-27 19:11:16,788 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 190 (test) ]: test loglike is -0.875941262884811, num_events is 10817, acc is 0.5828788018859203, rmse is 0.8355813675859747
# 2025-12-27 19:11:16,789 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8708 (updated at epoch-185)
# 2025-12-27 19:11:17,723 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 191 (train) ]: train loglike is -0.8404361764614309, num_events is 32620
# 2025-12-27 19:11:20,556 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 191 (valid) ]:  valid loglike is -0.8713488263248848, num_events is 10850, acc is 0.5846082949308756, rmse is 0.8336039435748547
# 2025-12-27 19:11:23,188 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 191 (test) ]: test loglike is -0.8744943397834427, num_events is 10817, acc is 0.5758528242581122, rmse is 0.834053804352442
# 2025-12-27 19:11:23,189 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8708 (updated at epoch-185)
# 2025-12-27 19:11:24,123 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 192 (train) ]: train loglike is -0.8399059826577828, num_events is 32620
# 2025-12-27 19:11:26,919 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 192 (valid) ]:  valid loglike is -0.8702044930875577, num_events is 10850, acc is 0.5949308755760369, rmse is 0.8283461709002053
# 2025-12-27 19:11:29,583 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 192 (test) ]: test loglike is -0.8751731577031524, num_events is 10817, acc is 0.5828788018859203, rmse is 0.8354748051799116
# 2025-12-27 19:11:29,584 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8702 (updated at epoch-192), best updated at this epoch
# 2025-12-27 19:11:30,517 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 193 (train) ]: train loglike is -0.8392901450413857, num_events is 32620
# 2025-12-27 19:11:33,341 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 193 (valid) ]:  valid loglike is -0.8710411866359447, num_events is 10850, acc is 0.5933640552995392, rmse is 0.8314212484656105
# 2025-12-27 19:11:36,001 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 193 (test) ]: test loglike is -0.8746143223629472, num_events is 10817, acc is 0.5840806138485717, rmse is 0.8288378263317712
# 2025-12-27 19:11:36,002 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8702 (updated at epoch-192)
# 2025-12-27 19:11:36,940 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 194 (train) ]: train loglike is -0.8388226254742106, num_events is 32620
# 2025-12-27 19:11:39,755 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 194 (valid) ]:  valid loglike is -0.8699222350230414, num_events is 10850, acc is 0.5893087557603687, rmse is 0.8265662207532453
# 2025-12-27 19:11:42,425 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 194 (test) ]: test loglike is -0.8741724903508367, num_events is 10817, acc is 0.579088471849866, rmse is 0.8295644899280241
# 2025-12-27 19:11:42,427 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8699 (updated at epoch-194), best updated at this epoch
# 2025-12-27 19:11:43,360 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 195 (train) ]: train loglike is -0.838664817225341, num_events is 32620
# 2025-12-27 19:11:46,167 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 195 (valid) ]:  valid loglike is -0.8707317468317972, num_events is 10850, acc is 0.5915207373271889, rmse is 0.8304486144044236
# 2025-12-27 19:11:48,811 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 195 (test) ]: test loglike is -0.8754508600466858, num_events is 10817, acc is 0.5827863548118702, rmse is 0.8309941258299612
# 2025-12-27 19:11:48,813 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8699 (updated at epoch-194)
# 2025-12-27 19:11:49,743 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 196 (train) ]: train loglike is -0.8384571929127069, num_events is 32620
# 2025-12-27 19:11:52,544 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 196 (valid) ]:  valid loglike is -0.8719020017281106, num_events is 10850, acc is 0.5917972350230415, rmse is 0.8379633878034787
# 2025-12-27 19:11:55,186 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 196 (test) ]: test loglike is -0.8752807718752889, num_events is 10817, acc is 0.5808449662568179, rmse is 0.8371370193275902
# 2025-12-27 19:11:55,187 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8699 (updated at epoch-194)
# 2025-12-27 19:11:56,120 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 197 (train) ]: train loglike is -0.8390776409100054, num_events is 32620
# 2025-12-27 19:11:58,942 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 197 (valid) ]:  valid loglike is -0.870167230702765, num_events is 10850, acc is 0.592073732718894, rmse is 0.8356624669485395
# 2025-12-27 19:12:01,572 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 197 (test) ]: test loglike is -0.8738850377299621, num_events is 10817, acc is 0.5808449662568179, rmse is 0.834252848901094
# 2025-12-27 19:12:01,574 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8699 (updated at epoch-194)
# 2025-12-27 19:12:02,506 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 198 (train) ]: train loglike is -0.8372499317424126, num_events is 32620
# 2025-12-27 19:12:05,323 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 198 (valid) ]:  valid loglike is -0.869591553859447, num_events is 10850, acc is 0.5882027649769586, rmse is 0.8291744546852365
# 2025-12-27 19:12:07,989 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 198 (test) ]: test loglike is -0.8745722517218267, num_events is 10817, acc is 0.5770546362207636, rmse is 0.8302874928313578
# 2025-12-27 19:12:07,991 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8696 (updated at epoch-198), best updated at this epoch
# 2025-12-27 19:12:08,923 - tpp_runner.py[pid:2254;line:96:_train_model] - INFO: [ Epoch 199 (train) ]: train loglike is -0.8374587834941178, num_events is 32620
# 2025-12-27 19:12:11,728 - tpp_runner.py[pid:2254;line:107:_train_model] - INFO: [ Epoch 199 (valid) ]:  valid loglike is -0.8718362975230415, num_events is 10850, acc is 0.58036866359447, rmse is 0.8301437330779763
# 2025-12-27 19:12:14,376 - tpp_runner.py[pid:2254;line:122:_train_model] - INFO: [ Epoch 199 (test) ]: test loglike is -0.8755295845081815, num_events is 10817, acc is 0.576499953776463, rmse is 0.8369133740701218
# 2025-12-27 19:12:14,377 - tpp_runner.py[pid:2254;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8696 (updated at epoch-198)
# 2025-12-27 19:12:14,379 - base_runner.py[pid:2254;line:110:train] - INFO: End AttNHP train! Cost time: 22.688m
# ✓ AttNHP on nonstationary_hawkes completed successfully!
#   - Log-Likelihood: -0.8755
#   - Accuracy: 0.5765
#   - RMSE: 0.8369
#
# ======================================================================
# ✓ AttNHP completed on all datasets
#   - Time: 22.7 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/AttNHP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model

# %% [markdown]
# ## Save Model Results

# %% [markdown]
# ### Function Definition

# %%
import pandas as pd
from typing import Optional, List

def format_results_table(
    results_df: pd.DataFrame,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    log_likelihood_col: str = 'log_likelihood',
    rmse_col: str = 'rmse',
    accuracy_col: str = 'accuracy',
    type_error_from_accuracy: bool = True,
    format_type: str = 'combined'
) -> pd.DataFrame:
    """
    Parameters
    ----------
    results_df : pd.DataFrame
        DataFrame containing columns: 'model', 'dataset', 'log_likelihood', 'rmse', 'accuracy'
    models : List[str], optional
        List of model names to include. If None, uses all models in results_df
    datasets : List[str], optional
        List of dataset names to include. If None, uses all datasets in results_df
    log_likelihood_col : str, default='log_likelihood'
        Column name for log-likelihood values
    rmse_col : str, default='rmse'
        Column name for RMSE values
    accuracy_col : str, default='accuracy'
        Column name for accuracy values
    type_error_from_accuracy : bool, default=True
        If True, compute Type Error Rate as (1 - accuracy) * 100
    format_type : str, default='combined'
        Output format type:
        - 'combined': "log_like/rmse/type_error% ± std_log/std_rmse/std_type"
        - 'log_likelihood': "log_like ± std_log"
        - 'rmse': "rmse ± std_rmse"
        - 'type_error': "type_error% ± std_type"

    Returns
    -------
    pd.DataFrame
        Formatted table with rows as models and columns as datasets
    """
    # Filter models and datasets if specified
    if models is not None:
        results_df = results_df[results_df['model'].isin(models)].copy()
    if datasets is not None:
        results_df = results_df[results_df['dataset'].isin(datasets)].copy()

    # Compute type error rate if needed
    if type_error_from_accuracy:
        results_df['type_error_rate'] = (1 - results_df[accuracy_col]) * 100

    # Get unique models and datasets (sorted)
    all_models = sorted(results_df['model'].unique())
    all_datasets = sorted(results_df['dataset'].unique())

    # Compute mean and std for each model-dataset combination
    agg_dict = {
        log_likelihood_col: ['mean', 'std'],
        rmse_col: ['mean', 'std'],
        'type_error_rate': ['mean', 'std']
    }

    grouped = results_df.groupby(['model', 'dataset']).agg(agg_dict).reset_index()

    # Flatten column names
    grouped.columns = ['model', 'dataset',
                       'log_like_mean', 'log_like_std',
                       'rmse_mean', 'rmse_std',
                       'type_error_mean', 'type_error_std']

    # Fill NaN std with 0 (for single runs)
    grouped['log_like_std'] = grouped['log_like_std'].fillna(0)
    grouped['rmse_std'] = grouped['rmse_std'].fillna(0)
    grouped['type_error_std'] = grouped['type_error_std'].fillna(0)

    # Create formatted strings based on format_type
    def format_cell(row):
        """Format a single cell based on format_type - HANDLES PARTIAL NaN VALUES"""
        log_like_mean = row['log_like_mean']
        log_like_std = row['log_like_std']
        rmse_mean = row['rmse_mean']
        rmse_std = row['rmse_std']
        type_mean = row['type_error_mean']
        type_std = row['type_error_std']

        if format_type == 'log_likelihood':
            # Log-likelihood only format
            if pd.isna(log_like_mean):
                return 'NaN'
            if log_like_std == 0:
                return f"{log_like_mean:.3f}"
            return f"{log_like_mean:.3f} ± {log_like_std:.3f}"

        elif format_type == 'rmse':
            # RMSE only format
            if pd.isna(rmse_mean):
                return 'NaN'
            if rmse_std == 0:
                return f"{rmse_mean:.3f}"
            return f"{rmse_mean:.3f} ± {rmse_std:.3f}"

        elif format_type == 'type_error':
            # Type Error only format
            if pd.isna(type_mean):
                return 'NaN'
            if type_std == 0:
                return f"{type_mean:.1f}%"
            return f"{type_mean:.1f}% ± {type_std:.3f}"

        else:  # format_type == 'combined' (default)
            # FIXED: Show available metrics even when some are NaN
            # Build mean string
            log_str = f"{log_like_mean:.3f}" if not pd.isna(log_like_mean) else "NaN"
            rmse_str = f"{rmse_mean:.3f}" if not pd.isna(rmse_mean) else "NaN"
            type_str = f"{type_mean:.1f}%" if not pd.isna(type_mean) else "NaN%"
            mean_str = f"{log_str}/{rmse_str}/{type_str}"

            # Build std string (only if at least one mean is not NaN)
            if not pd.isna(log_like_mean) or not pd.isna(rmse_mean) or not pd.isna(type_mean):
                log_std_str = f"{log_like_std:.3f}" if not pd.isna(log_like_mean) else "nan"
                rmse_std_str = f"{rmse_std:.3f}" if not pd.isna(rmse_mean) else "nan"
                type_std_str = f"{type_std:.3f}" if not pd.isna(type_mean) else "nan"
                std_str = f"{log_std_str}/{rmse_std_str}/{type_std_str}"
                return f"{mean_str} ± {std_str}"
            else:
                # All NaN case (shouldn't happen often)
                return 'NaN/NaN/NaN%'

    grouped['formatted'] = grouped.apply(format_cell, axis=1)

    # Pivot to create the final table
    formatted_table = grouped.pivot(index='model', columns='dataset', values='formatted')

    # Ensure all models and datasets are present (fill missing with N/A)
    formatted_table = formatted_table.reindex(index=all_models, columns=all_datasets, fill_value='N/A')

    return formatted_table


def save_results_easytpp_format(
    results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    save_csv: bool = True,
    save_latex: bool = True,
    save_markdown: bool = True,
    save_individual_metrics: bool = True,
    **format_kwargs
) -> dict:
    """
    Save formatted results in multiple formats (CSV, LaTeX, Markdown).

    Parameters
    ----------
    results_df : pd.DataFrame
        Results DataFrame with columns: model, dataset, log_likelihood, rmse, accuracy
    output_path : str
        Base path for output files (without extension)
    models : List[str], optional
        List of models to include
    datasets : List[str], optional
        List of datasets to include
    save_csv : bool, default=True
        Save as CSV
    save_latex : bool, default=True
        Save as LaTeX table
    save_markdown : bool, default=True
        Save as Markdown table
    save_individual_metrics : bool, default=True
        Save separate tables for each metric (log-likelihood, RMSE, Type Error)
    **format_kwargs
        Additional keyword arguments passed to format_results_table

    Returns
    -------
    dict
        Dictionary containing all generated tables
    """
    output_tables = {}

    # Generate combined table (with log-likelihood/RMSE/Type Error)
    combined_table = format_results_table(
        results_df,
        models=models,
        datasets=datasets,
        format_type='combined',
        **format_kwargs
    )
    output_tables['combined'] = combined_table

    # Save combined table
    if save_csv:
        combined_table.to_csv(f"{output_path}.csv")
        print(f"✓ Results saved to: {output_path}.csv")

    if save_latex:
        with open(f"{output_path}.tex", 'w') as f:
            f.write(combined_table.to_latex())
        print(f"✓ LaTeX table saved to: {output_path}.tex")

    if save_markdown:
        with open(f"{output_path}.md", 'w') as f:
            f.write(combined_table.to_markdown())
        print(f"✓ Markdown table saved to: {output_path}.md")

    return output_tables


def create_comparison_table(
    stationary_results_df: pd.DataFrame,
    nonstationary_results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None
) -> pd.DataFrame:
    """
    Create a side-by-side comparison table for stationary vs non-stationary results.

    Parameters
    ----------
    stationary_results_df : pd.DataFrame
        Results from stationary Hawkes data
    nonstationary_results_df : pd.DataFrame
        Results from non-stationary Hawkes data
    output_path : str
        Base path for output files
    models : List[str], optional
        List of models to include

    Returns
    -------
    pd.DataFrame
        Comparison table with degradation analysis
    """
    # Format both tables
    stat_table = format_results_table(stationary_results_df, models=models)
    nonstat_table = format_results_table(nonstationary_results_df, models=models)

    # Compute degradation statistics
    stat_grouped = stationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'stat_log_like',
        'rmse': 'stat_rmse',
        'accuracy': 'stat_type_error'
    })

    nonstat_grouped = nonstationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'nonstat_log_like',
        'rmse': 'nonstat_rmse',
        'accuracy': 'nonstat_type_error'
    })

    degradation = stat_grouped.join(nonstat_grouped)

    # Calculate degradation percentages
    degradation['log_like_degradation_%'] = (
        (degradation['nonstat_log_like'] - degradation['stat_log_like']) /
        abs(degradation['stat_log_like']) * 100
    )
    degradation['rmse_degradation_%'] = (
        (degradation['nonstat_rmse'] - degradation['stat_rmse']) /
        degradation['stat_rmse'] * 100
    )
    degradation['type_error_degradation_%'] = (
        degradation['nonstat_type_error'] - degradation['stat_type_error']
    )

    # Save comparison
    degradation.to_csv(f"{output_path}_degradation.csv")
    print(f"✓ Degradation analysis saved to: {output_path}_degradation.csv")

    return degradation

# %% [markdown]
# ### Function Execution

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
data_ids = ['nonstationary_hawkes']

# %%
import pandas as pd

def flatten_model_results(all_model_results):
    """
    Properly convert all_model_results dictionary to DataFrame.

    The issue: pd.DataFrame(dict) treats keys as COLUMN names, not data rows.
    This function flattens it correctly.
    """
    all_results = []
    for model_name, results_list in all_model_results.items():
        all_results.extend(results_list)
    return pd.DataFrame(all_results)

results_df = flatten_model_results(all_model_results)
results_df = results_df[
    results_df['status'] == 'success'
]

# Check the structure
print("✓ DataFrame created successfully!")
print(f"  Shape: {results_df.shape}")
print(f"  Columns: {list(results_df.columns)}")
print(f"\nFirst few rows:")
print(results_df.head())

formatted_table = format_results_table(
    results_df,
    models=model_ids,
    datasets=data_ids
)

print("\n✓ Formatted table:")
print(formatted_table)

# Save to files
saved_table = save_results_easytpp_format(
    results_df,
    output_path=f'{RESULTS_DIR}/Task5_results',
    models=model_ids,
    datasets=data_ids
)
# Out:
# ✓ DataFrame created successfully!
#   Shape: (7, 7)
#   Columns: ['model', 'dataset', 'log_likelihood', 'accuracy', 'rmse', 'status', 'time_seconds']
#
# First few rows:
#      model               dataset  log_likelihood  accuracy      rmse   status  \
# 0    RMTPP  nonstationary_hawkes       -0.857463  0.728853  1.111820  success
# 1      NHP  nonstationary_hawkes       -0.819737  0.721827  1.047376  success
# 2  FullyNN  nonstationary_hawkes       -1.118245  0.502727  1.076472  success
# 3     SAHP  nonstationary_hawkes       -0.877497  0.707313  1.008119  success
# 4      THP  nonstationary_hawkes       -0.861670  0.726819  1.017348  success
#
#    time_seconds
# 0     64.058577
# 1    188.386109
# 2     51.777111
# 3     18.783197
# 4     17.856057
#
# ✓ Formatted table:
# dataset                          nonstationary_hawkes
# model
# AttNHP         -0.876/0.837/42.4% ± 0.000/0.000/0.000
# FullyNN        -1.118/1.076/49.7% ± 0.000/0.000/0.000
# IntensityFree  -0.856/1.245/28.9% ± 0.000/0.000/0.000
# NHP            -0.820/1.047/27.8% ± 0.000/0.000/0.000
# RMTPP          -0.857/1.112/27.1% ± 0.000/0.000/0.000
# SAHP           -0.877/1.008/29.3% ± 0.000/0.000/0.000
# THP            -0.862/1.017/27.3% ± 0.000/0.000/0.000
# ✓ Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/Task5_results.csv
# ✓ LaTeX table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/Task5_results.tex
# ✓ Markdown table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/Task5_results.md

# %% [markdown]
# ## Data Conversion: EasyTPP → Meta-TPP Format
#
# Convert stationary Hawkes pickle files to npz format for Meta-TPP:
# - **EasyTPP format**: `{time_seqs: List[List[float]], type_seqs: List[List[int]]}`
# - **Meta-TPP format**: `.npz` with `TIMES`, `MARKS`, `MASKS` arrays

# %%
import pickle
import numpy as np
import json
import os


def convert_sparklen_hawkes_to_metatpp(dataset_dir, output_dir, dataset_name='stationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes dataset to Meta-TPP format.

    Your data format (from Sparklen):
    {
        'dim_process': 2,
        'train': [
            [
                {'idx_event': 1, 'type_event': 0, 'time_since_start': 0.876, ...},
                {'idx_event': 2, 'type_event': 1, 'time_since_start': 1.883, ...},
                ...
            ],
            ...
        ]
    }
    """
    os.makedirs(output_dir, exist_ok=True)

    print("="*70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("="*70)

    # Define file paths and their corresponding keys
    splits = {
        'train': ('train.pkl', 'train'),
        'dev': ('dev.pkl', 'dev'),
        'test': ('test.pkl', 'test')
    }

    all_times = []
    all_marks = []
    all_masks = []
    split_indices = {}

    current_idx = 0

    for split_name, (filename, data_key) in splits.items():
        pickle_path = os.path.join(dataset_dir, filename)

        print(f"\n{split_name.upper()} split:")

        # Load pickle file
        with open(pickle_path, 'rb') as f:
            data = pickle.load(f)

        # Extract sequences
        sequences = data[data_key]
        num_seqs = len(sequences)

        # Extract times and marks from event dictionaries
        time_seqs = []
        type_seqs = []

        for seq in sequences:
            # Each seq is a list of event dicts
            times = [event['time_since_start'] for event in seq]
            marks = [event['type_event'] for event in seq]

            time_seqs.append(times)
            type_seqs.append(marks)

        # Find max sequence length
        max_len = max(len(seq) for seq in time_seqs)

        # Create padded arrays
        times = np.zeros((num_seqs, max_len), dtype=np.float32)
        marks = np.zeros((num_seqs, max_len), dtype=np.int64)
        masks = np.zeros((num_seqs, max_len), dtype=np.float32)

        for i, (time_seq, type_seq) in enumerate(zip(time_seqs, type_seqs)):
            seq_len = len(time_seq)
            times[i, :seq_len] = time_seq
            marks[i, :seq_len] = type_seq
            masks[i, :seq_len] = 1.0

        all_times.append(times)
        all_marks.append(marks)
        all_masks.append(masks)

        split_indices[split_name] = (current_idx, current_idx + num_seqs)
        current_idx += num_seqs

        print(f"  - Sequences: {num_seqs}")
        print(f"  - Max length: {max_len}")
        print(f"  - Avg length: {np.mean([len(seq) for seq in time_seqs]):.1f}")

    # Pad to global max length
    global_max_len = max(arr.shape[1] for arr in all_times)

    def pad_to_length(arrays, target_len):
        padded = []
        for arr in arrays:
            if arr.shape[1] < target_len:
                pad_width = ((0, 0), (0, target_len - arr.shape[1]))
                padded.append(np.pad(arr, pad_width, mode='constant', constant_values=0))
            else:
                padded.append(arr)
        return padded

    all_times = pad_to_length(all_times, global_max_len)
    all_marks = pad_to_length(all_marks, global_max_len)
    all_masks = pad_to_length(all_masks, global_max_len)

    # Concatenate
    times_combined = np.concatenate(all_times, axis=0)
    marks_combined = np.concatenate(all_marks, axis=0)
    masks_combined = np.concatenate(all_masks, axis=0)

    # Save npz
    output_path = os.path.join(output_dir, f'{dataset_name}.npz')
    np.savez(
        output_path,
        times=times_combined,
        marks=marks_combined,
        masks=masks_combined
    )

    # Save split info
    split_info_path = os.path.join(output_dir, f'{dataset_name}_split_info.json')
    with open(split_info_path, 'w') as f:
        json.dump({
            'train': split_indices['train'],
            'val': split_indices['dev'],
            'test': split_indices['test'],
            'num_event_types': int(data['dim_process']),
            'global_max_len': int(global_max_len)
        }, f, indent=2)

    print(f"\n{'='*70}")
    print(f"✓ Conversion complete!")
    print(f"  - Output NPZ: {output_path}")
    print(f"  - Split info: {split_info_path}")
    print(f"  - Total sequences: {times_combined.shape[0]}")
    print(f"  - Sequence length: {times_combined.shape[1]}")
    print(f"  - Train: {split_indices['train']}")
    print(f"  - Val: {split_indices['dev']}")
    print(f"  - Test: {split_indices['test']}")
    print("="*70)

    return output_path


# ============================================================================
# RUN CONVERSION
# ============================================================================

# Convert the stationary Hawkes dataset
hawkes_input_dir = os.path.join(DATASET_DIR, dataset_name)
metatpp_dataset_dir = os.path.join(DATASET_DIR, 'metatpp_format')

# Convert the stationary Hawkes dataset
converted_npz_path = convert_sparklen_hawkes_to_metatpp(
    dataset_dir=hawkes_input_dir,
    output_dir=metatpp_dataset_dir,
    dataset_name=dataset_name
)
# Out:
# ======================================================================
# Converting nonstationary_hawkes to Meta-TPP format
# ======================================================================
#
# TRAIN split:
#   - Sequences: 300
#   - Max length: 163
#   - Avg length: 109.7
#
# DEV split:
#   - Sequences: 100
#   - Max length: 161
#   - Avg length: 109.5
#
# TEST split:
#   - Sequences: 100
#   - Max length: 152
#   - Avg length: 109.2
#
# ======================================================================
# ✓ Conversion complete!
#   - Output NPZ: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/nonstationary_hawkes.npz
#   - Split info: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/nonstationary_hawkes_split_info.json
#   - Total sequences: 500
#   - Sequence length: 163
#   - Train: (0, 300)
#   - Val: (300, 400)
#   - Test: (400, 500)
# ======================================================================

# %% [markdown]
# ## Meta TPP

# %% [markdown]
# ### Cell 1: Install Dependencies (CRITICAL - Run First, Then Restart Runtime)

# %%
# ==============================================================================
# CELL 1: Install Dependencies with Correct Versions
# ==============================================================================
# IMPORTANT: After running this cell, you MUST restart the runtime!
# Runtime → Restart runtime (or Ctrl+M .)

# Uninstall any existing stribor (Colab installs 0.2.0 which breaks)
# !pip uninstall stribor -y -q 2>/dev/null

# Install stribor 0.1.0 (does NOT require torchtyping)
# !pip install stribor==0.1.0 -q

# Install nfe (neural-flows-experiments) from GitHub
# !SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True pip install git+https://github.com/mbilos/neural-flows-experiments -q

# Install other Meta-TPP dependencies
# !pip install lightning pytorch-lightning hydra-core omegaconf hydra-colorlog pyrootutils torchmetrics rich -q

# Verify stribor version
import subprocess
result = subprocess.run(['pip', 'show', 'stribor'], capture_output=True, text=True)
version_line = [l for l in result.stdout.split('\n') if 'Version' in l][0]
print(f"✓ Installed: stribor {version_line.split(': ')[1]}")

print("\n" + "=" * 70)
print("⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime")
print("   Then continue to Cell 2 (do NOT re-run this cell)")
print("=" * 70)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 33.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for nfe (setup.py) ... done
#   Building wheel for reverse_geocoder (setup.py) ... done
#   Building wheel for sklearn (setup.py) ... done
# ✓ Installed: stribor 0.1.0
#
# ======================================================================
# ⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime
#    Then continue to Cell 2 (do NOT re-run this cell)
# ======================================================================

# %% [markdown]
# ### Cell 2: Verify Imports (Run After Restart)

# %%
# ==============================================================================
# CELL 2: Verify Imports After Runtime Restart
# ==============================================================================
# Run this AFTER restarting the runtime

import stribor

# This import should now work without torchtyping errors
import torch
print(f"✓ PyTorch version: {torch.__version__}")

# Test that stribor's distributions work
try:
    from stribor.dist import Normal
    print("✓ stribor.dist imports work")
except Exception as e:
    print(f"✗ Error: {e}")

print("\n✓ All imports successful - ready to proceed!")
# Out:
# ✓ PyTorch version: 2.9.0+cu126
# ✓ stribor.dist imports work
#
# ✓ All imports successful - ready to proceed!

# %% [markdown]
# ### Cell 3: Setup Paths and Clone Meta-TPP

# %%
# ==============================================================================
# CELL 3: Setup Paths and Clone Meta-TPP
# ==============================================================================
import os
import sys

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Base directories
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task5')
METATPP_DIR = '/content/meta-tpp'

os.makedirs(RESULTS_DIR, exist_ok=True)

# Clone Meta-TPP
if not os.path.exists(METATPP_DIR):
    # !git clone https://github.com/BorealisAI/meta-tpp.git {METATPP_DIR}
    print("✓ Meta-TPP cloned")
else:
    print("✓ Meta-TPP already exists")

# Add to Python path
if METATPP_DIR not in sys.path:
    sys.path.insert(0, METATPP_DIR)

# Change to Meta-TPP directory (required for Hydra)
os.chdir(METATPP_DIR)
print(f"✓ Working directory: {os.getcwd()}")

# Create data directories
os.makedirs(os.path.join(METATPP_DIR, 'data', 'synthetic'), exist_ok=True)
print("✓ Data directories ready")

# ==============================================================================
# Create .project-root indicator file (required by pyrootutils)
# ==============================================================================
project_root_file = os.path.join(METATPP_DIR, '.project-root')
if not os.path.exists(project_root_file):
    with open(project_root_file, 'w') as f:
        f.write('')  # Empty file is fine, just needs to exist
    print(f"✓ Created .project-root indicator file")
else:
    print(f"✓ .project-root already exists")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into '/content/meta-tpp'...
# remote: Enumerating objects: 3610, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 3610 (delta 159), reused 211 (delta 155), pack-reused 3384 (from 1)
# Receiving objects: 100% (3610/3610), 3.45 MiB | 37.99 MiB/s, done.
# Resolving deltas: 100% (2132/2132), done.
# ✓ Meta-TPP cloned
# ✓ Working directory: /content/meta-tpp
# ✓ Data directories ready
# ✓ Created .project-root indicator file

# %% [markdown]
# ### Cell 4: Convert Stationary Hawkes Data to Meta-TPP Format

# %%
# ==============================================================================
# CELL 4: Convert Stationary Hawkes Data to Meta-TPP Format
# ==============================================================================
import numpy as np
import pickle

def convert_hawkes_to_metatpp_format(dataset_dir, output_path, dataset_name='nonstationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes pickle files to Meta-TPP npz format.

    Meta-TPP expects:
    - Single npz file with all sequences
    - Keys: 'times', 'marks', 'masks'
    - Shape: (num_sequences, max_seq_len)
    - Split by indices: 60% train, 20% val, 20% test (or custom)
    """
    print("=" * 70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("=" * 70)

    all_times = []
    all_marks = []
    splits = ['train', 'dev', 'test']
    split_files = {'train': 'train.pkl', 'dev': 'dev.pkl', 'test': 'test.pkl'}

    for split in splits:
        pkl_path = os.path.join(dataset_dir, split_files[split])
        print(f"\nLoading {split}...")

        with open(pkl_path, 'rb') as f:
            data = pickle.load(f)

        # Handle different pickle structures
        if split in data:
            sequences = data[split]
        elif 'train' in data or 'dev' in data or 'test' in data:
            sequences = data.get(split, data.get('train', []))
        else:
            sequences = data if isinstance(data, list) else list(data.values())[0]

        print(f"  - {len(sequences)} sequences")

        for seq in sequences:
            if isinstance(seq, list) and len(seq) > 0 and isinstance(seq[0], dict):
                # Format: [{'time_since_start': t, 'type_event': m}, ...]
                times = [event['time_since_start'] for event in seq]
                marks = [event['type_event'] for event in seq]
            else:
                # Assume it's already (times, marks) format
                times = [e[0] if isinstance(e, (list, tuple)) else e for e in seq]
                marks = [e[1] if isinstance(e, (list, tuple)) else 0 for e in seq]

            all_times.append(times)
            all_marks.append(marks)

    # Find max sequence length
    max_len = max(len(t) for t in all_times)
    num_seqs = len(all_times)

    print(f"\n  Total sequences: {num_seqs}")
    print(f"  Max sequence length: {max_len}")

    # Create padded arrays
    times_arr = np.zeros((num_seqs, max_len), dtype=np.float32)
    marks_arr = np.zeros((num_seqs, max_len), dtype=np.int64)
    masks_arr = np.zeros((num_seqs, max_len), dtype=np.float32)

    for i, (t, m) in enumerate(zip(all_times, all_marks)):
        seq_len = len(t)
        times_arr[i, :seq_len] = t
        marks_arr[i, :seq_len] = m
        masks_arr[i, :seq_len] = 1.0

    # Save as npz
    np.savez(output_path, times=times_arr, marks=marks_arr, masks=masks_arr)

    print(f"\n✓ Saved to: {output_path}")
    print(f"  - times: {times_arr.shape}, dtype={times_arr.dtype}")
    print(f"  - marks: {marks_arr.shape}, dtype={marks_arr.dtype}")
    print(f"  - masks: {masks_arr.shape}, dtype={masks_arr.dtype}")
    print(f"  - Split: [0:{int(num_seqs*0.6)}] train, [{int(num_seqs*0.6)}:{int(num_seqs*0.8)}] val, [{int(num_seqs*0.8)}:] test")
    print("=" * 70)

    return output_path

# Convert the data
hawkes_input_dir = os.path.join(DATASET_DIR, dataset_name)
metatpp_data_path = os.path.join(METATPP_DIR, 'data', 'synthetic', 'nonstationary_hawkes.npz')

convert_hawkes_to_metatpp_format(hawkes_input_dir, metatpp_data_path)

# Verify
data = np.load(metatpp_data_path)
print("\n✓ Verification:")
for key in data.keys():
    print(f"  {key}: shape={data[key].shape}, dtype={data[key].dtype}")
# Out:
# ======================================================================
# Converting nonstationary_hawkes to Meta-TPP format
# ======================================================================
#
# Loading train...
#   - 300 sequences
#
# Loading dev...
#   - 100 sequences
#
# Loading test...
#   - 100 sequences
#
#   Total sequences: 500
#   Max sequence length: 163
#
# ✓ Saved to: /content/meta-tpp/data/synthetic/nonstationary_hawkes.npz
#   - times: (500, 163), dtype=float32
#   - marks: (500, 163), dtype=int64
#   - masks: (500, 163), dtype=float32
#   - Split: [0:300] train, [300:400] val, [400:] test
# ======================================================================
#
# ✓ Verification:
#   times: shape=(500, 163), dtype=float32
#   marks: shape=(500, 163), dtype=int64
#   masks: shape=(500, 163), dtype=float32

# %% [markdown]
# ### Cell 5: Create Dataset Config and Patch TPPDataset

# %%
# ==============================================================================
# CELL 5: Create Dataset Config and Register Dataset
# ==============================================================================
import yaml

# Create dataset config YAML
dataset_config = {
    'dataset': dataset_name,
    'num_classes': 2
}

config_dir = os.path.join(METATPP_DIR, 'configs', 'data', 'datasets')
config_path = os.path.join(config_dir, 'nonstationary_hawkes.yaml')

with open(config_path, 'w') as f:
    yaml.dump(dataset_config, f)

print(f"✓ Created dataset config: {config_path}")

# Patch TPPDataset to include our new dataset
tpp_dataset_path = os.path.join(METATPP_DIR, 'src', 'data', 'tpp_dataset.py')

with open(tpp_dataset_path, 'r') as f:
    content = f.read()

# Add nonstationary_hawkes to synthetic_data list if not already there
if 'nonstationary_hawkes' not in content:
    old_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\"]"
    new_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\", 'nonstationary_hawkes']"

    if old_line in content:
        content = content.replace(old_line, new_line)
        with open(tpp_dataset_path, 'w') as f:
            f.write(content)
        print("✓ Added 'nonstationary_hawkes' to synthetic_data list")
    else:
        # Try alternative format
        import re
        pattern = r"(synthetic_data\s*=\s*\[.*?\])"
        match = re.search(pattern, content, re.DOTALL)
        if match:
            old = match.group(1)
            if 'nonstationary_hawkes' not in old:
                new = old.rstrip(']') + ", 'nonstationary_hawkes']"
                content = content.replace(old, new)
                with open(tpp_dataset_path, 'w') as f:
                    f.write(content)
                print("✓ Added 'nonstationary_hawkes' to synthetic_data list")
else:
    print("✓ 'nonstationary_hawkes' already registered")

# Reload the module
import importlib
if 'src.data.tpp_dataset' in sys.modules:
    del sys.modules['src.data.tpp_dataset']

print("✓ Dataset configuration complete")
# Out:
# ✓ Created dataset config: /content/meta-tpp/configs/data/datasets/nonstationary_hawkes.yaml
# ✓ Added 'nonstationary_hawkes' to synthetic_data list
# ✓ Dataset configuration complete

# %% [markdown]
# ### Cell 6: Test Data Loading

# %%
# ==============================================================================
# CELL 6: Test Data Loading
# ==============================================================================
# Verify the data can be loaded by Meta-TPP's dataset class

from src.data.tpp_dataset import TPPDataset

# Test loading
data_dir = os.path.join(METATPP_DIR, 'data')

print("Testing data loading...")
try:
    train_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='train')
    val_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='val')
    test_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='test')

    print(f"\n✓ Train: {len(train_ds)} sequences")
    print(f"✓ Val: {len(val_ds)} sequences")
    print(f"✓ Test: {len(test_ds)} sequences")

    # Test a sample
    sample = train_ds[0]
    print(f"\nSample batch keys: {list(sample.keys())}")
    print(f"  times shape: {sample['times'].shape}")
    print(f"  marks shape: {sample['marks'].shape}")
    print(f"  masks shape: {sample['masks'].shape}")

    print("\n✓ Data loading test passed!")
except Exception as e:
    print(f"✗ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Testing data loading...
# time shape: torch.Size([300, 163, 1]), marks shape: torch.Size([300, 163, 1]), masks shape: torch.Size([300, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
#
# ✓ Train: 300 sequences
# ✓ Val: 100 sequences
# ✓ Test: 100 sequences
#
# Sample batch keys: ['times', 'marks', 'masks', 'missing_masks']
#   times shape: torch.Size([163, 1])
#   marks shape: torch.Size([163, 1])
#   masks shape: torch.Size([163, 1])
#
# ✓ Data loading test passed!

# %% [markdown]
# ### Cell 7: Train Meta-TPP Using Hydra

# %%
# ==============================================================================
# CELL 7: Train Meta-TPP Using Hydra
# ==============================================================================
import subprocess
import os

# Ensure we're in the Meta-TPP directory
os.chdir(METATPP_DIR)

# Training command using Hydra
# This replicates: python src/train.py data/datasets=nonstationary_hawkes
cmd = [
    'python', 'src/train.py',
    'data/datasets=nonstationary_hawkes',
    'model=thp_mix',
    'trainer.max_epochs=200',
    'trainer.accelerator=gpu',
    'trainer.devices=1',
    'data.batch_size=256',
    'tag=colab_run',
    'test=False',
    'seed=42'
]

print("=" * 70)
print("Starting Meta-TPP Training")
print("=" * 70)
print(f"Command: {' '.join(cmd)}")
print("=" * 70 + "\n")

# Run training
process = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

# Stream output
for line in iter(process.stdout.readline, ''):
    print(line, end='')

process.wait()

if process.returncode == 0:
    print("\n" + "=" * 70)
    print("✓ Training completed successfully!")
    print("=" * 70)
else:
    print(f"\n✗ Training failed with return code: {process.returncode}")
# Out:
# ======================================================================
# Starting Meta-TPP Training
# ======================================================================
# Command: python src/train.py data/datasets=nonstationary_hawkes model=thp_mix trainer.max_epochs=200 trainer.accelerator=gpu trainer.devices=1 data.batch_size=256 tag=colab_run test=False seed=42
# ======================================================================
#
# [2025-12-27 19:14:51,798][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2025-12-27 19:14:51,802][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# [2025-12-27 19:14:51,803][src.utils.rich_utils][WARNING] - Field 'logger' not found in config. Skipping 'logger' config printing...
# CONFIG
# ├── data
# │   └── _target_: src.data.tpp_dataset.TPPDataModule
# │       data_dir: /content/meta-tpp/data/
# │       batch_size: 256
# │       num_workers: 4
# │       pin_memory: false
# │       train_rate: 1.0
# │       eval_rate: 1.0
# │       noise_rate: 0.0
# │       seq_rate: 1.0
# │       missing_rate: 0.0
# │       use_mark: true
# │       run_bootstrap: false
# │       datasets:
# │         dataset: nonstationary_hawkes
# │         num_classes: 2
# │
# ├── model
# │   └── _target_: src.models.tpp_module.TPPLitModule
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.0001
# │         weight_decay: 0.0001
# │         eps: 1.0e-05
# │         betas:
# │         - 0.9
# │         - 0.999
# │       net:
# │         _target_: src.models.tpp.tpp_network.TransformerMix
# │         name: thp_mix
# │         num_classes: 2
# │         d_model: 64
# │         d_inner: 64
# │         n_layers: 2
# │         cattn_n_layers: 1
# │         n_head: 1
# │         d_k: 64
# │         d_v: 64
# │         dropout: 0.1
# │         attn_l: 0
# │         base_l: 0
# │         perm_invar: false
# │         use_avg: true
# │         share_weights: true
# │         attn_only: false
# │         concat: false
# │         num_latent: 64
# │         vi_method: None
# │         num_z_samples: 32
# │         compute_acc: true
# │         activation:
# │           name: tanh
# │           in_features: 64
# │           trainable: true
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: lightning.pytorch.callbacks.ModelCheckpoint
# │         dirpath: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_run
# │         filename: epoch_{epoch:03d}
# │         monitor: val/rmse
# │         verbose: false
# │         save_last: true
# │         save_top_k: 1
# │         mode: min
# │         auto_insert_metric_name: false
# │         save_weights_only: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: null
# │       early_stopping:
# │         _target_: lightning.pytorch.callbacks.EarlyStopping
# │         monitor: val/nll
# │         min_delta: 0.0
# │         patience: 500
# │         verbose: false
# │         mode: min
# │         strict: true
# │         check_finite: true
# │         stopping_threshold: null
# │         divergence_threshold: null
# │         check_on_train_epoch_end: null
# │       model_summary:
# │         _target_: lightning.pytorch.callbacks.RichModelSummary
# │         max_depth: -1
# │       rich_progress_bar:
# │         _target_: lightning.pytorch.callbacks.RichProgressBar
# │
# ├── trainer
# │   └── _target_: lightning.pytorch.trainer.Trainer
# │       default_root_dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_co
# │       min_epochs: 1
# │       max_epochs: 200
# │       accelerator: gpu
# │       devices: 1
# │       check_val_every_n_epoch: 1
# │       deterministic: false
# │
# ├── paths
# │   └── root_dir: /content/meta-tpp
# │       data_dir: /content/meta-tpp/data/
# │       log_dir: /content/meta-tpp/logs/
# │       output_dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_ru
# │       work_dir: /content/meta-tpp
# │       ckpt_dir: /content/meta-tpp/checkpoints/
# │
# ├── extras
# │   └── ignore_warnings: false
# │       enforce_tags: true
# │       print_config: true
# │
# ├── task_name
# │   └── nonstationary_hawkes_thp_mix_colab_run
# ├── tags
# │   └── ['dev']
# ├── tag
# │   └── colab_run
# ├── train
# │   └── True
# ├── test
# │   └── False
# ├── compile
# │   └── False
# ├── ckpt_path
# │   └── None
# └── seed
#     └── 42
# Seed set to 42
# [2025-12-27 19:14:51,861][__main__][INFO] - Instantiating datamodule <src.data.tpp_dataset.TPPDataModule>
# [2025-12-27 19:14:51,864][__main__][INFO] - Instantiating model <src.models.tpp_module.TPPLitModule>
# The number of trainable model parameters: 56284
# [2025-12-27 19:14:52,057][__main__][INFO] - Instantiating callbacks...
# [2025-12-27 19:14:52,058][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.ModelCheckpoint>
# [2025-12-27 19:14:52,072][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.EarlyStopping>
# [2025-12-27 19:14:52,073][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichModelSummary>
# [2025-12-27 19:14:52,073][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichProgressBar>
# [2025-12-27 19:14:52,074][__main__][INFO] - Instantiating loggers...
# [2025-12-27 19:14:52,074][src.utils.instantiators][WARNING] - No logger configs found! Skipping...
# [2025-12-27 19:14:52,074][__main__][INFO] - Instantiating trainer <lightning.pytorch.trainer.Trainer>
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# [2025-12-27 19:14:52,115][__main__][INFO] - Starting training!
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1551: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return _C._get_float32_matmul_precision()
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# time shape: torch.Size([300, 163, 1]), marks shape: torch.Size([300, 163, 1]), masks shape: torch.Size([300, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# ┏━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━┳━━━━┳━━━┓
# ┃    ┃ Name                                                 ┃ T… ┃ P… ┃ M… ┃ … ┃
# ┡━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━╇━━━━╇━━━┩
# │ 0  │ net                                                  │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 1  │ net.encoder                                          │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 2  │ net.encoder.event_emb                                │ E… │ 1… │ t… │ 0 │
# │ 3  │ net.encoder.layer_stack                              │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 4  │ net.encoder.layer_stack.0                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 5  │ net.encoder.layer_stack.0.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 6  │ net.encoder.layer_stack.0.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 7  │ net.encoder.layer_stack.0.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 8  │ net.encoder.layer_stack.0.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 9  │ net.encoder.layer_stack.0.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 10 │ net.encoder.layer_stack.0.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 11 │ net.encoder.layer_stack.0.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 12 │ net.encoder.layer_stack.0.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 13 │ net.encoder.layer_stack.0.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 14 │ net.encoder.layer_stack.0.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 15 │ net.encoder.layer_stack.0.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 16 │ net.encoder.layer_stack.0.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 17 │ net.encoder.layer_stack.0.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 18 │ net.encoder.layer_stack.0.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 19 │ net.encoder.layer_stack.1                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 20 │ net.encoder.layer_stack.1.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 21 │ net.encoder.layer_stack.1.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 22 │ net.encoder.layer_stack.1.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 23 │ net.encoder.layer_stack.1.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 24 │ net.encoder.layer_stack.1.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 25 │ net.encoder.layer_stack.1.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 26 │ net.encoder.layer_stack.1.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 27 │ net.encoder.layer_stack.1.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 28 │ net.encoder.layer_stack.1.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 29 │ net.encoder.layer_stack.1.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 30 │ net.encoder.layer_stack.1.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 31 │ net.encoder.layer_stack.1.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 32 │ net.encoder.layer_stack.1.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 33 │ net.encoder.layer_stack.1.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 34 │ net.linear                                           │ L… │ 1… │ t… │ 0 │
# │ 35 │ net.time_predictor                                   │ T… │ 64 │ t… │ 0 │
# │ 36 │ net.time_predictor.linear                            │ L… │ 64 │ t… │ 0 │
# │ 37 │ net.class_predictor                                  │ T… │ 1… │ t… │ 0 │
# │ 38 │ net.mark_linear                                      │ L… │ 1… │ t… │ 0 │
# │ 39 │ net.activation                                       │ T… │  0 │ t… │ 0 │
# │ 40 │ net.prob_dist                                        │ L… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 41 │ net.prob_dist.decoder                                │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 42 │ net.prob_dist.decoder.net                            │ S… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 43 │ net.prob_dist.decoder.net.0                          │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 44 │ net.prob_dist.decoder.net.1                          │ T… │  0 │ t… │ 0 │
# │ 45 │ net.prob_dist.decoder.net.2                          │ L… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 46 │ train_nll                                            │ M… │  0 │ t… │ 0 │
# │ 47 │ val_nll                                              │ M… │  0 │ t… │ 0 │
# │ 48 │ test_nll                                             │ M… │  0 │ t… │ 0 │
# │ 49 │ train_rmse                                           │ M… │  0 │ t… │ 0 │
# │ 50 │ val_rmse                                             │ M… │  0 │ t… │ 0 │
# │ 51 │ test_rmse                                            │ M… │  0 │ t… │ 0 │
# │ 52 │ train_acc                                            │ M… │  0 │ t… │ 0 │
# │ 53 │ val_acc                                              │ M… │  0 │ t… │ 0 │
# │ 54 │ test_acc                                             │ M… │  0 │ t… │ 0 │
# │ 55 │ val_nll_best                                         │ M… │  0 │ t… │ 0 │
# │ 56 │ val_rmse_best                                        │ M… │  0 │ t… │ 0 │
# └────┴──────────────────────────────────────────────────────┴────┴────┴────┴───┘
# Trainable params: 56.3 K
# Non-trainable params: 0
# Total params: 56.3 K
# Total estimated model params size (MB): 0
# Modules in train mode: 57
# Modules in eval mode: 0
# Total FLOPs: 0
# `Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 199/199 ━━━━━━━━━━━━━━━━ 2/2 0:00:00 • 0:00:00 31.79it/s val/nll: 2.806
#                                                                val/rmse: 19.242
#                                                                val/acc: 0.501
#                                                                val/nll_best:
#                                                                2.806
#                                                                val/rmse_best:
#                                                                19.242 train/nll:
#                                                                2.911
# [2025-12-27 19:16:25,400][src.utils.utils][INFO] - Output dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_run/seed42
# [2025-12-27 19:16:27,236][src.utils.utils][INFO] - Metric name is None! Skipping metric value retrieval...
# [W1227 19:16:28.566974217 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# ======================================================================
# ✓ Training completed successfully!
# ======================================================================

# %%
# ==============================================================================
# CELL 7b: Manual Testing with proper optimizer setup
# ==============================================================================
import torch
import lightning as L
from torch.utils.data import DataLoader
from functools import partial

# Fix for PyTorch 2.6 checkpoint loading
from omegaconf import ListConfig, DictConfig
torch.serialization.add_safe_globals([ListConfig, DictConfig])

from src.data.tpp_dataset import TPPDataset
from src.models.tpp_module import TPPLitModule
from src.models.tpp.tpp_network import TransformerMix

# Find the best checkpoint
import glob
ckpt_pattern = os.path.join(METATPP_DIR, 'logs', 'nonstationary_hawkes_thp_mix_colab_run', 'seed42', 'checkpoints', '*.ckpt')
ckpts = glob.glob(ckpt_pattern)
ckpts = [c for c in ckpts if 'last' not in c]
best_ckpt = sorted(ckpts)[-1] if ckpts else None

print(f"Best checkpoint: {best_ckpt}")

# Load data
data_dir = os.path.join(METATPP_DIR, 'data')
test_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='test')
test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2)

# Create model
net = TransformerMix(
    name='thp_mix', num_classes=2, d_model=64, d_inner=64, n_layers=2,
    cattn_n_layers=1, n_head=1, d_k=64, d_v=64, dropout=0.1,
    attn_l=0, base_l=0, perm_invar=False, use_avg=True, share_weights=True,
    attn_only=False, concat=False, num_latent=64, vi_method=None,
    num_z_samples=32, compute_acc=True,
    activation={'name': 'tanh', 'in_features': 64, 'trainable': True}
)

# Create optimizer as a partial function (this is what Hydra does)
optimizer = partial(
    torch.optim.Adam,
    lr=0.0001,
    weight_decay=0.0001,
    eps=1e-5,
    betas=(0.9, 0.999)
)

model = TPPLitModule(net=net, optimizer=optimizer)

# Load checkpoint
if best_ckpt:
    ckpt = torch.load(best_ckpt, map_location='cuda', weights_only=False)
    model.load_state_dict(ckpt['state_dict'])
    print("✓ Checkpoint loaded")

# Set model to eval mode
model.eval()

# Test
trainer = L.Trainer(accelerator='gpu', devices=1, logger=False, enable_progress_bar=True)
test_results = trainer.test(model, test_loader)

print("\n" + "=" * 70)
print("Meta-TPP Test Results")
print("=" * 70)
for k, v in test_results[0].items():
    print(f"  {k}: {v:.4f}")
# Out:
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 0:00:00 • 0:00:00 53.76it/s
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.5061477422714233     │
# │         test/nll          │    2.7888832092285156     │
# │         test/rmse         │     20.21638298034668     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
# Meta-TPP Test Results
# ======================================================================
#   test/nll: 2.7889
#   test/rmse: 20.2164
#   test/acc: 0.5061

# %% [markdown]
# ### Cell 8: Extract and Save Results

# %%
# ==============================================================================
# CELL 9: Extract and Save Results Properly
# ==============================================================================
import pandas as pd

# test_results is returned from trainer.test() - it's a list of dicts
# Print what we actually got to debug
print("=" * 70)
print("Raw test_results:")
print(test_results)
print("=" * 70)

# Extract metrics from test_results (it's a list with one dict)
if test_results and len(test_results) > 0:
    metrics = test_results[0]

    # Meta-TPP uses keys like 'test/nll', 'test/rmse', 'test/acc'
    # or 'test_nll', 'test_rmse', 'test_acc'

    # Try different possible key formats
    def get_metric(metrics, *possible_keys):
        for key in possible_keys:
            if key in metrics:
                val = metrics[key]
                # Handle tensor values
                if hasattr(val, 'item'):
                    return val.item()
                return val
        return float('nan')

    nll = get_metric(metrics, 'test/nll', 'test_nll', 'test_loss')
    rmse = get_metric(metrics, 'test/rmse', 'test_rmse')
    acc = get_metric(metrics, 'test/acc', 'test_acc', 'test_accuracy')

    # Log-likelihood is negative NLL
    log_likelihood = -nll if not pd.isna(nll) else float('nan')

    print(f"\nExtracted metrics:")
    print(f"  NLL: {nll}")
    print(f"  Log-Likelihood: {log_likelihood}")
    print(f"  RMSE: {rmse}")
    print(f"  Accuracy: {acc}")
else:
    print("No test results found!")
    log_likelihood = float('nan')
    acc = float('nan')
    rmse = float('nan')

# Create result entry
metatpp_result = {
    'model': 'Meta-TPP',
    'dataset': 'nonstationary_hawkes',
    'log_likelihood': log_likelihood,
    'accuracy': acc * 100 if not pd.isna(acc) and acc <= 1 else acc,  # Convert to percentage if needed
    'rmse': rmse,
    'status': 'success'
}

# Save results
results_df = pd.DataFrame([metatpp_result])
metatpp_results_path = os.path.join(RESULTS_DIR, 'metatpp_stationary_results.csv')
results_df.to_csv(metatpp_results_path, index=False)

print("\n" + "=" * 70)
print("Meta-TPP Results (Task 3b)")
print("=" * 70)
print(results_df.to_string(index=False))
print(f"\n✓ Saved to: {metatpp_results_path}")

# Also print in Table-1-like format for easy comparison
print("\n" + "=" * 70)
print("Table-1-like Format:")
print("=" * 70)
print(f"Model: Meta-TPP")
print(f"Dataset: nonstationary_hawkes")
print(f"Log-Likelihood: {log_likelihood:.3f}" if not pd.isna(log_likelihood) else "Log-Likelihood: N/A")
print(f"Accuracy: {metatpp_result['accuracy']:.1f}%" if not pd.isna(metatpp_result['accuracy']) else "Accuracy: N/A")
print(f"RMSE: {rmse:.3f}" if not pd.isna(rmse) else "RMSE: N/A")
# Out:
# ======================================================================
# Raw test_results:
# [{'test/nll': 2.7888832092285156, 'test/rmse': 20.21638298034668, 'test/acc': 0.5061477422714233}]
# ======================================================================
#
# Extracted metrics:
#   NLL: 2.7888832092285156
#   Log-Likelihood: -2.7888832092285156
#   RMSE: 20.21638298034668
#   Accuracy: 0.5061477422714233
#
# ======================================================================
# Meta-TPP Results (Task 3b)
# ======================================================================
#    model              dataset  log_likelihood  accuracy      rmse  status
# Meta-TPP nonstationary_hawkes       -2.788883 50.614774 20.216383 success
#
# ✓ Saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/metatpp_stationary_results.csv
#
# ======================================================================
# Table-1-like Format:
# ======================================================================
# Model: Meta-TPP
# Dataset: nonstationary_hawkes
# Log-Likelihood: -2.789
# Accuracy: 50.6%
# RMSE: 20.216
