# %% [markdown]
# ## Package Installation

# %%
import os
import sys
import types

# Install core dependencies
# !pip install easy-tpp lightning pytorch-lightning hydra-core omegaconf torchmetrics stribor -q

print("✓ Core dependencies installed")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 64.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.1 MB/s eta 0:00:00
# ✓ Core dependencies installed

# %%
# Import required libraries
import os

# Set PyTorch memory allocation config BEFORE importing torch
# This helps prevent OOM errors with large models like AttNHP
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

import yaml
import pandas as pd
import numpy as np
from datetime import datetime
from easy_tpp.config_factory import Config
from easy_tpp.runner import Runner
from google.colab import drive
import json
from IPython.display import display, clear_output
import time

# %%
# ==============================================================================
# FULLYNN GRADIENT FIX - Monkey Patch
# ==============================================================================
# FullyNN uses torch.autograd.grad() to compute intensity derivatives, but during
# validation/evaluation, EasyTPP runs under torch.no_grad() context which disables
# gradient tracking. This patch wraps the computation in torch.enable_grad().
# ==============================================================================

import torch
from easy_tpp.model.torch_model import torch_fullynn

def patched_compute_intensities_at_sample_times(self, time_seqs, time_delta_seqs, type_seqs, sample_dtimes, **kwargs):
    """Patched version that enables gradients during intensity computation.

    FullyNN requires gradient computation for intensity derivatives via autograd.grad().
    During validation, EasyTPP disables gradients with torch.no_grad(), causing failures.
    This patch wraps the computation in torch.enable_grad() to fix the issue.
    """
    compute_last_step_only = kwargs.get('compute_last_step_only', False)

    # Enable gradients for this computation even during evaluation
    with torch.enable_grad():
        # Forward pass to get hidden states
        hidden_states = self.forward(
            time_seqs=time_seqs,
            time_delta_seqs=time_delta_seqs,
            type_seqs=type_seqs,
        )

        num_samples = sample_dtimes.size()[-1]
        batch_size, seq_len, hidden_size = hidden_states.shape

        # Expand hidden states for all sample times
        hidden_states_ = hidden_states[..., None, :].expand(batch_size, seq_len, num_samples, hidden_size)

        # Clone sample_dtimes to avoid in-place modification issues
        sample_dtimes_grad = sample_dtimes.clone().detach().requires_grad_(True)

        # Compute intensities (this uses autograd.grad internally)
        _, derivative_integral_lambda = self.layer_intensity.forward(
            hidden_states=hidden_states_,
            time_delta_seqs=sample_dtimes_grad,
        )

    # Detach the result since we don't need gradients flowing back
    derivative_integral_lambda = derivative_integral_lambda.detach()

    if compute_last_step_only:
        return derivative_integral_lambda[:, -1:, :, :]
    return derivative_integral_lambda

# Apply the monkey patch
torch_fullynn.FullyNN.compute_intensities_at_sample_times = patched_compute_intensities_at_sample_times
print("✓ FullyNN patched for gradient computation during evaluation")
print("  This fixes the 'element 0 of tensors does not require grad' error")
# Out:
# ✓ FullyNN patched for gradient computation during evaluation
#   This fixes the 'element 0 of tensors does not require grad' error

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Base directory (your Drive location)
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
CHECKPOINT_DIR = os.path.join(BASE_DIR, 'checkpoints')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task5')

# Create results directory if it doesn't exist
os.makedirs(RESULTS_DIR, exist_ok=True)

print(f"✓ Base Directory: {BASE_DIR}")
print(f"✓ Dataset Directory: {DATASET_DIR}")
print(f"✓ Checkpoint Directory: {CHECKPOINT_DIR}")
print(f"✓ Results Directory: {RESULTS_DIR}")
# Out:
# Mounted at /content/drive
# ✓ Base Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025
# ✓ Dataset Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets
# ✓ Checkpoint Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints
# ✓ Results Directory: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5

# %% [markdown]
# ## Configuration Dictionary

# %% [markdown]
# ### Data Configuration

# %%
# Data specifications for each dataset
dataset_name = 'nonstationary_hawkes'
data_spec_dict = {
    dataset_name: {
        "data_format": "pkl",
        "train_dir": os.path.join(DATASET_DIR, dataset_name, "train.pkl"),
        "valid_dir": os.path.join(DATASET_DIR, dataset_name, "dev.pkl"),
        "test_dir": os.path.join(DATASET_DIR, dataset_name, "test.pkl"),
        "data_specs": {
            "num_event_types": 2,
            "pad_token_id": 2,
            "padding_side": "right",
            "max_seq_len": 20,
            "strict_pad_leng": True
        }
    }
}

print("✓ Data specifications loaded for Hawkes Stationary")
# Out:
# ✓ Data specifications loaded for Hawkes Stationary

# %% [markdown]
# ### Model Configuration

# %%
# ==============================================================================
# MODEL SPECIFICATIONS
# ==============================================================================

# Common thinning parameters
default_thinning = {
    "num_seq": 10,
    "num_sample": 1,
    "num_exp": 500,
    "look_ahead_time": 10,
    "patience_counter": 5,
    "over_sample_rate": 5,
    "num_samples_boundary": 5,
    "dtime_max": 5
}

# Memory-optimized thinning for OOM-prone models
memory_optimized_thinning = {
    "num_seq": 10,
    "num_sample": 1,
    "num_exp": 100,  # Reduced from 500
    "look_ahead_time": 10,
    "patience_counter": 5,
    "over_sample_rate": 5,
    "num_samples_boundary": 5,
    "dtime_max": 5
}

model_spec_dict = {
    # RMTPP: hidden=32, time_emb=16, layers=2
    "RMTPP": {
        "model_id": "RMTPP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "seed": 2019,
        "thinning": default_thinning.copy()
    },

    # NHP: hidden=64, time_emb=16, layers=2
    "NHP": {
        "model_id": "NHP",
        "hidden_size": 64,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "seed": 2019,
        "thinning": default_thinning.copy()
    },

    # FullyNN: hidden=32, time_emb=16, layers=2
    "FullyNN": {
        "model_id": "FullyNN",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "model_specs": {
            "num_mlp_layers": 3,
            "proper_marked_intensities": True
        },
        "thinning": default_thinning.copy()
    },

    # SAHP: hidden=32, time_emb=16, layers=2, heads=2
    "SAHP": {
        "model_id": "SAHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": default_thinning.copy()
    },

    # THP: hidden=64, time_emb=16, layers=2, heads=2
    "THP": {
        "model_id": "THP",
        "hidden_size": 64,
        "time_embed_size": 16,
        "num_layers": 2,
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": default_thinning.copy()
    },

    # IntensityFree: hidden=32, time_emb=16, layers=2
    "IntensityFree": {
        "model_id": "IntensityFree",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 2,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "mc_num_sample_per_step": 20,
        "num_mix_components": 3,
        "model_specs": {
            "num_mix_components": 3
        },
        "thinning": {
            **default_thinning,
            "num_step_gen": 10
        }
    },

    # AttNHP: hidden=32, time_emb=16, layers=1, heads=2
    "AttNHP": {
        "model_id": "AttNHP",
        "hidden_size": 32,
        "time_embed_size": 16,
        "num_layers": 1,  # NOTE: Only 1 layer per paper
        "num_heads": 2,
        "mc_num_sample_per_step": 20,
        "sharing_param_layer": False,
        "loss_integral_num_sample_per_step": 20,
        "dropout": 0.0,
        "use_ln": False,
        "seed": 2019,
        "thinning": default_thinning.copy()
    }
}

print("✓ Model specifications loaded for 7 models:")
print("\n" + "="*70)
print(f"{'Model':<15} {'hidden_size':<12} {'time_emb':<10} {'layers':<8} {'heads':<8}")
print("-"*70)
for model_id, spec in model_spec_dict.items():
    h = spec.get('hidden_size', '-')
    t = spec.get('time_embed_size', '-')
    l = spec.get('num_layers', '-')
    heads = spec.get('num_heads', '-')
    print(f"{model_id:<15} {h:<12} {t:<10} {l:<8} {heads:<8}")
print("="*70)
# Out:
# ✓ Model specifications loaded for 7 models:
#
# ======================================================================
# Model           hidden_size  time_emb   layers   heads
# ----------------------------------------------------------------------
# RMTPP           32           16         2        -
# NHP             64           16         2        -
# FullyNN         32           16         2        -
# SAHP            32           16         2        2
# THP             64           16         2        2
# IntensityFree   32           16         2        -
# AttNHP          32           16         1        2
# ======================================================================

# %% [markdown]
# ### Training Configuration

# %%
# Trainer configuration (shared across all experiments)
trainer_config = {
    "batch_size": 256,
    "max_epoch": 200,
    "shuffle": False,
    "optimizer": "adam",
    "learning_rate": 1e-3,
    "valid_freq": 1,
    "use_tfb": False,
    "metrics": ["acc", "rmse"],
    "seed": 2019,
    "gpu": 0
}

print("✓ Trainer configuration loaded")
print(f"  - Batch size: {trainer_config['batch_size']}")
print(f"  - Max epochs: {trainer_config['max_epoch']}")
print(f"  - Learning rate: {trainer_config['learning_rate']}")
# Out:
# ✓ Trainer configuration loaded
#   - Batch size: 256
#   - Max epochs: 200
#   - Learning rate: 0.001

# %% [markdown]
# ## Helper Functions

# %%
def create_experiment_config(model_id, data_id, data_spec, model_spec, trainer_cfg):
    """Create a complete experiment configuration."""
    experiment_id = f"{model_id}_{data_id}_train"

    config = {
        "pipeline_config_id": "runner_config",
        "data": {
            data_id: data_spec
        },
        experiment_id: {
            "base_config": {
                "stage": "train",
                "backend": "torch",
                "dataset_id": data_id,
                "runner_id": "std_tpp",
                "model_id": model_id,
                "base_dir": CHECKPOINT_DIR
            },
            "trainer_config": trainer_cfg,
            "model_config": model_spec
        }
    }

    return config, experiment_id

def extract_results_from_logs(log_path):
    """Extract best results from training logs.

    Args:
        log_path: Can be either a log file or a directory containing log files
    """
    try:
        # Determine if log_path is a file or directory
        if os.path.isfile(log_path):
            # It's a file - read it directly
            log_file = log_path
        elif os.path.isdir(log_path):
            # It's a directory - find .log files inside
            log_files = [f for f in os.listdir(log_path) if f.endswith('.log')]
            if not log_files:
                return None
            log_file = os.path.join(log_path, log_files[0])
        else:
            print(f"  Warning: Log path does not exist: {log_path}")
            return None

        # Read the log file
        with open(log_file, 'r') as f:
            lines = f.readlines()

        # Find the LAST test metrics (final epoch results)
        best_ll = None
        best_acc = None
        best_rmse = None

        for line in lines:
            if 'test loglike is' in line:
                try:
                    parts = line.split(',')
                    # Extract log-likelihood
                    ll_part = [p for p in parts if 'test loglike is' in p][0]
                    best_ll = float(ll_part.split('test loglike is')[1].strip())

                    # Extract accuracy
                    acc_parts = [p for p in parts if 'acc is' in p]
                    if acc_parts:
                        best_acc = float(acc_parts[0].split('acc is')[1].strip())

                    # Extract RMSE
                    rmse_parts = [p for p in parts if 'rmse is' in p]
                    if rmse_parts:
                        best_rmse = float(rmse_parts[0].split('rmse is')[1].strip())
                except (IndexError, ValueError) as e:
                    print(f"  Warning: Could not parse line: {e}")
                    continue

        if best_ll is None:
            return None

        return {
            'log_likelihood': best_ll,
            'accuracy': best_acc,
            'rmse': best_rmse
        }
    except Exception as e:
        print(f"  Warning: Could not extract results from logs: {e}")
        return None
def find_latest_checkpoint_dir(base_dir, model_id, data_id):
    """Find the most recent checkpoint directory for an experiment."""
    try:
        # EasyTPP creates directories with random names but puts
        # {model_id}_{data_id}_train_output.yaml inside them
        target_yaml = f"{model_id}_{data_id}_train_output.yaml"

        matching_dirs = []
        for d in os.listdir(base_dir):
            dir_path = os.path.join(base_dir, d)
            if os.path.isdir(dir_path):
                # Check if the target yaml file exists in this directory
                yaml_path = os.path.join(dir_path, target_yaml)
                if os.path.exists(yaml_path):
                    matching_dirs.append(dir_path)

        if not matching_dirs:
            return None

        # Return the most recently modified directory
        latest = max(matching_dirs, key=os.path.getmtime)
        return latest
    except Exception as e:
        print(f"  Warning: Error finding checkpoint dir: {e}")
        return None
print("✓ Helper functions loaded")
# Out:
# ✓ Helper functions loaded

# %%
def run_model_on_all_datasets(
    model_id,
    model_number,
    total_models,
    aggressive_gpu_clearing=False
):
    """
    Run a single TPP model on all configured datasets.

    This function encapsulates the complete workflow for running a model:
    - Creates and saves experiment configs for each dataset
    - Runs training and evaluation
    - Extracts metrics from logs
    - Saves results (both intermediate and model-specific)
    - Handles errors gracefully
    - Manages GPU memory

    Parameters
    ----------
    model_id : str
        The model identifier (e.g., 'RMTPP', 'NHP', 'AttNHP')
        Must exist as a key in model_spec_dict
    model_number : int
        Current model number (1-7) for progress tracking
    total_models : int
        Total number of models (typically 7) for progress tracking
    aggressive_gpu_clearing : bool, default=False
        If True, performs GPU memory clearing after EACH dataset.
        Use this for memory-intensive models like AttNHP.
        If False, only clears GPU memory after all datasets complete.

    Returns
    -------
    model_results : list of dict
        List containing result dictionaries for each dataset.
        Each dict contains: model, dataset, log_likelihood, accuracy,
        rmse, status, and time_seconds

    Side Effects
    ------------
    - Appends results to the global results_list
    - Saves intermediate results to 'intermediate_results.csv' after each dataset
    - Saves model-specific results to '{model_id}_results.csv'
    - Creates experiment config files in the configs directory
    - Clears GPU memory (timing depends on aggressive_gpu_clearing flag)

    Notes
    -----
    This function relies on several global variables and functions:
    - data_spec_dict: Dictionary of dataset configurations
    - model_spec_dict: Dictionary of model configurations
    - trainer_config: Training configuration
    - results_list: Global list to store all results
    - total_experiments: Total number of experiments
    - BASE_DIR, CHECKPOINT_DIR, RESULTS_DIR: Directory paths
    - create_experiment_config(): Function to create config dicts
    - find_latest_checkpoint_dir(): Function to locate checkpoints
    - extract_results_from_logs(): Function to parse training logs

    Example
    -------
    >>> # Run RMTPP on all datasets (standard memory management)
    >>> rmtpp_results = run_model_on_all_datasets('RMTPP', 1, 7)

    >>> # Run AttNHP with aggressive memory clearing
    >>> attnhp_results = run_model_on_all_datasets('AttNHP', 7, 7,
    ...                                             aggressive_gpu_clearing=True)
    """
    import time
    import os
    import yaml
    import pandas as pd
    import torch
    import gc
    from easy_tpp.config_factory import Config
    from easy_tpp.runner import Runner

    print("\n" + "=" * 70)
    print(f"[MODEL {model_number}/{total_models}] Running {model_id} on all datasets")
    print("=" * 70)

    model_start_time = time.time()
    model_results = []

    for data_id, data_spec in data_spec_dict.items():
        experiment_name = f"{model_id}_{data_id}"
        experiment_num = len(results_list) + 1

        print(f"\n[{experiment_num}/{total_experiments}] Running {model_id} on {data_id} dataset")
        print("=" * 70)

        try:
            # Create config
            config_dict, experiment_id = create_experiment_config(
                model_id=model_id,
                data_id=data_id,
                data_spec=data_spec,
                model_spec=model_spec_dict[model_id],
                trainer_cfg=trainer_config
            )

            # Save config
            CONFIG_DIR = os.path.join(BASE_DIR, 'configs')
            os.makedirs(CONFIG_DIR, exist_ok=True)
            config_path = os.path.join(CONFIG_DIR, f"{experiment_name}.yaml")
            with open(config_path, 'w') as f:
                yaml.dump(config_dict, f)

            # Build and run
            config = Config.build_from_yaml_file(config_path, experiment_id=experiment_id)
            runner = Runner.build_from_config(config)
            runner.run()

            # Find checkpoint directory
            checkpoint_dir = find_latest_checkpoint_dir(CHECKPOINT_DIR, model_id, data_id)

            # Extract results from logs
            if checkpoint_dir:
                log_dir = os.path.join(checkpoint_dir, 'log')
                metrics = extract_results_from_logs(log_dir)

                if metrics:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': metrics['log_likelihood'],
                        'accuracy': metrics['accuracy'],
                        'rmse': metrics['rmse'],
                        'status': 'success',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"✓ {model_id} on {data_id} completed successfully!")
                    print(f"  - Log-Likelihood: {metrics['log_likelihood']:.4f}")
                    if metrics['accuracy'] and metrics['accuracy'] > 0:
                        print(f"  - Accuracy: {metrics['accuracy']:.4f}")
                    if metrics['rmse'] and metrics['rmse'] > 0:
                        print(f"  - RMSE: {metrics['rmse']:.4f}")
                else:
                    result = {
                        'model': model_id,
                        'dataset': data_id,
                        'log_likelihood': None,
                        'accuracy': None,
                        'rmse': None,
                        'status': 'completed_no_metrics',
                        'time_seconds': time.time() - model_start_time
                    }
                    print(f"⚠ {model_id} on {data_id} completed but no metrics found")
            else:
                result = {
                    'model': model_id,
                    'dataset': data_id,
                    'log_likelihood': None,
                    'accuracy': None,
                    'rmse': None,
                    'status': 'no_checkpoint',
                    'time_seconds': time.time() - model_start_time
                }
                print(f"⚠ {model_id} on {data_id} - no checkpoint directory found")

        except Exception as e:
            result = {
                'model': model_id,
                'dataset': data_id,
                'log_likelihood': None,
                'accuracy': None,
                'rmse': None,
                'status': 'failed',
                'error': str(e),
                'time_seconds': time.time() - model_start_time
            }
            print(f"✗ Error running {model_id} on {data_id}: {str(e)}")

        results_list.append(result)
        model_results.append(result)

        # Save intermediate results after each experiment
        intermediate_df = pd.DataFrame(results_list)
        intermediate_df.to_csv(os.path.join(RESULTS_DIR, 'intermediate_results.csv'), index=False)

        # Aggressive GPU memory clearing (for memory-intensive models like AttNHP)
        if aggressive_gpu_clearing:
            try:
                del runner
                del config
            except:
                pass
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
                torch.cuda.synchronize()

    # Save model-specific results
    model_df = pd.DataFrame(model_results)
    model_csv_path = os.path.join(RESULTS_DIR, f'{model_id}_results.csv')
    model_df.to_csv(model_csv_path, index=False)

    # Model summary
    model_elapsed = time.time() - model_start_time
    successful = sum(1 for r in model_results if r['status'] == 'success')
    failed = sum(1 for r in model_results if r['status'] == 'failed')

    print(f"\n" + "=" * 70)
    print(f"✓ {model_id} completed on all datasets")
    print(f"  - Time: {model_elapsed/60:.1f} minutes")
    print(f"  - Successful: {successful}/{len(data_spec_dict)}")
    print(f"  - Failed: {failed}/{len(data_spec_dict)}")
    print(f"  - Results saved to: {model_csv_path}")
    print("=" * 70)

    # Clear GPU memory for next model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        print(f"✓ GPU memory cleared for next model")

    return model_results

# %% [markdown]
# ## Run Models On Data

# %%
# Initialize results storage
results_list = []
total_experiments = len(model_spec_dict) * len(data_spec_dict)

print(f"Starting {total_experiments} experiments...")
print(f"Running {len(model_spec_dict)} models on {len(data_spec_dict)} datasets")
print(f"Results will be saved incrementally to: {RESULTS_DIR}")
print("=" * 70)
# Out:
# Starting 7 experiments...
# Running 7 models on 1 datasets
# Results will be saved incrementally to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5
# ======================================================================

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
all_model_results = {}

for i, model_id in enumerate(model_ids, start=1):
    aggressive = (model_id == 'AttNHP')
    all_model_results[model_id] = run_model_on_all_datasets(
        model_id, i, len(model_ids), aggressive
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# 2026-01-01 14:59:47,221 - base_runner.py[pid:1768;line:110:train] - INFO: End RMTPP train! Cost time: 0.243m
# ✓ RMTPP on nonstationary_hawkes completed successfully!
#   - Log-Likelihood: -0.8575
#   - Accuracy: 0.7289
#   - RMSE: 1.1118
#
# ======================================================================
# ✓ RMTPP completed on all datasets
#   - Time: 1.2 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/RMTPP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model
#
# ======================================================================
# [MODEL 2/7] Running NHP on all datasets
# ======================================================================
#
# [2/7] Running NHP on nonstationary_hawkes dataset
# ======================================================================
# 2026-01-01 15:00:30,197 - config.py[pid:1768;line:34:build_from_yaml_file] - CRITICAL: Load pipeline config class RunnerConfig
# 2026-01-01 15:00:30,204 - runner_config.py[pid:1768;line:140:update_config] - CRITICAL: train model NHP using GPU with torch backend
# 2026-01-01 15:00:30,231 - runner_config.py[pid:1768;line:35:__init__] - INFO: Save the config to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/1768_135668393013888_260101-150030/NHP_nonstationary_hawkes_train_output.yaml
# 2026-01-01 15:00:30,235 - base_runner.py[pid:1768;line:176:save_log] - INFO: Save the log to /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/checkpoints/1768_135668393013888_260101-150030/log
# 0.5189538021705272 0.7216217648548782
# min_dt: 4.934766515507505e-05
# max_dt: 8.303566563742564
# 2026-01-01 15:00:30,273 - tpp_runner.py[pid:1768;line:60:_init_model] - INFO: Num of model parameters 58116
# 2026-01-01 15:00:30,308 - base_runner.py[pid:1768;line:98:train] - INFO: Data 'nonstationary_hawkes' loaded...
# 2026-01-01 15:00:30,309 - base_runner.py[pid:1768;line:103:train] - INFO: Start NHP training...
# 2026-01-01 15:00:30,841 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 0 (train) ]: train loglike is -1.10327914838481, num_events is 32620
# 2026-01-01 15:00:31,124 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 0 (valid) ]:  valid loglike is -1.059438724078341, num_events is 10850, acc is 0.6777880184331797, rmse is 1.0183441054761408
# 2026-01-01 15:00:31,389 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 0 (test) ]: test loglike is -1.061001707381899, num_events is 10817, acc is 0.671350651751872, rmse is 1.015300147178776
# 2026-01-01 15:00:31,390 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0594 (updated at epoch-0), best updated at this epoch
# 2026-01-01 15:00:31,789 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 1 (train) ]: train loglike is -1.0521644989893086, num_events is 32620
# 2026-01-01 15:00:32,061 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 1 (valid) ]:  valid loglike is -1.020592777937788, num_events is 10850, acc is 0.6885714285714286, rmse is 0.9556337074818064
# 2026-01-01 15:00:32,326 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 1 (test) ]: test loglike is -1.0228929289544235, num_events is 10817, acc is 0.682536747711935, rmse is 0.9640721448826893
# 2026-01-01 15:00:32,327 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -1.0206 (updated at epoch-1), best updated at this epoch
# 2026-01-01 15:00:32,726 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 2 (train) ]: train loglike is -1.014307119625613, num_events is 32620
# 2026-01-01 15:00:32,999 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 2 (valid) ]:  valid loglike is -0.9931540718605991, num_events is 10850, acc is 0.6923502304147465, rmse is 0.9334481507633944
# 2026-01-01 15:00:33,267 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 2 (test) ]: test loglike is -0.9962196008019784, num_events is 10817, acc is 0.6854026070074882, rmse is 0.9304601370889366
# 2026-01-01 15:00:33,268 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9932 (updated at epoch-2), best updated at this epoch
# 2026-01-01 15:00:33,691 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 3 (train) ]: train loglike is -0.987573526594114, num_events is 32620
# 2026-01-01 15:00:33,966 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 3 (valid) ]:  valid loglike is -0.9739539530529954, num_events is 10850, acc is 0.6940092165898617, rmse is 0.9034899547415977
# 2026-01-01 15:00:34,231 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 3 (test) ]: test loglike is -0.9778052992396228, num_events is 10817, acc is 0.6883609133770916, rmse is 0.9015113655985658
# 2026-01-01 15:00:34,232 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9740 (updated at epoch-3), best updated at this epoch
# 2026-01-01 15:00:34,632 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 4 (train) ]: train loglike is -0.9687899067385807, num_events is 32620
# 2026-01-01 15:00:34,902 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 4 (valid) ]:  valid loglike is -0.9591707769297235, num_events is 10850, acc is 0.6952995391705069, rmse is 0.877806396493274
# 2026-01-01 15:00:35,162 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 4 (test) ]: test loglike is -0.9638281863906352, num_events is 10817, acc is 0.6891929370435426, rmse is 0.8935196951043103
# 2026-01-01 15:00:35,163 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9592 (updated at epoch-4), best updated at this epoch
# 2026-01-01 15:00:35,563 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 5 (train) ]: train loglike is -0.9542989406901441, num_events is 32620
# 2026-01-01 15:00:35,832 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 5 (valid) ]:  valid loglike is -0.9463484663018433, num_events is 10850, acc is 0.6955760368663595, rmse is 0.880110610829117
# 2026-01-01 15:00:36,095 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 5 (test) ]: test loglike is -0.9518251435818619, num_events is 10817, acc is 0.6905796431542942, rmse is 0.8774489902810608
# 2026-01-01 15:00:36,097 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9463 (updated at epoch-5), best updated at this epoch
# 2026-01-01 15:00:36,502 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 6 (train) ]: train loglike is -0.9418692489988887, num_events is 32620
# 2026-01-01 15:00:36,774 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 6 (valid) ]:  valid loglike is -0.9352320348502304, num_events is 10850, acc is 0.6966820276497696, rmse is 0.8807825422532519
# 2026-01-01 15:00:37,033 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 6 (test) ]: test loglike is -0.9415004124006194, num_events is 10817, acc is 0.6915041138947953, rmse is 0.8832005323252671
# 2026-01-01 15:00:37,034 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9352 (updated at epoch-6), best updated at this epoch
# 2026-01-01 15:00:37,439 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 7 (train) ]: train loglike is -0.9313282417563995, num_events is 32620
# 2026-01-01 15:00:37,722 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 7 (valid) ]:  valid loglike is -0.9265061563940092, num_events is 10850, acc is 0.6999078341013825, rmse is 0.8990006687892891
# 2026-01-01 15:00:37,990 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 7 (test) ]: test loglike is -0.9334397317301469, num_events is 10817, acc is 0.6932606083017473, rmse is 0.8823522602205146
# 2026-01-01 15:00:37,991 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9265 (updated at epoch-7), best updated at this epoch
# 2026-01-01 15:00:38,397 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 8 (train) ]: train loglike is -0.9232423222189224, num_events is 32620
# 2026-01-01 15:00:38,663 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 8 (valid) ]:  valid loglike is -0.9201989127304148, num_events is 10850, acc is 0.7021198156682028, rmse is 0.8894656787871208
# 2026-01-01 15:00:38,921 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 8 (test) ]: test loglike is -0.9275419875832024, num_events is 10817, acc is 0.6961264675973006, rmse is 0.8977458245899823
# 2026-01-01 15:00:38,922 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9202 (updated at epoch-8), best updated at this epoch
# 2026-01-01 15:00:39,322 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 9 (train) ]: train loglike is -0.9174364006935929, num_events is 32620
# 2026-01-01 15:00:39,591 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 9 (valid) ]:  valid loglike is -0.9154138464861751, num_events is 10850, acc is 0.7048847926267281, rmse is 0.8882982666874836
# 2026-01-01 15:00:39,849 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 9 (test) ]: test loglike is -0.9228388329712489, num_events is 10817, acc is 0.7005639271517057, rmse is 0.8929278436120461
# 2026-01-01 15:00:39,850 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9154 (updated at epoch-9), best updated at this epoch
# 2026-01-01 15:00:40,250 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 10 (train) ]: train loglike is -0.9128783356405196, num_events is 32620
# 2026-01-01 15:00:40,520 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 10 (valid) ]:  valid loglike is -0.9111063508064516, num_events is 10850, acc is 0.7053456221198157, rmse is 0.8924549564289758
# 2026-01-01 15:00:40,779 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 10 (test) ]: test loglike is -0.918321565591199, num_events is 10817, acc is 0.7030599981510586, rmse is 0.904018361172192
# 2026-01-01 15:00:40,780 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9111 (updated at epoch-10), best updated at this epoch
# 2026-01-01 15:00:41,185 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 11 (train) ]: train loglike is -0.9085102841431637, num_events is 32620
# 2026-01-01 15:00:41,458 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 11 (valid) ]:  valid loglike is -0.9066784274193549, num_events is 10850, acc is 0.7060829493087558, rmse is 0.9110568259709516
# 2026-01-01 15:00:41,718 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 11 (test) ]: test loglike is -0.9134967130731718, num_events is 10817, acc is 0.701765739114357, rmse is 0.9004491348910281
# 2026-01-01 15:00:41,719 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9067 (updated at epoch-11), best updated at this epoch
# 2026-01-01 15:00:42,128 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 12 (train) ]: train loglike is -0.9038059442778587, num_events is 32620
# 2026-01-01 15:00:42,411 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 12 (valid) ]:  valid loglike is -0.9019785066244239, num_events is 10850, acc is 0.7056221198156682, rmse is 0.8957647159082271
# 2026-01-01 15:00:42,683 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 12 (test) ]: test loglike is -0.9083231978598503, num_events is 10817, acc is 0.7014883978922067, rmse is 0.9126806587815688
# 2026-01-01 15:00:42,684 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.9020 (updated at epoch-12), best updated at this epoch
# 2026-01-01 15:00:43,103 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 13 (train) ]: train loglike is -0.8987111291002452, num_events is 32620
# 2026-01-01 15:00:43,386 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 13 (valid) ]:  valid loglike is -0.8970762528801843, num_events is 10850, acc is 0.7060829493087558, rmse is 0.9006311568974446
# 2026-01-01 15:00:43,653 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 13 (test) ]: test loglike is -0.9029524200910604, num_events is 10817, acc is 0.7006563742257558, rmse is 0.9194232441105477
# 2026-01-01 15:00:43,654 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8971 (updated at epoch-13), best updated at this epoch
# 2026-01-01 15:00:44,074 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 14 (train) ]: train loglike is -0.8933692843251839, num_events is 32620
# 2026-01-01 15:00:44,359 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 14 (valid) ]:  valid loglike is -0.8921259360599079, num_events is 10850, acc is 0.7063594470046083, rmse is 0.9361923595315462
# 2026-01-01 15:00:44,632 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 14 (test) ]: test loglike is -0.8975879619464732, num_events is 10817, acc is 0.700841268373856, rmse is 0.92300142610415
# 2026-01-01 15:00:44,633 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8921 (updated at epoch-14), best updated at this epoch
# 2026-01-01 15:00:45,056 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 15 (train) ]: train loglike is -0.8879697648825491, num_events is 32620
# 2026-01-01 15:00:45,331 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 15 (valid) ]:  valid loglike is -0.8873007272465437, num_events is 10850, acc is 0.7069124423963133, rmse is 0.9227589645238329
# 2026-01-01 15:00:45,593 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 15 (test) ]: test loglike is -0.8924342181288712, num_events is 10817, acc is 0.7021355274105574, rmse is 0.9189247483102214
# 2026-01-01 15:00:45,595 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8873 (updated at epoch-15), best updated at this epoch
# 2026-01-01 15:00:46,004 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 16 (train) ]: train loglike is -0.8827059223635806, num_events is 32620
# 2026-01-01 15:00:46,280 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 16 (valid) ]:  valid loglike is -0.8827106134792627, num_events is 10850, acc is 0.7065437788018433, rmse is 0.929265678895618
# 2026-01-01 15:00:46,548 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 16 (test) ]: test loglike is -0.8876159560760839, num_events is 10817, acc is 0.7041693630396598, rmse is 0.9326283233812327
# 2026-01-01 15:00:46,549 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8827 (updated at epoch-16), best updated at this epoch
# 2026-01-01 15:00:46,964 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 17 (train) ]: train loglike is -0.8777076856845877, num_events is 32620
# 2026-01-01 15:00:47,239 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 17 (valid) ]:  valid loglike is -0.8783435339861752, num_events is 10850, acc is 0.707741935483871, rmse is 0.9322227045706921
# 2026-01-01 15:00:47,502 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 17 (test) ]: test loglike is -0.8831163836438014, num_events is 10817, acc is 0.7042618101137099, rmse is 0.9328750831464186
# 2026-01-01 15:00:47,503 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8783 (updated at epoch-17), best updated at this epoch
# 2026-01-01 15:00:47,914 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 18 (train) ]: train loglike is -0.8729803088835454, num_events is 32620
# 2026-01-01 15:00:48,193 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 18 (valid) ]:  valid loglike is -0.8741180335541474, num_events is 10850, acc is 0.7086635944700461, rmse is 0.9213927543476965
# 2026-01-01 15:00:48,453 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 18 (test) ]: test loglike is -0.8788321298361376, num_events is 10817, acc is 0.7046315984099103, rmse is 0.9307751852109096
# 2026-01-01 15:00:48,454 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8741 (updated at epoch-18), best updated at this epoch
# 2026-01-01 15:00:48,859 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 19 (train) ]: train loglike is -0.8684553248103157, num_events is 32620
# 2026-01-01 15:00:49,130 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 19 (valid) ]:  valid loglike is -0.8700012600806452, num_events is 10850, acc is 0.7075576036866359, rmse is 0.9330833464702334
# 2026-01-01 15:00:49,393 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 19 (test) ]: test loglike is -0.8746951232723953, num_events is 10817, acc is 0.7052787279282611, rmse is 0.9618549495358801
# 2026-01-01 15:00:49,394 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8700 (updated at epoch-19), best updated at this epoch
# 2026-01-01 15:00:49,807 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 20 (train) ]: train loglike is -0.8641025264887339, num_events is 32620
# 2026-01-01 15:00:50,082 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 20 (valid) ]:  valid loglike is -0.8660473070276498, num_events is 10850, acc is 0.7078341013824885, rmse is 0.9328813599243423
# 2026-01-01 15:00:50,345 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 20 (test) ]: test loglike is -0.8707185448830544, num_events is 10817, acc is 0.7054636220763613, rmse is 0.9453435328426569
# 2026-01-01 15:00:50,346 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8660 (updated at epoch-20), best updated at this epoch
# 2026-01-01 15:00:50,750 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 21 (train) ]: train loglike is -0.8599650988178265, num_events is 32620
# 2026-01-01 15:00:51,022 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 21 (valid) ]:  valid loglike is -0.8623570708525345, num_events is 10850, acc is 0.7066359447004609, rmse is 0.949313925749851
# 2026-01-01 15:00:51,284 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 21 (test) ]: test loglike is -0.8669656811904872, num_events is 10817, acc is 0.7053711750023112, rmse is 0.9286129956058666
# 2026-01-01 15:00:51,285 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8624 (updated at epoch-21), best updated at this epoch
# 2026-01-01 15:00:51,682 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 22 (train) ]: train loglike is -0.8561262681541232, num_events is 32620
# 2026-01-01 15:00:51,951 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 22 (valid) ]:  valid loglike is -0.8590601598502304, num_events is 10850, acc is 0.7072811059907834, rmse is 0.9510314709403792
# 2026-01-01 15:00:52,212 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 22 (test) ]: test loglike is -0.8635505562713783, num_events is 10817, acc is 0.7057409632985115, rmse is 0.9662653574697921
# 2026-01-01 15:00:52,213 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8591 (updated at epoch-22), best updated at this epoch
# 2026-01-01 15:00:52,615 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 23 (train) ]: train loglike is -0.8526981206410944, num_events is 32620
# 2026-01-01 15:00:52,889 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 23 (valid) ]:  valid loglike is -0.85626710109447, num_events is 10850, acc is 0.7074654377880184, rmse is 0.9768672144234639
# 2026-01-01 15:00:53,155 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 23 (test) ]: test loglike is -0.8605982084045947, num_events is 10817, acc is 0.7050013867061108, rmse is 0.9740677001514619
# 2026-01-01 15:00:53,156 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8563 (updated at epoch-23), best updated at this epoch
# 2026-01-01 15:00:53,566 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 24 (train) ]: train loglike is -0.8497684331410944, num_events is 32620
# 2026-01-01 15:00:53,839 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 24 (valid) ]:  valid loglike is -0.8539482826900922, num_events is 10850, acc is 0.7075576036866359, rmse is 0.9655079431385242
# 2026-01-01 15:00:54,100 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 24 (test) ]: test loglike is -0.8581116168415457, num_events is 10817, acc is 0.7056485162244615, rmse is 0.9869529129702356
# 2026-01-01 15:00:54,101 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8539 (updated at epoch-24), best updated at this epoch
# 2026-01-01 15:00:54,503 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 25 (train) ]: train loglike is -0.8472886319981989, num_events is 32620
# 2026-01-01 15:00:54,771 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 25 (valid) ]:  valid loglike is -0.8519813868087558, num_events is 10850, acc is 0.7067281105990784, rmse is 0.9842545511997162
# 2026-01-01 15:00:55,033 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 25 (test) ]: test loglike is -0.8559976122654156, num_events is 10817, acc is 0.7066654340390127, rmse is 1.0060383568625582
# 2026-01-01 15:00:55,034 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8520 (updated at epoch-25), best updated at this epoch
# 2026-01-01 15:00:55,440 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 26 (train) ]: train loglike is -0.8451391766218961, num_events is 32620
# 2026-01-01 15:00:55,712 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 26 (valid) ]:  valid loglike is -0.8503350014400922, num_events is 10850, acc is 0.7082027649769586, rmse is 0.9804204635995765
# 2026-01-01 15:00:55,976 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 26 (test) ]: test loglike is -0.8542358815984099, num_events is 10817, acc is 0.7055560691504114, rmse is 1.0013673069834788
# 2026-01-01 15:00:55,978 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8503 (updated at epoch-26), best updated at this epoch
# 2026-01-01 15:00:56,381 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 27 (train) ]: train loglike is -0.8433014159258124, num_events is 32620
# 2026-01-01 15:00:56,657 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 27 (valid) ]:  valid loglike is -0.8490417986751152, num_events is 10850, acc is 0.7072811059907834, rmse is 0.9886226851458569
# 2026-01-01 15:00:56,920 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 27 (test) ]: test loglike is -0.8528517936176851, num_events is 10817, acc is 0.7067578811130628, rmse is 1.000743541124865
# 2026-01-01 15:00:56,921 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8490 (updated at epoch-27), best updated at this epoch
# 2026-01-01 15:00:57,321 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 28 (train) ]: train loglike is -0.8418178612143623, num_events is 32620
# 2026-01-01 15:00:57,591 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 28 (valid) ]:  valid loglike is -0.8480536254320277, num_events is 10850, acc is 0.7075576036866359, rmse is 1.0009248118493188
# 2026-01-01 15:00:57,850 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 28 (test) ]: test loglike is -0.8517850410522788, num_events is 10817, acc is 0.7050013867061108, rmse is 0.9885444208278121
# 2026-01-01 15:00:57,851 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8481 (updated at epoch-28), best updated at this epoch
# 2026-01-01 15:00:58,252 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 29 (train) ]: train loglike is -0.8406546082253985, num_events is 32620
# 2026-01-01 15:00:58,524 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 29 (valid) ]:  valid loglike is -0.8472747155817972, num_events is 10850, acc is 0.7082027649769586, rmse is 0.9904760065747953
# 2026-01-01 15:00:58,787 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 29 (test) ]: test loglike is -0.8509321626259592, num_events is 10817, acc is 0.7041693630396598, rmse is 0.9994419956315089
# 2026-01-01 15:00:58,788 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8473 (updated at epoch-29), best updated at this epoch
# 2026-01-01 15:00:59,189 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 30 (train) ]: train loglike is -0.8397314842312998, num_events is 32620
# 2026-01-01 15:00:59,459 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 30 (valid) ]:  valid loglike is -0.8466496255760368, num_events is 10850, acc is 0.7082027649769586, rmse is 0.9857021292556986
# 2026-01-01 15:00:59,722 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 30 (test) ]: test loglike is -0.8502381776081631, num_events is 10817, acc is 0.7052787279282611, rmse is 1.0125944227648198
# 2026-01-01 15:00:59,724 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8466 (updated at epoch-30), best updated at this epoch
# 2026-01-01 15:01:00,136 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 31 (train) ]: train loglike is -0.838996547603081, num_events is 32620
# 2026-01-01 15:01:00,405 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 31 (valid) ]:  valid loglike is -0.8461442432315668, num_events is 10850, acc is 0.7074654377880184, rmse is 0.9838734459482853
# 2026-01-01 15:01:00,666 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 31 (test) ]: test loglike is -0.84967419628825, num_events is 10817, acc is 0.705186280854211, rmse is 1.009702031172716
# 2026-01-01 15:01:00,667 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8461 (updated at epoch-31), best updated at this epoch
# 2026-01-01 15:01:01,080 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 32 (train) ]: train loglike is -0.8384075564741723, num_events is 32620
# 2026-01-01 15:01:01,355 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 32 (valid) ]:  valid loglike is -0.8457063652073733, num_events is 10850, acc is 0.7078341013824885, rmse is 1.0052622363160273
# 2026-01-01 15:01:01,620 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 32 (test) ]: test loglike is -0.8491912867188223, num_events is 10817, acc is 0.7059258574466118, rmse is 1.015911553548639
# 2026-01-01 15:01:01,622 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8457 (updated at epoch-32), best updated at this epoch
# 2026-01-01 15:01:02,050 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 33 (train) ]: train loglike is -0.8379045160177805, num_events is 32620
# 2026-01-01 15:01:02,326 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 33 (valid) ]:  valid loglike is -0.8452867583525345, num_events is 10850, acc is 0.7086635944700461, rmse is 1.0092001311756225
# 2026-01-01 15:01:02,591 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 33 (test) ]: test loglike is -0.8487399752704077, num_events is 10817, acc is 0.705186280854211, rmse is 1.0092976550555388
# 2026-01-01 15:01:02,592 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8453 (updated at epoch-33), best updated at this epoch
# 2026-01-01 15:01:02,994 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 34 (train) ]: train loglike is -0.837435080448153, num_events is 32620
# 2026-01-01 15:01:03,265 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 34 (valid) ]:  valid loglike is -0.8449004536290322, num_events is 10850, acc is 0.7081105990783411, rmse is 1.0162777098319007
# 2026-01-01 15:01:03,525 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 34 (test) ]: test loglike is -0.8483327206307202, num_events is 10817, acc is 0.7031524452251087, rmse is 1.01174995083791
# 2026-01-01 15:01:03,526 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8449 (updated at epoch-34), best updated at this epoch
# 2026-01-01 15:01:03,925 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 35 (train) ]: train loglike is -0.8370032763641937, num_events is 32620
# 2026-01-01 15:01:04,193 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 35 (valid) ]:  valid loglike is -0.8445912838421659, num_events is 10850, acc is 0.7080184331797235, rmse is 1.011251852917778
# 2026-01-01 15:01:04,456 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 35 (test) ]: test loglike is -0.8480088850305075, num_events is 10817, acc is 0.7050013867061108, rmse is 1.012315757909684
# 2026-01-01 15:01:04,457 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8446 (updated at epoch-35), best updated at this epoch
# 2026-01-01 15:01:04,856 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 36 (train) ]: train loglike is -0.8366319610764101, num_events is 32620
# 2026-01-01 15:01:05,126 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 36 (valid) ]:  valid loglike is -0.8443609591013825, num_events is 10850, acc is 0.7080184331797235, rmse is 1.004887675268735
# 2026-01-01 15:01:05,384 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 36 (test) ]: test loglike is -0.8477715380015254, num_events is 10817, acc is 0.7040769159656097, rmse is 1.0005370015342827
# 2026-01-01 15:01:05,385 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8444 (updated at epoch-36), best updated at this epoch
# 2026-01-01 15:01:05,783 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 37 (train) ]: train loglike is -0.8363204609901901, num_events is 32620
# 2026-01-01 15:01:06,050 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 37 (valid) ]:  valid loglike is -0.8441677167338709, num_events is 10850, acc is 0.7083870967741935, rmse is 0.9913613961830665
# 2026-01-01 15:01:06,315 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 37 (test) ]: test loglike is -0.847592150954516, num_events is 10817, acc is 0.70435425718776, rmse is 1.0020242257841054
# 2026-01-01 15:01:06,316 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8442 (updated at epoch-37), best updated at this epoch
# 2026-01-01 15:01:06,736 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 38 (train) ]: train loglike is -0.8360568010902054, num_events is 32620
# 2026-01-01 15:01:07,006 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 38 (valid) ]:  valid loglike is -0.8439512528801844, num_events is 10850, acc is 0.7083870967741935, rmse is 1.01054036794874
# 2026-01-01 15:01:07,268 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 38 (test) ]: test loglike is -0.8474179098872145, num_events is 10817, acc is 0.7038920218175094, rmse is 0.9859293703374324
# 2026-01-01 15:01:07,269 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8440 (updated at epoch-38), best updated at this epoch
# 2026-01-01 15:01:07,671 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 39 (train) ]: train loglike is -0.8358120991363619, num_events is 32620
# 2026-01-01 15:01:07,946 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 39 (valid) ]:  valid loglike is -0.843704367079493, num_events is 10850, acc is 0.7094009216589862, rmse is 1.0028522575822583
# 2026-01-01 15:01:08,211 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 39 (test) ]: test loglike is -0.847234640785338, num_events is 10817, acc is 0.703429786447259, rmse is 1.0062069820562856
# 2026-01-01 15:01:08,212 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8437 (updated at epoch-39), best updated at this epoch
# 2026-01-01 15:01:08,617 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 40 (train) ]: train loglike is -0.8355658703680641, num_events is 32620
# 2026-01-01 15:01:08,885 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 40 (valid) ]:  valid loglike is -0.8434611715149769, num_events is 10850, acc is 0.7076497695852535, rmse is 0.9969561404663497
# 2026-01-01 15:01:09,155 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 40 (test) ]: test loglike is -0.8470617539232227, num_events is 10817, acc is 0.7052787279282611, rmse is 0.9988816040578262
# 2026-01-01 15:01:09,156 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8435 (updated at epoch-40), best updated at this epoch
# 2026-01-01 15:01:09,553 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 41 (train) ]: train loglike is -0.8353151360002491, num_events is 32620
# 2026-01-01 15:01:09,822 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 41 (valid) ]:  valid loglike is -0.8432434475806452, num_events is 10850, acc is 0.7094930875576037, rmse is 0.9967631300330394
# 2026-01-01 15:01:10,082 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 41 (test) ]: test loglike is -0.8469087287371729, num_events is 10817, acc is 0.7041693630396598, rmse is 0.989262590036426
# 2026-01-01 15:01:10,083 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8432 (updated at epoch-41), best updated at this epoch
# 2026-01-01 15:01:10,484 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 42 (train) ]: train loglike is -0.8350731359092389, num_events is 32620
# 2026-01-01 15:01:10,763 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 42 (valid) ]:  valid loglike is -0.8430443548387097, num_events is 10850, acc is 0.7086635944700461, rmse is 0.9943308980405103
# 2026-01-01 15:01:11,031 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 42 (test) ]: test loglike is -0.8467596758863363, num_events is 10817, acc is 0.7048164925580105, rmse is 0.9923890521809554
# 2026-01-01 15:01:11,032 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8430 (updated at epoch-42), best updated at this epoch
# 2026-01-01 15:01:11,440 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 43 (train) ]: train loglike is -0.8348419357851778, num_events is 32620
# 2026-01-01 15:01:11,712 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 43 (valid) ]:  valid loglike is -0.8428803643433179, num_events is 10850, acc is 0.7094009216589862, rmse is 0.9924943280988643
# 2026-01-01 15:01:11,972 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 43 (test) ]: test loglike is -0.8466217275180272, num_events is 10817, acc is 0.703429786447259, rmse is 1.0114084951505287
# 2026-01-01 15:01:11,974 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8429 (updated at epoch-43), best updated at this epoch
# 2026-01-01 15:01:12,385 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 44 (train) ]: train loglike is -0.8346268270879637, num_events is 32620
# 2026-01-01 15:01:12,659 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 44 (valid) ]:  valid loglike is -0.8427603866647465, num_events is 10850, acc is 0.7095852534562211, rmse is 1.0008776949770495
# 2026-01-01 15:01:12,922 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 44 (test) ]: test loglike is -0.8465046339095867, num_events is 10817, acc is 0.7050938337801609, rmse is 1.0094531709505077
# 2026-01-01 15:01:12,924 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8428 (updated at epoch-44), best updated at this epoch
# 2026-01-01 15:01:13,335 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 45 (train) ]: train loglike is -0.83443131250958, num_events is 32620
# 2026-01-01 15:01:13,607 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 45 (valid) ]:  valid loglike is -0.8426388788882488, num_events is 10850, acc is 0.7075576036866359, rmse is 0.988960904244447
# 2026-01-01 15:01:13,869 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 45 (test) ]: test loglike is -0.8463776997434593, num_events is 10817, acc is 0.703429786447259, rmse is 1.0001521799052873
# 2026-01-01 15:01:13,871 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8426 (updated at epoch-45), best updated at this epoch
# 2026-01-01 15:01:14,306 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 46 (train) ]: train loglike is -0.8342413588289394, num_events is 32620
# 2026-01-01 15:01:14,585 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 46 (valid) ]:  valid loglike is -0.8424792086693549, num_events is 10850, acc is 0.7100460829493087, rmse is 1.0037287715631362
# 2026-01-01 15:01:14,846 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 46 (test) ]: test loglike is -0.8462156465228344, num_events is 10817, acc is 0.7049089396320607, rmse is 1.0042454597808317
# 2026-01-01 15:01:14,847 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8425 (updated at epoch-46), best updated at this epoch
# 2026-01-01 15:01:15,268 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 47 (train) ]: train loglike is -0.8340385619443593, num_events is 32620
# 2026-01-01 15:01:15,546 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 47 (valid) ]:  valid loglike is -0.8423165682603687, num_events is 10850, acc is 0.7099539170506912, rmse is 0.983710060424159
# 2026-01-01 15:01:15,806 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 47 (test) ]: test loglike is -0.846053773862901, num_events is 10817, acc is 0.7054636220763613, rmse is 0.9981778354350838
# 2026-01-01 15:01:15,807 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8423 (updated at epoch-47), best updated at this epoch
# 2026-01-01 15:01:16,208 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 48 (train) ]: train loglike is -0.8338314390854921, num_events is 32620
# 2026-01-01 15:01:16,480 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 48 (valid) ]:  valid loglike is -0.8421702188940092, num_events is 10850, acc is 0.7105069124423963, rmse is 1.0003771491578834
# 2026-01-01 15:01:16,746 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 48 (test) ]: test loglike is -0.8459077002634742, num_events is 10817, acc is 0.705186280854211, rmse is 0.9846446891966063
# 2026-01-01 15:01:16,747 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8422 (updated at epoch-48), best updated at this epoch
# 2026-01-01 15:01:17,145 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 49 (train) ]: train loglike is -0.8336306779535178, num_events is 32620
# 2026-01-01 15:01:17,417 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 49 (valid) ]:  valid loglike is -0.8420254896313364, num_events is 10850, acc is 0.7092165898617512, rmse is 1.0056947289262832
# 2026-01-01 15:01:17,685 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 49 (test) ]: test loglike is -0.8457600016178238, num_events is 10817, acc is 0.7042618101137099, rmse is 0.9903573737205917
# 2026-01-01 15:01:17,686 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8420 (updated at epoch-49), best updated at this epoch
# 2026-01-01 15:01:18,087 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 50 (train) ]: train loglike is -0.8334344373898298, num_events is 32620
# 2026-01-01 15:01:18,357 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 50 (valid) ]:  valid loglike is -0.8418978614631336, num_events is 10850, acc is 0.711705069124424, rmse is 0.9993784943838787
# 2026-01-01 15:01:18,622 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 50 (test) ]: test loglike is -0.8456238588564297, num_events is 10817, acc is 0.7047240454839604, rmse is 0.9913995087065212
# 2026-01-01 15:01:18,623 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8419 (updated at epoch-50), best updated at this epoch
# 2026-01-01 15:01:19,034 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 51 (train) ]: train loglike is -0.8332440570992681, num_events is 32620
# 2026-01-01 15:01:19,302 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 51 (valid) ]:  valid loglike is -0.8417711333525346, num_events is 10850, acc is 0.7089400921658986, rmse is 1.0026381375889093
# 2026-01-01 15:01:19,568 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 51 (test) ]: test loglike is -0.8454870841326153, num_events is 10817, acc is 0.7074050106314135, rmse is 0.9824400604348631
# 2026-01-01 15:01:19,569 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8418 (updated at epoch-51), best updated at this epoch
# 2026-01-01 15:01:19,989 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 52 (train) ]: train loglike is -0.8330502938668761, num_events is 32620
# 2026-01-01 15:01:20,269 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 52 (valid) ]:  valid loglike is -0.8416067828341014, num_events is 10850, acc is 0.7097695852534562, rmse is 1.009236498352159
# 2026-01-01 15:01:20,538 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 52 (test) ]: test loglike is -0.8453160028774152, num_events is 10817, acc is 0.7052787279282611, rmse is 0.9983259485568822
# 2026-01-01 15:01:20,539 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8416 (updated at epoch-52), best updated at this epoch
# 2026-01-01 15:01:20,959 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 53 (train) ]: train loglike is -0.8328365099057327, num_events is 32620
# 2026-01-01 15:01:21,236 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 53 (valid) ]:  valid loglike is -0.8414241611463134, num_events is 10850, acc is 0.7114285714285714, rmse is 1.0091353874820674
# 2026-01-01 15:01:21,503 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 53 (test) ]: test loglike is -0.8451317406917352, num_events is 10817, acc is 0.7055560691504114, rmse is 1.0117277860068823
# 2026-01-01 15:01:21,505 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8414 (updated at epoch-53), best updated at this epoch
# 2026-01-01 15:01:21,926 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 54 (train) ]: train loglike is -0.8326033563572961, num_events is 32620
# 2026-01-01 15:01:22,205 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 54 (valid) ]:  valid loglike is -0.8412091373847926, num_events is 10850, acc is 0.7100460829493087, rmse is 1.003212155324101
# 2026-01-01 15:01:22,471 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 54 (test) ]: test loglike is -0.8449193110381806, num_events is 10817, acc is 0.7062956457428122, rmse is 0.9845090516307337
# 2026-01-01 15:01:22,472 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8412 (updated at epoch-54), best updated at this epoch
# 2026-01-01 15:01:22,886 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 55 (train) ]: train loglike is -0.8323422860543761, num_events is 32620
# 2026-01-01 15:01:23,166 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 55 (valid) ]:  valid loglike is -0.8409431703629032, num_events is 10850, acc is 0.7100460829493087, rmse is 0.9883372581532212
# 2026-01-01 15:01:23,432 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 55 (test) ]: test loglike is -0.8446586716799944, num_events is 10817, acc is 0.7074974577054636, rmse is 1.001307375191324
# 2026-01-01 15:01:23,434 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8409 (updated at epoch-55), best updated at this epoch
# 2026-01-01 15:01:23,847 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 56 (train) ]: train loglike is -0.8320304267176962, num_events is 32620
# 2026-01-01 15:01:24,121 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 56 (valid) ]:  valid loglike is -0.8405892677131337, num_events is 10850, acc is 0.7082027649769586, rmse is 0.9954821074491778
# 2026-01-01 15:01:24,399 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 56 (test) ]: test loglike is -0.8443109117881575, num_events is 10817, acc is 0.7054636220763613, rmse is 0.9947552246438447
# 2026-01-01 15:01:24,400 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8406 (updated at epoch-56), best updated at this epoch
# 2026-01-01 15:01:24,808 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 57 (train) ]: train loglike is -0.8316211206937845, num_events is 32620
# 2026-01-01 15:01:25,092 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 57 (valid) ]:  valid loglike is -0.8400543634792627, num_events is 10850, acc is 0.7102304147465438, rmse is 0.986326819442648
# 2026-01-01 15:01:25,357 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 57 (test) ]: test loglike is -0.8437857510169178, num_events is 10817, acc is 0.7060183045206619, rmse is 1.0027413837496433
# 2026-01-01 15:01:25,358 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8401 (updated at epoch-57), best updated at this epoch
# 2026-01-01 15:01:25,762 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 58 (train) ]: train loglike is -0.8310356846475514, num_events is 32620
# 2026-01-01 15:01:26,036 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 58 (valid) ]:  valid loglike is -0.8392592525921659, num_events is 10850, acc is 0.7103225806451613, rmse is 1.0089400180642538
# 2026-01-01 15:01:26,300 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 58 (test) ]: test loglike is -0.8430327226529999, num_events is 10817, acc is 0.7059258574466118, rmse is 0.9907145202246139
# 2026-01-01 15:01:26,301 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8393 (updated at epoch-58), best updated at this epoch
# 2026-01-01 15:01:26,704 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 59 (train) ]: train loglike is -0.830240326582618, num_events is 32620
# 2026-01-01 15:01:26,973 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 59 (valid) ]:  valid loglike is -0.8382852102534563, num_events is 10850, acc is 0.7125345622119815, rmse is 0.991999760232481
# 2026-01-01 15:01:27,232 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 59 (test) ]: test loglike is -0.8420521878177868, num_events is 10817, acc is 0.7050938337801609, rmse is 0.9990672482221042
# ...
# 2026-01-01 15:12:33,559 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 180 (valid) ]:  valid loglike is -0.890354262672811, num_events is 10850, acc is 0.6260829493087557, rmse is 0.8476607451765142
# 2026-01-01 15:12:34,546 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 180 (test) ]: test loglike is -0.8965275290052694, num_events is 10817, acc is 0.6107053711750023, rmse is 0.8463700201222502
# 2026-01-01 15:12:34,548 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8904 (updated at epoch-180), best updated at this epoch
# 2026-01-01 15:12:34,851 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 181 (train) ]: train loglike is -0.8870449494175352, num_events is 32620
# 2026-01-01 15:12:35,895 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 181 (valid) ]:  valid loglike is -0.890171640985023, num_events is 10850, acc is 0.6253456221198157, rmse is 0.8448826761227031
# 2026-01-01 15:12:36,879 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 181 (test) ]: test loglike is -0.8963336068225941, num_events is 10817, acc is 0.6109827123971526, rmse is 0.8420866651290408
# 2026-01-01 15:12:36,880 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8902 (updated at epoch-181), best updated at this epoch
# 2026-01-01 15:12:37,177 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 182 (train) ]: train loglike is -0.8868077243638872, num_events is 32620
# 2026-01-01 15:12:38,221 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 182 (valid) ]:  valid loglike is -0.8899857790898618, num_events is 10850, acc is 0.6265437788018433, rmse is 0.8468154666842663
# 2026-01-01 15:12:39,204 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 182 (test) ]: test loglike is -0.8961365248278174, num_events is 10817, acc is 0.6096884533604512, rmse is 0.8413803744392697
# 2026-01-01 15:12:39,206 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8900 (updated at epoch-182), best updated at this epoch
# 2026-01-01 15:12:39,505 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 183 (train) ]: train loglike is -0.8865664278050276, num_events is 32620
# 2026-01-01 15:12:40,546 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 183 (valid) ]:  valid loglike is -0.8897967669930875, num_events is 10850, acc is 0.6272811059907835, rmse is 0.8294233471524044
# 2026-01-01 15:12:41,555 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 183 (test) ]: test loglike is -0.8959363733012851, num_events is 10817, acc is 0.6100582416566516, rmse is 0.8496374048524472
# 2026-01-01 15:12:41,557 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8898 (updated at epoch-183), best updated at this epoch
# 2026-01-01 15:12:41,868 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 184 (train) ]: train loglike is -0.8863212393661863, num_events is 32620
# 2026-01-01 15:12:42,928 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 184 (valid) ]:  valid loglike is -0.8896045146889401, num_events is 10850, acc is 0.6297695852534563, rmse is 0.8359149493388097
# 2026-01-01 15:12:43,914 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 184 (test) ]: test loglike is -0.8957330619626513, num_events is 10817, acc is 0.6072848294351484, rmse is 0.8417044206860832
# 2026-01-01 15:12:43,915 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8896 (updated at epoch-184), best updated at this epoch
# 2026-01-01 15:12:44,213 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 185 (train) ]: train loglike is -0.8860721291098252, num_events is 32620
# 2026-01-01 15:12:45,258 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 185 (valid) ]:  valid loglike is -0.8894090221774194, num_events is 10850, acc is 0.6250691244239631, rmse is 0.8339785492221273
# 2026-01-01 15:12:46,261 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 185 (test) ]: test loglike is -0.8955266810922622, num_events is 10817, acc is 0.6092262179902006, rmse is 0.8400858801067773
# 2026-01-01 15:12:46,263 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8894 (updated at epoch-185), best updated at this epoch
# 2026-01-01 15:12:46,559 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 186 (train) ]: train loglike is -0.8858190371608675, num_events is 32620
# 2026-01-01 15:12:47,596 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 186 (valid) ]:  valid loglike is -0.8892101094470046, num_events is 10850, acc is 0.6258986175115208, rmse is 0.8300708758197981
# 2026-01-01 15:12:48,599 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 186 (test) ]: test loglike is -0.8953173209704631, num_events is 10817, acc is 0.6067301469908477, rmse is 0.8347423480368369
# 2026-01-01 15:12:48,601 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8892 (updated at epoch-186), best updated at this epoch
# 2026-01-01 15:12:48,899 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 187 (train) ]: train loglike is -0.8855620683006974, num_events is 32620
# 2026-01-01 15:12:49,947 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 187 (valid) ]:  valid loglike is -0.8890075964861751, num_events is 10850, acc is 0.6269124423963134, rmse is 0.8350216579086526
# 2026-01-01 15:12:50,928 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 187 (test) ]: test loglike is -0.8951050718776, num_events is 10817, acc is 0.6062679116205972, rmse is 0.8356175261491765
# 2026-01-01 15:12:50,929 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8890 (updated at epoch-187), best updated at this epoch
# 2026-01-01 15:12:51,223 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 188 (train) ]: train loglike is -0.8853011925917765, num_events is 32620
# 2026-01-01 15:12:52,259 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 188 (valid) ]:  valid loglike is -0.8888016633064516, num_events is 10850, acc is 0.6220276497695852, rmse is 0.8353342919030373
# 2026-01-01 15:12:53,245 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 188 (test) ]: test loglike is -0.8948898435333271, num_events is 10817, acc is 0.6059905703984468, rmse is 0.843562500491673
# 2026-01-01 15:12:53,247 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8888 (updated at epoch-188), best updated at this epoch
# 2026-01-01 15:12:53,554 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 189 (train) ]: train loglike is -0.8850363800965665, num_events is 32620
# 2026-01-01 15:12:54,608 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 189 (valid) ]:  valid loglike is -0.8885921298963133, num_events is 10850, acc is 0.6221198156682027, rmse is 0.8308793172250803
# 2026-01-01 15:12:55,602 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 189 (test) ]: test loglike is -0.8946718164983359, num_events is 10817, acc is 0.6058056762503466, rmse is 0.8449187756830328
# 2026-01-01 15:12:55,603 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8886 (updated at epoch-189), best updated at this epoch
# 2026-01-01 15:12:55,904 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 190 (train) ]: train loglike is -0.8847677805027591, num_events is 32620
# 2026-01-01 15:12:56,950 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 190 (valid) ]:  valid loglike is -0.88837890625, num_events is 10850, acc is 0.6227649769585254, rmse is 0.8290721607745102
# 2026-01-01 15:12:57,938 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 190 (test) ]: test loglike is -0.8944510810529722, num_events is 10817, acc is 0.6032171581769437, rmse is 0.8346455898720628
# 2026-01-01 15:12:57,939 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8884 (updated at epoch-190), best updated at this epoch
# 2026-01-01 15:12:58,237 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 191 (train) ]: train loglike is -0.8844954387166616, num_events is 32620
# 2026-01-01 15:12:59,283 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 191 (valid) ]:  valid loglike is -0.8881619023617512, num_events is 10850, acc is 0.6207373271889401, rmse is 0.8348840006027379
# 2026-01-01 15:13:00,277 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 191 (test) ]: test loglike is -0.8942277274775816, num_events is 10817, acc is 0.6054358879541463, rmse is 0.8382711921451279
# 2026-01-01 15:13:00,279 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8882 (updated at epoch-191), best updated at this epoch
# 2026-01-01 15:13:00,576 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 192 (train) ]: train loglike is -0.8842193846758124, num_events is 32620
# 2026-01-01 15:13:01,611 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 192 (valid) ]:  valid loglike is -0.8879412082373271, num_events is 10850, acc is 0.6213824884792627, rmse is 0.8238318612635662
# 2026-01-01 15:13:02,589 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 192 (test) ]: test loglike is -0.8940016654918185, num_events is 10817, acc is 0.6015531108440418, rmse is 0.8378954666740898
# 2026-01-01 15:13:02,591 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8879 (updated at epoch-192), best updated at this epoch
# 2026-01-01 15:13:02,889 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 193 (train) ]: train loglike is -0.883939663286519, num_events is 32620
# 2026-01-01 15:13:03,924 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 193 (valid) ]:  valid loglike is -0.8877167338709677, num_events is 10850, acc is 0.6156682027649769, rmse is 0.8250831530119829
# 2026-01-01 15:13:04,904 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 193 (test) ]: test loglike is -0.89377316593672, num_events is 10817, acc is 0.5997041693630396, rmse is 0.8301374227225138
# 2026-01-01 15:13:04,906 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8877 (updated at epoch-193), best updated at this epoch
# 2026-01-01 15:13:05,205 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 194 (train) ]: train loglike is -0.8836564990803188, num_events is 32620
# 2026-01-01 15:13:06,256 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 194 (valid) ]:  valid loglike is -0.8874884792626728, num_events is 10850, acc is 0.6167741935483871, rmse is 0.8244425103431716
# 2026-01-01 15:13:07,268 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 194 (test) ]: test loglike is -0.8935422288122862, num_events is 10817, acc is 0.5968383100674863, rmse is 0.8304246310982318
# 2026-01-01 15:13:07,269 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8875 (updated at epoch-194), best updated at this epoch
# 2026-01-01 15:13:07,569 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 195 (train) ]: train loglike is -0.8833698471509044, num_events is 32620
# 2026-01-01 15:13:08,603 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 195 (valid) ]:  valid loglike is -0.8872565344182027, num_events is 10850, acc is 0.612073732718894, rmse is 0.8313410209271496
# 2026-01-01 15:13:09,587 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 195 (test) ]: test loglike is -0.8933088541185171, num_events is 10817, acc is 0.5959138393269853, rmse is 0.8321572246188871
# 2026-01-01 15:13:09,588 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8873 (updated at epoch-195), best updated at this epoch
# 2026-01-01 15:13:09,888 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 196 (train) ]: train loglike is -0.883079932029813, num_events is 32620
# 2026-01-01 15:13:10,956 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 196 (valid) ]:  valid loglike is -0.8870210793490784, num_events is 10850, acc is 0.611889400921659, rmse is 0.8265792685862564
# 2026-01-01 15:13:11,940 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 196 (test) ]: test loglike is -0.8930734029767958, num_events is 10817, acc is 0.5926781917352316, rmse is 0.8359781946940803
# 2026-01-01 15:13:11,942 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8870 (updated at epoch-196), best updated at this epoch
# 2026-01-01 15:13:12,240 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 197 (train) ]: train loglike is -0.8827869183735055, num_events is 32620
# 2026-01-01 15:13:13,299 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 197 (valid) ]:  valid loglike is -0.8867822940668203, num_events is 10850, acc is 0.6092165898617512, rmse is 0.8310703392323014
# 2026-01-01 15:13:14,302 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 197 (test) ]: test loglike is -0.8928358753871222, num_events is 10817, acc is 0.5894425441434779, rmse is 0.8360972620245358
# 2026-01-01 15:13:14,303 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8868 (updated at epoch-197), best updated at this epoch
# 2026-01-01 15:13:14,602 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 198 (train) ]: train loglike is -0.8824910307135193, num_events is 32620
# 2026-01-01 15:13:15,644 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 198 (valid) ]:  valid loglike is -0.88654053859447, num_events is 10850, acc is 0.6078341013824885, rmse is 0.8214827230411544
# 2026-01-01 15:13:16,625 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 198 (test) ]: test loglike is -0.8925963616298419, num_events is 10817, acc is 0.5868540260700749, rmse is 0.8312911724029187
# 2026-01-01 15:13:16,627 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8865 (updated at epoch-198), best updated at this epoch
# 2026-01-01 15:13:16,930 - tpp_runner.py[pid:1768;line:96:_train_model] - INFO: [ Epoch 199 (train) ]: train loglike is -0.8821924037687768, num_events is 32620
# 2026-01-01 15:13:17,994 - tpp_runner.py[pid:1768;line:107:_train_model] - INFO: [ Epoch 199 (valid) ]:  valid loglike is -0.8862961729550691, num_events is 10850, acc is 0.6052534562211982, rmse is 0.823999626254066
# 2026-01-01 15:13:19,000 - tpp_runner.py[pid:1768;line:122:_train_model] - INFO: [ Epoch 199 (test) ]: test loglike is -0.8923550422656467, num_events is 10817, acc is 0.5880558380327263, rmse is 0.831632355359336
# 2026-01-01 15:13:19,001 - tpp_runner.py[pid:1768;line:124:_train_model] - CRITICAL: current best loglike on valid set is -0.8863 (updated at epoch-199), best updated at this epoch
# 2026-01-01 15:13:19,003 - base_runner.py[pid:1768;line:110:train] - INFO: End AttNHP train! Cost time: 7.842m
# ✓ AttNHP on nonstationary_hawkes completed successfully!
#   - Log-Likelihood: -0.8924
#   - Accuracy: 0.5881
#   - RMSE: 0.8316
#
# ======================================================================
# ✓ AttNHP completed on all datasets
#   - Time: 7.9 minutes
#   - Successful: 1/1
#   - Failed: 0/1
#   - Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/AttNHP_results.csv
# ======================================================================
# ✓ GPU memory cleared for next model

# %% [markdown]
# ## Save Model Results

# %% [markdown]
# ### Function Definition

# %%
import pandas as pd
from typing import Optional, List

def format_results_table(
    results_df: pd.DataFrame,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    log_likelihood_col: str = 'log_likelihood',
    rmse_col: str = 'rmse',
    accuracy_col: str = 'accuracy',
    type_error_from_accuracy: bool = True,
    format_type: str = 'combined'
) -> pd.DataFrame:
    """
    Parameters
    ----------
    results_df : pd.DataFrame
        DataFrame containing columns: 'model', 'dataset', 'log_likelihood', 'rmse', 'accuracy'
    models : List[str], optional
        List of model names to include. If None, uses all models in results_df
    datasets : List[str], optional
        List of dataset names to include. If None, uses all datasets in results_df
    log_likelihood_col : str, default='log_likelihood'
        Column name for log-likelihood values
    rmse_col : str, default='rmse'
        Column name for RMSE values
    accuracy_col : str, default='accuracy'
        Column name for accuracy values
    type_error_from_accuracy : bool, default=True
        If True, compute Type Error Rate as (1 - accuracy) * 100
    format_type : str, default='combined'
        Output format type:
        - 'combined': "log_like/rmse/type_error% ± std_log/std_rmse/std_type"
        - 'log_likelihood': "log_like ± std_log"
        - 'rmse': "rmse ± std_rmse"
        - 'type_error': "type_error% ± std_type"

    Returns
    -------
    pd.DataFrame
        Formatted table with rows as models and columns as datasets
    """
    # Filter models and datasets if specified
    if models is not None:
        results_df = results_df[results_df['model'].isin(models)].copy()
    if datasets is not None:
        results_df = results_df[results_df['dataset'].isin(datasets)].copy()

    # Compute type error rate if needed
    if type_error_from_accuracy:
        results_df['type_error_rate'] = (1 - results_df[accuracy_col]) * 100

    # Get unique models and datasets (sorted)
    all_models = sorted(results_df['model'].unique())
    all_datasets = sorted(results_df['dataset'].unique())

    # Compute mean and std for each model-dataset combination
    agg_dict = {
        log_likelihood_col: ['mean', 'std'],
        rmse_col: ['mean', 'std'],
        'type_error_rate': ['mean', 'std']
    }

    grouped = results_df.groupby(['model', 'dataset']).agg(agg_dict).reset_index()

    # Flatten column names
    grouped.columns = ['model', 'dataset',
                       'log_like_mean', 'log_like_std',
                       'rmse_mean', 'rmse_std',
                       'type_error_mean', 'type_error_std']

    # Fill NaN std with 0 (for single runs)
    grouped['log_like_std'] = grouped['log_like_std'].fillna(0)
    grouped['rmse_std'] = grouped['rmse_std'].fillna(0)
    grouped['type_error_std'] = grouped['type_error_std'].fillna(0)

    # Create formatted strings based on format_type
    def format_cell(row):
        """Format a single cell based on format_type - HANDLES PARTIAL NaN VALUES"""
        log_like_mean = row['log_like_mean']
        log_like_std = row['log_like_std']
        rmse_mean = row['rmse_mean']
        rmse_std = row['rmse_std']
        type_mean = row['type_error_mean']
        type_std = row['type_error_std']

        if format_type == 'log_likelihood':
            # Log-likelihood only format
            if pd.isna(log_like_mean):
                return 'NaN'
            if log_like_std == 0:
                return f"{log_like_mean:.3f}"
            return f"{log_like_mean:.3f} ± {log_like_std:.3f}"

        elif format_type == 'rmse':
            # RMSE only format
            if pd.isna(rmse_mean):
                return 'NaN'
            if rmse_std == 0:
                return f"{rmse_mean:.3f}"
            return f"{rmse_mean:.3f} ± {rmse_std:.3f}"

        elif format_type == 'type_error':
            # Type Error only format
            if pd.isna(type_mean):
                return 'NaN'
            if type_std == 0:
                return f"{type_mean:.1f}%"
            return f"{type_mean:.1f}% ± {type_std:.3f}"

        else:  # format_type == 'combined' (default)
            # FIXED: Show available metrics even when some are NaN
            # Build mean string
            log_str = f"{log_like_mean:.3f}" if not pd.isna(log_like_mean) else "NaN"
            rmse_str = f"{rmse_mean:.3f}" if not pd.isna(rmse_mean) else "NaN"
            type_str = f"{type_mean:.1f}%" if not pd.isna(type_mean) else "NaN%"
            mean_str = f"{log_str}/{rmse_str}/{type_str}"

            # Build std string (only if at least one mean is not NaN)
            if not pd.isna(log_like_mean) or not pd.isna(rmse_mean) or not pd.isna(type_mean):
                log_std_str = f"{log_like_std:.3f}" if not pd.isna(log_like_mean) else "nan"
                rmse_std_str = f"{rmse_std:.3f}" if not pd.isna(rmse_mean) else "nan"
                type_std_str = f"{type_std:.3f}" if not pd.isna(type_mean) else "nan"
                std_str = f"{log_std_str}/{rmse_std_str}/{type_std_str}"
                return f"{mean_str} ± {std_str}"
            else:
                # All NaN case (shouldn't happen often)
                return 'NaN/NaN/NaN%'

    grouped['formatted'] = grouped.apply(format_cell, axis=1)

    # Pivot to create the final table
    formatted_table = grouped.pivot(index='model', columns='dataset', values='formatted')

    # Ensure all models and datasets are present (fill missing with N/A)
    formatted_table = formatted_table.reindex(index=all_models, columns=all_datasets, fill_value='N/A')

    return formatted_table


def save_results_easytpp_format(
    results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None,
    datasets: Optional[List[str]] = None,
    save_csv: bool = True,
    save_latex: bool = True,
    save_markdown: bool = True,
    save_individual_metrics: bool = True,
    **format_kwargs
) -> dict:
    """
    Save formatted results in multiple formats (CSV, LaTeX, Markdown).

    Parameters
    ----------
    results_df : pd.DataFrame
        Results DataFrame with columns: model, dataset, log_likelihood, rmse, accuracy
    output_path : str
        Base path for output files (without extension)
    models : List[str], optional
        List of models to include
    datasets : List[str], optional
        List of datasets to include
    save_csv : bool, default=True
        Save as CSV
    save_latex : bool, default=True
        Save as LaTeX table
    save_markdown : bool, default=True
        Save as Markdown table
    save_individual_metrics : bool, default=True
        Save separate tables for each metric (log-likelihood, RMSE, Type Error)
    **format_kwargs
        Additional keyword arguments passed to format_results_table

    Returns
    -------
    dict
        Dictionary containing all generated tables
    """
    output_tables = {}

    # Generate combined table (with log-likelihood/RMSE/Type Error)
    combined_table = format_results_table(
        results_df,
        models=models,
        datasets=datasets,
        format_type='combined',
        **format_kwargs
    )
    output_tables['combined'] = combined_table

    # Save combined table
    if save_csv:
        combined_table.to_csv(f"{output_path}.csv")
        print(f"✓ Results saved to: {output_path}.csv")

    if save_latex:
        with open(f"{output_path}.tex", 'w') as f:
            f.write(combined_table.to_latex())
        print(f"✓ LaTeX table saved to: {output_path}.tex")

    if save_markdown:
        with open(f"{output_path}.md", 'w') as f:
            f.write(combined_table.to_markdown())
        print(f"✓ Markdown table saved to: {output_path}.md")

    return output_tables


def create_comparison_table(
    stationary_results_df: pd.DataFrame,
    nonstationary_results_df: pd.DataFrame,
    output_path: str,
    models: Optional[List[str]] = None
) -> pd.DataFrame:
    """
    Create a side-by-side comparison table for stationary vs non-stationary results.

    Parameters
    ----------
    stationary_results_df : pd.DataFrame
        Results from stationary Hawkes data
    nonstationary_results_df : pd.DataFrame
        Results from non-stationary Hawkes data
    output_path : str
        Base path for output files
    models : List[str], optional
        List of models to include

    Returns
    -------
    pd.DataFrame
        Comparison table with degradation analysis
    """
    # Format both tables
    stat_table = format_results_table(stationary_results_df, models=models)
    nonstat_table = format_results_table(nonstationary_results_df, models=models)

    # Compute degradation statistics
    stat_grouped = stationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'stat_log_like',
        'rmse': 'stat_rmse',
        'accuracy': 'stat_type_error'
    })

    nonstat_grouped = nonstationary_results_df.groupby('model').agg({
        'log_likelihood': 'mean',
        'rmse': 'mean',
        'accuracy': lambda x: (1 - x.mean()) * 100
    }).rename(columns={
        'log_likelihood': 'nonstat_log_like',
        'rmse': 'nonstat_rmse',
        'accuracy': 'nonstat_type_error'
    })

    degradation = stat_grouped.join(nonstat_grouped)

    # Calculate degradation percentages
    degradation['log_like_degradation_%'] = (
        (degradation['nonstat_log_like'] - degradation['stat_log_like']) /
        abs(degradation['stat_log_like']) * 100
    )
    degradation['rmse_degradation_%'] = (
        (degradation['nonstat_rmse'] - degradation['stat_rmse']) /
        degradation['stat_rmse'] * 100
    )
    degradation['type_error_degradation_%'] = (
        degradation['nonstat_type_error'] - degradation['stat_type_error']
    )

    # Save comparison
    degradation.to_csv(f"{output_path}_degradation.csv")
    print(f"✓ Degradation analysis saved to: {output_path}_degradation.csv")

    return degradation

# %% [markdown]
# ### Function Execution

# %%
model_ids = ['RMTPP', 'NHP', 'FullyNN', 'SAHP', 'THP', 'IntensityFree', 'AttNHP']
data_ids = ['nonstationary_hawkes']

# %%
import pandas as pd

def flatten_model_results(all_model_results):
    """
    Properly convert all_model_results dictionary to DataFrame.

    The issue: pd.DataFrame(dict) treats keys as COLUMN names, not data rows.
    This function flattens it correctly.
    """
    all_results = []
    for model_name, results_list in all_model_results.items():
        all_results.extend(results_list)
    return pd.DataFrame(all_results)

results_df = flatten_model_results(all_model_results)
results_df = results_df[
    results_df['status'] == 'success'
]

# Check the structure
print("✓ DataFrame created successfully!")
print(f"  Shape: {results_df.shape}")
print(f"  Columns: {list(results_df.columns)}")
print(f"\nFirst few rows:")
print(results_df.head())

formatted_table = format_results_table(
    results_df,
    models=model_ids,
    datasets=data_ids
)

print("\n✓ Formatted table:")
print(formatted_table)

# Save to files
saved_table = save_results_easytpp_format(
    results_df,
    output_path=f'{RESULTS_DIR}/Task5_results',
    models=model_ids,
    datasets=data_ids
)
# Out:
# ✓ DataFrame created successfully!
#   Shape: (7, 7)
#   Columns: ['model', 'dataset', 'log_likelihood', 'accuracy', 'rmse', 'status', 'time_seconds']
#
# First few rows:
#      model               dataset  log_likelihood  accuracy      rmse   status  \
# 0    RMTPP  nonstationary_hawkes       -0.857463  0.728853  1.111820  success
# 1      NHP  nonstationary_hawkes       -0.817354  0.718961  1.021048  success
# 2  FullyNN  nonstationary_hawkes       -1.118245  0.502727  1.076472  success
# 3     SAHP  nonstationary_hawkes       -0.877497  0.707313  1.008119  success
# 4      THP  nonstationary_hawkes       -0.873175  0.726819  0.995151  success
#
#    time_seconds
# 0     70.939631
# 1    190.038089
# 2     51.928117
# 3     18.857409
# 4     19.037817
#
# ✓ Formatted table:
# dataset                          nonstationary_hawkes
# model
# AttNHP         -0.892/0.832/41.2% ± 0.000/0.000/0.000
# FullyNN        -1.118/1.076/49.7% ± 0.000/0.000/0.000
# IntensityFree  -0.856/1.245/28.9% ± 0.000/0.000/0.000
# NHP            -0.817/1.021/28.1% ± 0.000/0.000/0.000
# RMTPP          -0.857/1.112/27.1% ± 0.000/0.000/0.000
# SAHP           -0.877/1.008/29.3% ± 0.000/0.000/0.000
# THP            -0.873/0.995/27.3% ± 0.000/0.000/0.000
# ✓ Results saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/Task5_results.csv
# ✓ LaTeX table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/Task5_results.tex
# ✓ Markdown table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/Task5_results.md

# %% [markdown]
# ## Data Conversion: EasyTPP → Meta-TPP Format
#
# Convert stationary Hawkes pickle files to npz format for Meta-TPP:
# - **EasyTPP format**: `{time_seqs: List[List[float]], type_seqs: List[List[int]]}`
# - **Meta-TPP format**: `.npz` with `TIMES`, `MARKS`, `MASKS` arrays

# %%
import pickle
import numpy as np
import json
import os


def convert_sparklen_hawkes_to_metatpp(dataset_dir, output_dir, dataset_name='stationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes dataset to Meta-TPP format.

    Your data format (from Sparklen):
    {
        'dim_process': 2,
        'train': [
            [
                {'idx_event': 1, 'type_event': 0, 'time_since_start': 0.876, ...},
                {'idx_event': 2, 'type_event': 1, 'time_since_start': 1.883, ...},
                ...
            ],
            ...
        ]
    }
    """
    os.makedirs(output_dir, exist_ok=True)

    print("="*70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("="*70)

    # Define file paths and their corresponding keys
    splits = {
        'train': ('train.pkl', 'train'),
        'dev': ('dev.pkl', 'dev'),
        'test': ('test.pkl', 'test')
    }

    all_times = []
    all_marks = []
    all_masks = []
    split_indices = {}

    current_idx = 0

    for split_name, (filename, data_key) in splits.items():
        pickle_path = os.path.join(dataset_dir, filename)

        print(f"\n{split_name.upper()} split:")

        # Load pickle file
        with open(pickle_path, 'rb') as f:
            data = pickle.load(f)

        # Extract sequences
        sequences = data[data_key]
        num_seqs = len(sequences)

        # Extract times and marks from event dictionaries
        time_seqs = []
        type_seqs = []

        for seq in sequences:
            # Each seq is a list of event dicts
            times = [event['time_since_start'] for event in seq]
            marks = [event['type_event'] for event in seq]

            time_seqs.append(times)
            type_seqs.append(marks)

        # Find max sequence length
        max_len = max(len(seq) for seq in time_seqs)

        # Create padded arrays
        times = np.zeros((num_seqs, max_len), dtype=np.float32)
        marks = np.zeros((num_seqs, max_len), dtype=np.int64)
        masks = np.zeros((num_seqs, max_len), dtype=np.float32)

        for i, (time_seq, type_seq) in enumerate(zip(time_seqs, type_seqs)):
            seq_len = len(time_seq)
            times[i, :seq_len] = time_seq
            marks[i, :seq_len] = type_seq
            masks[i, :seq_len] = 1.0

        all_times.append(times)
        all_marks.append(marks)
        all_masks.append(masks)

        split_indices[split_name] = (current_idx, current_idx + num_seqs)
        current_idx += num_seqs

        print(f"  - Sequences: {num_seqs}")
        print(f"  - Max length: {max_len}")
        print(f"  - Avg length: {np.mean([len(seq) for seq in time_seqs]):.1f}")

    # Pad to global max length
    global_max_len = max(arr.shape[1] for arr in all_times)

    def pad_to_length(arrays, target_len):
        padded = []
        for arr in arrays:
            if arr.shape[1] < target_len:
                pad_width = ((0, 0), (0, target_len - arr.shape[1]))
                padded.append(np.pad(arr, pad_width, mode='constant', constant_values=0))
            else:
                padded.append(arr)
        return padded

    all_times = pad_to_length(all_times, global_max_len)
    all_marks = pad_to_length(all_marks, global_max_len)
    all_masks = pad_to_length(all_masks, global_max_len)

    # Concatenate
    times_combined = np.concatenate(all_times, axis=0)
    marks_combined = np.concatenate(all_marks, axis=0)
    masks_combined = np.concatenate(all_masks, axis=0)

    # Save npz
    output_path = os.path.join(output_dir, f'{dataset_name}.npz')
    np.savez(
        output_path,
        times=times_combined,
        marks=marks_combined,
        masks=masks_combined
    )

    # Save split info
    split_info_path = os.path.join(output_dir, f'{dataset_name}_split_info.json')
    with open(split_info_path, 'w') as f:
        json.dump({
            'train': split_indices['train'],
            'val': split_indices['dev'],
            'test': split_indices['test'],
            'num_event_types': int(data['dim_process']),
            'global_max_len': int(global_max_len)
        }, f, indent=2)

    print(f"\n{'='*70}")
    print(f"✓ Conversion complete!")
    print(f"  - Output NPZ: {output_path}")
    print(f"  - Split info: {split_info_path}")
    print(f"  - Total sequences: {times_combined.shape[0]}")
    print(f"  - Sequence length: {times_combined.shape[1]}")
    print(f"  - Train: {split_indices['train']}")
    print(f"  - Val: {split_indices['dev']}")
    print(f"  - Test: {split_indices['test']}")
    print("="*70)

    return output_path


# ============================================================================
# RUN CONVERSION
# ============================================================================

# Convert the stationary Hawkes dataset
hawkes_input_dir = os.path.join(DATASET_DIR, dataset_name)
metatpp_dataset_dir = os.path.join(DATASET_DIR, 'metatpp_format')

# Convert the stationary Hawkes dataset
converted_npz_path = convert_sparklen_hawkes_to_metatpp(
    dataset_dir=hawkes_input_dir,
    output_dir=metatpp_dataset_dir,
    dataset_name=dataset_name
)
# Out:
# ======================================================================
# Converting nonstationary_hawkes to Meta-TPP format
# ======================================================================
#
# TRAIN split:
#   - Sequences: 300
#   - Max length: 163
#   - Avg length: 109.7
#
# DEV split:
#   - Sequences: 100
#   - Max length: 161
#   - Avg length: 109.5
#
# TEST split:
#   - Sequences: 100
#   - Max length: 152
#   - Avg length: 109.2
#
# ======================================================================
# ✓ Conversion complete!
#   - Output NPZ: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/nonstationary_hawkes.npz
#   - Split info: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/Datasets/metatpp_format/nonstationary_hawkes_split_info.json
#   - Total sequences: 500
#   - Sequence length: 163
#   - Train: (0, 300)
#   - Val: (300, 400)
#   - Test: (400, 500)
# ======================================================================

# %% [markdown]
# ## Meta TPP

# %% [markdown]
# ### Cell 1: Install Dependencies (CRITICAL - Run First, Then Restart Runtime)

# %%
# ==============================================================================
# CELL 1: Install Dependencies with Correct Versions
# ==============================================================================
# IMPORTANT: After running this cell, you MUST restart the runtime!
# Runtime → Restart runtime (or Ctrl+M .)

# Uninstall any existing stribor (Colab installs 0.2.0 which breaks)
# !pip uninstall stribor -y -q 2>/dev/null

# Install stribor 0.1.0 (does NOT require torchtyping)
# !pip install stribor==0.1.0 -q

# Install nfe (neural-flows-experiments) from GitHub
# !SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True pip install git+https://github.com/mbilos/neural-flows-experiments -q

# Install other Meta-TPP dependencies
# !pip install lightning pytorch-lightning hydra-core omegaconf hydra-colorlog pyrootutils torchmetrics rich -q

# Verify stribor version
import subprocess
result = subprocess.run(['pip', 'show', 'stribor'], capture_output=True, text=True)
version_line = [l for l in result.stdout.split('\n') if 'Version' in l][0]
print(f"✓ Installed: stribor {version_line.split(': ')[1]}")

print("\n" + "=" * 70)
print("⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime")
print("   Then continue to Cell 2 (do NOT re-run this cell)")
print("=" * 70)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 42.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for nfe (setup.py) ... done
#   Building wheel for reverse_geocoder (setup.py) ... done
#   Building wheel for sklearn (setup.py) ... done
# ✓ Installed: stribor 0.1.0
#
# ======================================================================
# ⚠️  RESTART RUNTIME NOW: Runtime → Restart runtime
#    Then continue to Cell 2 (do NOT re-run this cell)
# ======================================================================

# %% [markdown]
# ### Cell 2: Verify Imports (Run After Restart)

# %%
# ==============================================================================
# CELL 2: Verify Imports After Runtime Restart
# ==============================================================================
# Run this AFTER restarting the runtime

import stribor

# This import should now work without torchtyping errors
import torch
print(f"✓ PyTorch version: {torch.__version__}")

# Test that stribor's distributions work
try:
    from stribor.dist import Normal
    print("✓ stribor.dist imports work")
except Exception as e:
    print(f"✗ Error: {e}")

print("\n✓ All imports successful - ready to proceed!")
# Out:
# ✓ PyTorch version: 2.9.0+cu126
# ✓ stribor.dist imports work
#
# ✓ All imports successful - ready to proceed!

# %% [markdown]
# ### Cell 3: Setup Paths and Clone Meta-TPP

# %%
# ==============================================================================
# CELL 3: Setup Paths and Clone Meta-TPP
# ==============================================================================
import os
import sys

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Base directories
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
DATASET_DIR = os.path.join(BASE_DIR, 'Datasets')
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task5')
METATPP_DIR = '/content/meta-tpp'

os.makedirs(RESULTS_DIR, exist_ok=True)

# Clone Meta-TPP
if not os.path.exists(METATPP_DIR):
    # !git clone https://github.com/BorealisAI/meta-tpp.git {METATPP_DIR}
    print("✓ Meta-TPP cloned")
else:
    print("✓ Meta-TPP already exists")

# Add to Python path
if METATPP_DIR not in sys.path:
    sys.path.insert(0, METATPP_DIR)

# Change to Meta-TPP directory (required for Hydra)
os.chdir(METATPP_DIR)
print(f"✓ Working directory: {os.getcwd()}")

# Create data directories
os.makedirs(os.path.join(METATPP_DIR, 'data', 'synthetic'), exist_ok=True)
print("✓ Data directories ready")

# ==============================================================================
# Create .project-root indicator file (required by pyrootutils)
# ==============================================================================
project_root_file = os.path.join(METATPP_DIR, '.project-root')
if not os.path.exists(project_root_file):
    with open(project_root_file, 'w') as f:
        f.write('')  # Empty file is fine, just needs to exist
    print(f"✓ Created .project-root indicator file")
else:
    print(f"✓ .project-root already exists")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into '/content/meta-tpp'...
# remote: Enumerating objects: 3610, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 3610 (delta 159), reused 211 (delta 155), pack-reused 3384 (from 1)
# Receiving objects: 100% (3610/3610), 3.45 MiB | 39.26 MiB/s, done.
# Resolving deltas: 100% (2132/2132), done.
# ✓ Meta-TPP cloned
# ✓ Working directory: /content/meta-tpp
# ✓ Data directories ready
# ✓ Created .project-root indicator file

# %% [markdown]
# ### Cell 4: Convert Stationary Hawkes Data to Meta-TPP Format

# %%
# ==============================================================================
# CELL 4: Convert Stationary Hawkes Data to Meta-TPP Format
# ==============================================================================
import numpy as np
import pickle

def convert_hawkes_to_metatpp_format(dataset_dir, output_path, dataset_name='nonstationary_hawkes'):
    """
    Convert Sparklen-generated Hawkes pickle files to Meta-TPP npz format.

    Meta-TPP expects:
    - Single npz file with all sequences
    - Keys: 'times', 'marks', 'masks'
    - Shape: (num_sequences, max_seq_len)
    - Split by indices: 60% train, 20% val, 20% test (or custom)
    """
    print("=" * 70)
    print(f"Converting {dataset_name} to Meta-TPP format")
    print("=" * 70)

    all_times = []
    all_marks = []
    splits = ['train', 'dev', 'test']
    split_files = {'train': 'train.pkl', 'dev': 'dev.pkl', 'test': 'test.pkl'}

    for split in splits:
        pkl_path = os.path.join(dataset_dir, split_files[split])
        print(f"\nLoading {split}...")

        with open(pkl_path, 'rb') as f:
            data = pickle.load(f)

        # Handle different pickle structures
        if split in data:
            sequences = data[split]
        elif 'train' in data or 'dev' in data or 'test' in data:
            sequences = data.get(split, data.get('train', []))
        else:
            sequences = data if isinstance(data, list) else list(data.values())[0]

        print(f"  - {len(sequences)} sequences")

        for seq in sequences:
            if isinstance(seq, list) and len(seq) > 0 and isinstance(seq[0], dict):
                # Format: [{'time_since_start': t, 'type_event': m}, ...]
                times = [event['time_since_start'] for event in seq]
                marks = [event['type_event'] for event in seq]
            else:
                # Assume it's already (times, marks) format
                times = [e[0] if isinstance(e, (list, tuple)) else e for e in seq]
                marks = [e[1] if isinstance(e, (list, tuple)) else 0 for e in seq]

            all_times.append(times)
            all_marks.append(marks)

    # Find max sequence length
    max_len = max(len(t) for t in all_times)
    num_seqs = len(all_times)

    print(f"\n  Total sequences: {num_seqs}")
    print(f"  Max sequence length: {max_len}")

    # Create padded arrays
    times_arr = np.zeros((num_seqs, max_len), dtype=np.float32)
    marks_arr = np.zeros((num_seqs, max_len), dtype=np.int64)
    masks_arr = np.zeros((num_seqs, max_len), dtype=np.float32)

    for i, (t, m) in enumerate(zip(all_times, all_marks)):
        seq_len = len(t)
        times_arr[i, :seq_len] = t
        marks_arr[i, :seq_len] = m
        masks_arr[i, :seq_len] = 1.0

    # Save as npz
    np.savez(output_path, times=times_arr, marks=marks_arr, masks=masks_arr)

    print(f"\n✓ Saved to: {output_path}")
    print(f"  - times: {times_arr.shape}, dtype={times_arr.dtype}")
    print(f"  - marks: {marks_arr.shape}, dtype={marks_arr.dtype}")
    print(f"  - masks: {masks_arr.shape}, dtype={masks_arr.dtype}")
    print(f"  - Split: [0:{int(num_seqs*0.6)}] train, [{int(num_seqs*0.6)}:{int(num_seqs*0.8)}] val, [{int(num_seqs*0.8)}:] test")
    print("=" * 70)

    return output_path

# Convert the data
hawkes_input_dir = os.path.join(DATASET_DIR, dataset_name)
metatpp_data_path = os.path.join(METATPP_DIR, 'data', 'synthetic', 'nonstationary_hawkes.npz')

convert_hawkes_to_metatpp_format(hawkes_input_dir, metatpp_data_path)

# Verify
data = np.load(metatpp_data_path)
print("\n✓ Verification:")
for key in data.keys():
    print(f"  {key}: shape={data[key].shape}, dtype={data[key].dtype}")
# Out:
# ======================================================================
# Converting nonstationary_hawkes to Meta-TPP format
# ======================================================================
#
# Loading train...
#   - 300 sequences
#
# Loading dev...
#   - 100 sequences
#
# Loading test...
#   - 100 sequences
#
#   Total sequences: 500
#   Max sequence length: 163
#
# ✓ Saved to: /content/meta-tpp/data/synthetic/nonstationary_hawkes.npz
#   - times: (500, 163), dtype=float32
#   - marks: (500, 163), dtype=int64
#   - masks: (500, 163), dtype=float32
#   - Split: [0:300] train, [300:400] val, [400:] test
# ======================================================================
#
# ✓ Verification:
#   times: shape=(500, 163), dtype=float32
#   marks: shape=(500, 163), dtype=int64
#   masks: shape=(500, 163), dtype=float32

# %% [markdown]
# ### Cell 5: Create Dataset Config and Patch TPPDataset

# %%
# ==============================================================================
# CELL 5: Create Dataset Config and Register Dataset
# ==============================================================================
import yaml

# Create dataset config YAML
dataset_config = {
    'dataset': dataset_name,
    'num_classes': 2
}

config_dir = os.path.join(METATPP_DIR, 'configs', 'data', 'datasets')
config_path = os.path.join(config_dir, 'nonstationary_hawkes.yaml')

with open(config_path, 'w') as f:
    yaml.dump(dataset_config, f)

print(f"✓ Created dataset config: {config_path}")

# Patch TPPDataset to include our new dataset
tpp_dataset_path = os.path.join(METATPP_DIR, 'src', 'data', 'tpp_dataset.py')

with open(tpp_dataset_path, 'r') as f:
    content = f.read()

# Add nonstationary_hawkes to synthetic_data list if not already there
if 'nonstationary_hawkes' not in content:
    old_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\"]"
    new_line = "synthetic_data = ['sin', 'hawkes_univariate', 'hawkes_multivariate_3d', \"hawkes_regime_changes\", 'nonstationary_hawkes']"

    if old_line in content:
        content = content.replace(old_line, new_line)
        with open(tpp_dataset_path, 'w') as f:
            f.write(content)
        print("✓ Added 'nonstationary_hawkes' to synthetic_data list")
    else:
        # Try alternative format
        import re
        pattern = r"(synthetic_data\s*=\s*\[.*?\])"
        match = re.search(pattern, content, re.DOTALL)
        if match:
            old = match.group(1)
            if 'nonstationary_hawkes' not in old:
                new = old.rstrip(']') + ", 'nonstationary_hawkes']"
                content = content.replace(old, new)
                with open(tpp_dataset_path, 'w') as f:
                    f.write(content)
                print("✓ Added 'nonstationary_hawkes' to synthetic_data list")
else:
    print("✓ 'nonstationary_hawkes' already registered")

# Reload the module
import importlib
if 'src.data.tpp_dataset' in sys.modules:
    del sys.modules['src.data.tpp_dataset']

print("✓ Dataset configuration complete")
# Out:
# ✓ Created dataset config: /content/meta-tpp/configs/data/datasets/nonstationary_hawkes.yaml
# ✓ Added 'nonstationary_hawkes' to synthetic_data list
# ✓ Dataset configuration complete

# %% [markdown]
# ### Cell 6: Test Data Loading

# %%
# ==============================================================================
# CELL 6: Test Data Loading
# ==============================================================================
# Verify the data can be loaded by Meta-TPP's dataset class

from src.data.tpp_dataset import TPPDataset

# Test loading
data_dir = os.path.join(METATPP_DIR, 'data')

print("Testing data loading...")
try:
    train_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='train')
    val_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='val')
    test_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='test')

    print(f"\n✓ Train: {len(train_ds)} sequences")
    print(f"✓ Val: {len(val_ds)} sequences")
    print(f"✓ Test: {len(test_ds)} sequences")

    # Test a sample
    sample = train_ds[0]
    print(f"\nSample batch keys: {list(sample.keys())}")
    print(f"  times shape: {sample['times'].shape}")
    print(f"  marks shape: {sample['marks'].shape}")
    print(f"  masks shape: {sample['masks'].shape}")

    print("\n✓ Data loading test passed!")
except Exception as e:
    print(f"✗ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Testing data loading...
# time shape: torch.Size([300, 163, 1]), marks shape: torch.Size([300, 163, 1]), masks shape: torch.Size([300, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
#
# ✓ Train: 300 sequences
# ✓ Val: 100 sequences
# ✓ Test: 100 sequences
#
# Sample batch keys: ['times', 'marks', 'masks', 'missing_masks']
#   times shape: torch.Size([163, 1])
#   marks shape: torch.Size([163, 1])
#   masks shape: torch.Size([163, 1])
#
# ✓ Data loading test passed!

# %% [markdown]
# ### Cell 7: Train Meta-TPP Using Hydra

# %%
# ==============================================================================
# CELL 7: Train Meta-TPP Using Hydra
# ==============================================================================
import subprocess
import os

# Ensure we're in the Meta-TPP directory
os.chdir(METATPP_DIR)

# Training command using Hydra
# This replicates: python src/train.py data/datasets=nonstationary_hawkes
cmd = [
    'python', 'src/train.py',
    'data/datasets=nonstationary_hawkes',
    'model=thp_mix',
    'trainer.max_epochs=200',
    'trainer.accelerator=gpu',
    'trainer.devices=1',
    'data.batch_size=256',
    'tag=colab_run',
    'test=False',
    'seed=42'
]

print("=" * 70)
print("Starting Meta-TPP Training")
print("=" * 70)
print(f"Command: {' '.join(cmd)}")
print("=" * 70 + "\n")

# Run training
process = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1
)

# Stream output
for line in iter(process.stdout.readline, ''):
    print(line, end='')

process.wait()

if process.returncode == 0:
    print("\n" + "=" * 70)
    print("✓ Training completed successfully!")
    print("=" * 70)
else:
    print(f"\n✗ Training failed with return code: {process.returncode}")
# Out:
# ======================================================================
# Starting Meta-TPP Training
# ======================================================================
# Command: python src/train.py data/datasets=nonstationary_hawkes model=thp_mix trainer.max_epochs=200 trainer.accelerator=gpu trainer.devices=1 data.batch_size=256 tag=colab_run test=False seed=42
# ======================================================================
#
# [2026-01-01 15:15:57,917][src.utils.utils][INFO] - Enforcing tags! <cfg.extras.enforce_tags=True>
# [2026-01-01 15:15:57,922][src.utils.utils][INFO] - Printing config tree with Rich! <cfg.extras.print_config=True>
# [2026-01-01 15:15:57,922][src.utils.rich_utils][WARNING] - Field 'logger' not found in config. Skipping 'logger' config printing...
# CONFIG
# ├── data
# │   └── _target_: src.data.tpp_dataset.TPPDataModule
# │       data_dir: /content/meta-tpp/data/
# │       batch_size: 256
# │       num_workers: 4
# │       pin_memory: false
# │       train_rate: 1.0
# │       eval_rate: 1.0
# │       noise_rate: 0.0
# │       seq_rate: 1.0
# │       missing_rate: 0.0
# │       use_mark: true
# │       run_bootstrap: false
# │       datasets:
# │         dataset: nonstationary_hawkes
# │         num_classes: 2
# │
# ├── model
# │   └── _target_: src.models.tpp_module.TPPLitModule
# │       optimizer:
# │         _target_: torch.optim.Adam
# │         _partial_: true
# │         lr: 0.0001
# │         weight_decay: 0.0001
# │         eps: 1.0e-05
# │         betas:
# │         - 0.9
# │         - 0.999
# │       net:
# │         _target_: src.models.tpp.tpp_network.TransformerMix
# │         name: thp_mix
# │         num_classes: 2
# │         d_model: 64
# │         d_inner: 64
# │         n_layers: 2
# │         cattn_n_layers: 1
# │         n_head: 1
# │         d_k: 64
# │         d_v: 64
# │         dropout: 0.1
# │         attn_l: 0
# │         base_l: 0
# │         perm_invar: false
# │         use_avg: true
# │         share_weights: true
# │         attn_only: false
# │         concat: false
# │         num_latent: 64
# │         vi_method: None
# │         num_z_samples: 32
# │         compute_acc: true
# │         activation:
# │           name: tanh
# │           in_features: 64
# │           trainable: true
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: lightning.pytorch.callbacks.ModelCheckpoint
# │         dirpath: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_run
# │         filename: epoch_{epoch:03d}
# │         monitor: val/rmse
# │         verbose: false
# │         save_last: true
# │         save_top_k: 1
# │         mode: min
# │         auto_insert_metric_name: false
# │         save_weights_only: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: null
# │       early_stopping:
# │         _target_: lightning.pytorch.callbacks.EarlyStopping
# │         monitor: val/nll
# │         min_delta: 0.0
# │         patience: 500
# │         verbose: false
# │         mode: min
# │         strict: true
# │         check_finite: true
# │         stopping_threshold: null
# │         divergence_threshold: null
# │         check_on_train_epoch_end: null
# │       model_summary:
# │         _target_: lightning.pytorch.callbacks.RichModelSummary
# │         max_depth: -1
# │       rich_progress_bar:
# │         _target_: lightning.pytorch.callbacks.RichProgressBar
# │
# ├── trainer
# │   └── _target_: lightning.pytorch.trainer.Trainer
# │       default_root_dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_co
# │       min_epochs: 1
# │       max_epochs: 200
# │       accelerator: gpu
# │       devices: 1
# │       check_val_every_n_epoch: 1
# │       deterministic: false
# │
# ├── paths
# │   └── root_dir: /content/meta-tpp
# │       data_dir: /content/meta-tpp/data/
# │       log_dir: /content/meta-tpp/logs/
# │       output_dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_ru
# │       work_dir: /content/meta-tpp
# │       ckpt_dir: /content/meta-tpp/checkpoints/
# │
# ├── extras
# │   └── ignore_warnings: false
# │       enforce_tags: true
# │       print_config: true
# │
# ├── task_name
# │   └── nonstationary_hawkes_thp_mix_colab_run
# ├── tags
# │   └── ['dev']
# ├── tag
# │   └── colab_run
# ├── train
# │   └── True
# ├── test
# │   └── False
# ├── compile
# │   └── False
# ├── ckpt_path
# │   └── None
# └── seed
#     └── 42
# Seed set to 42
# [2026-01-01 15:15:57,981][__main__][INFO] - Instantiating datamodule <src.data.tpp_dataset.TPPDataModule>
# [2026-01-01 15:15:57,984][__main__][INFO] - Instantiating model <src.models.tpp_module.TPPLitModule>
# The number of trainable model parameters: 56284
# [2026-01-01 15:15:58,177][__main__][INFO] - Instantiating callbacks...
# [2026-01-01 15:15:58,177][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.ModelCheckpoint>
# [2026-01-01 15:15:58,191][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.EarlyStopping>
# [2026-01-01 15:15:58,192][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichModelSummary>
# [2026-01-01 15:15:58,193][src.utils.instantiators][INFO] - Instantiating callback <lightning.pytorch.callbacks.RichProgressBar>
# [2026-01-01 15:15:58,193][__main__][INFO] - Instantiating loggers...
# [2026-01-01 15:15:58,193][src.utils.instantiators][WARNING] - No logger configs found! Skipping...
# [2026-01-01 15:15:58,193][__main__][INFO] - Instantiating trainer <lightning.pytorch.trainer.Trainer>
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# [2026-01-01 15:15:58,234][__main__][INFO] - Starting training!
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1551: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return _C._get_float32_matmul_precision()
# You are using a CUDA device ('NVIDIA A100-SXM4-80GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# time shape: torch.Size([300, 163, 1]), marks shape: torch.Size([300, 163, 1]), masks shape: torch.Size([300, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# time shape: torch.Size([100, 163, 1]), marks shape: torch.Size([100, 163, 1]), masks shape: torch.Size([100, 163, 1])
# ┏━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━┳━━━━┳━━━┓
# ┃    ┃ Name                                                 ┃ T… ┃ P… ┃ M… ┃ … ┃
# ┡━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━╇━━━━╇━━━┩
# │ 0  │ net                                                  │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 1  │ net.encoder                                          │ T… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 2  │ net.encoder.event_emb                                │ E… │ 1… │ t… │ 0 │
# │ 3  │ net.encoder.layer_stack                              │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 4  │ net.encoder.layer_stack.0                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 5  │ net.encoder.layer_stack.0.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 6  │ net.encoder.layer_stack.0.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 7  │ net.encoder.layer_stack.0.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 8  │ net.encoder.layer_stack.0.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 9  │ net.encoder.layer_stack.0.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 10 │ net.encoder.layer_stack.0.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 11 │ net.encoder.layer_stack.0.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 12 │ net.encoder.layer_stack.0.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 13 │ net.encoder.layer_stack.0.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 14 │ net.encoder.layer_stack.0.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 15 │ net.encoder.layer_stack.0.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 16 │ net.encoder.layer_stack.0.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 17 │ net.encoder.layer_stack.0.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 18 │ net.encoder.layer_stack.0.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 19 │ net.encoder.layer_stack.1                            │ E… │ 2… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 20 │ net.encoder.layer_stack.1.slf_attn                   │ M… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 21 │ net.encoder.layer_stack.1.slf_attn.w_qs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 22 │ net.encoder.layer_stack.1.slf_attn.w_ks              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 23 │ net.encoder.layer_stack.1.slf_attn.w_vs              │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 24 │ net.encoder.layer_stack.1.slf_attn.fc                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 25 │ net.encoder.layer_stack.1.slf_attn.attention         │ S… │  0 │ t… │ 0 │
# │ 26 │ net.encoder.layer_stack.1.slf_attn.attention.dropout │ D… │  0 │ t… │ 0 │
# │ 27 │ net.encoder.layer_stack.1.slf_attn.layer_norm        │ L… │ 1… │ t… │ 0 │
# │ 28 │ net.encoder.layer_stack.1.slf_attn.dropout           │ D… │  0 │ t… │ 0 │
# │ 29 │ net.encoder.layer_stack.1.pos_ffn                    │ P… │ 8… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 30 │ net.encoder.layer_stack.1.pos_ffn.w_1                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 31 │ net.encoder.layer_stack.1.pos_ffn.w_2                │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 32 │ net.encoder.layer_stack.1.pos_ffn.layer_norm         │ L… │ 1… │ t… │ 0 │
# │ 33 │ net.encoder.layer_stack.1.pos_ffn.dropout            │ D… │  0 │ t… │ 0 │
# │ 34 │ net.linear                                           │ L… │ 1… │ t… │ 0 │
# │ 35 │ net.time_predictor                                   │ T… │ 64 │ t… │ 0 │
# │ 36 │ net.time_predictor.linear                            │ L… │ 64 │ t… │ 0 │
# │ 37 │ net.class_predictor                                  │ T… │ 1… │ t… │ 0 │
# │ 38 │ net.mark_linear                                      │ L… │ 1… │ t… │ 0 │
# │ 39 │ net.activation                                       │ T… │  0 │ t… │ 0 │
# │ 40 │ net.prob_dist                                        │ L… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 41 │ net.prob_dist.decoder                                │ M… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 42 │ net.prob_dist.decoder.net                            │ S… │ 5… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 43 │ net.prob_dist.decoder.net.0                          │ L… │ 4… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 44 │ net.prob_dist.decoder.net.1                          │ T… │  0 │ t… │ 0 │
# │ 45 │ net.prob_dist.decoder.net.2                          │ L… │ 1… │ t… │ 0 │
# │    │                                                      │    │  K │    │   │
# │ 46 │ train_nll                                            │ M… │  0 │ t… │ 0 │
# │ 47 │ val_nll                                              │ M… │  0 │ t… │ 0 │
# │ 48 │ test_nll                                             │ M… │  0 │ t… │ 0 │
# │ 49 │ train_rmse                                           │ M… │  0 │ t… │ 0 │
# │ 50 │ val_rmse                                             │ M… │  0 │ t… │ 0 │
# │ 51 │ test_rmse                                            │ M… │  0 │ t… │ 0 │
# │ 52 │ train_acc                                            │ M… │  0 │ t… │ 0 │
# │ 53 │ val_acc                                              │ M… │  0 │ t… │ 0 │
# │ 54 │ test_acc                                             │ M… │  0 │ t… │ 0 │
# │ 55 │ val_nll_best                                         │ M… │  0 │ t… │ 0 │
# │ 56 │ val_rmse_best                                        │ M… │  0 │ t… │ 0 │
# └────┴──────────────────────────────────────────────────────┴────┴────┴────┴───┘
# Trainable params: 56.3 K
# Non-trainable params: 0
# Total params: 56.3 K
# Total estimated model params size (MB): 0
# Modules in train mode: 57
# Modules in eval mode: 0
# Total FLOPs: 0
# `Trainer.fit` stopped: `max_epochs=200` reached.
# Epoch 199/199 ━━━━━━━━━━━━━━━━ 2/2 0:00:00 • 0:00:00 32.19it/s val/nll: 2.806
#                                                                val/rmse: 19.242
#                                                                val/acc: 0.501
#                                                                val/nll_best:
#                                                                2.806
#                                                                val/rmse_best:
#                                                                19.242 train/nll:
#                                                                2.911
# [2026-01-01 15:17:29,692][src.utils.utils][INFO] - Output dir: /content/meta-tpp/logs/nonstationary_hawkes_thp_mix_colab_run/seed42
# [2026-01-01 15:17:31,548][src.utils.utils][INFO] - Metric name is None! Skipping metric value retrieval...
# [W101 15:17:32.251812588 AllocatorConfig.cpp:28] Warning: PYTORCH_CUDA_ALLOC_CONF is deprecated, use PYTORCH_ALLOC_CONF instead (function operator())
#
# ======================================================================
# ✓ Training completed successfully!
# ======================================================================

# %%
# ==============================================================================
# CELL 7b: Manual Testing with proper optimizer setup
# ==============================================================================
import torch
import lightning as L
from torch.utils.data import DataLoader
from functools import partial

# Fix for PyTorch 2.6 checkpoint loading
from omegaconf import ListConfig, DictConfig
torch.serialization.add_safe_globals([ListConfig, DictConfig])

from src.data.tpp_dataset import TPPDataset
from src.models.tpp_module import TPPLitModule
from src.models.tpp.tpp_network import TransformerMix

# Find the best checkpoint
import glob
ckpt_pattern = os.path.join(METATPP_DIR, 'logs', 'nonstationary_hawkes_thp_mix_colab_run', 'seed42', 'checkpoints', '*.ckpt')
ckpts = glob.glob(ckpt_pattern)
ckpts = [c for c in ckpts if 'last' not in c]
best_ckpt = sorted(ckpts)[-1] if ckpts else None

print(f"Best checkpoint: {best_ckpt}")

# Load data
data_dir = os.path.join(METATPP_DIR, 'data')
test_ds = TPPDataset(data_dir, dataset_name, num_classes=2, mode='test')
test_loader = DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=2)

# Create model
net = TransformerMix(
    name='thp_mix', num_classes=2, d_model=64, d_inner=64, n_layers=2,
    cattn_n_layers=1, n_head=1, d_k=64, d_v=64, dropout=0.1,
    attn_l=0, base_l=0, perm_invar=False, use_avg=True, share_weights=True,
    attn_only=False, concat=False, num_latent=64, vi_method=None,
    num_z_samples=32, compute_acc=True,
    activation={'name': 'tanh', 'in_features': 64, 'trainable': True}
)

# Create optimizer as a partial function (this is what Hydra does)
optimizer = partial(
    torch.optim.Adam,
    lr=0.0001,
    weight_decay=0.0001,
    eps=1e-5,
    betas=(0.9, 0.999)
)

model = TPPLitModule(net=net, optimizer=optimizer)

# Load checkpoint
if best_ckpt:
    ckpt = torch.load(best_ckpt, map_location='cuda', weights_only=False)
    model.load_state_dict(ckpt['state_dict'])
    print("✓ Checkpoint loaded")

# Set model to eval mode
model.eval()

# Test
trainer = L.Trainer(accelerator='gpu', devices=1, logger=False, enable_progress_bar=True)
test_results = trainer.test(model, test_loader)

print("\n" + "=" * 70)
print("Meta-TPP Test Results")
print("=" * 70)
for k, v in test_results[0].items():
    print(f"  {k}: {v:.4f}")
# Out:
# Testing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 0:00:00 • 0:00:00 54.50it/s
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.5061477422714233     │
# │         test/nll          │    2.7888832092285156     │
# │         test/rmse         │     20.21638298034668     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
# Meta-TPP Test Results
# ======================================================================
#   test/nll: 2.7889
#   test/rmse: 20.2164
#   test/acc: 0.5061

# %% [markdown]
# ### Cell 8: Extract and Save Results

# %%
# ==============================================================================
# CELL 9: Extract and Save Results Properly
# ==============================================================================
import pandas as pd

# test_results is returned from trainer.test() - it's a list of dicts
# Print what we actually got to debug
print("=" * 70)
print("Raw test_results:")
print(test_results)
print("=" * 70)

# Extract metrics from test_results (it's a list with one dict)
if test_results and len(test_results) > 0:
    metrics = test_results[0]

    # Meta-TPP uses keys like 'test/nll', 'test/rmse', 'test/acc'
    # or 'test_nll', 'test_rmse', 'test_acc'

    # Try different possible key formats
    def get_metric(metrics, *possible_keys):
        for key in possible_keys:
            if key in metrics:
                val = metrics[key]
                # Handle tensor values
                if hasattr(val, 'item'):
                    return val.item()
                return val
        return float('nan')

    nll = get_metric(metrics, 'test/nll', 'test_nll', 'test_loss')
    rmse = get_metric(metrics, 'test/rmse', 'test_rmse')
    acc = get_metric(metrics, 'test/acc', 'test_acc', 'test_accuracy')

    # Log-likelihood is negative NLL
    log_likelihood = -nll if not pd.isna(nll) else float('nan')

    print(f"\nExtracted metrics:")
    print(f"  NLL: {nll}")
    print(f"  Log-Likelihood: {log_likelihood}")
    print(f"  RMSE: {rmse}")
    print(f"  Accuracy: {acc}")
else:
    print("No test results found!")
    log_likelihood = float('nan')
    acc = float('nan')
    rmse = float('nan')

# Create result entry
metatpp_result = {
    'model': 'Meta-TPP',
    'dataset': 'nonstationary_hawkes',
    'log_likelihood': log_likelihood,
    'accuracy': acc * 100 if not pd.isna(acc) and acc <= 1 else acc,  # Convert to percentage if needed
    'rmse': rmse,
    'status': 'success'
}

# Save results
results_df = pd.DataFrame([metatpp_result])
metatpp_results_path = os.path.join(RESULTS_DIR, 'metatpp_stationary_results.csv')
results_df.to_csv(metatpp_results_path, index=False)

print("\n" + "=" * 70)
print("Meta-TPP Results (Task 3b)")
print("=" * 70)
print(results_df.to_string(index=False))
print(f"\n✓ Saved to: {metatpp_results_path}")

# Also print in Table-1-like format for easy comparison
print("\n" + "=" * 70)
print("Table-1-like Format:")
print("=" * 70)
print(f"Model: Meta-TPP")
print(f"Dataset: nonstationary_hawkes")
print(f"Log-Likelihood: {log_likelihood:.3f}" if not pd.isna(log_likelihood) else "Log-Likelihood: N/A")
print(f"Accuracy: {metatpp_result['accuracy']:.1f}%" if not pd.isna(metatpp_result['accuracy']) else "Accuracy: N/A")
print(f"RMSE: {rmse:.3f}" if not pd.isna(rmse) else "RMSE: N/A")
# Out:
# ======================================================================
# Raw test_results:
# [{'test/nll': 2.7888832092285156, 'test/rmse': 20.21638298034668, 'test/acc': 0.5061477422714233}]
# ======================================================================
#
# Extracted metrics:
#   NLL: 2.7888832092285156
#   Log-Likelihood: -2.7888832092285156
#   RMSE: 20.21638298034668
#   Accuracy: 0.5061477422714233
#
# ======================================================================
# Meta-TPP Results (Task 3b)
# ======================================================================
#    model              dataset  log_likelihood  accuracy      rmse  status
# Meta-TPP nonstationary_hawkes       -2.788883 50.614774 20.216383 success
#
# ✓ Saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/metatpp_stationary_results.csv
#
# ======================================================================
# Table-1-like Format:
# ======================================================================
# Model: Meta-TPP
# Dataset: nonstationary_hawkes
# Log-Likelihood: -2.789
# Accuracy: 50.6%
# RMSE: 20.216

# %% [markdown]
# ## Reformat Results

# %%
# ==============================================================================
# TASK 5: COMBINE EASYTPP + META-TPP RESULTS AND GENERATE FINAL TABLE
# ==============================================================================
# This cell reloads all results from Google Drive, parses the existing format,
# combines with Meta-TPP, and outputs RMSE/ErrorRate% format.
# ==============================================================================

import pandas as pd
import numpy as np
import os
import re

# Paths
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/MilestoneFall2025'
RESULTS_DIR = os.path.join(BASE_DIR, 'results/Task5')

# ==============================================================================
# STEP 1: Load results files
# ==============================================================================
print("=" * 70)
print("LOADING RESULTS FROM GOOGLE DRIVE")
print("=" * 70)

easytpp_path = os.path.join(RESULTS_DIR, 'Task5_results.csv')
metatpp_path = os.path.join(RESULTS_DIR, 'metatpp_stationary_results.csv')

# Load EasyTPP results
if os.path.exists(easytpp_path):
    easytpp_df = pd.read_csv(easytpp_path)
    print(f"✓ Loaded EasyTPP results: {len(easytpp_df)} rows")
    print(f"  Columns: {list(easytpp_df.columns)}")
else:
    print(f"✗ EasyTPP results not found at: {easytpp_path}")
    easytpp_df = pd.DataFrame()

# Load Meta-TPP results
if os.path.exists(metatpp_path):
    metatpp_df = pd.read_csv(metatpp_path)
    print(f"✓ Loaded Meta-TPP results: {len(metatpp_df)} rows")
    print(f"  Columns: {list(metatpp_df.columns)}")
else:
    print(f"✗ Meta-TPP results not found at: {metatpp_path}")
    metatpp_df = pd.DataFrame()

# ==============================================================================
# STEP 2: Parse EasyTPP results (format: "LL/RMSE/Acc% ± std_LL/std_RMSE/std_Acc")
# ==============================================================================
print("\n" + "=" * 70)
print("PARSING EASYTPP RESULTS")
print("=" * 70)

def parse_easytpp_cell(cell_value):
    """
    Parse cell value like '-1.166/0.877/43.9% ± 0.000/0.000/0.000'
    Returns: (log_likelihood, rmse, accuracy)
    """
    try:
        # Split on ± to get mean values
        mean_part = cell_value.split('±')[0].strip()

        # Split on / to get individual values
        parts = mean_part.split('/')

        log_likelihood = float(parts[0])
        rmse = float(parts[1])
        # Remove % sign and convert to float
        accuracy = float(parts[2].replace('%', ''))

        return log_likelihood, rmse, accuracy
    except Exception as e:
        print(f"  Warning: Could not parse '{cell_value}': {e}")
        return None, None, None

# Get dataset columns (all columns except 'model')
dataset_cols = [col for col in easytpp_df.columns if col != 'model']
print(f"  Dataset columns found: {dataset_cols}")

# Parse EasyTPP results into structured format
easytpp_parsed = []
for _, row in easytpp_df.iterrows():
    model = row['model']
    for dataset in dataset_cols:
        cell_value = row[dataset]
        ll, rmse, acc = parse_easytpp_cell(cell_value)
        if rmse is not None:
            easytpp_parsed.append({
                'model': model,
                'dataset': dataset,
                'log_likelihood': ll,
                'rmse': rmse,
                'accuracy': acc  # This is already in percentage (0-100)
            })

easytpp_parsed_df = pd.DataFrame(easytpp_parsed)
print(f"✓ Parsed {len(easytpp_parsed_df)} EasyTPP results")

# ==============================================================================
# STEP 3: Parse Meta-TPP results
# ==============================================================================
print("\n" + "=" * 70)
print("PARSING META-TPP RESULTS")
print("=" * 70)

metatpp_parsed = []
if not metatpp_df.empty:
    for _, row in metatpp_df.iterrows():
        acc = row['accuracy']
        # Convert to percentage if needed (check if it's 0-1 scale)
        if pd.notna(acc) and acc <= 1:
            acc = acc * 100

        metatpp_parsed.append({
            'model': row['model'],
            'dataset': row['dataset'],
            'log_likelihood': row['log_likelihood'],
            'rmse': row['rmse'],
            'accuracy': acc
        })

metatpp_parsed_df = pd.DataFrame(metatpp_parsed)
print(f"✓ Parsed {len(metatpp_parsed_df)} Meta-TPP results")

# ==============================================================================
# STEP 4: Combine all results
# ==============================================================================
print("\n" + "=" * 70)
print("COMBINING RESULTS")
print("=" * 70)

# Combine dataframes
dfs_to_concat = [df for df in [easytpp_parsed_df, metatpp_parsed_df] if not df.empty]
if dfs_to_concat:
    combined_df = pd.concat(dfs_to_concat, ignore_index=True)
else:
    combined_df = pd.DataFrame()

# Calculate error rate (100 - accuracy)
combined_df['error_rate'] = 100 - combined_df['accuracy']

print(f"✓ Combined results: {len(combined_df)} total experiments")
print(f"  Models: {sorted(combined_df['model'].unique().tolist())}")
print(f"  Datasets: {sorted(combined_df['dataset'].unique().tolist())}")

# ==============================================================================
# STEP 5: Save combined results (detailed version)
# ==============================================================================
combined_path = os.path.join(RESULTS_DIR, 'Task5_combined_results.csv')
combined_df.to_csv(combined_path, index=False)
print(f"✓ Saved detailed results to: {combined_path}")

# ==============================================================================
# STEP 6: Generate report table (RMSE/ErrorRate% format)
# ==============================================================================
print("\n" + "=" * 70)
print("TABLE FOR REPORT")
print("=" * 70)

def format_report_table(df):
    """
    Format results as RMSE/ErrorRate% table for report.
    Format: RMSE/ErrorRate% (e.g., "0.877/56.1%")
    """
    if df.empty:
        print("No data to format!")
        return pd.DataFrame()

    # Get unique models and datasets
    models = sorted(df['model'].unique())
    datasets = sorted(df['dataset'].unique())

    # Build table data
    table_data = []
    for model in models:
        row = {'model': model}
        for dataset in datasets:
            mask = (df['model'] == model) & (df['dataset'] == dataset)
            if mask.any():
                entry = df[mask].iloc[0]
                rmse = entry['rmse']
                error_rate = entry['error_rate']
                row[dataset] = f"{rmse:.3f}/{error_rate:.1f}%"
            else:
                row[dataset] = "N/A"
        table_data.append(row)

    return pd.DataFrame(table_data)

# Generate and display table
report_table = format_report_table(combined_df)

# Print as markdown table
print(report_table.to_markdown(index=False))

# ==============================================================================
# STEP 7: Save the report table
# ==============================================================================
report_table_path = os.path.join(RESULTS_DIR, 'Task5_report_table.csv')
report_table.to_csv(report_table_path, index=False)
print(f"\n✓ Report table saved to: {report_table_path}")

# ==============================================================================
# STEP 8: Display detailed results summary
# ==============================================================================
print("\n" + "=" * 70)
print("DETAILED RESULTS SUMMARY")
print("=" * 70)

print(f"\n{'Model':<15} {'Dataset':<20} {'RMSE':<10} {'Acc%':<10} {'ErrRate%':<10}")
print("-" * 70)

for _, row in combined_df.sort_values(['dataset', 'model']).iterrows():
    print(f"{row['model']:<15} {row['dataset']:<20} {row['rmse']:<10.3f} {row['accuracy']:<10.1f} {row['error_rate']:<10.1f}")

print("\n" + "=" * 70)
print(f"Total models: {combined_df['model'].nunique()}")
print(f"Total datasets: {combined_df['dataset'].nunique()}")
print(f"Total experiments: {len(combined_df)}")
print("=" * 70)
# Out:
# ======================================================================
# LOADING RESULTS FROM GOOGLE DRIVE
# ======================================================================
# ✓ Loaded EasyTPP results: 7 rows
#   Columns: ['model', 'nonstationary_hawkes']
# ✓ Loaded Meta-TPP results: 1 rows
#   Columns: ['model', 'dataset', 'log_likelihood', 'accuracy', 'rmse', 'status']
#
# ======================================================================
# PARSING EASYTPP RESULTS
# ======================================================================
#   Dataset columns found: ['nonstationary_hawkes']
# ✓ Parsed 7 EasyTPP results
#
# ======================================================================
# PARSING META-TPP RESULTS
# ======================================================================
# ✓ Parsed 1 Meta-TPP results
#
# ======================================================================
# COMBINING RESULTS
# ======================================================================
# ✓ Combined results: 8 total experiments
#   Models: ['AttNHP', 'FullyNN', 'IntensityFree', 'Meta-TPP', 'NHP', 'RMTPP', 'SAHP', 'THP']
#   Datasets: ['nonstationary_hawkes']
# ✓ Saved detailed results to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/Task5_combined_results.csv
#
# ======================================================================
# TABLE FOR REPORT
# ======================================================================
# | model         | nonstationary_hawkes   |
# |:--------------|:-----------------------|
# | AttNHP        | 0.832/58.8%            |
# | FullyNN       | 1.076/50.3%            |
# | IntensityFree | 1.245/71.1%            |
# | Meta-TPP      | 20.216/49.4%           |
# | NHP           | 1.021/71.9%            |
# | RMTPP         | 1.112/72.9%            |
# | SAHP          | 1.008/70.7%            |
# | THP           | 0.995/72.7%            |
#
# ✓ Report table saved to: /content/drive/MyDrive/Colab Notebooks/MilestoneFall2025/results/Task5/Task5_report_table.csv
#
# ======================================================================
# DETAILED RESULTS SUMMARY
# ======================================================================
#
# Model           Dataset              RMSE       Acc%       ErrRate%
# ----------------------------------------------------------------------
# AttNHP          nonstationary_hawkes 0.832      41.2       58.8
# FullyNN         nonstationary_hawkes 1.076      49.7       50.3
# IntensityFree   nonstationary_hawkes 1.245      28.9       71.1
# Meta-TPP        nonstationary_hawkes 20.216     50.6       49.4
# NHP             nonstationary_hawkes 1.021      28.1       71.9
# RMTPP           nonstationary_hawkes 1.112      27.1       72.9
# SAHP            nonstationary_hawkes 1.008      29.3       70.7
# THP             nonstationary_hawkes 0.995      27.3       72.7
#
# ======================================================================
# Total models: 8
# Total datasets: 1
# Total experiments: 8
# ======================================================================
